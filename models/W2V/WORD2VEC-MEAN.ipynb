# %%
import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)

# %%
import nltk
from nltk.tokenize import word_tokenize
from stop_words import get_stop_words
from nltk.stem import WordNetLemmatizer
from gensim import corpora, models
import gensim
import glob2
from itertools import chain
import os
import numpy as np
import itertools
import cPickle as pickle
from  scipy.stats import rankdata
import copy
from openpyxl import Workbook
from openpyxl.compat import range
from openpyxl.utils import get_column_letter
from openpyxl import load_workbook
import pandas as pd
from scipy.stats import hmean
from nltk.stem import PorterStemmer
from nltk.tokenize import sent_tokenize, word_tokenize
# Out:
# 2018-04-08 22:23:49,476 : INFO : 'pattern' package not found; tag filters are not available for English

# %%
# ignores everything except english alphabet and  
def only_alphabet(text):
    return ''.join(i for i in text if (ord(i)<123 and ord(i)>96) or (ord(i)<91 and ord(i)>64) or ord(i)==32)

# %%
full_filenames = []
x= ['LegalAdhocTask/ConsumerCourtAdhocdata/DCDRC/**/*.txt','LegalAdhocTask/ConsumerCourtAdhocdata/NCDRC/**/*.txt','LegalAdhocTask/ConsumerCourtAdhocdata/SCDRC/**/*.txt', 'LegalAdhocTask/SC-HCAdhocData/DelhiHC/**/*.txt','LegalAdhocTask/SC-HCAdhocData/JharkhandHC/**/*.txt', 'LegalAdhocTask/SC-HCAdhocData/JodhpurHC/**/*.txt' ,'LegalAdhocTask/SC-HCAdhocData/KolkataHC/**/*.txt', 'LegalAdhocTask/SC-HCAdhocData/SupremeCourt/**/*.txt']
for glob_filenames in x:
    glob_filenames = os.path.normpath(glob_filenames)
    for filename in sorted(glob2.glob(glob_filenames)):
        full_filenames.append(filename)
            
filenames = []
x= ['LegalAdhocTask/ConsumerCourtAdhocdata/DCDRC/**/*.txt','LegalAdhocTask/ConsumerCourtAdhocdata/NCDRC/**/*.txt','LegalAdhocTask/ConsumerCourtAdhocdata/SCDRC/**/*.txt', 'LegalAdhocTask/SC-HCAdhocData/DelhiHC/**/*.txt','LegalAdhocTask/SC-HCAdhocData/JharkhandHC/**/*.txt', 'LegalAdhocTask/SC-HCAdhocData/JodhpurHC/**/*.txt' ,'LegalAdhocTask/SC-HCAdhocData/KolkataHC/**/*.txt', 'LegalAdhocTask/SC-HCAdhocData/SupremeCourt/**/*.txt']
for glob_filenames in x:
    glob_filenames = os.path.normpath(glob_filenames)
    for filename in sorted(glob2.glob(glob_filenames)):
        filenames.append(os.path.basename(filename))

en_stop = set(get_stop_words('en'))
ps = PorterStemmer()

# "yield" for each file return token list  i.e list of lists
def files_to_tokens(glob_filenames):
    glob_filenames = os.path.normpath(glob_filenames)
    for filename in sorted(glob2.glob(glob_filenames)):
        f = open(filename)
        # read the whole file as lowercase string
        string = only_alphabet(f.read()).lower()
        tokens = []
        # tokenize that string
        for word in word_tokenize(string):
            if word not in en_stop:
                tokens.append(ps.stem(word))

        yield tokens
        f.close()


        
# yields token list for files specific to courts; needed for creating dictionaries
class texts:
    def DCDRC(self):
        for text in files_to_tokens('LegalAdhocTask/ConsumerCourtAdhocdata/DCDRC/*.txt'):
            yield text
    def NCDRC(self):
        for text in files_to_tokens('LegalAdhocTask/ConsumerCourtAdhocdata/NCDRC/**/*.txt'):
            yield text
    def SCDRC(self):
        for text in files_to_tokens('LegalAdhocTask/ConsumerCourtAdhocdata/SCDRC/**/*.txt'):
            yield text
    def DelhiHC(self):
        for text in files_to_tokens('LegalAdhocTask/SC-HCAdhocData/DelhiHC/**/*.txt'):
            yield text
    def JharkhandHC(self):
        for text in files_to_tokens('LegalAdhocTask/SC-HCAdhocData/JharkhandHC/**/*.txt'):
            yield text
    def JodhpurHC(self):
        for text in  files_to_tokens('LegalAdhocTask/SC-HCAdhocData/JodhpurHC/**/*.txt'):
            yield text
    def KolkataHC(self):
        for text in  files_to_tokens('LegalAdhocTask/SC-HCAdhocData/KolkataHC/**/*.txt'):
            yield text
    def SupremeCourt(self):
        for text in  files_to_tokens('LegalAdhocTask/SC-HCAdhocData/SupremeCourt/**/*.txt'):
            yield text
    def everything(self):
        return chain(self.DCDRC(), self.NCDRC(), self.SCDRC(), self.DelhiHC(),
                     self.JharkhandHC(), self.JodhpurHC(), self.KolkataHC(), self.SupremeCourt())
        
# yields bow for each file - tuples id,fq ; needed to train models   
class my_corpus:    
    def DCDRC(self):
        for text in files_to_tokens('LegalAdhocTask/ConsumerCourtAdhocdata/DCDRC/*.txt'):
            yield dictionary.doc2bow(text)
    def NCDRC(self):
        for text in files_to_tokens('LegalAdhocTask/ConsumerCourtAdhocdata/NCDRC/**/*.txt'):
            yield dictionary.doc2bow(text)            
    def SCDRC(self):
        for text in files_to_tokens('LegalAdhocTask/ConsumerCourtAdhocdata/SCDRC/**/*.txt'):
            yield dictionary.doc2bow(text)
    def DelhiHC(self):
        for text in files_to_tokens('LegalAdhocTask/SC-HCAdhocData/DelhiHC/**/*.txt'):
            yield dictionary.doc2bow(text)
    def JharkhandHC(self):
        for text in files_to_tokens('LegalAdhocTask/SC-HCAdhocData/JharkhandHC/**/*.txt'):
            yield dictionary.doc2bow(text)
    def JodhpurHC(self):
        for text in  files_to_tokens('LegalAdhocTask/SC-HCAdhocData/JodhpurHC/**/*.txt'):
            yield dictionary.doc2bow(text)
    def KolkataHC(self):
        for text in  files_to_tokens('LegalAdhocTask/SC-HCAdhocData/KolkataHC/**/*.txt'):
            yield dictionary.doc2bow(text)
    def SupremeCourt(self):
        for text in  files_to_tokens('LegalAdhocTask/SC-HCAdhocData/SupremeCourt/**/*.txt'):
            yield dictionary.doc2bow(text)
    def everything(self):
        return chain(self.DCDRC(), self.NCDRC(), self.SCDRC(), self.DelhiHC(),
                     self.JharkhandHC(), self.JodhpurHC(), self.KolkataHC(), self.SupremeCourt())

# %%
#################################### laod the dictinary
dictionary = corpora.Dictionary.load('stem100_dictionary')
# Out:
# 2018-04-08 22:40:40,865 : INFO : loading Dictionary object from stem100_dictionary
# 2018-04-08 22:40:40,889 : INFO : loaded stem100_dictionary

# %%
######################################## load BOW
corpus = corpora.MmCorpus('stem100.mm')
# Out:
# 2018-04-08 22:40:41,758 : INFO : loaded corpus index from stem100.mm.index
# 2018-04-08 22:40:41,759 : INFO : initializing corpus reader from stem100.mm
# 2018-04-08 22:40:41,760 : INFO : accepted corpus with 351985 documents, 40069 features, 92572684 non-zero entries

# %%
# %%time

# c = texts()
# count = 0
# for x in c.everything():
#     x = [ i for i in x if i in dictionary.token2id]
#     with open(os.path.normpath('Token_corpus/' + str(count)), 'wb') as fp:
#         pickle.dump(x, fp)
#     count=count+1

# %%
def token_corpus(i):
    with open (os.path.normpath('Token_corpus/' + str(i)), 'rb') as fp:
            itemlist = pickle.load(fp)
            return itemlist

# %%
class iter_token_corpus:
    def __iter__(self):
        for i in xrange(0, 351985):
            with open (os.path.normpath('Token_corpus/' + str(i)), 'rb') as fp:
                itemlist = pickle.load(fp)
                yield itemlist

# %%
# %%time
# model = gensim.models.Word2Vec(iter_token_corpus(), size=300, iter = 10, min_count=0, sample=0, workers=8)

# %%
# model.save('word2vec')

# %%
model = gensim.models.Word2Vec.load('word2vec')
# Out:
# 2018-04-08 22:40:46,282 : INFO : loading Word2Vec object from word2vec
# 2018-04-08 22:40:46,492 : INFO : loading wv recursively from word2vec.wv.* with mmap=None
# 2018-04-08 22:40:46,493 : INFO : loading syn0 from word2vec.wv.syn0.npy with mmap=None
# 2018-04-08 22:40:46,520 : INFO : setting ignored attribute syn0norm to None
# 2018-04-08 22:40:46,521 : INFO : loading syn1neg from word2vec.syn1neg.npy with mmap=None
# 2018-04-08 22:40:46,562 : INFO : setting ignored attribute cum_table to None
# 2018-04-08 22:40:46,562 : INFO : loaded word2vec

# %%
# x.doesnt_match(words)

# #     Which word from the given list doesn’t go with the others?
# #     Parameters:	words – List of words
# #     Returns:	The word further away from the mean of all words.
# #     Return type:	str

# x.index2word
# ### list of words in the sorted order of their frequency 

# y = x.vocab['parti']
# y.count
# # find freq. of any word


# x.most_similar_cosmul(positive=None, negative=None, topn=10)
# # Find the top-N most similar words, using the multiplicative combination objective proposed by 
# # Omer Levy and Yoav Goldberg.Positive words still contribute positively towards the similarity, negative words 
# # negatively, but with less susceptibility to one large distance dominating the calculation.

# x.most_similar_to_given(entity1, entities_list)
# #    Return the entity from entities_list most similar to entity1.

# x.n_similarity(ws1, ws2)
# #Compute cosine similarity between two sets of words


# x.similar_by_vector(x['fit'], topn=10, restrict_vocab=None)
# # closest vectors
# # if topn is False, similar_by_vector returns the vector of similarity scores.

# x.similar_by_word(word, topn=10, restrict_vocab=None)
# #  Find the top-N most similar words.

# x.similarity(w1, w2)
# #Compute cosine similarity between two words.

# x.wmdistance(doc1, doc2)
# # word movers distance

# y = x.vocab['parti']
# y.count
# #freq in corpus

# %%
#preprocess a word
def T(word):
    if word not in en_stop:
        return ps.stem(word)

# %%
len(dictionary)
# Out:
# 40069

# %%
dictionary.id2token
# Out:
# {0: u'aloksinghjmanishtextdoc',
#  1: u'anyev',
#  2: u'evenbefor',
#  3: u'insuranceschem',
#  4: u'commissionchandigarh',
#  5: u'vanj',
#  6: u'ofpow',
#  7: u'jairam',
#  8: u'centralgovern',
#  9: u'scold',
#  10: u'accret',
#  11: u'harassmentto',
#  12: u'nosuresh',
#  13: u'acquisitionproceed',
#  14: u'jagannath',
#  15: u'datedrd',
#  16: u'respondentbi',
#  17: u'repliedthat',
#  18: u'milit',
#  19: u'awardedto',
#  20: u'awardedth',
#  21: u'thatext',
#  22: u'policyfor',
#  23: u'considereda',
#  24: u'pigment',
#  25: u'andinstead',
#  26: u'ispass',
#  27: u'kottayam',
#  28: u'kaushal',
#  29: u'wooden',
#  30: u'showcas',
#  31: u'wednesday',
#  32: u'thesedocu',
#  33: u'videth',
#  34: u'multipurpos',
#  35: u'asami',
#  36: u'servedth',
#  37: u'billamount',
#  38: u'dialogu',
#  39: u'thatord',
#  40: u'atjodhpursb',
#  41: u'jalil',
#  42: u'complainantwrot',
#  43: u'theaudit',
#  44: u'aksharmapresid',
#  45: u'thetribun',
#  46: u'succumb',
#  47: u'sation',
#  48: u'andpubl',
#  49: u'mrsandeep',
#  50: u'trivikram',
#  51: u'ophthalm',
#  52: u'bhubaneshwar',
#  53: u'complianceof',
#  54: u'maharashtrast',
#  55: u'china',
#  56: u'enteredinto',
#  57: u'deterior',
#  58: u'mullick',
#  59: u'gayathri',
#  60: u'respectivecontent',
#  61: u'pastur',
#  62: u'hasbrought',
#  63: u'neurologist',
#  64: u'controversi',
#  65: u'golden',
#  66: u'jurisprudenti',
#  67: u'basudeo',
#  68: u'parbhani',
#  69: u'topographi',
#  70: u'sterl',
#  71: u'stern',
#  72: u'sneha',
#  73: u'andinform',
#  74: u'dtand',
#  75: u'dna',
#  76: u'dnb',
#  77: u'dno',
#  78: u'thereofth',
#  79: u'dnj',
#  80: u'music',
#  81: u'nobhanwar',
#  82: u'renuka',
#  83: u'mrsbmhase',
#  84: u'collectoratecampu',
#  85: u'memberii',
#  86: u'nebul',
#  87: u'hu',
#  88: u'asuit',
#  89: u'thismann',
#  90: u'manojkumar',
#  91: u'extensionof',
#  92: u'exce',
#  93: u'excb',
#  94: u'excc',
#  95: u'haveoccur',
#  96: u'engg',
#  97: u'unpack',
#  98: u'therent',
#  99: u'furtherinform',
#  100: u'shvishal',
#  101: u'generalis',
#  102: u'locker',
#  103: u'ofth',
#  104: u'couldb',
#  105: u'pintu',
#  106: u'hissignatur',
#  107: u'incidentand',
#  108: u'unjust',
#  109: u'wani',
#  110: u'forrun',
#  111: u'want',
#  112: u'rayon',
#  113: u'pinto',
#  114: u'souhard',
#  115: u'beforedistrict',
#  116: u'italso',
#  117: u'moreoverin',
#  118: u'moreoverit',
#  119: u'anywritten',
#  120: u'theproject',
#  121: u'infractu',
#  122: u'toreport',
#  123: u'servicein',
#  124: u'districtjudg',
#  125: u'kalidasmukherje',
#  126: u'notsatisfactori',
#  127: u'andcompens',
#  128: u'jethmalani',
#  129: u'exchequ',
#  130: u'thewritten',
#  131: u'modest',
#  132: u'sohal',
#  133: u'sohan',
#  134: u'patankar',
#  135: u'irappa',
#  136: u'bsnl',
#  137: u'shneeraj',
#  138: u'shreya',
#  139: u'singapor',
#  140: u'chittoor',
#  141: u'shreyu',
#  142: u'ritesh',
#  143: u'havesuff',
#  144: u'finalis',
#  145: u'disinclin',
#  146: u'selfgovern',
#  147: u'mrdiwan',
#  148: u'lohra',
#  149: u'noamount',
#  150: u'respondentscoramhonblemrjusticerkmerathia',
#  151: u'uponconsider',
#  152: u'arethat',
#  153: u'thelicens',
#  154: u'notcaus',
#  155: u'kuer',
#  156: u'thirumramachandran',
#  157: u'fir',
#  158: u'fit',
#  159: u'atmunnolipresidentund',
#  160: u'fix',
#  161: u'inan',
#  162: u'inal',
#  163: u'inam',
#  164: u'checkedth',
#  165: u'fie',
#  166: u'uoi',
#  167: u'isheld',
#  168: u'fin',
#  169: u'theadvertis',
#  170: u'voyksdufdka',
#  171: u'effecth',
#  172: u'shivam',
#  173: u'effectu',
#  174: u'andcommit',
#  175: u'sixteen',
#  176: u'preemin',
#  177: u'districtand',
#  178: u'sarakki',
#  179: u'arrog',
#  180: u'thetrad',
#  181: u'hemorrhag',
#  182: u'cccase',
#  183: u'accommod',
#  184: u'wererecord',
#  185: u'adefault',
#  186: u'arrow',
#  187: u'betweenbeml',
#  188: u'saidapet',
#  189: u'burial',
#  190: u'appearsto',
#  191: u'allah',
#  192: u'allam',
#  193: u'ofsuffici',
#  194: u'abhimanyu',
#  195: u'wassanct',
#  196: u'prescribedperiod',
#  197: u'allay',
#  198: u'malkiat',
#  199: u'chequeand',
#  200: u'mason',
#  201: u'adapt',
#  202: u'strata',
#  203: u'shubham',
#  204: u'sannahanumanthappa',
#  205: u'leela',
#  206: u'theopcompani',
#  207: u'fpfdrlk',
#  208: u'pngtextdoc',
#  209: u'kfu',
#  210: u'kfr',
#  211: u'vertebr',
#  212: u'vehiclecould',
#  213: u'wasultim',
#  214: u'areadmit',
#  215: u'kfk',
#  216: u'alwar',
#  217: u'oppositepartycoramhonblemrjusticenarendranathtiwariforthepetition',
#  218: u'returnedth',
#  219: u'furtheradmit',
#  220: u'silenc',
#  221: u'bankfor',
#  222: u'katara',
#  223: u'totri',
#  224: u'master',
#  225: u'kramaswami',
#  226: u'wassubmit',
#  227: u'sisir',
#  228: u'madeclear',
#  229: u'districtcentr',
#  230: u'videexp',
#  231: u'cardiacarrest',
#  232: u'task',
#  233: u'shallcontinuejayaroyjanittextdoc',
#  234: u'issuingth',
#  235: u'complaintcom',
#  236: u'havericomplaint',
#  237: u'individualcapac',
#  238: u'pvenkateshwar',
#  239: u'unlaw',
#  240: u'interimappl',
#  241: u'docdocnoconsumercourtscdrcdocnotextappealno',
#  242: u'friend',
#  243: u'affirmativepoint',
#  244: u'abovenam',
#  245: u'uncontrovert',
#  246: u'beforeconsum',
#  247: u'spectrum',
#  248: u'mishra',
#  249: u'quasiperman',
#  250: u'staypetit',
#  251: u'mishri',
#  252: u'dozen',
#  253: u'toother',
#  254: u'hymen',
#  255: u'noncommun',
#  256: u'wascommun',
#  257: u'annexureii',
#  258: u'nischal',
#  259: u'variousground',
#  260: u'wasassess',
#  261: u'ekuuk',
#  262: u'partyregard',
#  263: u'beenconvict',
#  264: u'pecuniaryjurisdict',
#  265: u'simplifi',
#  266: u'andpromis',
#  267: u'toil',
#  268: u'argumentsth',
#  269: u'mouth',
#  270: u'issaid',
#  271: u'smtbkaruna',
#  272: u'affirmativea',
#  273: u'singer',
#  274: u'maji',
#  275: u'affirmativeh',
#  276: u'maje',
#  277: u'inaddit',
#  278: u'anydocu',
#  279: u'goonda',
#  280: u'tech',
#  281: u'hiatu',
#  282: u'khattar',
#  283: u'scream',
#  284: u'documentsproduc',
#  285: u'ldc',
#  286: u'mostli',
#  287: u'dickey',
#  288: u'defectiveth',
#  289: u'exibita',
#  290: u'exibitb',
#  291: u'exibitc',
#  292: u'prefatori',
#  293: u'ulcer',
#  294: u'saidhous',
#  295: u'restaur',
#  296: u'bliss',
#  297: u'maganl',
#  298: u'jsushiltextdoc',
#  299: u'versusm',
#  300: u'xlvii',
#  301: u'rice',
#  302: u'notnecessari',
#  303: u'ruledout',
#  304: u'plate',
#  305: u'ldh',
#  306: u'afals',
#  307: u'pwafdftyk',
#  308: u'thewpc',
#  309: u'iata',
#  310: u'ceil',
#  311: u'memberbetweenccomplain',
#  312: u'ceiv',
#  313: u'mandya',
#  314: u'becameth',
#  315: u'boarder',
#  316: u'appealrevis',
#  317: u'forumvazhuthacaud',
#  318: u'patch',
#  319: u'eqdsk',
#  320: u'kabra',
#  321: u'smtminakshirkulkarni',
#  322: u'weaccept',
#  323: u'commissionthat',
#  324: u'determinationin',
#  325: u'forabout',
#  326: u'convey',
#  327: u'athat',
#  328: u'news',
#  329: u'lalita',
#  330: u'billand',
#  331: u'ramanatha',
#  332: u'majithia',
#  333: u'irr',
#  334: u'jhajjar',
#  335: u'lotu',
#  336: u'xvi',
#  337: u'iri',
#  338: u'irk',
#  339: u'advisedli',
#  340: u'dalhousi',
#  341: u'imprimatur',
#  342: u'irc',
#  343: u'ire',
#  344: u'complaintfail',
#  345: u'extend',
#  346: u'anddelay',
#  347: u'rgr',
#  348: u'extens',
#  349: u'hansaria',
#  350: u'criminalcas',
#  351: u'extent',
#  352: u'extenu',
#  353: u'behand',
#  354: u'andfind',
#  355: u'veer',
#  356: u'ganpat',
#  357: u'thedivis',
#  358: u'aredeni',
#  359: u'tyranni',
#  360: u'andassur',
#  361: u'himalayan',
#  362: u'stateof',
#  363: u'assur',
#  364: u'haryanast',
#  365: u'himund',
#  366: u'esic',
#  367: u'kashalkar',
#  368: u'chetna',
#  369: u'wasreport',
#  370: u'stategovt',
#  371: u'asgar',
#  372: u'assum',
#  373: u'againon',
#  374: u'raheja',
#  375: u'patilro',
#  376: u'union',
#  377: u'chini',
#  378: u'aranganathan',
#  379: u'frh',
#  380: u'fro',
#  381: u'monthaft',
#  382: u'followswheth',
#  383: u'uniot',
#  384: u'roadshimoga',
#  385: u'frt',
#  386: u'levelledagainst',
#  387: u'regul',
#  388: u'retrospect',
#  389: u'ofrsp',
#  390: u'freehold',
#  391: u'dave',
#  392: u'amountdu',
#  393: u'adocu',
#  394: u'spin',
#  395: u'davi',
#  396: u'afterconduct',
#  397: u'responsefrom',
#  398: u'intak',
#  399: u'employ',
#  400: u'oktextdoc',
#  401: u'overto',
#  402: u'overth',
#  403: u'kalyankartextdoc',
#  404: u'permittedto',
#  405: u'jrshekharcptextdoc',
#  406: u'majid',
#  407: u'parekh',
#  408: u'laproscop',
#  409: u'thecomplainantappel',
#  410: u'expar',
#  411: u'disprov',
#  412: u'anycog',
#  413: u'publicauthor',
#  414: u'eighteen',
#  415: u'ifjoknhdh',
#  416: u'withoutth',
#  417: u'electricsuppli',
#  418: u'ifjoknhdk',
#  419: u'shailendra',
#  420: u'fudkyk',
#  421: u'hong',
#  422: u'dilut',
#  423: u'nerul',
#  424: u'remand',
#  425: u'oflic',
#  426: u'tointerest',
#  427: u'ramrao',
#  428: u'split',
#  429: u'shjit',
#  430: u'statefrom',
#  431: u'refix',
#  432: u'issac',
#  433: u'oneof',
#  434: u'nnmathurhonbl',
#  435: u'tounfair',
#  436: u'bidawat',
#  437: u'tocomplet',
#  438: u'boiler',
#  439: u'refin',
#  440: u'dadhich',
#  441: u'jagadhri',
#  442: u'submittedwritten',
#  443: u'kamini',
#  444: u'ofschem',
#  445: u'petitionersversusthestateofjharkhandor',
#  446: u'bankapura',
#  447: u'jagarnath',
#  448: u'peremptori',
#  449: u'anupama',
#  450: u'propertyand',
#  451: u'depositedwith',
#  452: u'bycomplain',
#  453: u'stno',
#  454: u'maketh',
#  455: u'thatwa',
#  456: u'hai',
#  457: u'nondeliveri',
#  458: u'hal',
#  459: u'han',
#  460: u'injuryor',
#  461: u'intoforc',
#  462: u'hay',
#  463: u'endur',
#  464: u'haq',
#  465: u'har',
#  466: u'hat',
#  467: u'ftci',
#  468: u'fykdj',
#  469: u'knock',
#  470: u'shambhu',
#  471: u'preethakumarikp',
#  472: u'dagar',
#  473: u'ofreput',
#  474: u'fykdr',
#  475: u'shadow',
#  476: u'amsapr',
#  477: u'claimantappel',
#  478: u'bysh',
#  479: u'underrti',
#  480: u'partiesjointli',
#  481: u'gurnam',
#  482: u'basudev',
#  483: u'docdocnoconsumercourtscdrcdocnotextnd',
#  484: u'sreenivasan',
#  485: u'crowd',
#  486: u'fiduciari',
#  487: u'forceth',
#  488: u'thelaboratori',
#  489: u'crown',
#  490: u'agreementfor',
#  491: u'hasrend',
#  492: u'snakebit',
#  493: u'thedefens',
#  494: u'moideen',
#  495: u'bottom',
#  496: u'maheshwar',
#  497: u'inhuman',
#  498: u'wayth',
#  499: u'privatelimit',
#  500: u'thedefend',
#  501: u'muthuramalingammabl',
#  502: u'sdxxx',
#  503: u'wasinspect',
#  504: u'chequesand',
#  505: u'sdpresid',
#  506: u'binder',
#  507: u'costsdr',
#  508: u'krishnaji',
#  509: u'downstair',
#  510: u'beinga',
#  511: u'apollohospit',
#  512: u'rswhich',
#  513: u'mangol',
#  514: u'mba',
#  515: u'mbb',
#  516: u'creativ',
#  517: u'smtkgbeena',
#  518: u'krudayabhanu',
#  519: u'theseopposit',
#  520: u'claimedcompens',
#  521: u'plat',
#  522: u'theweight',
#  523: u'fabric',
#  524: u'suffici',
#  525: u'thatof',
#  526: u'ofdistrict',
#  527: u'vandana',
#  528: u'aggrievedagainst',
#  529: u'faircopi',
#  530: u'selfserv',
#  531: u'jarnail',
#  532: u'onehand',
#  533: u'headach',
#  534: u'responseth',
#  535: u'responseto',
#  536: u'defendantsrespond',
#  537: u'nethaji',
#  538: u'safeguard',
#  539: u'kalina',
#  540: u'fromthem',
#  541: u'fromthes',
#  542: u'inchief',
#  543: u'bhau',
#  544: u'excw',
#  545: u'micukksa',
#  546: u'appellantten',
#  547: u'mirror',
#  548: u'whatord',
#  549: u'rajnik',
#  550: u'minar',
#  551: u'orderfrom',
#  552: u'bedsheet',
#  553: u'raiganj',
#  554: u'thisbackground',
#  555: u'acceptth',
#  556: u'xka',
#  557: u'xkg',
#  558: u'purohit',
#  559: u'profus',
#  560: u'rspm',
#  561: u'roll',
#  562: u'intend',
#  563: u'devot',
#  564: u'ointment',
#  565: u'notcal',
#  566: u'notcar',
#  567: u'intens',
#  568: u'intent',
#  569: u'cenvat',
#  570: u'annappa',
#  571: u'mrsd',
#  572: u'hawker',
#  573: u'theterm',
#  574: u'brindavan',
#  575: u'havedeposit',
#  576: u'raut',
#  577: u'corpu',
#  578: u'chain',
#  579: u'whoever',
#  580: u'exca',
#  581: u'shivakumarjba',
#  582: u'osl',
#  583: u'osa',
#  584: u'chair',
#  585: u'corpn',
#  586: u'osd',
#  587: u'defectth',
#  588: u'herebi',
#  589: u'andnecessari',
#  590: u'eanoin',
#  591: u'rlakshminarasimha',
#  592: u'outwheth',
#  593: u'mrss',
#  594: u'saidreason',
#  595: u'exci',
#  596: u'toproduc',
#  597: u'thebottl',
#  598: u'jerk',
#  599: u'mrjagdish',
#  600: u'perview',
#  601: u'embark',
#  602: u'docdocnojodhpurhcdocnotextsbcrmisc',
#  603: u'shaji',
#  604: u'henev',
#  605: u'exact',
#  606: u'choudhri',
#  607: u'lawtherefor',
#  608: u'proceedingsg',
#  609: u'undeni',
#  610: u'opstat',
#  611: u'srchaudhari',
#  612: u'sniranjan',
#  613: u'underreceipt',
#  614: u'butstil',
#  615: u'meadow',
#  616: u'answeringopposit',
#  617: u'bidar',
#  618: u'harichandra',
#  619: u'abdullah',
#  620: u'smtpushpa',
#  621: u'aratnavelu',
#  622: u'casewa',
#  623: u'diseaseand',
#  624: u'boost',
#  625: u'subbarao',
#  626: u'uptoth',
#  627: u'electricityand',
#  628: u'honour',
#  629: u'modif',
#  630: u'address',
#  631: u'sukhdeo',
#  632: u'docdocnokolkatahcoriginalsitekolkatahcoriginalsitedocnotext',
#  633: u'apeejay',
#  634: u'haveproduc',
#  635: u'lnsharma',
#  636: u'queue',
#  637: u'koppa',
#  638: u'nointent',
#  639: u'claimbut',
#  640: u'satisfyth',
#  641: u'foqr',
#  642: u'werecal',
#  643: u'ofconsign',
#  644: u'proportion',
#  645: u'areun',
#  646: u'blazeflash',
#  647: u'instal',
#  648: u'makeit',
#  649: u'besubmit',
#  650: u'opinsurancecompani',
#  651: u'waterand',
#  652: u'vigour',
#  653: u'samewa',
#  654: u'enhanc',
#  655: u'shyamala',
#  656: u'holdth',
#  657: u'thedepart',
#  658: u'chargeabl',
#  659: u'bharath',
#  660: u'wvg',
#  661: u'policyund',
#  662: u'answerthi',
#  663: u'coramhonbl',
#  664: u'docdocnojharkhandhcdocnotextinthehighcourtofjharkhandatranchibanoof',
#  665: u'ofpres',
#  666: u'vsmkrishnan',
#  667: u'valorem',
#  668: u'royapettah',
#  669: u'accidentaldeath',
#  670: u'chiefexamin',
#  671: u'saurishchakraborti',
#  672: u'diminut',
#  673: u'evena',
#  674: u'adeclar',
#  675: u'directionfor',
#  676: u'conditionpreced',
#  677: u'reasonof',
#  678: u'setout',
#  679: u'absentand',
#  680: u'benefitund',
#  681: u'septic',
#  682: u'allopath',
#  683: u'originalappl',
#  684: u'partiesaccordingli',
#  685: u'haddirect',
#  686: u'furthercomplain',
#  687: u'kaurmemb',
#  688: u'companywhich',
#  689: u'atal',
#  690: u'atam',
#  691: u'aict',
#  692: u'duecertif',
#  693: u'andremind',
#  694: u'nmehta',
#  695: u'willnot',
#  696: u'itwil',
#  697: u'harmon',
#  698: u'manhandl',
#  699: u'interestedin',
#  700: u'pollachi',
#  701: u'sandeep',
#  702: u'mangu',
#  703: u'puller',
#  704: u'ideolog',
#  705: u'maxwel',
#  706: u'kahlon',
#  707: u'anendors',
#  708: u'mango',
#  709: u'fatehabad',
#  710: u'swollen',
#  711: u'withliberti',
#  712: u'rson',
#  713: u'anddat',
#  714: u'pujadewan',
#  715: u'nsk',
#  716: u'crpc',
#  717: u'tula',
#  718: u'isprov',
#  719: u'aprovision',
#  720: u'isprop',
#  721: u'illam',
#  722: u'jia',
#  723: u'jin',
#  724: u'representativesof',
#  725: u'ambala',
#  726: u'shibpur',
#  727: u'jit',
#  728: u'informedhim',
#  729: u'jalpaiguri',
#  730: u'nonjoind',
#  731: u'thousandthirteen',
#  732: u'belowa',
#  733: u'civilian',
#  734: u'notknown',
#  735: u'belowi',
#  736: u'claimamount',
#  737: u'blfysbl',
#  738: u'thesettl',
#  739: u'beloww',
#  740: u'aprop',
#  741: u'bearingnumb',
#  742: u'toverifi',
#  743: u'fdifjoknh',
#  744: u'accountth',
#  745: u'gradeiii',
#  746: u'fisherman',
#  747: u'jmay',
#  748: u'untrac',
#  749: u'mniqj',
#  750: u'quarter',
#  751: u'towardscost',
#  752: u'sriam',
#  753: u'personparti',
#  754: u'themotor',
#  755: u'receipt',
#  756: u'isenclos',
#  757: u'wasstolen',
#  758: u'falselyimpl',
#  759: u'atransact',
#  760: u'constructionagr',
#  761: u'nsr',
#  762: u'rskj',
#  763: u'rajni',
#  764: u'expedi',
#  765: u'directingthem',
#  766: u'urmil',
#  767: u'afterverif',
#  768: u'trauma',
#  769: u'internet',
#  770: u'andcommiss',
#  771: u'tkfr',
#  772: u'palani',
#  773: u'samajd',
#  774: u'digambar',
#  775: u'travancorecochin',
#  776: u'anoop',
#  777: u'thedismiss',
#  778: u'bronchiti',
#  779: u'thesuprem',
#  780: u'byth',
#  781: u'thestenotypist',
#  782: u'himanshu',
#  783: u'marla',
#  784: u'workmanship',
#  785: u'opsbi',
#  786: u'wrong',
#  787: u'yieldth',
#  788: u'moradabad',
#  789: u'controversyinvolv',
#  790: u'parbat',
#  791: u'neglect',
#  792: u'reassess',
#  793: u'gunshot',
#  794: u'oni',
#  795: u'ono',
#  796: u'spoken',
#  797: u'ona',
#  798: u'thealleg',
#  799: u'one',
#  800: u'onr',
#  801: u'chabra',
#  802: u'onu',
#  803: u'brochur',
#  804: u'anticorrupt',
#  805: u'topress',
#  806: u'heapproach',
#  807: u'inopposit',
#  808: u'heobtain',
#  809: u'forthcom',
#  810: u'unfil',
#  811: u'jaipurbench',
#  812: u'shawl',
#  813: u'properlyth',
#  814: u'mamlatdar',
#  815: u'snatch',
#  816: u'disqualif',
#  817: u'sbcrimin',
#  818: u'practiceth',
#  819: u'izfr',
#  820: u'irrecover',
#  821: u'justicesurjit',
#  822: u'waspreexist',
#  823: u'ftlesa',
#  824: u'aforesaidamount',
#  825: u'sdjm',
#  826: u'inaccept',
#  827: u'personsth',
#  828: u'eknath',
#  829: u'danger',
#  830: u'thelic',
#  831: u'thelif',
#  832: u'foospuk',
#  833: u'thelik',
#  834: u'turner',
#  835: u'borough',
#  836: u'thelin',
#  837: u'eow',
#  838: u'reorgan',
#  839: u'amort',
#  840: u'vanaspati',
#  841: u'ramanan',
#  842: u'bhagwana',
#  843: u'sankar',
#  844: u'indiranagar',
#  845: u'inrejoind',
#  846: u'bhagwant',
#  847: u'denomin',
#  848: u'concern',
#  849: u'rourkela',
#  850: u'notrespons',
#  851: u'offload',
#  852: u'prabhadevi',
#  853: u'knowingli',
#  854: u'theseground',
#  855: u'indiainsur',
#  856: u'jnktextdoc',
#  857: u'renusagar',
#  858: u'vishwa',
#  859: u'allevi',
#  860: u'byput',
#  861: u'receiptsand',
#  862: u'kalawati',
#  863: u'andabov',
#  864: u'stigmat',
#  865: u'forumdirect',
#  866: u'smriti',
#  867: u'jgrk',
#  868: u'heardand',
#  869: u'anshu',
#  870: u'friction',
#  871: u'durgapur',
#  872: u'noscop',
#  873: u'transact',
#  874: u'noclaim',
#  875: u'estat',
#  876: u'rspaid',
#  877: u'formwa',
#  878: u'ghanshyam',
#  879: u'nolocu',
#  880: u'noticeof',
#  881: u'litigi',
#  882: u'bewithdrawn',
#  883: u'noticeon',
#  884: u'anyexpert',
#  885: u'haspaid',
#  886: u'letharg',
#  887: u'policydecis',
#  888: u'toavail',
#  889: u'casein',
#  890: u'choudhuri',
#  891: u'tiku',
#  892: u'theyear',
#  893: u'properand',
#  894: u'asno',
#  895: u'keenli',
#  896: u'tika',
#  897: u'additionalamount',
#  898: u'deathth',
#  899: u'vision',
#  900: u'recoverth',
#  901: u'tyagi',
#  902: u'requiredbut',
#  903: u'sulbha',
#  904: u'euclid',
#  905: u'howsoev',
#  906: u'televis',
#  907: u'ofpolic',
#  908: u'twothre',
#  909: u'sponsorship',
#  910: u'recordthi',
#  911: u'emphat',
#  912: u'academicyear',
#  913: u'drawnon',
#  914: u'vender',
#  915: u'dischargedth',
#  916: u'shjaswindersingh',
#  917: u'thanikachalampresid',
#  918: u'spoint',
#  919: u'assumpt',
#  920: u'awardd',
#  921: u'housingsocieti',
#  922: u'quasijudici',
#  923: u'asstexeengin',
#  924: u'awardr',
#  925: u'belongingto',
#  926: u'shranjit',
#  927: u'presidentdcdrf',
#  928: u'welfareassoci',
#  929: u'confisc',
#  930: u's',
#  931: u'gvihi',
#  932: u'proposalfor',
#  933: u'rajaji',
#  934: u'andgon',
#  935: u'hazaribagh',
#  936: u'ofintim',
#  937: u'ofchang',
#  938: u'ghulam',
#  939: u'andgot',
#  940: u'threefour',
#  941: u'bankbranch',
#  942: u'chitra',
#  943: u'west',
#  944: u'dismisseda',
#  945: u'wese',
#  946: u'izfdzk',
#  947: u'mpd',
#  948: u'mandidistrict',
#  949: u'dulyinform',
#  950: u'tomed',
#  951: u'resolut',
#  952: u'apparentthat',
#  953: u'theexpress',
#  954: u'shsk',
#  955: u'incontrovert',
#  956: u'towndistcuttack',
#  957: u'shss',
#  958: u'wanti',
#  959: u'checkth',
#  960: u'noobject',
#  961: u'former',
#  962: u'mukundakam',
#  963: u'bhave',
#  964: u'accounton',
#  965: u'causedth',
#  966: u'causedto',
#  967: u'straighten',
#  968: u'accountof',
#  969: u'forrajasthan',
#  970: u'ascit',
#  971: u'nonmemb',
#  972: u'zamindari',
#  973: u'whichremain',
#  974: u'convinc',
#  975: u'isresid',
#  976: u'ofsurgeri',
#  977: u'sriram',
#  978: u'unionof',
#  979: u'submittedthat',
#  980: u'nearbi',
#  981: u'pointof',
#  982: u'anydefici',
#  983: u'appellantsh',
#  984: u'informationabout',
#  985: u'mentaland',
#  986: u'noticedthat',
#  987: u'opportunityto',
#  988: u'thirusbalasubramonian',
#  989: u'appellantsv',
#  990: u'appellantst',
#  991: u'khamba',
#  992: u'merelybecaus',
#  993: u'theissuanc',
#  994: u'byrespond',
#  995: u'itought',
#  996: u'deft',
#  997: u'tolaw',
#  998: u'malout',
#  999: u'aggrievedfrom',
#  ...}

# %%
# %%time

import math
from six import iteritems
from six.moves import xrange
idf = {}
for word, freq in dictionary.dfs.iteritems():
    idf[dictionary.id2token[word]] = math.log(dictionary.num_docs) - math.log(freq)
# Out:
# CPU times: user 36 ms, sys: 0 ns, total: 36 ms
# Wall time: 30 ms

# %%
# get the query truth in dictionary
query_truth = {}
for i in range(1,11):
    query_truth[str(i)]=[]
    
    
f = open('LegalAdhocTask/Consumer.qrels')
lines = [line.rstrip('\n').split("\t") for line in f]
for line in lines:
    del line[1]
    query_truth[line[0]].append(line[1:])

# %%
w2v = model.wv
def vec(document):
    return np.add.reduce([w2v[i] for i in document if i in dictionary.token2id])

# %%
# %%time
doc_vec = []
for x in iter_token_corpus():
    x = vec(x)
    doc_vec.append(x)
# Out:
# CPU times: user 13min 48s, sys: 9.27 s, total: 13min 57s
# Wall time: 13min 57s

# %%
from scipy.spatial.distance import cosine
def get_scores(query):
    scores = []
    query = vec(query)
    for x in doc_vec:
        if isinstance(x, np.ndarray):
            score = 1 - cosine(x, query)
        else:
            score = -1000
        scores.append(score)
    return scores

# %%
# from scipy.spatial.distance import cosine
# xx = 0
# def get_scores(query):
#     global xx
#     scores = []
#     for x in iter_token_corpus():
#         if x:
#             score = w2v.n_similarity(x, query)
#         else:
#             score = -1000
#             print xx
#         xx = xx + 1    
#         scores.append(score)
#     return scores

# %%
# queries = [0]
# for i,query in enumerate(files_to_tokens('LegalAdhocTask/q*.txt')):
    
#     query = [i for i in query if i in dictionary.token2id]
#     queries.append(query)

# %%
# %%time
results = copy.deepcopy(query_truth)

sim_list = [0]
rank_list = [0]
queries = [0]
for i,query in enumerate(files_to_tokens('LegalAdhocTask/q*.txt')):
    queries.append(query)
    sims = get_scores(query)
    sim_list.append(sims)
    # rank of every document wrt similarity
    ranks = rankdata(sims, method='ordinal')
    ranks= len(ranks)+1 - ranks 
    rank_list.append(ranks)
    
    # update the query truth tuples with similarity score and the ranks
    for x in results[str(i+1)]:
        x.append(sims[filenames.index(x[0]+'.txt')])
        x.append(ranks[filenames.index(x[0]+'.txt')])
# Out:
# CPU times: user 1min 33s, sys: 44 ms, total: 1min 33s
# Wall time: 1min 33s

# %%
results
# Out:
# {'1': [['ConsumerCourt_DCDRC_100385', '1', 0.45164937505465941, 5420],
#   ['ConsumerCourt_DCDRC_106530', '0', 0.22561599176895752, 56203],
#   ['ConsumerCourt_DCDRC_107608', '1', 0.49886743210356443, 2898],
#   ['ConsumerCourt_DCDRC_114291', '1', 0.5567317196724515, 988],
#   ['ConsumerCourt_DCDRC_114382', '1', 0.59853371715494763, 361],
#   ['ConsumerCourt_DCDRC_118185', '1', 0.65386663415756041, 66],
#   ['ConsumerCourt_DCDRC_130318', '0', 0.49909734141604833, 2887],
#   ['ConsumerCourt_DCDRC_130570', '1', 0.46232035598281906, 4768],
#   ['ConsumerCourt_DCDRC_131146', '1', 0.60775374028702978, 276],
#   ['ConsumerCourt_DCDRC_131717', '1', 0.58925864226207059, 474],
#   ['ConsumerCourt_DCDRC_131741', '1', 0.61549818355866315, 229],
#   ['ConsumerCourt_DCDRC_131818', '1', 0.63698780739444338, 114],
#   ['ConsumerCourt_DCDRC_131950', '0', 0.54824362077217359, 1214],
#   ['ConsumerCourt_DCDRC_131972', '0', 0.60314569914443417, 315],
#   ['ConsumerCourt_DCDRC_132932', '0', 0.72258154252929074, 4],
#   ['ConsumerCourt_DCDRC_133592', '1', 0.6177057012297652, 216],
#   ['ConsumerCourt_DCDRC_134386', '0', 0.44083859972268868, 6152],
#   ['ConsumerCourt_DCDRC_135474', '1', 0.30049511167848064, 27029],
#   ['ConsumerCourt_DCDRC_139024', '0', 0.59733863090469808, 375],
#   ['ConsumerCourt_DCDRC_139205', '0', 0.60170630073424292, 333],
#   ['ConsumerCourt_DCDRC_140039', '1', 0.51131818242559235, 2348],
#   ['ConsumerCourt_DCDRC_145708', '0', 0.3850396869821473, 11176],
#   ['ConsumerCourt_DCDRC_187214', '1', 0.60022843776788593, 347],
#   ['ConsumerCourt_DCDRC_207784', '1', 0.50559538810899485, 2603],
#   ['ConsumerCourt_DCDRC_217344', '1', 0.54994000623633732, 1161],
#   ['ConsumerCourt_DCDRC_217471', '1', 0.50871434852831687, 2463],
#   ['ConsumerCourt_DCDRC_222797', '0', 0.52782146132236285, 1804],
#   ['ConsumerCourt_DCDRC_222844', '1', 0.69407715330340203, 16],
#   ['ConsumerCourt_DCDRC_224228', '0', 0.51456272052388774, 2239],
#   ['ConsumerCourt_DCDRC_224833', '0', 0.071421808663698183, 165153],
#   ['ConsumerCourt_DCDRC_226072', '1', 0.55022058254106521, 1156],
#   ['ConsumerCourt_DCDRC_38498', '0', 0.59211053993550022, 437],
#   ['ConsumerCourt_DCDRC_39186', '1', 0.57697085671130988, 641],
#   ['ConsumerCourt_DCDRC_41317', '1', 0.55785938346712405, 970],
#   ['ConsumerCourt_DCDRC_41588', '1', 0.55929688198375438, 934],
#   ['ConsumerCourt_DCDRC_42118', '1', 0.60444145898283863, 303],
#   ['ConsumerCourt_DCDRC_42618', '1', 0.47237650287285304, 4177],
#   ['ConsumerCourt_DCDRC_42649', '1', 0.64687037941983139, 79],
#   ['ConsumerCourt_DCDRC_44200', '1', 0.55944702163974669, 932],
#   ['ConsumerCourt_DCDRC_46368', '1', 0.56316776862254947, 860],
#   ['ConsumerCourt_DCDRC_46519', '1', 0.54756085390138232, 1233],
#   ['ConsumerCourt_DCDRC_46543', '1', 0.51541162958832631, 2206],
#   ['ConsumerCourt_DCDRC_53138', '1', 0.55206858306134587, 1117],
#   ['ConsumerCourt_DCDRC_55517', '1', 0.6405010770112638, 101],
#   ['ConsumerCourt_DCDRC_55612', '1', 0.6051329012367227, 296],
#   ['ConsumerCourt_DCDRC_55678', '1', 0.55515603108107081, 1021],
#   ['ConsumerCourt_DCDRC_55899', '1', 0.62485719187889566, 173],
#   ['ConsumerCourt_DCDRC_57484', '0', 0.60542386154084826, 294],
#   ['ConsumerCourt_DCDRC_74868', '1', 0.37196803041387538, 12812],
#   ['ConsumerCourt_DCDRC_80057', '1', 0.44421754011576975, 5930],
#   ['ConsumerCourt_DCDRC_83596', '0', 0.41734953699040733, 7987],
#   ['ConsumerCourt_DCDRC_83779', '0', 0.54910141135412327, 1188],
#   ['ConsumerCourt_DCDRC_96667', '1', 0.52739554044570824, 1815],
#   ['ConsumerCourt_DCDRC_98733', '1', 0.58476599229955939, 544],
#   ['ConsumerCourt_SCDRC_52678', '0', 0.41782796707707326, 7952],
#   ['DelhiHC_2011_4267', '0', 0.15463887718906744, 101428],
#   ['KolkataHCOriginalSite_2012_36', '0', 0.24097170296534332, 48662]],
#  '10': [['ConsumerCourt_DCDRC_220958', '0', 0.47520326188393991, 937],
#   ['ConsumerCourt_DCDRC_222509', '0', 0.46351500667993017, 1275],
#   ['ConsumerCourt_DCDRC_223570', '0', 0.49822240100401349, 511],
#   ['ConsumerCourt_DCDRC_227314', '0', 0.37450580324886307, 11879],
#   ['ConsumerCourt_DCDRC_228688', '1', 0.61772842161423913, 2],
#   ['ConsumerCourt_DCDRC_235883', '0', 0.49802378995904306, 516],
#   ['ConsumerCourt_DCDRC_38192', '0', 0.51895993865834211, 275],
#   ['ConsumerCourt_DCDRC_41485', '0', 0.46827350441524118, 1130],
#   ['ConsumerCourt_DCDRC_41489', '0', 0.46827350441524118, 1129],
#   ['ConsumerCourt_DCDRC_41520', '0', 0.46632063192930207, 1180],
#   ['ConsumerCourt_SCDRC_44836', '0', 0.39331909564430045, 7741],
#   ['ConsumerCourt_SCDRC_56350', '0', 0.61883735401628004, 1],
#   ['ConsumerCourt_SCDRC_65898', '0', 0.34359887115905907, 22731],
#   ['ConsumerCourt_SCDRC_68718', '0', 0.48953292254395409, 641],
#   ['ConsumerCourt_SCDRC_69937', '1', 0.58926415191280535, 22],
#   ['ConsumerCourt_SCDRC_70632', '0', 0.47789501750261676, 873],
#   ['DelhiHC_2008_2771', '0', 0.42665971837834404, 3370],
#   ['DelhiHC_2008_2772', '0', 0.42665971837834404, 3369]],
#  '2': [['ConsumerCourt_DCDRC_103241', '0', 0.63759119368104122, 1460],
#   ['ConsumerCourt_DCDRC_107786', '1', 0.52642760931542876, 13400],
#   ['ConsumerCourt_DCDRC_114305', '1', 0.64872085170456317, 1038],
#   ['ConsumerCourt_DCDRC_120930', '1', 0.58791280079899333, 4503],
#   ['ConsumerCourt_DCDRC_123490', '1', 0.62427037478793057, 2020],
#   ['ConsumerCourt_DCDRC_125352', '1', 0.53933938378089585, 10906],
#   ['ConsumerCourt_DCDRC_127791', '0', 0.80435150295765068, 2],
#   ['ConsumerCourt_DCDRC_130071', '0', 0.69292554715310317, 230],
#   ['ConsumerCourt_DCDRC_130920', '1', 0.53206077839037325, 12269],
#   ['ConsumerCourt_DCDRC_131972', '0', 0.6852115213730976, 302],
#   ['ConsumerCourt_DCDRC_133106', '1', 0.60908233671474477, 2881],
#   ['ConsumerCourt_DCDRC_133260', '0', 0.6743644203039767, 455],
#   ['ConsumerCourt_DCDRC_143284', '1', 0.63758454074400794, 1461],
#   ['ConsumerCourt_DCDRC_143334', '0', 0.64356278490622087, 1216],
#   ['ConsumerCourt_DCDRC_144440', '0', 0.59317202113459511, 4065],
#   ['ConsumerCourt_DCDRC_202900', '0', 0.30140624355516132, 124914],
#   ['ConsumerCourt_DCDRC_202903', '0', 0.45509682351403791, 35535],
#   ['ConsumerCourt_DCDRC_207376', '1', 0.71795641020579537, 82],
#   ['ConsumerCourt_DCDRC_212601', '0', 0.63414843997220816, 1590],
#   ['ConsumerCourt_DCDRC_212692', '1', 0.65580678846137952, 840],
#   ['ConsumerCourt_DCDRC_214518', '1', 0.6793501415629053, 388],
#   ['ConsumerCourt_DCDRC_226924', '0', 0.62564998986921261, 1942],
#   ['ConsumerCourt_DCDRC_227866', '1', 0.74420380771186245, 21],
#   ['ConsumerCourt_DCDRC_228749', '1', 0.62855073966218744, 1802],
#   ['ConsumerCourt_DCDRC_229221', '0', 0.62683490103292161, 1890],
#   ['ConsumerCourt_DCDRC_230361', '1', 0.74060686651613084, 26],
#   ['ConsumerCourt_DCDRC_41190', '0', 0.52561485749755366, 13573],
#   ['ConsumerCourt_DCDRC_50671', '1', 0.52326532570235618, 14020],
#   ['ConsumerCourt_DCDRC_52620', '1', 0.58955911355258184, 4360],
#   ['ConsumerCourt_DCDRC_53093', '1', 0.62780021251763218, 1848],
#   ['ConsumerCourt_DCDRC_53138', '0', 0.54791680654115882, 9428],
#   ['ConsumerCourt_DCDRC_53153', '1', 0.64759992767729624, 1079],
#   ['ConsumerCourt_DCDRC_53432', '0', 0.60816210511425184, 2931],
#   ['ConsumerCourt_DCDRC_53875', '0', 0.47436336899611908, 28004],
#   ['ConsumerCourt_DCDRC_53881', '0', 0.47436336899611908, 28003],
#   ['ConsumerCourt_DCDRC_56471', '1', 0.64585068897132059, 1150],
#   ['ConsumerCourt_DCDRC_56761', '0', 0.58944038966980339, 4375],
#   ['ConsumerCourt_DCDRC_57453', '0', 0.60360415251342558, 3246],
#   ['ConsumerCourt_DCDRC_57583', '0', 0.54766436205797886, 9470],
#   ['ConsumerCourt_DCDRC_62986', '0', 0.58673887889118859, 4613],
#   ['ConsumerCourt_DCDRC_63724', '0', 0.51368527306836309, 16216],
#   ['ConsumerCourt_DCDRC_68765', '0', 0.46541794274680282, 31358],
#   ['ConsumerCourt_DCDRC_68808', '0', 0.4143603477068023, 55496],
#   ['ConsumerCourt_DCDRC_69863', '0', 0.49765270523774285, 20561],
#   ['ConsumerCourt_DCDRC_74887', '0', 0.53624814405339938, 11472],
#   ['ConsumerCourt_DCDRC_75562', '0', 0.57830514082869733, 5505],
#   ['ConsumerCourt_DCDRC_76114', '0', 0.56181548838790774, 7451],
#   ['ConsumerCourt_DCDRC_76186', '0', 0.41369510249214625, 55851],
#   ['ConsumerCourt_DCDRC_76270', '0', 0.38742119567484112, 71176],
#   ['ConsumerCourt_DCDRC_77085', '1', 0.67300670406960272, 478],
#   ['ConsumerCourt_DCDRC_77280', '0', 0.77068603410275827, 5],
#   ['ConsumerCourt_DCDRC_77935', '1', 0.71036417157093057, 119],
#   ['ConsumerCourt_DCDRC_87186', '0', 0.54256256369783462, 10319],
#   ['ConsumerCourt_DCDRC_91864', '1', 0.67052211673516471, 513],
#   ['ConsumerCourt_DCDRC_96244', '1', 0.58046525350735712, 5278],
#   ['ConsumerCourt_NCDRC_1317', '0', 0.37153852237100393, 80865],
#   ['ConsumerCourt_SCDRC_49685', '0', 0.49109114566400169, 22550],
#   ['ConsumerCourt_SCDRC_60064', '1', 0.59043980669998253, 4284],
#   ['ConsumerCourt_SCDRC_62062', '1', 0.58216243349218011, 5095]],
#  '3': [['ConsumerCourt_DCDRC_103355', '0', 0.6329361863919013, 1163],
#   ['ConsumerCourt_DCDRC_129293', '1', 0.45434417722629072, 4842],
#   ['ConsumerCourt_DCDRC_133013', '1', 0.46268855436378353, 4542],
#   ['ConsumerCourt_DCDRC_133017', '0', 0.52290171630321036, 2973],
#   ['ConsumerCourt_DCDRC_137661', '0', 0.5113999708416197, 3191],
#   ['ConsumerCourt_DCDRC_153064', '0', 0.66289054370855827, 743],
#   ['ConsumerCourt_DCDRC_187619', '1', 0.4391252549198742, 5499],
#   ['ConsumerCourt_DCDRC_200840', '0', 0.54681335880391591, 2546],
#   ['ConsumerCourt_DCDRC_222260', '1', 0.52295791924979418, 2972],
#   ['ConsumerCourt_DCDRC_222772', '1', 0.56553114938047133, 2216],
#   ['ConsumerCourt_DCDRC_223618', '1', 0.26091433572675071, 25062],
#   ['ConsumerCourt_DCDRC_228476', '0', 0.58797366013498809, 1872],
#   ['ConsumerCourt_DCDRC_228963', '1', 0.69302701571346015, 414],
#   ['ConsumerCourt_DCDRC_230634', '1', 0.40715057825757495, 7207],
#   ['ConsumerCourt_DCDRC_235824', '0', 0.57132648633091598, 2120],
#   ['ConsumerCourt_DCDRC_45666', '0', 0.54067817690909192, 2663],
#   ['ConsumerCourt_DCDRC_47493', '1', 0.59038038142762206, 1833],
#   ['ConsumerCourt_DCDRC_52566', '0', 0.68699852780325599, 462],
#   ['ConsumerCourt_DCDRC_73184', '0', 0.50015725080417928, 3452],
#   ['ConsumerCourt_DCDRC_73185', '0', 0.55145746244623228, 2468],
#   ['ConsumerCourt_NCDRC_2861', '1', 0.71208470932982326, 263],
#   ['ConsumerCourt_NCDRC_2902', '0', 0.67882299164719595, 560],
#   ['ConsumerCourt_NCDRC_2979', '0', 0.64765970042569998, 948],
#   ['ConsumerCourt_NCDRC_632', '0', 0.54487540168778181, 2583],
#   ['ConsumerCourt_NCDRC_637', '0', 0.54870210041041323, 2518],
#   ['ConsumerCourt_SCDRC_2052', '0', 0.53989016475943463, 2681],
#   ['ConsumerCourt_SCDRC_22704', '0', 0.70267948147608206, 337],
#   ['ConsumerCourt_SCDRC_29484', '0', 0.74658321741137668, 96],
#   ['ConsumerCourt_SCDRC_29552', '0', 0.71650759240277961, 238],
#   ['ConsumerCourt_SCDRC_30176', '0', 0.22933365760716662, 33294],
#   ['ConsumerCourt_SCDRC_48394', '0', 0.63326324038861181, 1158],
#   ['ConsumerCourt_SCDRC_63569', '0', 0.70170188977757142, 342],
#   ['ConsumerCourt_SCDRC_63609', '0', 0.15983367098945567, 62779],
#   ['ConsumerCourt_SCDRC_65919', '0', 0.40392739851481729, 7400],
#   ['ConsumerCourt_SCDRC_66200', '0', 0.6839792246854699, 507],
#   ['ConsumerCourt_SCDRC_69801', '0', 0.69578944843503532, 391],
#   ['ConsumerCourt_SCDRC_814', '0', 0.51449501145560372, 3130],
#   ['DelhiHC_2012_388', '0', 0.26238567828286119, 24705]],
#  '4': [['ConsumerCourt_DCDRC_106570', '0', 0.61339847506988543, 2265],
#   ['ConsumerCourt_DCDRC_116129', '1', 0.69984583664014999, 408],
#   ['ConsumerCourt_DCDRC_128836', '0', 0.72044161967139453, 223],
#   ['ConsumerCourt_DCDRC_130725', '1', 0.63957817083302104, 1431],
#   ['ConsumerCourt_DCDRC_133137', '0', 0.79981049659087633, 8],
#   ['ConsumerCourt_DCDRC_173376', '0', 0.29666632439809582, 67789],
#   ['ConsumerCourt_DCDRC_174292', '0', 0.5610810242665536, 4469],
#   ['ConsumerCourt_DCDRC_174300', '1', 0.58494996954825507, 3331],
#   ['ConsumerCourt_DCDRC_202903', '0', 0.43624254061380263, 16484],
#   ['ConsumerCourt_DCDRC_205816', '1', 0.71765488518769527, 246],
#   ['ConsumerCourt_DCDRC_207155', '0', 0.54010393699922576, 5648],
#   ['ConsumerCourt_DCDRC_207197', '0', 0.70244194205190003, 381],
#   ['ConsumerCourt_DCDRC_212467', '1', 0.66919576375110768, 834],
#   ['ConsumerCourt_DCDRC_213156', '0', 0.55149283702792096, 4960],
#   ['ConsumerCourt_DCDRC_213473', '0', 0.63013991058315988, 1699],
#   ['ConsumerCourt_DCDRC_213784', '0', 0.73613134046137019, 141],
#   ['ConsumerCourt_DCDRC_214475', '0', 0.62661647800733744, 1812],
#   ['ConsumerCourt_DCDRC_218582', '0', 0.690177651066463, 518],
#   ['ConsumerCourt_DCDRC_221177', '0', 0.75529414615901458, 66],
#   ['ConsumerCourt_DCDRC_221424', '0', 0.77026131272221887, 34],
#   ['ConsumerCourt_DCDRC_223275', '0', 0.62848181616163745, 1743],
#   ['ConsumerCourt_DCDRC_226909', '0', 0.31211415497543804, 59122],
#   ['ConsumerCourt_DCDRC_227099', '0', 0.57927707861110067, 3575],
#   ['ConsumerCourt_DCDRC_229902', '0', 0.47917692906937381, 10634],
#   ['ConsumerCourt_DCDRC_47636', '0', 0.54739425546598275, 5200],
#   ['ConsumerCourt_DCDRC_49131', '0', 0.60349519267943941, 2661],
#   ['ConsumerCourt_DCDRC_51881', '0', 0.6491684862340098, 1231],
#   ['ConsumerCourt_DCDRC_52357', '0', 0.73541916064762647, 146],
#   ['ConsumerCourt_DCDRC_53202', '0', 0.64160951560239854, 1384],
#   ['ConsumerCourt_DCDRC_53580', '1', 0.62627843056178689, 1820],
#   ['ConsumerCourt_DCDRC_54056', '1', 0.61605722814563146, 2166],
#   ['ConsumerCourt_DCDRC_70122', '0', 0.63359143187516465, 1605],
#   ['ConsumerCourt_DCDRC_73309', '0', 0.54565758077020599, 5298],
#   ['ConsumerCourt_NCDRC_2154', '0', -0.067703699605436984, 281900],
#   ['ConsumerCourt_NCDRC_3506', '0', 0.088381896154506867, 205001],
#   ['ConsumerCourt_SCDRC_1143', '1', 0.54355005539498769, 5429],
#   ['ConsumerCourt_SCDRC_1288', '1', 0.69899006672526998, 417],
#   ['ConsumerCourt_SCDRC_22830', '0', 0.60487413970629678, 2620],
#   ['ConsumerCourt_SCDRC_37679', '1', 0.64357730392762669, 1347],
#   ['ConsumerCourt_SCDRC_471', '0', 0.20898108023131101, 127322],
#   ['ConsumerCourt_SCDRC_49973', '1', 0.72093654173814425, 221],
#   ['ConsumerCourt_SCDRC_5406', '0', -0.039633067540085776, 270026],
#   ['ConsumerCourt_SCDRC_7046', '1', 0.7543293787645905, 72],
#   ['DelhiHC_2012_3856', '0', 0.44514734916751675, 15054],
#   ['SupremeCourt_2009_1421', '0', 0.54916504206629912, 5095]],
#  '5': [['ConsumerCourt_DCDRC_124651', '0', 0.28382111296241308, 46422],
#   ['ConsumerCourt_DCDRC_138545', '0', 0.62549409709024295, 255],
#   ['ConsumerCourt_DCDRC_139183', '0', 0.72425517597798128, 5],
#   ['ConsumerCourt_DCDRC_141380', '0', 0.62287607825451619, 278],
#   ['ConsumerCourt_DCDRC_148691', '1', 0.53401623467491521, 1529],
#   ['ConsumerCourt_DCDRC_202903', '0', 0.2588398850608542, 59958],
#   ['ConsumerCourt_DCDRC_208296', '0', 0.55748570559034383, 1035],
#   ['ConsumerCourt_DCDRC_223817', '0', 0.63773682839598833, 180],
#   ['ConsumerCourt_DCDRC_226994', '0', 0.63502678255384337, 192],
#   ['ConsumerCourt_DCDRC_229911', '1', 0.54923348420350737, 1202],
#   ['ConsumerCourt_DCDRC_41155', '1', 0.534871350460698, 1507],
#   ['ConsumerCourt_DCDRC_41262', '0', 0.46033254801677526, 4720],
#   ['ConsumerCourt_DCDRC_41428', '0', 0.43289215487197441, 7030],
#   ['ConsumerCourt_DCDRC_42411', '0', 0.62628694708312349, 249],
#   ['ConsumerCourt_DCDRC_46404', '0', 0.18216339650311464, 113223],
#   ['ConsumerCourt_DCDRC_53679', '1', 0.61328858181514334, 337],
#   ['ConsumerCourt_DCDRC_57315', '1', 0.56146424366101366, 977],
#   ['ConsumerCourt_DCDRC_57465', '0', 0.4690158192161431, 4124],
#   ['ConsumerCourt_DCDRC_57488', '0', 0.28239053531313707, 47173],
#   ['ConsumerCourt_DCDRC_57914', '1', 0.2784482604635532, 49457],
#   ['ConsumerCourt_DCDRC_66294', '0', 0.23069213515657028, 77969],
#   ['ConsumerCourt_DCDRC_96799', '0', 0.7128685215153947, 8],
#   ['ConsumerCourt_NCDRC_1337', '1', 0.65828165214747247, 98],
#   ['ConsumerCourt_NCDRC_1338', '0', 0.65828165214747247, 97],
#   ['ConsumerCourt_NCDRC_2983', '1', 0.69183640531662272, 24],
#   ['ConsumerCourt_SCDRC_28656', '0', 0.47174786299717619, 3965],
#   ['ConsumerCourt_SCDRC_33517', '1', 0.65614997841361278, 107],
#   ['ConsumerCourt_SCDRC_5122', '0', 0.33123683729859688, 27207],
#   ['ConsumerCourt_SCDRC_71374', '1', 0.69484336943028757, 20]],
#  '6': [['ConsumerCourt_DCDRC_103021', '1', 0.52357807923142963, 1885],
#   ['ConsumerCourt_DCDRC_119836', '1', 0.59337052743490715, 218],
#   ['ConsumerCourt_DCDRC_125237', '1', 0.45051523036033125, 9097],
#   ['ConsumerCourt_DCDRC_126276', '0', 0.53195285748438359, 1512],
#   ['ConsumerCourt_DCDRC_131266', '1', 0.56685660440954289, 641],
#   ['ConsumerCourt_DCDRC_133353', '1', 0.65033079288412254, 29],
#   ['ConsumerCourt_DCDRC_133354', '0', 0.6426596876934052, 39],
#   ['ConsumerCourt_DCDRC_134804', '0', 0.29385144790379125, 80141],
#   ['ConsumerCourt_DCDRC_138617', '1', 0.52743752506063424, 1711],
#   ['ConsumerCourt_DCDRC_143983', '0', 0.43610073039109498, 11705],
#   ['ConsumerCourt_DCDRC_207387', '1', 0.62448373689257164, 82],
#   ['ConsumerCourt_DCDRC_220958', '1', 0.63306294109160655, 61],
#   ['ConsumerCourt_DCDRC_223570', '1', 0.56809848955653885, 616],
#   ['ConsumerCourt_DCDRC_223783', '0', 0.63453618097014231, 57],
#   ['ConsumerCourt_DCDRC_38192', '1', 0.67315991739122383, 5],
#   ['ConsumerCourt_DCDRC_41485', '0', 0.6196470001535066, 93],
#   ['ConsumerCourt_DCDRC_41489', '0', 0.6196470001535066, 92],
#   ['ConsumerCourt_DCDRC_41520', '1', 0.65433132549818396, 23],
#   ['ConsumerCourt_DCDRC_45421', '0', 0.46579974450929562, 6799],
#   ['ConsumerCourt_DCDRC_52148', '0', 0.40893846963065039, 18382],
#   ['ConsumerCourt_DCDRC_70186', '0', 0.42834642481883445, 13357],
#   ['ConsumerCourt_DCDRC_70341', '0', 0.40972054144694769, 18171],
#   ['ConsumerCourt_DCDRC_90054', '0', 0.34594575576627928, 45707],
#   ['ConsumerCourt_SCDRC_28640', '1', 0.71062541300033744, 1],
#   ['ConsumerCourt_SCDRC_64152', '0', 0.31823856550166285, 62968],
#   ['ConsumerCourt_SCDRC_68718', '1', 0.52000929166271326, 2041],
#   ['ConsumerCourt_SCDRC_70632', '0', 0.68684584281751604, 2],
#   ['DelhiHC_2009_735', '1', 0.65460687141052576, 20],
#   ['DelhiHC_2012_372', '0', 0.58744040127276198, 274],
#   ['DelhiHC_2012_374', '0', 0.58744040127276198, 273],
#   ['SupremeCourt_1996_416', '0', 0.6283240260133296, 70]],
#  '7': [['ConsumerCourt_DCDRC_119406', '1', 0.51889964811819067, 2327],
#   ['ConsumerCourt_DCDRC_121344', '0', 0.30589842093591391, 98299],
#   ['ConsumerCourt_DCDRC_127019', '0', 0.47866226339098228, 6194],
#   ['ConsumerCourt_DCDRC_130205', '0', 0.51671953246978852, 2461],
#   ['ConsumerCourt_DCDRC_207672', '1', 0.60216913558900698, 157],
#   ['ConsumerCourt_DCDRC_222487', '0', 0.55963393146731022, 795],
#   ['ConsumerCourt_DCDRC_224805', '0', 0.51380910644527233, 2668],
#   ['ConsumerCourt_DCDRC_235755', '0', 0.41049457392293376, 25947],
#   ['ConsumerCourt_DCDRC_236026', '1', 0.415738522728061, 23393],
#   ['ConsumerCourt_DCDRC_236229', '0', 0.28461504048088959, 115217],
#   ['ConsumerCourt_DCDRC_33939', '0', 0.57345893917353985, 509],
#   ['ConsumerCourt_DCDRC_44337', '1', 0.53059712550496463, 1722],
#   ['ConsumerCourt_DCDRC_45534', '0', 0.60161367861481718, 162],
#   ['ConsumerCourt_DCDRC_46470', '0', 0.47856773144173026, 6206],
#   ['ConsumerCourt_DCDRC_48811', '0', 0.500194498560528, 3652],
#   ['ConsumerCourt_DCDRC_51454', '1', 0.49048744599944283, 4624],
#   ['ConsumerCourt_DCDRC_64180', '0', 0.6370332158016293, 22],
#   ['ConsumerCourt_DCDRC_73953', '0', 0.46398377073932706, 8632],
#   ['ConsumerCourt_DCDRC_75554', '0', 0.55568990493699777, 891],
#   ['ConsumerCourt_SCDRC_1050', '0', 0.37153315794709374, 47755],
#   ['ConsumerCourt_SCDRC_1387', '0', 0.19045314472768871, 178497],
#   ['ConsumerCourt_SCDRC_1418', '0', 0.1849760267667514, 181525],
#   ['ConsumerCourt_SCDRC_65323', '0', 0.36158127243120186, 54612],
#   ['ConsumerCourt_SCDRC_66203', '0', 0.60248849802796522, 156],
#   ['DelhiHC_2012_2026', '0', 0.25504506337506638, 137621]],
#  '8': [['ConsumerCourt_DCDRC_101057', '1', 0.60372340740189834, 9139],
#   ['ConsumerCourt_DCDRC_118168', '0', 0.65487114042877748, 1616],
#   ['ConsumerCourt_DCDRC_118989', '0', 0.52186976646395056, 38451],
#   ['ConsumerCourt_DCDRC_120003', '1', 0.58296466470087893, 14601],
#   ['ConsumerCourt_DCDRC_120004', '1', 0.5869862203024746, 13405],
#   ['ConsumerCourt_DCDRC_121058', '0', 0.56025543439953718, 22252],
#   ['ConsumerCourt_DCDRC_125286', '0', 0.51916855877504919, 39651],
#   ['ConsumerCourt_DCDRC_126274', '0', 0.6466899002597174, 2307],
#   ['ConsumerCourt_DCDRC_128072', '1', 0.63444692867199348, 3672],
#   ['ConsumerCourt_DCDRC_129352', '0', 0.4354254937077241, 86792],
#   ['ConsumerCourt_DCDRC_129820', '0', 0.46920634755689317, 66215],
#   ['ConsumerCourt_DCDRC_131144', '0', 0.54448264763209087, 28298],
#   ['ConsumerCourt_DCDRC_131587', '0', 0.50840451498820549, 44922],
#   ['ConsumerCourt_DCDRC_131846', '0', 0.5736793517168417, 17558],
#   ['ConsumerCourt_DCDRC_132917', '0', 0.59333686769488281, 11632],
#   ['ConsumerCourt_DCDRC_132928', '0', 0.65399014221534812, 1686],
#   ['ConsumerCourt_DCDRC_134709', '0', 0.51704812675052003, 40696],
#   ['ConsumerCourt_DCDRC_140632', '0', 0.54574562517900671, 27763],
#   ['ConsumerCourt_DCDRC_140644', '0', 0.65302256335172293, 1753],
#   ['ConsumerCourt_DCDRC_145502', '0', 0.38054323558136627, 122493],
#   ['ConsumerCourt_DCDRC_169855', '0', -0.13023901706964769, 313765],
#   ['ConsumerCourt_DCDRC_202901', '0', 0.37257724755141264, 127809],
#   ['ConsumerCourt_DCDRC_203935', '0', 0.41283112468697447, 101031],
#   ['ConsumerCourt_DCDRC_222781', '0', 0.4709504187883683, 65156],
#   ['ConsumerCourt_DCDRC_223340', '0', 0.58183364479272381, 14963],
#   ['ConsumerCourt_DCDRC_228779', '0', 0.43428908332811789, 87528],
#   ['ConsumerCourt_DCDRC_229540', '0', 0.45468592438450339, 74826],
#   ['ConsumerCourt_DCDRC_39867', '0', 0.3229094901913987, 159852],
#   ['ConsumerCourt_DCDRC_40822', '0', 0.51824362337510299, 40094],
#   ['ConsumerCourt_DCDRC_41058', '0', 0.42652475616886076, 92368],
#   ['ConsumerCourt_DCDRC_41514', '0', 0.3022613005657846, 172288],
#   ['ConsumerCourt_DCDRC_57900', '1', 0.35232421369238576, 141365],
#   ['ConsumerCourt_DCDRC_69224', '0', 0.65469272733834627, 1627],
#   ['ConsumerCourt_DCDRC_71619', '0', 0.49972022627503043, 49338],
#   ['ConsumerCourt_DCDRC_73864', '0', 0.59746764984655831, 10598],
#   ['ConsumerCourt_DCDRC_75339', '0', 0.64378342402502564, 2617],
#   ['ConsumerCourt_DCDRC_75574', '1', 0.57523003587433419, 17052],
#   ['ConsumerCourt_DCDRC_76123', '0', 0.38675746279288847, 118370],
#   ['ConsumerCourt_DCDRC_85243', '0', 0.35276953725250704, 141061],
#   ['ConsumerCourt_SCDRC_29744', '0', 0.050621602758313511, 269858],
#   ['ConsumerCourt_SCDRC_33757', '0', 0.063854243828977753, 266480],
#   ['ConsumerCourt_SCDRC_53283', '0', 0.58735406817237201, 13304],
#   ['ConsumerCourt_SCDRC_63603', '0', 0.20831249716049594, 219241],
#   ['ConsumerCourt_SCDRC_66106', '1', 0.55800060636794602, 23010],
#   ['ConsumerCourt_SCDRC_66890', '0', 0.51601888289455999, 41139],
#   ['ConsumerCourt_SCDRC_67067', '0', 0.53024523564621895, 34700],
#   ['ConsumerCourt_SCDRC_67949', '0', 0.38403156805167771, 120205],
#   ['ConsumerCourt_SCDRC_67951', '0', 0.3876550935307832, 117786],
#   ['ConsumerCourt_SCDRC_72333', '1', 0.5594641831274888, 22495],
#   ['JodhpurHC_2008_1906', '0', 0.18437347731726295, 228922]],
#  '9': [['ConsumerCourt_DCDRC_108097', '0', 0.6931981294353603, 54],
#   ['ConsumerCourt_DCDRC_119856', '1', 0.76740843606986664, 2],
#   ['ConsumerCourt_DCDRC_119986', '0', 0.67897578834204175, 89],
#   ['ConsumerCourt_DCDRC_128297', '0', 0.75385545051197489, 6],
#   ['ConsumerCourt_DCDRC_128836', '0', 0.60165217626662615, 1290],
#   ['ConsumerCourt_DCDRC_130625', '0', 0.54317625329575459, 6411],
#   ['ConsumerCourt_DCDRC_133010', '0', 0.74314067592533006, 11],
#   ['ConsumerCourt_DCDRC_138306', '1', 0.47597614444427117, 28416],
#   ['ConsumerCourt_DCDRC_139625', '0', 0.60054531797636324, 1338],
#   ['ConsumerCourt_DCDRC_143537', '0', 0.60250389281660899, 1264],
#   ['ConsumerCourt_DCDRC_202901', '0', 0.42581096531748353, 58650],
#   ['ConsumerCourt_DCDRC_202902', '0', 0.47292357928882334, 29911],
#   ['ConsumerCourt_DCDRC_202903', '0', 0.51097396440330789, 14114],
#   ['ConsumerCourt_DCDRC_222047', '1', 0.56607659794885956, 3575],
#   ['ConsumerCourt_DCDRC_224718', '1', 0.6559746862226068, 236],
#   ['ConsumerCourt_DCDRC_226994', '0', 0.64278695426577614, 377],
#   ['ConsumerCourt_DCDRC_227115', '0', 0.64009097393126679, 415],
#   ['ConsumerCourt_DCDRC_227445', '0', 0.67323235444554841, 113],
#   ['ConsumerCourt_DCDRC_236013', '1', 0.47576187739032116, 28520],
#   ['ConsumerCourt_DCDRC_38039', '1', 0.5086900303764984, 14796],
#   ['ConsumerCourt_DCDRC_38552', '0', 0.62982725627509917, 567],
#   ['ConsumerCourt_DCDRC_45418', '0', 0.64973714962923468, 303],
#   ['ConsumerCourt_DCDRC_53237', '1', 0.63821771662717519, 436],
#   ['ConsumerCourt_DCDRC_56957', '0', 0.63435001177259587, 491],
#   ['ConsumerCourt_DCDRC_89958', '0', 0.71673160689759574, 22],
#   ['ConsumerCourt_NCDRC_2916', '0', 0.60657546047059496, 1128],
#   ['ConsumerCourt_NCDRC_437', '0', 0.4718390502770835, 30439],
#   ['ConsumerCourt_SCDRC_40659', '0', 0.64517442857777241, 350],
#   ['ConsumerCourt_SCDRC_49689', '0', 0.67562707947111911, 101],
#   ['ConsumerCourt_SCDRC_53178', '0', 0.5979523027377428, 1440],
#   ['ConsumerCourt_SCDRC_65050', '0', 0.46560216545621302, 33726],
#   ['ConsumerCourt_SCDRC_67634', '0', 0.60614401922195849, 1136],
#   ['ConsumerCourt_SCDRC_68803', '0', 0.61304146781037006, 944],
#   ['DelhiHC_2008_1343', '0', 0.50963524846778729, 14506],
#   ['DelhiHC_2009_453', '0', 0.11579613224723273, 239864],
#   ['DelhiHC_2010_4683', '0', 0.50773696285115721, 15105],
#   ['DelhiHC_2010_6192', '0', 0.5310679033283543, 8686],
#   ['DelhiHC_2011_69', '0', 0.4112945919954154, 69126],
#   ['DelhiHC_2013_811', '0', 0.46022711873083988, 36705],
#   ['SupremeCourt_2008_278', '0', 0.17712076945930677, 216035]]}

# %%
# "yield" for each file return token list  i.e list of lists
def files_to_tokens(glob_filenames):
    glob_filenames = os.path.normpath(glob_filenames)
    for filename in sorted(glob2.glob(glob_filenames)):
        f = open(filename)
        # read the whole file as lowercase string
        string = (f.read()).lower()
        #print string
        string = (string.decode("windows-1252")).lower()
        #print string
        tokens = []
        # tokenize that string
        for word in word_tokenize(string):
            if word not in en_stop:
                tokens.append(ps.stem(word))

        yield tokens
        f.close()

# %%
model_name = 'w2v_mean'
# Store results in 1st sheet
wb = Workbook()
dest_filename = model_name + '.xlsx'
ws1 = wb.active
ws1.title = " "
ws1.append(['Query','Filename', 'Relevance', 'Score', 'Rank'])
for key,value in results.iteritems():
    for i in value:
        ws1.append([int(key)]+ i)

wb.save(filename = dest_filename)


#Query wise (F score)

import pandas as pd

f = pd.ExcelFile(dest_filename)

from scipy.stats import hmean



places = 4
wb = load_workbook(dest_filename)
ws1 = wb.create_sheet(title="evaluation_Qwise")

ws1.append(['Query','Docs considered', 'Precision/Recall', 'Model', 1, 5 ,10, 25, 50, 100, 500, 1000])

k = [1.0, 5.0 ,10.0, 25.0, 50.0, 100.0, 500.0, 1000.0]
for sheet in f.sheet_names:
    if(sheet == "evaluation"):
        continue
    for q in np.arange(1,11):

        x = f.parse(sheet)
        x = x[x['Query'] == q]
        total_1 = (float)(x[x['Relevance'] == 1].shape[0])
        total_0 = (float)(x[x['Relevance'] == 0].shape[0])
        total = (float)(x.shape[0])
        
        ####  repitition due to complication in considering both 1 & 0 relevance
        # precision 1
        row = [q, 1, 'P', model_name + ' :' + sheet]
        for i in k:
            row.append(x[np.logical_and(x['Relevance'] == 1 , x['Rank'] <= i)].shape[0]/i)
        ws1.append(row);
        p1 = row;
        # precision 0
        row = [q, 0, 'P', model_name + ' :' + sheet]
        for i in k:
            row.append(x[np.logical_and(x['Relevance'] == 0 , x['Rank'] <= i)].shape[0]/i)    
        ws1.append(row);
        p0 = row;
        #precision 10
        row = [q, 10, 'P', model_name + ' :' + sheet]
        for i in k:
            row.append(x[x['Rank'] <= i].shape[0]/i)  
        ws1.append(row);
        p10 = row;  
        
        
        # recall 1
        row = [q, 1, 'R', model_name + ' :' + sheet]
        for i in k:
            row.append(x[np.logical_and(x['Relevance'] == 1 , x['Rank'] <= i)].shape[0]/total_1)
            row[-1] = round(row[-1],places)
        ws1.append(row);
        r1 = row;    
        # recall 0
        row = [q, 0, 'R', model_name + ' :' + sheet]
        for i in k:
            row.append(x[np.logical_and(x['Relevance'] == 0 , x['Rank'] <= i)].shape[0]/total_0)
            row[-1] = round(row[-1],places)
        ws1.append(row);
        r0 = row;
        #recall 10
        row = [q, 10, 'R', model_name + ' :' + sheet]
        for i in k:
            row.append(x[x['Rank'] <= i].shape[0]/total)
            row[-1] = round(row[-1],places)
        ws1.append(row);
        r10 = row;      


        # F 1
        row = [q, 1, 'F', model_name + ' :' + sheet]
        for i in range(-len(k), 0, 1):
            if p1[i] == 0.0 :
                row.append(0.0)
            else:
                row.append(hmean([p1[i],r1[i]]))
            row[-1] = round(row[-1],places)
        ws1.append(row);

        # F 0
        row = [q, 0, 'F', model_name + ' :' + sheet]
        for i in range(-len(k), 0, 1):
            if p0[i] == 0.0:
                row.append(0.0)
            else:
                row.append(hmean([p0[i],r0[i]]))
            row[-1] = round(row[-1],places)
        ws1.append(row);

        # F 10
        row = [q, 10, 'F', model_name + ' :' + sheet]
        for i in range(-len(k), 0, 1):
            if p10[i] == 0.0:
                row.append(0.0)
            else:
                row.append(hmean([p10[i],r10[i]]))
            row[-1] = round(row[-1],places)
        ws1.append(row);
        
wb.save(filename = dest_filename)


#Query wise Average precision
# precision sum
def p_sum(z):
    z = z.copy()  
    z.sort_values(inplace=True)
    result = 0
    for i,val in enumerate(z):
        result += (i+1)/float(val) 
    return result


import pandas as pd

f = pd.ExcelFile(dest_filename)

from scipy.stats import hmean


places = 4
wb = load_workbook(dest_filename)
ws1 = wb.create_sheet(title="AP_Qwise")

ws1.append(['Query','Docs considered', 'Precision/Recall', 'Model', 1, 5 ,10, 25, 50, 100, 500, 1000])


for sheet in f.sheet_names:    
    if(sheet == "evaluation"or sheet == "evaluation_Qwise"):
        continue
    for q in np.arange(1,11):
        x = f.parse(sheet)
        x = x[x['Query'] == q]
        total = {}
        total[1] = (float)(x[x['Relevance'] == 1].shape[0])
        total[0] = (float)(x[x['Relevance'] == 0].shape[0])
        total[10] = (float)(x.shape[0])
        
        for rel in [1,0]:
            # precision 1
            row = [q, rel, 'AP', model_name + ' :' + sheet]
            for i in [1.0, 5.0, 10.0, 25.0, 50.0, 100.0, 500.0, 1000.0]:
                row.append(p_sum(x[np.logical_and(x['Relevance'] == rel, x['Rank'] <= i)]['Rank'])/total[rel])
            ws1.append(row);

        row = [q, 10, 'AP', model_name + ' :' + sheet]
        for i in [1.0, 5.0, 10.0, 25.0, 50.0, 100.0, 500.0, 1000.0]:
            row.append(p_sum(x[x['Rank'] <= i]['Rank'])/total[10])
        ws1.append(row);
wb.save(filename = dest_filename)

# %%
def append_df_to_excel(filename, df, sheet_name='Sheet1', startrow=None,
                       truncate_sheet=False, 
                       **to_excel_kwargs):
    """
    Append a DataFrame [df] to existing Excel file [filename]
    into [sheet_name] Sheet.
    If [filename] doesn't exist, then this function will create it.

    Parameters:
      filename : File path or existing ExcelWriter
                 (Example: '/path/to/file.xlsx')
      df : dataframe to save to workbook
      sheet_name : Name of sheet which will contain DataFrame.
                   (default: 'Sheet1')
      startrow : upper left cell row to dump data frame.
                 Per default (startrow=None) calculate the last row
                 in the existing DF and write to the next row...
      truncate_sheet : truncate (remove and recreate) [sheet_name]
                       before writing DataFrame to Excel file
      to_excel_kwargs : arguments which will be passed to `DataFrame.to_excel()`
                        [can be dictionary]

    Returns: None
    """
    from openpyxl import load_workbook

    # ignore [engine] parameter if it was passed
    if 'engine' in to_excel_kwargs:
        to_excel_kwargs.pop('engine')

    writer = pd.ExcelWriter(filename, engine='openpyxl')

    try:
        # try to open an existing workbook
        writer.book = load_workbook(filename)

        # get the last row in the existing Excel sheet
        # if it was not specified explicitly
        if startrow is None and sheet_name in writer.book.sheetnames:
            startrow = writer.book[sheet_name].max_row

        # truncate sheet
        if truncate_sheet and sheet_name in writer.book.sheetnames:
            # index of [sheet_name] sheet
            idx = writer.book.sheetnames.index(sheet_name)
            # remove [sheet_name]
            writer.book.remove(writer.book.worksheets[idx])
            # create an empty sheet [sheet_name] using old index
            writer.book.create_sheet(sheet_name, idx)

        # copy existing sheets
        writer.sheets = {ws.title:ws for ws in writer.book.worksheets}
    except FileNotFoundError:
        # file does not exist yet, we will create it
        pass

    if startrow is None:
        startrow = 0

    # write out the new sheet
    df.to_excel(writer, sheet_name, startrow=startrow, index= False, header = False, **to_excel_kwargs)

    # save the workbook
    writer.save()

    
f = pd.ExcelFile(dest_filename)
f2 = pd.ExcelFile('all_results.xlsx')
append_df_to_excel("all_results.xlsx", f.parse(1), sheet_name= f2.sheet_names[0])
append_df_to_excel("all_results.xlsx", f.parse(2), sheet_name= f2.sheet_names[1])

# %%
del model

# %%
import gc
gc.collect()
# Out:
# 0
