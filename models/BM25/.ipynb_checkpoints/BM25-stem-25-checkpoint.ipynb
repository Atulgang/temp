# %%
import os
os.chdir("/home/atulgang/Thesis")

# %%
import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)

# %%
import nltk
from nltk.tokenize import word_tokenize
from stop_words import get_stop_words
from nltk.stem import WordNetLemmatizer
from gensim import corpora, models
import gensim
import glob2
from itertools import chain
import os
import numpy as np
import itertools
import cPickle as pickle
from  scipy.stats import rankdata
import copy
from openpyxl import Workbook
from openpyxl.compat import range
from openpyxl.utils import get_column_letter
from openpyxl import load_workbook
import pandas as pd
from scipy.stats import hmean
from nltk.stem import PorterStemmer
from nltk.tokenize import sent_tokenize, word_tokenize
# Out:
# 2018-04-28 02:11:44,718 : INFO : 'pattern' package not found; tag filters are not available for English

# %%
# ignores everything except english alphabet and  
def only_alphabet(text):
    return ''.join(i for i in text if (ord(i)<123 and ord(i)>96) or (ord(i)<91 and ord(i)>64) or ord(i)==32) 

full_filenames = []
x= ['LegalAdhocTask/ConsumerCourtAdhocdata/DCDRC/**/*.txt','LegalAdhocTask/ConsumerCourtAdhocdata/NCDRC/**/*.txt','LegalAdhocTask/ConsumerCourtAdhocdata/SCDRC/**/*.txt', 'LegalAdhocTask/SC-HCAdhocData/DelhiHC/**/*.txt','LegalAdhocTask/SC-HCAdhocData/JharkhandHC/**/*.txt', 'LegalAdhocTask/SC-HCAdhocData/JodhpurHC/**/*.txt' ,'LegalAdhocTask/SC-HCAdhocData/KolkataHC/**/*.txt', 'LegalAdhocTask/SC-HCAdhocData/SupremeCourt/**/*.txt']
for glob_filenames in x:
    glob_filenames = os.path.normpath(glob_filenames)
    for filename in sorted(glob2.glob(glob_filenames)):
        full_filenames.append(filename)
            
filenames = []
x= ['LegalAdhocTask/ConsumerCourtAdhocdata/DCDRC/**/*.txt','LegalAdhocTask/ConsumerCourtAdhocdata/NCDRC/**/*.txt','LegalAdhocTask/ConsumerCourtAdhocdata/SCDRC/**/*.txt', 'LegalAdhocTask/SC-HCAdhocData/DelhiHC/**/*.txt','LegalAdhocTask/SC-HCAdhocData/JharkhandHC/**/*.txt', 'LegalAdhocTask/SC-HCAdhocData/JodhpurHC/**/*.txt' ,'LegalAdhocTask/SC-HCAdhocData/KolkataHC/**/*.txt', 'LegalAdhocTask/SC-HCAdhocData/SupremeCourt/**/*.txt']
for glob_filenames in x:
    glob_filenames = os.path.normpath(glob_filenames)
    for filename in sorted(glob2.glob(glob_filenames)):
        filenames.append(os.path.basename(filename))

# %%
en_stop = set(get_stop_words('en'))
ps = PorterStemmer()

# "yield" for each file return token list  i.e list of lists
def files_to_tokens(glob_filenames):
    glob_filenames = os.path.normpath(glob_filenames)
    for filename in sorted(glob2.glob(glob_filenames)):
        f = open(filename)
        # read the whole file as lowercase string
        string = (f.read()).lower()
        try:
            temp = word_tokenize(string)
        except:
            string = string.decode("latin-1")
            temp = word_tokenize(string)

        tokens = []
        # tokenize that string
        for word in temp:
            w =  only_alphabet(word).lower()
            if w not in en_stop:
                if w:
                    tokens.append(ps.stem(w))

        yield tokens
        f.close()


        
# yields token list for files specific to courts; needed for creating dictionaries
class texts:
    def DCDRC(self):
        return files_to_tokens('LegalAdhocTask/ConsumerCourtAdhocdata/DCDRC/**/*.txt')
    def NCDRC(self):
        return files_to_tokens('LegalAdhocTask/ConsumerCourtAdhocdata/NCDRC/**/*.txt')
    def SCDRC(self):
        return files_to_tokens('LegalAdhocTask/ConsumerCourtAdhocdata/SCDRC/**/*.txt')
    def DelhiHC(self):
        return files_to_tokens('LegalAdhocTask/SC-HCAdhocData/DelhiHC/**/*.txt')
    def JharkhandHC(self):
        return files_to_tokens('LegalAdhocTask/SC-HCAdhocData/JharkhandHC/**/*.txt')
    def JodhpurHC(self):
        return files_to_tokens('LegalAdhocTask/SC-HCAdhocData/JodhpurHC/**/*.txt')
    def KolkataHC(self):
        return files_to_tokens('LegalAdhocTask/SC-HCAdhocData/KolkataHC/**/*.txt')
    def SupremeCourt(self):
        return files_to_tokens('LegalAdhocTask/SC-HCAdhocData/SupremeCourt/**/*.txt')
    def everything(self):
        return chain(self.DCDRC(), self.NCDRC(), self.SCDRC(), self.DelhiHC(),
                     self.JharkhandHC(), self.JodhpurHC(), self.KolkataHC(), self.SupremeCourt())

# yields bow for each file - tuples id,fq ; needed to train models   
class my_corpus:    
    def DCDRC(self):
        for text in files_to_tokens('LegalAdhocTask/ConsumerCourtAdhocdata/DCDRC/*.txt'):
            yield dictionary.doc2bow(text)
    def NCDRC(self):
        for text in files_to_tokens('LegalAdhocTask/ConsumerCourtAdhocdata/NCDRC/**/*.txt'):
            yield dictionary.doc2bow(text)            
    def SCDRC(self):
        for text in files_to_tokens('LegalAdhocTask/ConsumerCourtAdhocdata/SCDRC/**/*.txt'):
            yield dictionary.doc2bow(text)
    def DelhiHC(self):
        for text in files_to_tokens('LegalAdhocTask/SC-HCAdhocData/DelhiHC/**/*.txt'):
            yield dictionary.doc2bow(text)
    def JharkhandHC(self):
        for text in files_to_tokens('LegalAdhocTask/SC-HCAdhocData/JharkhandHC/**/*.txt'):
            yield dictionary.doc2bow(text)
    def JodhpurHC(self):
        for text in  files_to_tokens('LegalAdhocTask/SC-HCAdhocData/JodhpurHC/**/*.txt'):
            yield dictionary.doc2bow(text)
    def KolkataHC(self):
        for text in  files_to_tokens('LegalAdhocTask/SC-HCAdhocData/KolkataHC/**/*.txt'):
            yield dictionary.doc2bow(text)
    def SupremeCourt(self):
        for text in  files_to_tokens('LegalAdhocTask/SC-HCAdhocData/SupremeCourt/**/*.txt'):
            yield dictionary.doc2bow(text)
    def everything(self):
        return chain(self.DCDRC(), self.NCDRC(), self.SCDRC(), self.DelhiHC(),
                     self.JharkhandHC(), self.JodhpurHC(), self.KolkataHC(), self.SupremeCourt())

# %%
filenames.index('ConsumerCourt_NCDRC_3506.txt')

# %%
# "yield" for each file return token list  i.e list of lists
def files_to_tokens(glob_filenames):
    glob_filenames = os.path.normpath(glob_filenames)
    for filename in sorted(glob2.glob(glob_filenames)):
        f = open(filename)
        # read the whole file as lowercase string
        string = (f.read()).lower()
        try:
            temp = word_tokenize(string)
        except:
            string = string.decode("latin-1")
            temp = word_tokenize(string)

        tokens = []
        # tokenize that string
        for word in temp:
            w =  only_alphabet(word).lower()
            if w not in en_stop:
                if w:
                    tokens.append(ps.stem(w))

        yield tokens
        f.close()

# %%
for x in files_to_tokens(full_filenames[1]):
    print x

# %%
T = texts()
dictionary_DCDRC = corpora.Dictionary(text for text in T.DCDRC())
dictionary_NCDRC = corpora.Dictionary(text for text in T.NCDRC())
dictionary_SCDRC = corpora.Dictionary(text for text in T.SCDRC())
dictionary_DelhiHC = corpora.Dictionary(text for text in T.DelhiHC())
dictionary_JharkhandHC = corpora.Dictionary(text for text in T.JharkhandHC())
dictionary_JodhpurHC = corpora.Dictionary(text for text in T.JodhpurHC())
dictionary_KolkataHC = corpora.Dictionary(text for text in T.KolkataHC())
dictionary_SupremeCourt = corpora.Dictionary(text for text in T.SupremeCourt())
# discard words occuring in less than 5 documents and in more than 50% 
dictionary_DCDRC.filter_extremes(keep_n=None)
dictionary_NCDRC.filter_extremes(keep_n=None) 
dictionary_SCDRC .filter_extremes(keep_n=None)
dictionary_DelhiHC.filter_extremes(keep_n=None) 
dictionary_JharkhandHC.filter_extremes(keep_n=None) 
dictionary_JodhpurHC.filter_extremes(keep_n=None) 
dictionary_KolkataHC.filter_extremes(keep_n=None) 
dictionary_SupremeCourt.filter_extremes(keep_n=None) 
# Merge all the dictionaries
dictionary = dictionary_DCDRC
dictionary.merge_with(dictionary_DelhiHC)
dictionary.merge_with(dictionary_NCDRC)
dictionary.merge_with(dictionary_SCDRC)
dictionary.merge_with(dictionary_SupremeCourt)
dictionary.merge_with(dictionary_JharkhandHC)
dictionary.merge_with(dictionary_JodhpurHC)
dictionary.merge_with(dictionary_KolkataHC)
dictionary.compactify()
# Out:
# 2018-04-28 02:14:44,406 : INFO : adding document #0 to Dictionary(0 unique tokens: [])
# 2018-04-28 02:23:40,312 : INFO : adding document #10000 to Dictionary(156686 unique tokens: [u'gudadannavar', u'alsocont', u'beencredit', u'delhifano', u'alsocons']...)
# 2018-04-28 02:31:17,069 : INFO : adding document #20000 to Dictionary(275694 unique tokens: [u'gudadannavar', u'falselitig', u'againstcomplain', u'ofday', u'boncer']...)
# 2018-04-28 02:38:17,381 : INFO : adding document #30000 to Dictionary(417266 unique tokens: [u'gudadannavar', u'boncer', u'metersand', u'hisclub', u'paizu']...)
# 2018-04-28 02:44:29,848 : INFO : adding document #40000 to Dictionary(581851 unique tokens: [u'gudadannavar', u'woodb', u'oldwhirlpool', u'atsugham', u'boncer']...)
# 2018-04-28 02:49:22,411 : INFO : adding document #50000 to Dictionary(679677 unique tokens: [u'gudadannavar', u'woodb', u'oldwhirlpool', u'atsugham', u'boncer']...)
# 2018-04-28 02:53:50,863 : INFO : adding document #60000 to Dictionary(782657 unique tokens: [u'oldwhirlpool', u'asstregistrarcoop', u'boncer', u'tenantvanish', u'pricepremium']...)
# 2018-04-28 02:57:41,513 : INFO : adding document #70000 to Dictionary(857981 unique tokens: [u'oldwhirlpool', u'asstregistrarcoop', u'boncer', u'tenantvanish', u'pricepremium']...)
# 2018-04-28 03:02:15,473 : INFO : adding document #80000 to Dictionary(944650 unique tokens: [u'mdbg', u'oldwhirlpool', u'asstregistrarcoop', u'boncer', u'tenantvanish']...)
# 2018-04-28 03:07:41,941 : INFO : adding document #90000 to Dictionary(1023454 unique tokens: [u'mdbg', u'oldwhirlpool', u'asstregistrarcoop', u'boncer', u'tenantvanish']...)
# 2018-04-28 03:13:57,993 : INFO : adding document #100000 to Dictionary(1125069 unique tokens: [u'mdbg', u'oldwhirlpool', u'asstregistrarcoop', u'boncer', u'tenantvanish']...)
# 2018-04-28 03:19:59,791 : INFO : adding document #110000 to Dictionary(1237289 unique tokens: [u'mdbg', u'oldwhirlpool', u'asstregistrarcoop', u'venkatapurshottam', u'boncer']...)
# 2018-04-28 03:24:21,672 : INFO : adding document #120000 to Dictionary(1274482 unique tokens: [u'mdbg', u'oldwhirlpool', u'asstregistrarcoop', u'venkatapurshottam', u'boncer']...)
# 2018-04-28 03:26:13,117 : INFO : built Dictionary(1288949 unique tokens: [u'mdbg', u'oldwhirlpool', u'asstregistrarcoop', u'venkatapurshottam', u'boncer']...) from 122895 documents (total 108791642 corpus positions)
# 2018-04-28 03:26:13,246 : INFO : adding document #0 to Dictionary(0 unique tokens: [])
# 2018-04-28 03:28:23,071 : INFO : built Dictionary(174969 unique tokens: [u'beencredit', u'vmunicip', u'beingcertif', u'fromdrrajendra', u'gavar']...) from 3484 documents (total 3417825 corpus positions)
# 2018-04-28 03:28:24,199 : INFO : adding document #0 to Dictionary(0 unique tokens: [])
# 2018-04-28 03:32:24,081 : INFO : adding document #10000 to Dictionary(78150 unique tokens: [u'advshrirvkulkarni', u'sonji', u'gavar', u'gavat', u'releasedsanct']...)
# 2018-04-28 03:35:59,994 : INFO : adding document #20000 to Dictionary(220409 unique tokens: [u'mrchandrabali', u'advshrirvkulkarni', u'woodi', u'gavar', u'gavas']...)
# 2018-04-28 03:39:19,992 : INFO : adding document #30000 to Dictionary(365330 unique tokens: [u'mrchandrabali', u'advshrirvkulkarni', u'woodi', u'pricepremium', u'ltdvill']...)
# 2018-04-28 03:43:51,424 : INFO : adding document #40000 to Dictionary(516963 unique tokens: [u'mrchandrabali', u'advshrirvkulkarni', u'woodi', u'theoryha', u'atjagarajup']...)
# 2018-04-28 03:48:30,340 : INFO : adding document #50000 to Dictionary(623079 unique tokens: [u'ofsterlis', u'mrchandrabali', u'isearth', u'advshrirvkulkarni', u'woodi']...)
# 2018-04-28 03:51:02,005 : INFO : built Dictionary(680527 unique tokens: [u'ofsterlis', u'mrchandrabali', u'isearth', u'advshrirvkulkarni', u'woodi']...) from 56745 documents (total 36136013 corpus positions)
# 2018-04-28 03:51:02,712 : INFO : adding document #0 to Dictionary(0 unique tokens: [])
# 2018-04-28 04:00:46,106 : INFO : adding document #10000 to Dictionary(88035 unique tokens: [u'circuitri', u'gangoor', u'sutain', u'cityvii', u'gavat']...)
# 2018-04-28 04:10:41,038 : INFO : adding document #20000 to Dictionary(133600 unique tokens: [u'circuitri', u'gangoor', u'vang', u'sutain', u'cityvii']...)
# 2018-04-28 04:20:08,221 : INFO : adding document #30000 to Dictionary(171166 unique tokens: [u'fawn', u'ramdhir', u'circuitri', u'gangoor', u'vang']...)
# 2018-04-28 04:23:52,004 : INFO : built Dictionary(185318 unique tokens: [u'gangoor', u'woodi', u'gavat', u'pricepremium', u'pawnor']...) from 34008 documents (total 45860848 corpus positions)
# 2018-04-28 04:23:53,622 : INFO : adding document #0 to Dictionary(0 unique tokens: [])
# 2018-04-28 04:26:42,628 : INFO : adding document #10000 to Dictionary(33411 unique tokens: [u'averma', u'indardeo', u'vani', u'gavan', u'petitionersborrow']...)
# 2018-04-28 04:27:48,618 : INFO : adding document #20000 to Dictionary(39257 unique tokens: [u'averma', u'indardeo', u'vani', u'polytechniqu', u'gavan']...)
# 2018-04-28 04:29:16,646 : INFO : adding document #30000 to Dictionary(45756 unique tokens: [u'ramdhir', u'averma', u'indardeo', u'vani', u'polytechniqu']...)
# 2018-04-28 04:30:55,699 : INFO : adding document #40000 to Dictionary(51657 unique tokens: [u'ramdhir', u'averma', u'indardeo', u'vani', u'polytechniqu']...)
# 2018-04-28 04:31:59,836 : INFO : adding document #50000 to Dictionary(55469 unique tokens: [u'ramdhir', u'averma', u'tajudeen', u'indardeo', u'vani']...)
# 2018-04-28 04:33:57,403 : INFO : adding document #60000 to Dictionary(61444 unique tokens: [u'ramdhir', u'averma', u'tajudeen', u'indardeo', u'vani']...)
# 2018-04-28 04:35:27,216 : INFO : adding document #70000 to Dictionary(66715 unique tokens: [u'ramdhir', u'averma', u'tajudeen', u'indardeo', u'vani']...)
# 2018-04-28 04:35:36,593 : INFO : built Dictionary(67204 unique tokens: [u'ramdhir', u'averma', u'tajudeen', u'indardeo', u'vani']...) from 71312 documents (total 15686880 corpus positions)
# 2018-04-28 04:35:37,255 : INFO : adding document #0 to Dictionary(0 unique tokens: [])
# 2018-04-28 04:38:48,215 : INFO : adding document #10000 to Dictionary(31061 unique tokens: [u'pricepremium', u'jagdip', u'ultimatley', u'lakhavi', u'jairam']...)
# 2018-04-28 04:42:04,155 : INFO : adding document #20000 to Dictionary(43380 unique tokens: [u'jaluram', u'pricepremium', u'asiswhereisbasi', u'jagdip', u'cmxcm']...)
# 2018-04-28 04:46:12,984 : INFO : adding document #30000 to Dictionary(57022 unique tokens: [u'superdiginama', u'conent', u'jaluram', u'gavat', u'pricepremium']...)
# 2018-04-28 04:47:14,764 : INFO : built Dictionary(59458 unique tokens: [u'superdiginama', u'conent', u'jaluram', u'gavat', u'pricepremium']...) from 32240 documents (total 16337844 corpus positions)
# 2018-04-28 04:47:14,836 : INFO : adding document #0 to Dictionary(0 unique tokens: [])
# 2018-04-28 04:48:51,838 : INFO : built Dictionary(28421 unique tokens: [u'noezi', u'tapodip', u'publicityori', u'jairam', u'scold']...) from 1210 documents (total 2365047 corpus positions)
# 2018-04-28 04:48:52,532 : INFO : adding document #0 to Dictionary(0 unique tokens: [])
# 2018-04-28 05:06:42,664 : INFO : adding document #10000 to Dictionary(162002 unique tokens: [u'insolventwheth', u'jaungipur', u'circuitri', u'vmunicip', u'jaluram']...)
# 2018-04-28 05:17:06,911 : INFO : adding document #20000 to Dictionary(226181 unique tokens: [u'insolventwheth', u'samul', u'vmunicip', u'jaluram', u'khirwar']...)
# 2018-04-28 05:27:50,247 : INFO : adding document #30000 to Dictionary(276341 unique tokens: [u'insolventwheth', u'samul', u'vmunicip', u'jaluram', u'khirwar']...)
# 2018-04-28 05:28:00,655 : INFO : built Dictionary(277112 unique tokens: [u'insolventwheth', u'samul', u'vmunicip', u'jaluram', u'khirwar']...) from 30091 documents (total 56132462 corpus positions)
# 2018-04-28 05:28:02,944 : INFO : discarding 1168433 tokens: [(u'act', 91288), (u'affidavit', 74648), (u'alleg', 72552), (u'allow', 64122), (u'also', 99311), (u'amount', 99291), (u'anandavalleeswaram', 3), (u'aryasala', 3), (u'can', 67431), (u'case', 110887)]...
# 2018-04-28 05:28:02,944 : INFO : keeping 120516 tokens which were in no less than 10 and no more than 61447 (=50.0%) documents
# 2018-04-28 05:28:03,625 : INFO : resulting dictionary: Dictionary(120516 unique tokens: [u'ksrinivasa', u'percopi', u'halagundi', u'ofbeneficiari', u'largeord']...)
# 2018-04-28 05:28:04,011 : INFO : discarding 162479 tokens: [(u'abbreviationsthi', 2), (u'aboveclaus', 2), (u'actuat', 5), (u'acv', 2), (u'advoc', 3311), (u'aircushion', 2), (u'alleg', 1807), (u'allow', 2349), (u'also', 3115), (u'alsocompens', 3)]...
# 2018-04-28 05:28:04,011 : INFO : keeping 12490 tokens which were in no less than 10 and no more than 1742 (=50.0%) documents
# 2018-04-28 05:28:04,082 : INFO : resulting dictionary: Dictionary(12490 unique tokens: [u'andfin', u'andfil', u'gavar', u'mohind', u'yellow']...)
# 2018-04-28 05:28:05,249 : INFO : discarding 623255 tokens: [(u'allow', 31187), (u'commiss', 49398), (u'complaint', 44019), (u'consum', 49081), (u'consumercourtscdrc', 56745), (u'cost', 39094), (u'date', 49475), (u'direct', 34922), (u'disput', 45192), (u'district', 45488)]...
# 2018-04-28 05:28:05,249 : INFO : keeping 57272 tokens which were in no less than 10 and no more than 28372 (=50.0%) documents
# 2018-04-28 05:28:05,564 : INFO : resulting dictionary: Dictionary(57272 unique tokens: [u'ksrinivasa', u'pathanan', u'gavat', u'pricepremium', u'hssaini']...)
# 2018-04-28 05:28:05,893 : INFO : discarding 159963 tokens: [(u'advoc', 25609), (u'allow', 28911), (u'appel', 18378), (u'coram', 32386), (u'court', 33986), (u'delhi', 33981), (u'delhihc', 28345), (u'digest', 21726), (u'doc', 34008), (u'docno', 34008)]...
# 2018-04-28 05:28:05,894 : INFO : keeping 25355 tokens which were in no less than 10 and no more than 17004 (=50.0%) documents
# 2018-04-28 05:28:05,985 : INFO : resulting dictionary: Dictionary(25355 unique tokens: [u'gag', u'jagdip', u'cmxcm', u'jairam', u'scold']...)
# 2018-04-28 05:28:06,095 : INFO : discarding 54563 tokens: [(u'coram', 69336), (u'counsel', 57869), (u'court', 71213), (u'date', 37161), (u'direct', 37078), (u'doc', 71312), (u'docno', 71312), (u'high', 71148), (u'honbl', 71191), (u'j', 70448)]...
# 2018-04-28 05:28:06,096 : INFO : keeping 12641 tokens which were in no less than 10 and no more than 35656 (=50.0%) documents
# 2018-04-28 05:28:06,126 : INFO : resulting dictionary: Dictionary(12641 unique tokens: [u'mohini', u'indranil', u'ramna', u'chandravanshi', u'mohind']...)
# 2018-04-28 05:28:06,213 : INFO : discarding 45080 tokens: [(u'case', 20056), (u'civil', 19346), (u'counsel', 26732), (u'court', 27561), (u'date', 31574), (u'doc', 32240), (u'docno', 32240), (u'fact', 16156), (u'heard', 16453), (u'high', 17620)]...
# 2018-04-28 05:28:06,213 : INFO : keeping 14378 tokens which were in no less than 10 and no more than 16120 (=50.0%) documents
# 2018-04-28 05:28:06,244 : INFO : resulting dictionary: Dictionary(14378 unique tokens: [u'mohini', u'succour', u'gavat', u'mohind', u'yellow']...)
# 2018-04-28 05:28:06,286 : INFO : discarding 23521 tokens: [(u'accept', 846), (u'accord', 969), (u'accordingli', 675), (u'act', 1085), (u'aforesaid', 710), (u'agre', 712), (u'air', 685), (u'alleg', 753), (u'allow', 883), (u'appeal', 851)]...
# 2018-04-28 05:28:06,286 : INFO : keeping 4900 tokens which were in no less than 10 and no more than 605 (=50.0%) documents
# 2018-04-28 05:28:06,300 : INFO : resulting dictionary: Dictionary(4900 unique tokens: [u'candidatur', u'dasadhikari', u'mohind', u'foul', u'four']...)
# 2018-04-28 05:28:06,761 : INFO : discarding 248951 tokens: [(u'accept', 17240), (u'accord', 20613), (u'accordingli', 18093), (u'act', 26203), (u'air', 15204), (u'allow', 22671), (u'allsop', 4), (u'also', 26741), (u'amp', 19169), (u'amroha', 8)]...
# 2018-04-28 05:28:06,762 : INFO : keeping 28161 tokens which were in no less than 10 and no more than 15045 (=50.0%) documents
# 2018-04-28 05:28:06,883 : INFO : resulting dictionary: Dictionary(28161 unique tokens: [u'gavat', u'pawnor', u'gag', u'jagdip', u'unautho']...)
# CPU times: user 3h 11min 57s, sys: 22.8 s, total: 3h 12min 20s
# Wall time: 3h 13min 25s

# %%
for x,y in dictionary.iteritems():
    if dictionary.dfs[x] < 25:
        print y, dictionary.dfs[x]
# Out:
# halagundi 23
# largeord 17
# pawnor 11
# circuitri 15
# unautho 23
# alsoconc 16
# gavad 19
# aboutsuch 20
# commissionchandigarh 12
# cardschem 15
# tomiss 10
# fordelet 17
# oneadvoc 10
# bstcbed 14
# malguzar 21
# mrrjkfkdkjh 22
# vihykfkhzifjoknh 11
# benefitsaccru 12
# filedfifteen 15
# visakhapatnamin 11
# smtsenehalata 12
# sendinga 15
# govinjol 21
# mrnsaravanan 10
# digambarmath 12
# appraisingth 15
# newspapersand 10
# neveravail 10
# kaushar 10
# kkdkj 10
# tumer 10
# gavan 11
# jamsar 11
# novemebr 10
# frederick 24
# forchildren 14
# ekkksiqja 16
# mrtajta 15
# ovkffkzd 14
# ajmermerwara 24
# ghalpuji 11
# complainantlastli 14
# therecogn 14
# shrijpagnihotri 12
# hesow 21
# mssapna 11
# complianceon 16
# pkaggarw 10
# supediwalabungalow 14
# bsknd 10
# saidfour 10
# lmh 22
# anycom 12
# otherdeal 12
# hencean 17
# garidi 16
# varietywestern 14
# sumwa 12
# tadep 20
# gulzarsingh 14
# itsspecif 14
# eachamount 11
# officedepart 11
# constjai 11
# forcours 18
# lastth 19
# kilaniya 10
# partiessanct 13
# liabilitya 18
# dnc 24
# liabilityh 11
# filedsuit 12
# saidmadhavilatha 12
# abelow 11
# vihyvkafkd 20
# wandra 14
# mrskverma 10
# pankajsharma 11
# kannankeri 10
# stealingelectr 22
# rdbangalor 18
# giju 11
# meteorologist 13
# besidesaffidavit 21
# kottai 19
# ninetysix 14
# orcheat 12
# getconnect 12
# releasehi 11
# vizagapatam 18
# ownershipand 12
# neverassoci 10
# maintainingminimum 10
# petitionerhospit 22
# whereasapp 10
# karurvysya 17
# gmohana 19
# manmodi 10
# wascontrol 22
# mrcasundaram 12
# andadvertis 20
# bottleto 10
# bottleth 13
# theirapp 10
# norplast 14
# bookto 18
# saidmanufactur 13
# retireda 11
# basavnyappa 23
# duniya 11
# gappul 10
# lindsey 14
# oldtil 15
# mrpnmohnani 17
# brochureattach 15
# nazmi 16
# theencumbr 20
# holdersmembersand 14
# favaour 16
# prodip 15
# gavisiddappa 10
# sede 17
# ajunior 12
# opscommit 22
# appellantscounsel 13
# vravi 16
# architectof 11
# mrbansal 12
# haveassess 11
# partypetition 16
# flusek 20
# inanticip 20
# dahal 11
# chandol 12
# kevfkdkjh 11
# complainantbeen 14
# treatmentonli 24
# kpc 10
# fiw 11
# fiu 13
# shriramc 22
# vsnkmodi 10
# ukwu 22
# vrushali 14
# basveshwar 12
# entireproperti 15
# effecta 10
# attainedth 13
# manjakkadpo 10
# lightcommerci 11
# charalingaiah 15
# citationsr 21
# voucheri 17
# sova 23
# dtapril 16
# srishivarama 10
# mdkerala 20
# barton 19
# bookingadv 11
# suppliedit 12
# wererecord 17
# lasubmit 15
# hospitalizationfor 20
# shdina 15
# superdar 15
# ppjpvfp 12
# abovebu 18
# yrmeena 16
# coimbatoreh 14
# distrit 17
# appearsth 15
# mustatil 13
# minimumrequir 20
# tcji 23
# remindedth 18
# boardingand 14
# onfac 11
# renad 13
# leelu 12
# fundorganis 13
# othermatt 16
# appellantsworkmen 13
# wellsubstanti 13
# keepretain 16
# hashowev 22
# masulipatam 16
# theaccompani 10
# whichotherwis 23
# adtiya 16
# arguedand 11
# wasscrutin 10
# expressionbranch 17
# advocatehad 13
# kaliganj 17
# tadkalkar 21
# ketanconsult 23
# misclassif 12
# problemwhil 10
# judicagtur 21
# poojan 12
# tenantund 11
# billsdt 13
# makthal 12
# dhlqfokk 10
# authorizedsurveyor 20
# tohotel 12
# interestcomplain 18
# psiec 13
# nathsharma 12
# urumbath 13
# depotii 10
# directorspartnersmemb 17
# remainingpay 23
# thirusbalasubramanian 15
# notsubject 21
# dharwadcnagendra 13
# dpoddar 22
# souvarsha 23
# proofin 20
# aphbcoloni 19
# mortgagedwith 15
# hingad 20
# hatkhola 16
# viscer 10
# hingan 13
# withoutreason 10
# gnagendra 10
# bhayandar 19
# variouscomplaint 15
# atmachilipatnam 13
# arrangementsettl 15
# practicinga 11
# sirtol 11
# annexurein 15
# becontain 10
# vgz 18
# vgt 17
# anyconsumpt 18
# statementalleg 11
# tonecessarili 19
# swagruha 12
# kariya 11
# encomium 11
# whichmet 22
# hadconvey 10
# kkdrkz 14
# lullanagar 10
# adiyoli 13
# nolr 10
# efgyklnl 12
# hishero 10
# dicken 10
# oneoccas 19
# karagudari 10
# pharwahi 12
# ownermanag 21
# thcase 12
# commonlaw 19
# preexistingil 24
# weresought 19
# ysaa 12
# agriculturistspurchas 15
# fqjjsliksmsav 18
# exbrepudi 19
# pallath 12
# dharshi 10
# ajayp 19
# lube 18
# sakila 13
# damageda 24
# defenceplea 13
# damagedh 11
# contravenedth 15
# onplain 16
# threefifth 11
# paramathivelur 23
# releasedonli 11
# xiva 15
# driveheavi 13
# saviker 12
# againopposit 10
# alsoseek 12
# twodriv 11
# formalitieswhich 10
# receiptsund 11
# punemumbai 22
# blifjokn 21
# issold 16
# perfunctorili 22
# notconvey 16
# moksha 10
# dishwash 10
# noticeeven 14
# inwidest 14
# pensionaccount 19
# acorrobor 10
# xvn 13
# lota 19
# ird 13
# irg 14
# subjudgeiv 10
# exrha 16
# nodlg 16
# ormateri 17
# pledgedjewel 13
# nodll 20
# backtoback 19
# nodlr 19
# punjabgovt 24
# allotteeof 10
# anyeffect 17
# substantialreason 11
# complainantthought 10
# foundsatisfactori 13
# purchasedgood 13
# obligationsand 15
# anddetect 14
# deliveryfrom 12
# uitdk 11
# tulshibhaisojitra 15
# thusconclud 22
# amardatt 10
# sitaraman 10
# preseizur 13
# ofrsrais 10
# niyx 10
# splappeal 20
# niya 11
# attigupp 11
# stategovt 17
# languageand 17
# yasoban 12
# alsoaccompani 12
# frp 15
# srigagopi 11
# appealrepresent 12
# andtransact 22
# backthi 10
# ldlid 19
# doubti 22
# jeon 16
# spic 21
# whichcompens 10
# uitdh 15
# mentioin 10
# jeof 10
# gauravbhardwaj 10
# certainsum 15
# bpentoji 13
# rmzlgf 21
# givenreport 15
# anybodili 15
# prasd 13
# damagefor 12
# mandhir 19
# henceal 13
# permittedth 14
# professionalli 23
# leftdat 11
# iatadgca 22
# australiaand 14
# watersewerag 13
# kayami 10
# videpropos 14
# deoband 12
# undertaketo 18
# tympani 12
# remani 14
# octpresid 20
# indescrib 20
# depositedfor 19
# dhalbhumgarh 23
# consumptionunit 10
# nohrf 17
# wakfalalaulad 16
# issak 10
# orderdeserv 15
# rejoinderagainst 13
# issay 12
# villagebut 24
# cetop 19
# nsusl 10
# justifiedadjust 10
# withcattl 13
# noonman 11
# hiscontribut 16
# zfbl 20
# neverment 11
# instructionno 22
# mayyil 23
# dtat 17
# examinationheld 18
# dksehvj 10
# ahvasanth 10
# kaliamman 14
# satnami 21
# hatli 12
# executinga 17
# haa 13
# hab 13
# hac 12
# had 10
# thedistforum 11
# shrisurend 13
# haw 21
# pgdipl 16
# atpanchayat 18
# issuebefor 22
# simhadrino 20
# facthowev 12
# toinspector 14
# dependsalso 15
# choyi 12
# objectionfor 23
# slipno 17
# barbitr 14
# newticket 11
# whoenter 14
# requirementsoth 18
# cpcaseno 14
# mgfland 11
# kskqi 20
# withlic 14
# againchang 13
# cglmhk 13
# dangwal 15
# untracedcertif 14
# cominginto 17
# optionform 10
# intentionallydelay 10
# thatpetit 13
# thestoppag 11
# thepspc 19
# underkisan 10
# toschedul 23
# hoovinayakanah 24
# shrikanwar 10
# specifiedbi 14
# ofmurd 17
# poboxno 20
# huddar 11
# mehidipatnam 10
# kshegd 14
# considerit 11
# estwick 10
# costsdu 10
# cumspeci 23
# constitutio 12
# acon 11
# alagesan 14
# acog 11
# boxwith 12
# ashlar 20
# btulsi 20
# managerchief 15
# dadahu 14
# dyson 10
# wasexempt 13
# abdulhamid 10
# deceasedsmt 11
# chairmanmanagingdirectorprincip 24
# shridinkar 13
# reghunathan 23
# timewith 24
# lohgaon 18
# facilityprovid 22
# mainswitch 18
# universityi 23
# muchwat 14
# continuedthereaft 17
# universitya 11
# discloseal 16
# hissever 13
# universityv 10
# itemand 13
# gwa 22
# executedinters 10
# kanjur 12
# mubarikpur 13
# shirsath 24
# bifrund 10
# policyreviv 23
# reportwheth 10
# marodia 11
# redressali 14
# rstaken 14
# borstal 21
# fctuksj 19
# onlyopposit 20
# ritta 10
# isko 20
# actpast 11
# keptcomplain 14
# withfev 10
# sameapart 10
# iskk 22
# bodyth 13
# needbas 14
# isnkokj 22
# liabilitywhen 10
# sambasivam 13
# winnerof 10
# hiraben 12
# alsonev 15
# tfzlb 24
# smtsurind 22
# documentexhr 19
# kumbalagodu 16
# beenind 24
# ofwindow 13
# mtfgm 10
# devendradand 10
# wontedli 15
# hemiarthroplasti 14
# mrdcmathur 15
# chikkusappa 17
# replacethos 11
# stoppedfurth 12
# sarapancha 10
# sripraveen 18
# hundredthirti 22
# yeshwanthpura 19
# thechain 14
# bhimaji 14
# transferredchang 18
# illegallyon 10
# hazaribaghrespond 10
# thechair 13
# ingroup 10
# orsubstanti 10
# referredcas 15
# bharatiairtel 11
# bouncingof 18
# modifyingelimin 20
# gotthi 10
# raghuveera 14
# factsrequir 23
# machi 23
# amitmitt 24
# remainingargu 10
# ajmerbikan 14
# gloomi 15
# blackwood 15
# kaibarta 11
# goodrel 11
# prizemoney 13
# acknowledgmentfor 16
# sareewa 12
# skewer 17
# fmsf 10
# rdatar 13
# besummarili 12
# glaringexampl 10
# hnof 14
# loansinclud 10
# fnuk 13
# oftv 23
# interesttoward 20
# centralmarket 10
# layoutulsoor 20
# remainunchalleng 13
# securityin 15
# ofbreak 19
# earliertreat 16
# zru 21
# dnom 11
# generalin 10
# conductedaft 10
# julena 12
# paidanoth 14
# jitin 18
# forathu 18
# fyqkq 18
# appellantpseb 13
# apartmentfor 16
# actualphys 13
# shardhananddubey 16
# paymentbasi 15
# jabbaral 11
# fisheriescumceo 24
# ipkrifjoknh 15
# torespondentcomplain 10
# kazhakkoottam 10
# studentwho 11
# kuanur 12
# gulistan 12
# embodiedin 15
# bigam 10
# chillycrop 23
# pulivendula 23
# autocentr 17
# nobodycan 10
# passengershav 10
# koorkkancheri 11
# itselfthi 12
# fkkukfkdkjh 13
# chella 18
# lingambudhi 15
# wvi 15
# welloff 18
# palakol 14
# causedheavi 15
# kbalasubramanyam 16
# srinivasapur 18
# rangement 22
# aredon 14
# fmvsyl 12
# proximityif 15
# mrjinsiwal 13
# santagudipadu 13
# manufacturerin 12
# asnorm 11
# waspertin 13
# hkkxzo 14
# reportnor 11
# reportnot 16
# howe 10
# mistakeor 17
# mistakeon 15
# bagsand 11
# concocteddocu 13
# beforedecid 22
# inkollu 14
# thippa 14
# ftmfoizqksfctuksj 14
# takingforc 13
# heardm 18
# theshutt 24
# aforum 22
# sublimit 14
# aphys 15
# throughprocess 19
# plotsmeasur 10
# mallaya 13
# lineswer 10
# substandardc 24
# nonministeri 15
# casescit 12
# achines 17
# umrer 13
# exabunch 10
# respondentamount 17
# returnedit 18
# constitutesth 12
# datestamp 12
# eklaux 17
# andcommerc 11
# properlyaccount 13
# jig 11
# sktalwar 12
# jim 10
# receivedat 14
# jiw 11
# tulu 18
# latabai 13
# druveekarana 10
# occurwithin 18
# terminii 14
# bedevil 10
# taliti 10
# meharchand 13
# didi 21
# shharwind 11
# tohealth 16
# foragainst 21
# shameer 23
# parshottamda 10
# suppliedvari 10
# opsrightli 12
# shyamcharan 10
# andipatti 10
# furtherdisclos 24
# commissionwherein 10
# theninform 12
# sarangpur 23
# fsnariman 15
# manufacturerboth 11
# nfzm 19
# falselyimpl 17
# complainantrespondentand 12
# ahelpless 11
# servicessuch 20
# cardappl 19
# replaceda 15
# sidana 23
# apic 12
# eightinstal 15
# andnotifi 13
# thattractor 14
# warrantyclaim 13
# servicebranch 24
# palanc 13
# paland 23
# pkanungo 11
# pksfk 16
# fixedand 17
# revivalschem 11
# acrecalcul 15
# sbojha 11
# subregist 19
# filecopi 17
# whosefield 19
# hamen 11
# pharmacyth 12
# hamer 12
# bafana 16
# quitecontrari 21
# blameth 14
# ifaft 18
# thiscov 12
# gunrockenclav 10
# pensionpap 16
# lncome 17
# policyrel 16
# firmhad 20
# veerbhadra 18
# legalclaim 15
# intermarriag 10
# sahayogi 20
# topress 10
# medisaf 18
# minakshirana 17
# hemaram 21
# andthoroughli 18
# nonaffiliateto 15
# remainsuncontrovert 11
# cerebra 14
# iscompens 22
# sellingit 13
# awaypromis 16
# timepromissori 15
# naturewould 15
# complaintparticularli 13
# aoconcern 13
# rootcaus 10
# ghanauli 20
# febrauri 13
# boxin 15
# usingatm 10
# nowhat 10
# nevertook 20
# sundarpahari 10
# studentswer 14
# thepun 10
# eveninspit 17
# underlock 10
# alongwithcrop 10
# benakanakatti 11
# narindersharma 11
# rnnanjundappa 12
# nirmata 13
# ljpomzd 19
# thatsuffer 11
# kabuliat 14
# thesequest 14
# squalor 17
# sesmast 10
# vivad 18
# vkxkehfcyksa 11
# itselffrom 10
# rathnakaran 17
# talwandibhai 16
# incrop 19
# rknk 20
# entrieswer 15
# opguilti 21
# noncommiss 22
# troublewhil 18
# wyne 13
# millerganj 23
# aimlessli 10
# closeddu 11
# versionaffidavit 14
# jurisdictiontribun 20
# raziqu 18
# personalti 12
# srissudarshan 23
# gaveanoth 13
# assetsproperti 14
# noticeop 16
# etcetera 11
# mrjparora 22
# gaggar 18
# thenonapplicantrespond 12
# advvmanikantan 14
# policydecis 20
# respondentdefendantten 15
# issueclear 20
# panchet 13
# tncooper 12
# nbgbodfmc 10
# noroom 13
# maintabl 11
# himassur 10
# versionther 10
# vallikkattil 23
# versionthey 14
# kritan 24
# meerpur 11
# indirangar 17
# lukhnow 19
# fincorpltd 10
# objectionsha 10
# withund 12
# motiveof 12
# afterwithdraw 21
# herepeatedli 17
# mshkghuman 10
# pgddqv 11
# jvsdeora 10
# bylighten 18
# beenshift 18
# feltpain 13
# haveev 11
# noworth 13
# advdskulkarni 13
# underservic 12
# incouncil 11
# maheswarareddi 10
# jwelleri 12
# uou 13
# aryanad 10
# ekursgsa 11
# offuel 19
# khajoor 13
# fdmdr 18
# ofchand 11
# recordalongwith 15
# huggi 10
# questionadmittedli 11
# indoubt 11
# stockinsur 11
# atala 10
# proceedingstherefor 18
# wirebi 12
# opponentproduc 15
# transferabsorpt 13
# jdauit 12
# thesustain 10
# uitjda 13
# rajalaxmida 17
# anddepend 23
# monetarybenefit 13
# ofhimself 17
# fortransmiss 17
# nagorao 23
# encumbranc 10
# chassisand 10
# prayingcompens 18
# mrrnsahay 11
# delaytherefor 18
# photon 21
# mrgmkhan 12
# gwf 16
# oflici 14
# readingi 11
# readingd 10
# withoutcaus 13
# stoodtil 12
# lawauthor 15
# opplac 17
# orallyargu 10
# aspot 11
# thatapprov 11
# toauction 21
# hastal 11
# becommerci 10
# tolaboratori 22
# weresever 14
# sriraj 13
# bbxv 15
# cheatth 14
# beenrevis 21
# aiiai 11
# ordeclin 10
# counsil 15
# appellantsh 23
# cubicl 12
# theorissa 11
# thetransferor 12
# outdu 11
# afdr 17
# otta 10
# atproddatur 10
# mvvasudeva 10
# fairenough 12
# energycount 13
# gulbargaagainst 17
# onlyshow 11
# sksa 11
# zdze 13
# deadth 15
# spchengalvaraya 19
# effecti 11
# contemplat 15
# ofinject 23
# canecrop 12
# correctfact 15
# pradyuman 10
# gulnar 19
# roadto 16
# insa 12
# theverdict 17
# problemon 14
# butperus 11
# gwz 16
# theftar 11
# followingcondit 23
# shivak 19
# cctvfootag 10
# being 11
# localityof 24
# norcdaia 10
# narayanchowdhuri 12
# anappoint 18
# savlaram 16
# roadpassag 14
# obtainingpm 13
# voucherd 22
# soramachandran 12
# itsobject 15
# goodstransport 11
# butsuppl 17
# lwpuknh 10
# tounfairtradepractic 10
# beforeput 14
# makingcomplaint 14
# preferringthi 16
# yashwanthpur 10
# zion 20
# werepromptli 13
# stenographertranscrib 20
# remco 17
# inadvertentlyth 11
# unesco 16
# palkar 21
# allegationregard 19
# beenexclud 13
# globalcompens 14
# obliquemot 17
# billalong 11
# presentcomplainantar 23
# establishtheir 24
# notobey 14
# suchdeduct 18
# gajjar 22
# firmdeal 15
# suchschem 21
# fivediffer 10
# bahgirath 16
# nojodh 10
# informedon 15
# applicationst 13
# thesamsung 20
# ftmfoizqk 13
# applicationsd 10
# documentsfurnish 23
# mishraw 17
# mishrav 19
# disciplinaryact 17
# carbook 12
# conditiontherefor 22
# beliefthat 20
# sanadhaya 13
# berestrict 16
# assignmentof 17
# partysworkshop 11
# thusopposit 21
# thatsoon 17
# consideringfact 10
# wassatisfactori 18
# calso 19
# aazslav 11
# chequebefor 14
# storeand 11
# oppbjmarket 23
# informantopno 10
# anyremark 10
# tqdistdhul 13
# formund 21
# meetha 24
# foradministr 16
# followingquest 17
# yif 12
# mrvinayak 20
# kbasavarajappa 24
# sealer 18
# rangarajapuram 15
# thebrick 18
# pathalil 20
# beenhir 15
# suchdocumentari 22
# lakshmik 12
# vuqeksfnr 10
# withstandinganyth 14
# wassuspect 11
# totalperiod 11
# corporationin 14
# sarif 24
# sarig 17
# subramonian 10
# kanjhawla 19
# cannotassum 14
# sukhani 14
# raga 17
# surveyorshould 12
# ragi 21
# sufferirrepar 10
# reachedbetween 13
# modifiedand 11
# bhubaneswarto 10
# bhubaneswarth 14
# appellantregard 11
# requiredinterest 15
# ssaspal 11
# furtherassist 11
# watcher 11
# soodan 15
# distrib 11
# mediumtal 13
# wlgf 21
# acompound 17
# bajaja 10
# mmadhusudhanreddi 10
# valiya 14
# ambalathara 17
# doctorcertif 19
# koninklijk 11
# troubleth 11
# unlawfuland 24
# durgapuri 23
# mahndiyan 21
# terraceroof 11
# finallyh 17
# wasborrow 10
# certificatesar 20
# mythili 19
# sopanrao 12
# orsect 16
# koppam 11
# golei 21
# shoppunia 12
# lienand 12
# bansjor 10
# plusregard 11
# baugh 21
# inconcaten 21
# jayaramappa 15
# versuspardeep 10
# hanumana 21
# qutubullapur 12
# saidoutstand 23
# corporateaffair 10
# budhar 15
# norr 20
# holambi 21
# orderupon 12
# norb 13
# norg 12
# nork 11
# remedybi 18
# norl 13
# medininagar 17
# expato 13
# avimaladevi 21
# pmahesh 10
# hmqfl 11
# complainantsinvest 16
# policecumchairman 10
# yeshpal 19
# loanpropos 11
# achuthanpillai 12
# ltdunder 10
# dayor 15
# yearguarante 20
# debitedon 11
# willrectifi 12
# opcal 14
# opcam 18
# dhabal 16
# dhaban 13
# getlitig 10
# abbott 18
# financiercontend 10
# varioustim 10
# ofbu 15
# sarra 13
# thepreop 20
# gangannavar 17
# areharass 24
# leiz 20
# ladakh 10
# noncler 10
# cuttackon 13
# hasl 24
# hash 20
# completedtrain 11
# partymani 15
# rsshown 20
# hass 16
# kheraj 16
# elaborateor 10
# ascalcul 20
# motijheel 12
# indupl 17
# andblock 12
# periodif 10
# livelihoodon 11
# auchandi 18
# wifenomine 13
# ranojirao 13
# societyarchitect 13
# remittedbi 16
# vizkfkhzi 14
# detailsgiven 20
# theyintim 11
# lossesincur 15
# morh 20
# gdeshmukh 16
# automati 11
# mora 18
# jagesha 24
# mentionedmithu 24
# ngujjarappa 12
# sundarnagar 10
# dfyl 18
# lsigi 11
# tomaximum 13
# patriarch 16
# muttemap 16
# centreha 11
# ipcbefor 12
# actaccordingli 24
# ogfoi 10
# mukadma 13
# uponan 10
# mrprabhash 18
# illnessth 10
# byalih 15
# thego 11
# meha 10
# lesotho 13
# irxyambn 16
# asundetect 15
# alianc 12
# aforesaidobject 18
# dhgh 10
# committedord 10
# kzfudkyk 18
# liabilitywil 11
# inrepossess 12
# minathirath 11
# vle 11
# veerraju 17
# intimationon 11
# complaintalong 15
# fractureinjuri 11
# forfollowup 10
# assailedbi 10
# licenceon 11
# hatkanangl 20
# msvenkataramanapesticid 10
# veeresham 11
# khoshbagan 13
# complainantaccompani 20
# ofwheat 18
# oraffect 18
# subsequentpay 16
# avermentsalso 11
# roshi 11
# ahmednagr 24
# mpstatecommiss 16
# bajajfin 19
# remarksinsuffici 10
# dictatedin 11
# availani 13
# newinsur 11
# startedin 17
# collectsth 10
# didthey 10
# bycarri 17
# specificallyinform 18
# discussfurth 13
# nowe 13
# whichevermay 10
# iatkcuskuy 17
# susant 11
# inpatientand 12
# andprompt 18
# courseb 10
# haldhar 16
# thispara 15
# fromdisplay 12
# coursei 17
# hisstock 10
# autocraci 15
# bothin 16
# udagan 23
# mgdevihosur 12
# licensebear 11
# sudarshab 15
# blenat 13
# wasfloat 13
# appellantj 10
# shridev 12
# anuradhaest 11
# appellants 12
# havedebit 15
# toactual 20
# sinceparti 12
# dhanasekar 20
# currentyear 11
# dhanabagyam 11
# werequest 12
# lipstick 13
# jagadindra 11
# dnfvm 24
# otherconsequenti 18
# ezhil 19
# issuerevis 15
# alldiseas 13
# watertap 13
# andnotif 12
# staterep 10
# ipopposit 21
# lbsc 11
# defectiveaft 24
# awid 24
# shereport 11
# pointsand 24
# negligencewhil 11
# rajkotbranch 22
# goparatnam 16
# csadvkwq 22
# thefair 16
# trawler 16
# furthercorrobor 15
# redemptionand 10
# hissaria 18
# gurgaonharyana 24
# pspo 10
# saina 11
# nomf 22
# nomg 19
# nome 12
# nomk 12
# nomn 10
# nomo 18
# noml 22
# settlementvouch 13
# nomv 24
# thereft 12
# suchattitud 14
# gotanalyz 14
# issuedcattl 17
# gutheppa 15
# msenthilkumar 15
# shimbhu 18
# wayleav 23
# sbbl 16
# radhakisan 22
# vkoafvrfd 16
# santoshrani 10
# forfjr 23
# purposehowev 15
# stayinjunct 23
# parishat 17
# applianceor 10
# parishar 13
# thirthappa 23
# suchwa 12
# advisefrom 14
# cehqu 14
# loanoff 14
# gettingelectr 21
# kbabu 19
# fortelephon 12
# pendingdispos 14
# displayproblem 13
# waterus 12
# shrirajan 13
# pattani 11
# baluchistan 23
# engineervisit 19
# arunachalbuild 16
# officersdo 13
# kodiveettil 22
# edachira 11
# tosomeon 20
# hawasingh 12
# hospitalhav 13
# gaveinstruct 13
# nedumaran 12
# bmpatil 10
# devgan 24
# berepay 10
# imkslh 23
# consumerhimself 12
# vhroad 11
# upgradationpromot 17
# bypresid 20
# onretir 11
# evh 13
# otherdirect 16
# andeventu 15
# qualifyingselect 10
# causeharass 10
# blender 14
# losswith 11
# andassert 21
# asurpris 19
# vehiclegav 10
# ofadopt 14
# golpark 10
# okth 15
# drprabha 13
# abalakrishna 17
# shaniwarpeth 11
# nabadwip 20
# endeavourinsur 12
# saidadmiss 16
# optionalbasi 10
# todishonour 19
# shrijawalkar 13
# suchsuppli 17
# aruppukottai 12
# anyadmiss 14
# electroplast 19
# jkkk 15
# sectb 14
# ofretain 22
# settlementbetween 16
# secti 11
# kanhar 10
# gotverifi 22
# djksyha 16
# servedani 11
# dhayani 13
# thatregist 16
# normalwork 10
# pershrisgdeshmukh 24
# notelephon 11
# maheshwaram 21
# partyjogind 12
# ansalh 10
# itselfon 10
# theymight 10
# tsulht 12
# bonafideand 22
# vuyyuru 18
# ccimmedi 18
# intimationth 23
# shankarsingh 10
# vemulap 11
# regardingservic 12
# wifebut 10
# kovilakam 18
# vicker 11
# keralapuram 21
# registrationwa 15
# properlybut 22
# nangla 12
# whocommit 15
# perinstal 16
# purchasedpacket 15
# sugarand 10
# nayyer 14
# khilar 11
# msaksinha 14
# getprop 12
# ravindu 14
# koratageretaluk 16
# presentposit 10
# dozer 16
# altogetherdiffer 18
# thatneglig 13
# coursefrom 13
# kerimattah 10
# centralrailway 22
# xenm 24
# palaksha 16
# acrequint 11
# andmotiv 12
# bramakrishna 20
# theinterior 19
# glloxlizl 13
# ageat 11
# nrk 17
# allegationlevel 24
# nro 13
# aerospac 14
# utimutu 13
# yearseven 11
# notechn 23
# electricti 17
# chester 13
# reputedinstitut 10
# tmtpvr 22
# subtractsometh 12
# conceit 11
# somethird 11
# penologist 12
# fromncmsl 16
# lief 14
# bhundawat 12
# bytelephon 11
# gangadevi 18
# ahemedabad 10
# byprofession 10
# sattigudi 15
# arumuga 17
# andguid 21
# accountsbear 11
# tkldrha 11
# ofdepositpay 12
# abovefactor 20
# omnisci 11
# ltdb 15
# lluhdf 14
# ltde 10
# ltdf 12
# cumbam 11
# basavannaiah 18
# ukfer 11
# komala 22
# tyrewith 11
# knm 11
# knh 16
# regionalhealth 15
# directlyth 11
# kng 21
# knc 13
# manureand 13
# indraprashta 10
# riddhi 12
# societiesth 13
# thefard 12
# salvo 10
# unsatur 11
# perspicac 12
# tkldk 10
# krnagar 22
# alsocontinu 10
# kewalsingh 19
# jjnagar 14
# bhiwanithrough 15
# skaggarw 18
# privatecomplaint 19
# thesedetail 15
# propertyit 10
# phonebear 18
# supportthi 10
# amountfinanc 13
# allowedbut 11
# bijjalappa 10
# vgx 11
# ljlorh 10
# mrpof 13
# khui 18
# vkjdsvksaxkor 20
# aschool 18
# usmijksdr 23
# excso 11
# lsifjokfn 13
# indriv 11
# cjthese 19
# subdistributor 18
# crescendo 11
# theator 17
# aspetition 11
# ksbhullar 10
# mahadevpet 16
# mideast 14
# dubaiand 12
# basdeo 18
# thesubpost 24
# partpart 18
# supplementsand 15
# kirlampudi 24
# rajendera 12
# theinstitutionunivers 14
# trisun 24
# policydetail 14
# waterchannel 13
# wasreadmit 17
# fordiabet 19
# dhanunjay 23
# complainantselect 12
# xviib 12
# unfortunateev 12
# cinemaroad 11
# defencetend 13
# delhixi 10
# psbindra 21
# sangharsh 24
# thedisclosur 15
# escoot 10
# voterslist 10
# zfblg 18
# notifiedbi 15
# raicar 15
# whosepres 22
# budyappa 23
# distnayagarh 21
# katip 11
# inti 14
# kjkfufezr 11
# justicevb 20
# lotsat 16
# nagamaiah 22
# entertainedand 15
# negligencewhich 10
# mrpkprasad 10
# annexh 15
# othercompet 12
# videotap 11
# bradford 19
# wholepurpos 13
# hospitalizationtreat 20
# handsethad 12
# transmissionregard 10
# noninsur 18
# encroache 23
# documentsno 10
# istranspir 16
# etccaus 17
# witnessto 12
# witnessth 12
# ministerin 11
# informedimmedi 22
# edappilli 11
# mrsunni 11
# srianantha 24
# advld 11
# maskati 10
# bhoyar 16
# herproperti 10
# committedgross 11
# initiateact 12
# sradhakrishna 12
# gamhariya 10
# alnanjundaraja 22
# againfail 14
# productionreceipt 15
# chiefoffic 11
# representedbefor 10
# creditedon 15
# soundararajan 15
# kaup 13
# ofbharat 15
# ijesfjv 11
# apartmentsin 11
# maycaus 20
# requisitionto 15
# orlawy 12
# intendedpurchas 14
# exceptin 23
# pgpm 21
# workshopfor 18
# saseendran 22
# salipur 14
# manchala 11
# vukan 14
# damagedburnt 21
# compensationne 12
# suchstep 12
# anyshow 12
# firdriv 11
# sincecommon 18
# comploain 11
# dmbn 21
# dhallek 10
# informedh 24
# udaykumar 24
# asenhanc 12
# thoppu 16
# withmultipl 14
# takehi 10
# istic 10
# unforseen 11
# careltd 11
# manavalagan 13
# limbaji 11
# customerscomplain 19
# partycancel 12
# patientcam 11
# tribunaliii 14
# byassign 12
# distancebetween 17
# dodmanicgudleppa 15
# hajira 18
# opnofail 11
# brushasid 10
# layingdown 13
# showwheth 14
# fdrofr 12
# salima 10
# oszf 22
# saidqueri 14
# willrec 22
# waslittl 15
# justifiableand 13
# hadrun 23
# weretransport 16
# roomrent 20
# pershrivgjoshi 17
# videmembership 16
# telephonein 13
# pranjnalaya 17
# vkkkfjrg 11
# videh 14
# motherth 13
# nmr 23
# videa 15
# foryour 18
# withfilthi 19
# atraiganj 22
# jayaw 15
# chargesdamag 10
# respondentrdopposit 13
# ljsmj 13
# theirremedi 12
# bhagvan 10
# nargi 10
# beendetect 11
# becommenc 23
# pruthvisecur 12
# hadrepossess 11
# mussel 10
# pathsalashiksha 14
# jvvnltd 13
# rive 22
# saidlic 13
# saidlif 10
# thesoft 23
# permitcondit 15
# saidlin 14
# commercialestablish 17
# exanew 10
# printerwa 16
# hedgenagar 17
# forsometim 20
# kashifco 17
# beinginterlink 18
# mijksdrfu 10
# labourwork 10
# pff 10
# inlimit 10
# pensioan 11
# aschandiok 18
# woodifield 10
# filesth 11
# limitedground 10
# hadseiz 14
# mrrkbishnoi 11
# partyinterest 21
# thesestat 17
# towith 20
# havingservic 12
# absentcomplaint 24
# singhghangha 19
# dulystamp 14
# opbankfor 11
# makkhan 23
# leftfoot 10
# baisinga 11
# levelth 10
# claimassess 12
# theinabl 15
# jcseth 11
# eurekaforb 17
# smtshobhna 10
# areconduct 16
# comedk 22
# doubtther 10
# collegeit 10
# suz 10
# mekhri 16
# panchkulaand 10
# gurumoorthi 13
# maldabranch 15
# hislearn 10
# thebeverag 10
# printingsuch 16
# actwithout 10
# courierag 13
# goodsat 13
# skilledprofession 24
# shmsbhatia 22
# getloan 10
# bnda 11
# tobaccobarn 15
# yaravinda 21
# devichand 10
# mjd 20
# gksvksj 16
# badnam 12
# revn 16
# rebari 19
# kanaiyal 18
# houston 24
# salsett 10
# pkdeomani 13
# radauri 10
# whatrat 23
# appollohospit 21
# hernioplasti 15
# lakhiram 11
# yearloane 13
# samuktala 12
# chsahoo 11
# suchail 14
# toreconcil 12
# overat 12
# butstat 23
# pkkashyap 13
# fagad 16
# loanimmedi 11
# noninform 15
# penaltiesund 15
# wemodifi 11
# crossbharathi 20
# ofbad 10
# sesam 17
# booki 21
# tothen 15
# actwil 19
# givingliberti 11
# coarismt 17
# aroom 14
# againstm 18
# inse 16
# signand 10
# plausiblereason 19
# learnedaddit 24
# maruthia 23
# issuedbut 20
# wajib 10
# atpodistdhenkan 13
# haseffect 12
# prepara 24
# trustworthyevid 23
# aforesaidcomplaint 22
# growthfund 21
# partiesremov 13
# kumaraggarw 13
# unwieldi 13
# sincebegin 24
# hisgrand 18
# registar 12
# unnao 24
# perashok 13
# creditinvoic 11
# chikkamagalur 18
# andmischiev 11
# acknowledgementdt 18
# fivedocu 13
# samediseas 22
# ofkishor 10
# balancecharg 10
# billsextc 13
# ordiffer 24
# articless 11
# sameop 10
# sameor 18
# mausa 24
# agriculturerur 24
# limitationto 12
# involvedi 10
# hll 11
# herfinanci 13
# khkhkhkh 23
# havingsign 12
# medicinespurchas 10
# chandubhai 11
# fujlrhdjk 17
# complainantsvisit 17
# specificplead 11
# matterrequir 12
# interestb 18
# fewhour 15
# ikoyhdk 14
# roofterrac 12
# devoutli 17
# twon 10
# buokbl 10
# detailsthereof 14
# rajarajeshwarinagar 17
# bankingauthor 14
# ltdcontest 13
# rightinterest 11
# bandhana 16
# mrbhawesh 23
# hasther 10
# principalsubordin 11
# andessenti 17
# sudish 20
# asidein 15
# mrssmita 16
# matia 12
# dugha 11
# collectionreceipt 10
# disassembl 11
# strainand 19
# atin 16
# monetarytransact 11
# agreementregard 13
# mahendroo 18
# shallhandov 13
# srama 22
# mumbaibranch 13
# claimedthrough 10
# consumersinterest 20
# manof 11
# dkdguk 13
# chauki 10
# manon 10
# ksjk 19
# manualof 21
# havesuccess 17
# statingabout 11
# dhozlifnlgf 22
# wellbuilt 11
# makean 17
# dkstfj 11
# kuravankonam 17
# deliveryrun 10
# nodisconnect 17
# innegoti 12
# ofmukhtiar 13
# fgsfzdf 19
# repudiationon 15
# peari 13
# acceptingdeposit 16
# andbar 17
# marthah 20
# jagvind 16
# ofthrob 13
# preparedestim 12
# jdsingh 17
# timingbelt 10
# loada 11
# illegaldeduct 10
# misappropriationof 23
# purchs 16
# documentsboth 20
# completelyapplic 12
# theirmembership 23
# paymentsinc 23
# srimanoj 11
# consumerstherefor 12
# jsliksumsuvu 16
# abbi 14
# supplementaryestim 22
# faceth 14
# theseevid 22
# nallalam 10
# adavanc 18
# aei 10
# aeh 23
# ofjalandhar 13
# hanuw 23
# sixtythre 12
# driverat 14
# allperson 10
# yldin 11
# hasallegedli 18
# pssharma 12
# pindira 14
# natura 11
# carewa 15
# thatsomebodi 22
# ahibhushand 11
# thiruldeenadayalan 18
# urmar 19
# pensionarybenefit 18
# membranc 16
# mcwg 18
# favourbut 18
# waslook 15
# areimport 15
# allegedse 12
# ofhyundai 21
# repairsa 16
# otherfin 13
# otherfil 15
# nomenclatureof 10
# oncea 24
# permanentemploye 11
# onceh 10
# orgauhati 10
# nonrectifi 10
# raniwada 10
# renderjustic 16
# gendal 18
# kesarkar 15
# saidintim 12
# marti 23
# committeeha 20
# shgurjit 18
# czkapesustj 13
# isthen 15
# mahanand 17
# pklayout 11
# adangalpahani 17
# kavinmoola 15
# dysuria 11
# oxen 13
# entitlr 11
# subhasnagar 14
# thatgood 13
# mshimalaya 10
# workedonli 11
# keepinggood 12
# andless 12
# niyantran 15
# feather 17
# sufferedexpart 11
# kaha 22
# bcamp 21
# blightobserv 14
# cheruthana 17
# bdcc 17
# bynon 11
# sokallappa 14
# kalling 10
# cvv 15
# complainantutkur 10
# cvr 11
# cvp 13
# cvm 11
# cvh 16
# nonarriv 11
# cvd 17
# rbd 11
# teacherand 12
# brothersin 10
# pjfranci 10
# brepli 17
# srisushil 13
# ckcrizkfkzuk 19
# thepetitionersappel 16
# agricultureunivers 22
# disb 14
# gurbaxsingh 21
# ishrat 20
# givingsever 12
# nonclearanceand 22
# factsnot 17
# divniii 11
# interdependentand 10
# skmahajan 10
# achala 18
# ofconsci 12
# ofe 20
# ofi 15
# ofn 11
# ofo 11
# ofl 22
# salereceipt 12
# ofw 16
# itsvari 11
# ofx 11
# vishweshwarayya 11
# liableif 11
# liablein 23
# andseizur 19
# occupationalneglig 18
# rulesord 17
# nosub 19
# connectiontransferredchang 11
# mschhabra 13
# jagitialand 20
# enlight 13
# notaffili 11
# justicethi 12
# technet 10
# jktx 16
# ysfdubl 19
# complainantinvok 24
# nosum 17
# rentalagr 11
# panchawati 10
# principaldirector 12
# chinchwadgaon 10
# anyfraudul 17
# ghasiram 20
# deedto 13
# gsrqvihykavl 17
# settingsxmlpki 20
# chowgan 15
# hearriv 10
# sprain 18
# freshpropos 20
# jjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjj 17
# specifiedtim 20
# producedcertifi 14
# muralidharar 22
# assetsand 18
# cknifjokfnuh 14
# plaintschedul 14
# badakh 10
# gudla 16
# venkatreddi 11
# afternegoti 21
# theaeaeexen 11
# gorappa 17
# bullow 20
# esiph 24
# andobvi 23
# jalappa 10
# acceptedto 24
# manta 11
# agreementinvolv 12
# localdeal 15
# kharat 23
# sofara 16
# notconsist 23
# roadrur 17
# offeredani 13
# offeredand 10
# somemisunderstand 12
# withpropos 13
# fre 12
# thendefinit 15
# guruteg 12
# shrisantosh 16
# cameron 14
# isunexception 17
# wasforg 22
# letterp 16
# sifynet 11
# districton 11
# correctbut 12
# absolvedof 12
# letterb 15
# povenkitangu 10
# dphani 11
# forintegr 16
# herleg 19
# badabazar 12
# warrantyservic 23
# ofaccommod 20
# hypoecho 12
# kalighat 22
# munaswami 10
# manpreetkaur 10
# independentexpert 11
# fru 11
# goodsoth 14
# khadappa 24
# fromwhat 18
# thayannur 14
# shnkgupta 12
# sukalyani 11
# mansoori 12
# pthulasipathi 11
# refrigeratorth 22
# chequehowev 12
# mundhra 19
# refrigeratorto 19
# nofraud 12
# lksingla 23
# bhambu 24
# ofsdo 19
# baloon 10
# aboveplea 10
# datethat 11
# filibust 14
# puttheir 13
# iestat 16
# personallyrequest 11
# technicalplea 12
# srmt 12
# circularand 10
# inflect 12
# contributionof 11
# bholi 12
# bhupathi 10
# crosscut 13
# whileproceed 15
# shrinivasa 14
# casesccomplain 10
# drivein 10
# repairfrom 10
# syllabl 22
# competi 19
# alsocredit 13
# ndnovemb 21
# policecommission 10
# subjudgevi 20
# damodara 12
# katwaria 12
# technocommerci 14
# cbicum 13
# cutan 11
# deviah 13
# bibek 11
# iswrongli 21
# fromappear 10
# opcomplet 21
# fatheruncl 12
# singhalm 12
# voyksdul 16
# afterallot 17
# ofappellantcomplain 12
# afterallow 14
# installmentwhich 13
# acwith 16
# advspchandran 11
# cmj 13
# cme 12
# bhupalp 13
# separatenotic 10
# casecommenc 10
# healthylif 15
# petitionrepresent 21
# companyst 12
# rectifyreplac 13
# machineh 11
# fathersh 23
# surpura 10
# feescharg 21
# shyamasundar 23
# ramamohan 20
# tawar 13
# companyso 13
# mruthyunjaya 11
# jessica 11
# feevid 22
# deducteda 19
# andde 13
# drshenoy 21
# barredu 10
# sardargarh 11
# effectivelicens 12
# tehsilanandpur 13
# tehsiljagraon 12
# raneadvoc 10
# availedh 11
# lesss 17
# mahindratractor 20
# partytherein 10
# shpsghuman 11
# richest 12
# redcross 13
# grhegd 14
# impliedlyassur 24
# qilla 13
# hanker 11
# otteri 11
# succeedsin 18
# gandharba 11
# atmatur 16
# moneycollect 15
# lostbaggag 16
# pkwatra 16
# thequart 24
# pendentilit 22
# advsrisreghukumar 14
# tosmt 21
# percal 16
# propertyfor 18
# mukavva 10
# telecomdepart 22
# brj 14
# bri 23
# accountsend 10
# hascov 20
# jgmk 11
# programmefrom 11
# exactd 17
# thatmachin 20
# thewpno 19
# judgmentswhich 18
# rfkkvihykfkhzxk 23
# dkmvj 10
# jayshreeyeng 12
# whosesignatur 10
# thetruste 14
# meetout 13
# gbrg 15
# execas 16
# taufeequ 20
# theirwhim 17
# mather 19
# mrfranci 14
# johdpur 20
# tnu 24
# kondiram 13
# tnr 13
# thresiamma 12
# tng 16
# engineerxen 13
# erc 14
# tnl 12
# tni 13
# tnh 12
# tnk 14
# bundelkhand 15
# oppoisteparti 19
# hallikh 10
# interestaccord 14
# repol 15
# jlsfz 10
# kirtinagar 20
# adlibitum 15
# asaccount 17
# andsimultan 18
# mayseek 11
# hameedfrontlin 20
# mahanandano 20
# barew 10
# navjeet 11
# nothappen 18
# oflin 15
# pssundaram 13
# ardhendu 10
# mpk 12
# indiaguid 11
# excwould 13
# shanawaz 10
# vera 13
# vasi 17
# onadvic 10
# manchikoppavsoppon 23
# whichmark 11
# limitationund 24
# furtherprocess 16
# forconvert 11
# cardetc 15
# hono 11
# tookher 16
# satyasai 15
# registrarand 12
# parra 10
# nsfn 20
# daysotherwis 11
# andthiev 20
# fjmzli 13
# hkkxhnkjh 11
# adhiktam 12
# gramaswami 12
# bajpaye 10
# levelbest 23
# sahaya 16
# srandhawa 13
# claimedlitig 11
# jurispru 19
# kotireddi 10
# ofranjit 14
# energyfor 20
# koilstreet 12
# agriculturalresearch 24
# bama 14
# paidhenc 18
# upit 22
# failureomiss 10
# personstravel 22
# jhunjhunwalla 23
# rajitha 18
# gkbzfczm 15
# isexoner 12
# suggestiveof 11
# persepar 11
# cashdd 14
# espac 13
# includinginsur 17
# keshvanand 21
# electricitytherefor 11
# sojoseph 19
# substitutesfor 16
# canttroad 11
# ruleshav 10
# orarbitrari 13
# pmroad 19
# dischargedaft 12
# fornext 18
# dabirudin 14
# krshivashankar 13
# refiq 12
# colortek 11
# cbisit 12
# mersey 20
# explainedabov 11
# striation 21
# dischargingthi 10
# inasu 15
# aclandestin 10
# jacubpura 16
# ofdecid 10
# expressedthat 16
# andmost 22
# smtramjot 22
# mlbansal 18
# toschool 11
# smtsharada 13
# auspi 18
# kotkapuracoop 10
# sultanpet 19
# presentnatur 17
# vanquish 19
# jaikishan 14
# authorizedrepair 12
# chandigarhbut 18
# deces 10
# zalki 16
# formextop 10
# sompura 21
# shsita 24
# nomii 17
# preexistingwhen 14
# faridabadand 19
# ldcivil 11
# withinnorm 11
# werepersuad 15
# mellitusand 20
# calcuttaand 23
# staffwith 11
# chackochan 22
# thatvari 21
# switchingoff 12
# ngocoloni 14
# givenhim 17
# msneerja 10
# entireprocess 12
# puransingh 14
# earlierthi 17
# mranup 14
# dalia 14
# indiasal 22
# occupationand 14
# msgoyal 20
# certainlythi 10
# wvlz 15
# itmoreov 14
# interdistrict 14
# srajendran 18
# yudhisht 15
# nosdat 10
# dsvnk 14
# thereafterno 12
# kurnooland 21
# gurikara 11
# repairedin 18
# saidwithdraw 14
# nohpth 19
# wasrath 10
# acknowledgementa 10
# twoloan 21
# pwafdifjokfnuh 12
# channaiah 10
# goldpolici 14
# agedyr 19
# cronic 23
# senioradvoc 13
# swamp 21
# outanyth 10
# ctdvr 10
# reserva 24
# chhaila 20
# followingpetition 17
# membermemberpres 19
# andfurnitur 10
# lyingat 15
# thataverag 18
# thediabet 16
# evenoff 19
# yahoocom 22
# opoppos 18
# ajudhia 19
# bankconcern 16
# somefault 10
# pqu 11
# opsubsequ 14
# providerund 11
# partyadopt 14
# devadiga 16
# alagapuram 23
# itbeen 23
# emg 13
# cgmt 17
# slpatankar 13
# emm 22
# gsatk 15
# herpropos 16
# emt 12
# mentionedreason 10
# buffalocov 13
# indemnifyingth 10
# statedherein 11
# dhanwant 11
# nandish 16
# aseat 16
# dzzjaz 12
# krihna 10
# postsand 12
# drraghavendra 17
# anambul 19
# reportdid 13
# claimprocess 10
# parishkruthi 21
# chopada 15
# introductionof 10
# sovenkatarayudu 13
# okfilfi 19
# notwithstandingani 11
# cablenetwork 15
# thesolar 15
# rliax 16
# inrectifi 14
# shriprabhakar 10
# sheenfin 16
# hak 11
# successfulon 12
# pointsaros 19
# knockedth 10
# kkgiqjk 21
# mrmithilesh 11
# viuskifk 13
# customerno 17
# nallur 16
# mrksriniva 13
# abdullapur 23
# anismin 23
# beethnok 18
# onemotor 12
# skmehta 11
# tong 11
# codon 15
# newmotor 13
# partyschool 16
# tworoom 16
# forumdistconsum 13
# colonydodda 20
# regardcan 13
# askedop 11
# bishu 24
# mjid 12
# exarepresent 11
# arefix 10
# forreinspect 13
# sulesh 13
# bishi 10
# fopnsan 15
# responsibleoffici 12
# harjindra 11
# appellantsat 11
# courtcit 14
# jhuh 22
# jhun 19
# theweak 10
# ghisul 19
# shobhakar 17
# andinstrument 18
# shribabu 10
# pmfrom 16
# thehumanitarian 11
# xrayof 13
# hadtheir 15
# narkhed 15
# ofenjoy 16
# receivinglett 14
# cison 15
# setit 20
# sumoto 15
# shlabh 21
# stipula 16
# allotteescomplain 12
# discomfortand 10
# videoconcompani 10
# submittedand 23
# islaps 21
# andsolv 13
# thirunavukkarasu 24
# gujarathousng 15
# processingand 15
# applicantfor 11
# anuat 11
# quebecor 23
# receiptund 24
# anandadv 12
# mrdeshpand 12
# departmentit 15
# theirjurisdict 14
# ritualscontinu 11
# goliwada 20
# victimsassoci 13
# departmentin 20
# rocobsmulimani 11
# mrsmaji 22
# qkbuy 20
# gsrqfnukad 16
# bendich 15
# projectcost 10
# chequecollect 11
# coomar 11
# qualifiedand 12
# alongwithterm 12
# sojagadeeshwaraiah 10
# simranjit 12
# ummadi 23
# ordinarypost 23
# koklkata 21
# usinghi 20
# hadaward 12
# ipdn 13
# sriksriniva 11
# furtherconstruct 18
# miz 14
# foulsmel 11
# smtkistoori 22
# gulbargahad 12
# ipdv 10
# saidapur 11
# bmrajashekaraiah 11
# vehicledeliveri 13
# lsku 11
# mrsurend 19
# kunnumpurathu 13
# nimbhel 10
# unirrigatedth 13
# againwith 10
# bhangi 19
# slavish 21
# vehicleexcept 10
# bhanga 11
# installmentwith 10
# sparsh 13
# highlydoubt 10
# harikrupa 13
# properappreci 13
# wrongfact 19
# varadarajulu 10
# inconsistencyin 14
# arafa 23
# exbtcalongwith 14
# theymust 20
# vittala 22
# againstiano 18
# representedstandard 16
# valuableright 16
# sakhadar 20
# yourlett 16
# weturn 24
# forforeclosur 10
# alsofeel 24
# sanchalan 17
# scholl 11
# hospitalizationof 17
# sanchalak 14
# theirtelephon 10
# usedunauthor 13
# stayedth 24
# sainiadvoc 10
# rashnessor 13
# jensher 10
# submittedrelev 18
# indianlimit 10
# nawdiha 10
# opiv 16
# societyregist 21
# juneth 15
# isstipul 12
# jherhehuk 13
# gadr 12
# shskmonga 21
# aunder 20
# regardingnonpay 14
# msomanohar 17
# nsmtjmi 11
# cheepurup 20
# telecal 14
# mangerof 11
# ubremma 10
# areacropcalcul 19
# lavag 14
# andrisk 10
# snmmbn 10
# tribunalhigh 14
# ancil 18
# isclaus 10
# frill 11
# fdaccount 12
# respondand 12
# gotstolen 11
# grantedcompens 11
# angamm 12
# shallcomplet 24
# gavhan 12
# recordfor 19
# courtsappel 19
# machra 13
# tcil 11
# basusab 14
# fnyhi 18
# ecgc 10
# shrameshwar 10
# isil 11
# secratori 15
# governmentschem 15
# vwn 17
# deceasedconsum 10
# jurisdictionassail 14
# kumawathno 17
# xiia 18
# vwa 10
# hasdebit 19
# revealth 20
# divoffic 17
# bellanakereccomplain 15
# rmpt 12
# herhowev 12
# desireto 16
# tibber 13
# perlampadi 12
# eachpremium 16
# karnatakain 20
# fruitsand 13
# pleasefind 10
# affidavitsar 10
# anythingon 13
# assailedth 15
# fdlhchekjh 10
# billcumnotic 19
# gobbl 10
# hyperthropathi 12
# farmerlik 10
# mdid 10
# chprabhakar 13
# meritit 11
# instrumentand 14
# meritij 12
# sschalam 12
# janarogya 10
# constit 19
# couldproduc 17
# mandip 20
# procedurefollow 17
# actiondecis 13
# usifjokfnuh 13
# irregularitycommit 14
# shivayogaiah 24
# semesteritself 10
# ftldsfi 22
# gigi 16
# neitherreplac 10
# meddlesom 22
# loanwhich 20
# allegedoccurr 16
# wasclassifi 10
# bysribvbasavaraj 10
# sritmravishankar 13
# ofkm 11
# dfclli 16
# kanjaiah 17
# chargescharg 13
# jurisdictionar 18
# notificationno 14
# replyrespond 16
# undisputeddocu 20
# injunctionwa 10
# guu 10
# amounttaken 16
# underspeci 24
# srdivmanag 11
# imroz 10
# towardspolici 22
# shshailend 12
# managercum 12
# westernsid 12
# standtransf 10
# heract 10
# barbil 15
# thecog 18
# wre 12
# suchdefault 14
# coeffici 13
# forheavi 10
# healthcumevalu 14
# ekkaduthang 16
# rajabagicha 11
# arecategor 11
# suchrul 15
# tablish 15
# chqeue 15
# ccomplainantskrushnappa 10
# figgi 10
# sampathnagar 12
# uzi 11
# suribranch 11
# uksmi 10
# registrationnohpb 15
# andregistrar 17
# mckenna 14
# permitgr 12
# aprecondit 20
# pvg 10
# andlot 13
# bndathathreya 18
# dhannaram 20
# tmlfinanci 11
# mrkksenthilkumar 24
# ushkh 17
# totalconsumpt 19
# tosho 13
# sanctimoni 10
# arealon 20
# thoroughexamin 17
# foroverhaul 14
# pksfkh 16
# apcsact 19
# dermatologist 24
# distyavatm 16
# orail 11
# thirumsaravanakumar 19
# kasan 11
# forumforthwith 11
# producednotar 14
# trand 10
# trane 11
# nominatedth 15
# yielddata 10
# kasat 12
# srikaprakash 11
# culat 19
# prepag 12
# mazza 10
# thrustinglitig 14
# vihykavifjoknhu 13
# koorkkencheri 24
# vehiclestop 14
# snbvxm 10
# dlz 24
# haveinsur 21
# seekcancel 15
# vikasa 15
# manycondit 13
# ismanag 24
# undercurr 13
# shripmkulkarni 14
# froud 23
# cwherea 21
# tegbahadur 12
# nibro 14
# nagalla 12
# sheexpir 14
# babichenvgeorg 19
# becomesdifficult 11
# nakshatra 14
# panavila 24
# pergener 15
# advsubodh 12
# aforesaidconnect 15
# sonyericson 13
# advarchana 10
# nospeci 20
# sixthday 15
# hediscontinu 11
# nogiven 10
# suemoto 10
# refundedalong 11
# ukkadam 16
# gistrat 11
# kazakhstan 21
# obtainnecessari 10
# zerois 16
# mamtha 11
# complainantsabout 15
# anddodg 10
# hagargi 11
# ejacul 18
# mangoo 10
# hadinstal 24
# byact 18
# damnifi 17
# noraj 14
# norat 18
# beingn 18
# mentaldepress 10
# europetour 10
# respectivepay 14
# critiqu 10
# vpnk 15
# chopd 11
# increaseth 14
# sjlg 23
# cect 18
# paidalong 21
# paperbut 11
# mayappli 10
# teststh 12
# samesimilar 10
# whilenarr 14
# severalremaind 10
# statementexbtr 13
# disputedposit 23
# mbp 23
# krjain 12
# epjpkd 15
# managerceo 11
# areoth 12
# avv 23
# partychang 15
# carstreet 11
# joiningemploye 10
# wrongdirect 15
# nowopposit 23
# shmanu 22
# excelsior 11
# coinag 14
# constructedin 15
# sabbir 18
# interestapart 16
# mohammadganj 18
# outcri 21
# aswella 15
# sritashok 16
# notest 15
# checkingcomplain 11
# ahcpss 19
# itssub 11
# fabrik 10
# monththen 12
# noticedin 15
# svcomplex 22
# noticedid 18
# hisfault 13
# ajmervidhyut 12
# andforeign 11
# theyneith 14
# afterperform 12
# returnit 14
# rajimwal 17
# hegganah 13
# giveinstruct 19
# flooradmeasur 11
# beeninadvert 12
# thirummurugesan 10
# pandeyv 21
# andground 20
# vdrl 13
# bajp 24
# yhxbz 19
# districtforumx 15
# haveagain 11
# bajo 10
# kumaranallur 11
# accounthav 11
# appellantndopposit 17
# orhypertens 16
# applel 10
# accounthad 11
# annexseri 11
# gajendragad 13
# burmashel 11
# jabbarpension 11
# beattract 10
# ayyannanavar 10
# mrramakrishna 10
# amountvoluntarili 11
# monthbi 10
# remainedunansw 12
# versionstat 22
# hesecur 14
# mrsjyoti 17
# receivedinterest 17
# bassipathana 24
# neversold 12
# neverattend 21
# educationin 14
# newpolic 11
# somebil 10
# nazeeruddinno 20
# ofcmc 10
# badmash 11
# neki 10
# partiessuch 10
# werespect 12
# nameetak 12
# balugaon 16
# jodhur 20
# rsstand 16
# ghola 20
# earlieralso 18
# getdon 12
# saidissu 18
# chequespres 12
# holidaypackag 13
# buccertif 12
# jamatraj 10
# littlemor 10
# atbalurghat 12
# chhattisgarhst 19
# vessal 11
# duvvasi 10
# magistratefirstclass 15
# disttmuktsar 18
# mortemwa 18
# immediaterepair 12
# flatbut 15
# wasnon 12
# berhamporedivision 13
# notclos 24
# whilea 12
# expensesinclud 23
# selfstat 23
# garagefor 10
# continuingcaus 24
# approxi 10
# vehicledeliv 20
# anunnatur 15
# zyjfgf 15
# revolvesround 13
# courtvid 23
# chettyar 14
# pdjose 13
# adamson 11
# towardswhich 22
# derivingwrong 20
# seatin 21
# historywa 12
# lancashir 13
# constitutedth 15
# assessorof 10
# smtshantabai 15
# insuranceadvis 18
# electronicclear 16
# mobileinstru 19
# shrnsaini 10
# raisedaft 14
# batteryha 14
# wereverifi 14
# illegalconstruct 14
# alternativeaccommod 12
# blockdj 17
# lieagainst 11
# prakosth 19
# chargeor 10
# dnolig 19
# chargeov 12
# sadhuwala 19
# nila 17
# schemeinstructionsaft 10
# fojkskkhkk 19
# dharwadc 18
# bkpandey 22
# chargeon 12
# creptin 14
# parkmediclaim 11
# repeatedth 16
# brata 13
# hvg 22
# tgkwa 24
# shrsrangpuri 19
# complainantssb 14
# khasijaintia 12
# sharmaadv 11
# stx 15
# anyadulter 11
# approvedand 17
# ofconcept 14
# acompli 12
# divisionalbranch 15
# nandwana 15
# weekaft 13
# vascoda 10
# inproduct 10
# amicuscuri 10
# whichcas 19
# bhatwari 10
# explanationappend 16
# mkjg 17
# rajnit 10
# kantimath 10
# enjoyingelectr 13
# itemsto 12
# bipen 10
# itemsth 18
# hercompens 13
# asindustri 22
# padayachi 19
# takingcogniz 10
# thestorm 10
# afterexplain 18
# alsoparticip 12
# spooner 22
# assigningreason 13
# immoder 11
# redressala 13
# duerespect 15
# deceasedor 11
# thisentir 15
# investigationabout 11
# hislevel 16
# alreadyrepudi 11
# kardam 13
# horticulturebefor 21
# biass 10
# ofderiv 12
# dkizekk 14
# mssun 11
# acdl 11
# rubbernylonplast 14
# sogangappa 11
# afores 12
# muchaft 20
# givenbefor 16
# methodadopt 22
# caseref 20
# factabout 19
# accidentaccord 17
# hesuppli 22
# vnew 20
# shrajmat 17
# abandonedth 16
# haswil 20
# lichfl 13
# surethat 17
# havedischarg 23
# whenalreadi 16
# mechanicsengin 12
# rappa 23
# kecheri 15
# neon 22
# mlwith 14
# datesa 10
# vaidyan 13
# alreadycollect 18
# runningon 11
# pestonji 23
# kantam 22
# datesh 16
# keeperschief 15
# kiranam 13
# keshavarao 23
# submtit 17
# jacobmatthew 11
# sukriti 18
# memoinvoic 15
# havingalreadi 12
# respevid 14
# chitspvt 12
# ifkdr 20
# dhanani 18
# wherebya 10
# offorgeri 11
# blhansaria 12
# unwrought 13
# standslaps 10
# ofappearnc 16
# onperson 16
# theworkmanship 12
# thattechn 10
# continuouslyand 13
# cholamandalaminvest 17
# iranna 20
# tookhi 20
# haral 16
# orinterfer 11
# tricuspid 10
# madapp 15
# roshancoop 10
# mpsrtc 12
# bydd 12
# fofkuqlkj 17
# plantationsand 21
# fjvuz 16
# plici 13
# propertyoppon 10
# thetrack 16
# warangaland 15
# chargesment 14
# verbat 15
# aiadmk 12
# suchinact 20
# investigatorof 18
# kaiser 10
# takhta 11
# documentscannot 12
# yeval 23
# faianoand 12
# bodyar 15
# driverrespond 14
# nabagram 19
# aquif 10
# laltu 19
# oorguam 11
# haveeasili 11
# aquit 12
# complainantremit 19
# aquir 11
# promug 19
# partyrefund 22
# innocentperson 10
# byacknowledg 12
# advmpramod 14
# palma 13
# receivecancel 11
# shkkbagai 14
# omission 10
# mannheim 20
# tudor 22
# krpet 16
# commissionamount 16
# documentexhp 17
# kindperus 12
# allahabadup 17
# haveserv 15
# apromot 15
# practicesand 12
# mohanachandran 12
# thefactsaver 17
# exaha 11
# marili 22
# whichvers 11
# counselsappear 14
# activitiesin 16
# neib 19
# mldkdksbz 13
# fullydescrib 15
# pitcher 12
# rgopala 20
# greatemphasi 24
# jdsrespond 16
# mahra 14
# enchash 24
# agentappear 16
# scheduledd 11
# reimbursementclaim 12
# gazi 23
# vihykfkhzvfkodrk 16
# ludhianathat 17
# madeinspect 20
# bctripathi 11
# nopost 19
# kottacheri 23
# counterbal 14
# collg 13
# bhargwa 10
# opsitu 10
# lightin 19
# garriag 20
# tkapizfrosnu 22
# initiallyand 18
# rulingsfact 13
# electricityvoltag 16
# stateif 11
# intactand 14
# statein 17
# vkctoszkal 11
# bulu 13
# cropto 13
# evidencenor 14
# hasvari 21
# byspeci 16
# mrmsnaikadvoc 15
# theallur 16
# suppliedonli 10
# corer 11
# andprematur 23
# mrramkalyansharma 10
# toshould 10
# kanjli 11
# fnuesa 13
# ceaser 10
# whetheroppon 19
# vishweshwaraya 12
# receivingbal 13
# moneytherefor 10
# bandhbah 18
# roomshal 14
# wmz 11
# wmr 14
# wmp 24
# decidingtelephonedisput 12
# complainantaffidavit 18
# wmi 12
# vyasmr 18
# recoveryoffic 22
# specialexclus 14
# hjfanfzl 14
# sreekrishnapuram 12
# okndjk 10
# distinctfrom 10
# deathcomplain 14
# directeda 11
# waverli 12
# recordlett 13
# relevantconnect 10
# tononjoin 18
# courtapp 16
# abmotor 20
# seriousproblem 13
# bhagyashri 23
# tgupta 10
# popsdistboudhcomplain 13
# jordanand 10
# shchetan 12
# fdrsamount 20
# rsunfortun 16
# dslosz 12
# ishita 15
# manjusre 10
# cproduc 22
# issuedbefor 11
# advsanjay 16
# munisiff 11
# corpm 16
# thattamala 10
# lulla 12
# matho 12
# doneanyth 10
# mohannair 11
# shriravi 24
# policymean 13
# gvschalapathi 14
# trajashekharaiah 22
# fromoppparti 24
# kumarmishra 14
# opintend 12
# implementingag 13
# theatric 12
# krishnakali 12
# dune 22
# opintent 19
# catalys 12
# sabarw 22
# bosaria 13
# prlayout 10
# sreelakshmi 23
# rbith 11
# programmeth 16
# raushan 18
# thesefacil 20
# tofraudul 11
# bigjo 11
# singhhold 12
# registerfor 12
# jrg 14
# mrssjodha 22
# receivedto 10
# thesethi 12
# deniedindemnif 10
# pmadhava 11
# addenda 12
# ithappen 17
# intergovernment 18
# regioncumindustri 15
# feyl 14
# datedfor 18
# thegujarat 20
# andmotor 21
# mathu 13
# cceven 15
# hanner 14
# barthakur 15
# slgfv 10
# accountexr 13
# uterusand 17
# quantumdisput 13
# chellam 11
# accountexa 16
# hannen 11
# accountexc 15
# capacitya 21
# nrama 18
# partnerand 10
# examinationbi 12
# courtsand 24
# vksoj 24
# noticethereof 13
# mlsrinivasa 13
# abneg 24
# regulationact 19
# nanjundeshwara 12
# vikascoloni 17
# goneth 19
# munsifcourt 11
# thirusashanmugavel 10
# theftwhich 10
# underquest 10
# agrahar 15
# complainantenjoy 15
# shsatyawan 17
# ddaflat 22
# wereadjust 17
# carwhil 12
# professionalmisconduct 13
# takesuit 20
# singaiah 12
# trafficpolic 20
# lalkj 20
# foiqi 14
# reoccurr 19
# ofhandwrit 11
# withoutverif 22
# asroad 10
# sbtempl 10
# haveforward 20
# abovedetail 20
# dksizsf 17
# gsrqvkosnu 22
# assurancesand 15
# repudiatedfor 11
# policeno 11
# ofautomobil 12
# alsohi 20
# singleton 18
# whowould 15
# toutter 12
# sutli 10
# maddipadu 14
# furtherexa 11
# inchit 17
# wasbread 13
# policynoc 10
# mentionedcomplaint 10
# differen 22
# againsthir 15
# jayaprabha 14
# rehta 11
# afzalpur 23
# aravindnagar 11
# rehti 10
# onwardtransmiss 18
# thatex 12
# allegedcomplaintdismissedh 23
# fairi 12
# technicalinstitut 13
# hourah 20
# hadduli 20
# tkrsg 13
# acharyya 11
# papermil 11
# hedeserv 10
# hkkxhnkj 18
# seizingth 24
# udumbannoor 12
# cicata 10
# cvcigp 15
# picup 22
# kumbarpet 13
# abbasi 13
# ceejay 10
# msmanpreet 16
# hawrah 16
# srimekala 17
# finallycomplain 12
# advsskalkura 21
# appellantindustri 15
# earnr 17
# somdev 15
# complainantvac 10
# tononsettl 12
# cooki 11
# hedaya 12
# contemplationof 10
# dwpradeepkumarpv 13
# mchandra 10
# bepossess 12
# sixteenthday 10
# brahmpur 18
# rsmtanita 10
# arepostpon 16
# ssnagaral 23
# towardsnotic 12
# gayatrinagar 18
# aadhar 12
# unmix 11
# semilibanchasukumar 24
# saquib 12
# jkttfj 13
# orapprov 23
# gopiram 14
# thirunurugan 13
# podiabidhan 24
# himha 22
# hislawy 15
# himhi 18
# lovepreet 13
# bhuvaneswarinagar 20
# basav 18
# postwhich 10
# insurerag 14
# basar 14
# chandigarhconsum 20
# itempow 20
# agriculturistsand 14
# rawl 15
# muthyal 15
# towarr 11
# assessmentshal 10
# dbagd 10
# annaram 11
# namasivaya 11
# inadmit 14
# rcrcrimin 24
# organo 20
# modystreet 14
# hasaffirm 13
# urcoopcrsocieti 13
# morgu 12
# jamwant 17
# partiesacknowledg 10
# adrift 11
# beinginform 22
# returnfrom 15
# complainantobvi 18
# wasunmarri 13
# repliedand 10
# wentinto 12
# tisement 19
# unimpeachableevid 15
# opsingharia 23
# urgedin 18
# ramalingaiah 12
# serviceshir 23
# sghi 15
# sdoassist 14
# informationwhich 12
# indiainfolin 11
# mrashvini 21
# allegedpurchas 12
# syan 19
# themselvesregist 12
# videexsa 10
# hasalway 15
# holdon 13
# stepfor 12
# firersist 15
# feecomplain 11
# complaintsno 14
# bairappa 23
# pleadedand 15
# depositorsissu 10
# governemnt 22
# dkxksz 12
# hsbhangu 12
# sectorundertak 12
# decadesth 12
# nvenkatachala 10
# whichcommenc 24
# aliroad 15
# ownersinclud 10
# vakalburgi 11
# renewalpolici 12
# painsuff 12
# createdon 12
# divisionsub 15
# countryplan 18
# bhayend 10
# allegedfir 13
# unfurnish 12
# payvalu 13
# mantralayam 13
# transactionmad 14
# shakgupta 20
# supportthat 10
# hype 14
# rsrana 10
# rinform 14
# throughprop 18
# dhuda 18
# bpressur 11
# causingcoloss 13
# srisdkulkarni 11
# delug 24
# hampappa 23
# judgmentstand 14
# plazast 11
# connectiontherefor 20
# afterattain 22
# thatexcess 23
# karnatakah 19
# kpbpxi 20
# complainantjaya 12
# ofquarterli 11
# fjrsnkj 14
# holdingeffect 14
# anddishonour 12
# amountapart 11
# withstemroot 23
# karuppasami 10
# advkdhananjayan 18
# partygiven 13
# bikeand 14
# butagainst 10
# estimatedvalu 18
# doneup 14
# thecoupl 10
# andhimself 20
# eenadutelugu 11
# gursagar 24
# forsuit 10
# skjha 15
# consentedfor 13
# partyjd 10
# krishnagrameena 12
# venkatapathi 24
# ultimatelyfat 10
# temmemb 10
# proton 10
# certificatesproduc 11
# complaintsuff 12
# shankarapuram 19
# respectwa 17
# srirgopala 17
# bolani 18
# mrajaya 10
# ofsetoff 14
# governmentfor 23
# kalasogi 23
# tqtuljapur 22
# sudra 23
# providerof 21
# wrongentri 20
# besatisfactorili 20
# studentsadmit 10
# observationth 15
# industrialpurpos 12
# petitionwhich 10
# wasmortgag 15
# passcertif 11
# srivatsan 10
# fewdocu 16
# ksrinivasarao 12
# letterconfirm 14
# dohar 10
# adh 13
# nathvania 17
# shafaqath 18
# onaft 20
# chaitanyafinanci 15
# balwa 19
# etcbefor 10
# purchasedit 17
# hullikatti 10
# animalwa 10
# noxxxxxxxx 19
# wwwj 17
# dueinform 18
# appellantspost 19
# zope 19
# grani 19
# thanigaivel 12
# kavung 13
# nandwaniwhil 11
# financeof 13
# havecompromis 11
# smtmamatakanungo 19
# sviii 10
# dhkrksz 16
# physicianmed 20
# chandigarhvid 22
# drgopinath 12
# shrkgoyalld 10
# sakarl 11
# shaifi 16
# fastand 12
# jalandharroad 13
# patialabut 12
# opregist 10
# revisionalpetition 16
# anyrejoind 20
# hospitalwherein 11
# worthnot 13
# waswaiv 12
# waswait 11
# settlementi 14
# letterrepli 12
# esacdk 10
# someforeign 15
# manikbag 16
# fullaccredit 14
# lwjt 13
# secretri 10
# reportther 21
# shajra 11
# reportthey 12
# chandrimachakraborti 14
# peripheralfloret 14
# msdcm 10
# rebateto 12
# parjapat 12
# usfrom 11
# dalgonganj 20
# heseek 10
# ofpoint 14
# ofscienc 22
# aktaria 17
# guljag 21
# optician 10
# serviceburden 11
# andmakan 10
# sawroop 10
# authorizeddistributor 21
# connectionloaddemand 17
# chowanag 12
# keki 10
# rnatarajan 10
# optionnotic 10
# themusclemen 10
# exbpost 13
# apmcyard 10
# ashir 10
# gracia 18
# weighingabout 12
# intramuscularli 10
# tostrik 10
# shekept 10
# querist 10
# fruitflow 17
# staterun 11
# certificatesno 10
# tillerpurchas 10
# complainantsurind 18
# depositsbi 17
# complainantsupport 11
# benefactor 17
# witnessnam 11
# besidesh 12
# sritv 10
# shdharmend 14
# besidesb 13
# besidesa 22
# gmac 17
# dictationbi 23
# ofshbaldev 13
# emjay 14
# esankkz 21
# ...
# schadha 10
# oftipp 14
# kunnathur 13
# thedoubt 22
# smaj 21
# mehli 10
# baptis 10
# mshroff 18
# benaka 12
# andchron 10
# itsremov 19
# madrasa 22
# shahbuddin 13
# dsfnu 12
# collegeunivers 12
# incar 10
# anident 12
# fromexploit 14
# antisikh 11
# norneglig 14
# prestress 12
# buswould 10
# camefor 22
# connectionaccordingli 11
# vfjfdfvfj 16
# evidenceboth 17
# totallyburnt 13
# tenterhook 20
# ughacurk 22
# recorddo 19
# rengali 17
# policyincept 20
# vitiatesth 11
# notharass 10
# bzone 13
# lastment 22
# forciblytook 23
# memonoca 11
# necessaryclaim 10
# kypkrpk 23
# falselyclaim 10
# jrcolleg 10
# thatrelev 13
# jubli 10
# usmdr 21
# alsocommon 17
# extractth 11
# juble 17
# technicalterm 11
# orleav 13
# notfair 17
# asnatur 10
# jsliksmsavlua 16
# itssignific 10
# respondentfind 20
# mschandra 22
# ofcylind 22
# specificquest 13
# activitycarri 16
# mentionedaddress 12
# molehil 10
# itrec 14
# miycknlrkost 15
# moula 10
# surrenderedand 11
# fnykbzg 10
# bkadu 14
# claact 12
# corporationhad 11
# veerupaxappa 11
# jeengar 20
# suchinjuri 17
# samemet 10
# papay 13
# engineeringdepart 10
# disputesa 16
# andpast 13
# mdfgl 12
# msanagram 15
# caralongwith 12
# constitutea 12
# regardingrepudi 12
# hnble 11
# yxoku 15
# khuda 22
# dkvolj 23
# rssanction 10
# sateeshv 14
# configurationrequir 13
# pushpalaya 13
# chunakkara 11
# allamount 11
# forwhos 12
# rissu 17
# onlyprovid 21
# avenkata 17
# airtim 11
# bonusetc 10
# djanardhan 11
# paytoward 13
# onexecut 19
# differentinsur 13
# thatsmt 24
# hdlgljcmf 12
# kabja 11
# shsurinderkumar 15
# kchandrasekhar 13
# provisionalregistr 24
# deedwould 16
# distbuldhana 11
# raney 16
# throughvari 24
# anothercertif 13
# fuleshwar 10
# dong 13
# heexplain 13
# talesara 21
# exhibitwa 16
# malampuzha 18
# namburi 14
# kithoma 10
# pkrn 15
# specificrequest 24
# defectiveengin 18
# eor 13
# ananesthetist 10
# kgseach 12
# allact 15
# replydtd 20
# andfriend 23
# kauri 24
# itselfor 16
# builtuparea 17
# disputesaris 14
# esatkjh 15
# otheremploye 21
# suchinstal 20
# haddiscuss 10
# opponentalso 24
# baggageand 16
# mortgagingth 11
# subsequentlyfil 12
# conductorin 13
# andxray 19
# saidgovern 10
# bhattasali 17
# losshowev 13
# zakhira 14
# goodsli 10
# avermentswer 11
# partydepart 16
# chanwar 24
# counterin 15
# partychos 11
# precauti 11
# raisecommerci 17
# modhiya 12
# schemeha 18
# oilmil 15
# magesh 10
# informationh 12
# thedecreet 19
# somarajan 23
# redemptionproce 12
# rulingcit 19
# reachingth 17
# wrongdeclar 18
# esat 13
# onsurmis 16
# singhrana 13
# tmfl 17
# izfrj 12
# esag 21
# cannotnow 11
# esad 10
# auctionon 17
# districtfazilka 10
# polam 10
# smuralino 20
# veryattract 11
# mohi 14
# tractorsand 11
# forless 17
# shrikk 15
# courierconsign 20
# whichonli 11
# promptlyand 19
# shrikc 10
# mezzaninefloor 12
# shimlahp 14
# onlycommit 18
# datainform 12
# durham 17
# palwindersingh 10
# foraon 10
# heapplic 15
# necessarypesticid 15
# withapp 11
# sharnam 23
# fraudulentlyobtain 12
# alreadyref 13
# sherri 14
# bykmadhulatha 22
# llth 17
# aassist 11
# whenview 11
# dudley 22
# bhusar 17
# oflay 17
# honblehpst 14
# exportersversu 23
# appearsin 12
# theassumpt 12
# unspoken 12
# noticeagainst 22
# courtsmarti 15
# kumarnarang 13
# jaibibi 20
# weknow 20
# rivulet 15
# thepetitionercompani 12
# complainedregard 13
# ravikar 10
# sellingcotton 10
# insurednomine 20
# konanatambigi 11
# paymonthli 22
# eseksfj 16
# theyit 21
# categorywa 10
# theyforward 15
# auditedaccount 15
# ondeliveri 15
# shurveer 11
# gsrqjsliksmsav 10
# pallom 15
# plusminu 18
# hirasingh 10
# numberon 18
# fordeficiencyinservic 15
# andimaginari 20
# vlohdkjfd 21
# thatconclus 13
# societycummanag 12
# lalgudi 10
# winth 16
# arrearsfor 11
# fortap 13
# murud 21
# infoway 15
# consumptionshown 24
# inentireti 16
# bhalod 16
# singhbrar 13
# businesswa 14
# althoughin 13
# uponelig 15
# arz 10
# haveconvert 10
# matiz 24
# recoveryfrom 13
# gangavaram 21
# soughtdismiss 23
# pvk 20
# brightpoint 10
# aro 18
# srijagadish 16
# ppchaudhari 19
# payrsa 12
# annexii 15
# raghubirsingh 10
# gourab 24
# thenoncompli 21
# heoper 16
# annexureand 18
# emailexc 14
# properon 11
# suchempow 22
# shahaji 18
# aldou 11
# advsrikanta 10
# cannotdemand 12
# partlyand 22
# cldda 21
# delhid 10
# muniraju 21
# descriptionofth 12
# mobilepurchas 20
# qav 10
# bullstori 13
# hulash 18
# shriusheranj 15
# contractbi 17
# mobicar 21
# supplycomplain 10
# cvi 14
# lalmuankima 18
# pskushmandi 10
# finda 10
# uponhi 15
# bothapp 24
# chinniampalayam 11
# shpawanpuri 17
# nationalisedbank 23
# accountwhen 22
# providefacil 10
# customersin 10
# asmembership 21
# drbhika 18
# jasim 12
# kullayappa 13
# receivedinform 23
# orrecept 17
# tikrikalan 16
# sajjansingh 15
# agreementhav 11
# mannam 12
# partyenclos 11
# delhig 14
# surgerywhich 15
# nippanitq 24
# niyamith 14
# judlmemb 17
# tulcha 19
# licensewhich 13
# bronchoscopi 10
# infeb 13
# bmahesh 17
# opponentregard 12
# roomof 22
# hindco 11
# sribalakrishna 10
# gnrayj 12
# thesolitari 13
# noform 15
# conclusionin 11
# abol 11
# kvijaya 16
# incomet 17
# santharam 24
# treatmentso 12
# carryingcapac 16
# colonyproject 17
# ofunforeseen 21
# heperson 22
# adjustmentrefund 19
# factbut 11
# laxminarain 24
# balancesum 13
# chequealongwith 21
# wereinferior 11
# tocrimin 14
# jhlr 18
# pleasecompli 11
# complainantadvanc 14
# rif 23
# boroda 19
# fileevid 24
# agreementform 13
# vacantif 11
# respondentsther 20
# tksj 21
# andexo 15
# servicethereaft 14
# orderp 10
# neitherplead 12
# settingsxmlpkc 10
# forsignatur 20
# brightman 12
# kadapadist 24
# shripardeep 17
# chlorat 10
# rationabil 10
# thyyldin 23
# ssidhu 11
# khandiat 11
# hadcaught 12
# manjuddin 10
# torealis 12
# mohannagar 15
# hasemphat 13
# afterhand 13
# bllsoknk 10
# aresummar 10
# paymentsubsequ 14
# iscustom 10
# sagaci 11
# wetlandcultiv 13
# metif 13
# pobek 23
# bewith 12
# orproperti 11
# vpgopalakrishnan 13
# jewan 10
# appellantcredit 18
# surgicaltreat 21
# acknowledgementth 11
# suru 12
# thismarla 15
# prakalp 11
# conditionsvit 13
# werestor 11
# shsukhpal 20
# incustodi 12
# reductio 14
# parishath 12
# indushekar 23
# thatbuild 20
# ccsb 10
# employerha 19
# detailth 20
# srdivn 19
# onbothsid 21
# sangameswararao 11
# furnishingal 23
# respondentwer 14
# devarabesanah 14
# satpalsingh 18
# nophotograph 14
# pksvksa 15
# petitionerdtc 20
# firmtherefor 12
# sauvidya 10
# mastoidectomi 15
# morether 11
# onanalyz 11
# hightemperatur 11
# denieddefici 19
# octoberand 23
# whileoper 16
# pokhar 14
# butsam 10
# fraudagainst 15
# ckrdk 14
# beenstop 22
# liein 15
# duringexpart 16
# beforetheir 11
# gsagekj 18
# sediti 16
# mrmshamikh 16
# tvse 22
# ailmentat 16
# ysusdk 11
# evillag 10
# donakondamand 17
# mobik 13
# medinipor 16
# ckykth 24
# avoidfurth 22
# prot 16
# explanationregard 11
# mrmj 17
# lastlyargu 20
# annd 19
# annb 21
# againsuff 11
# isconcoct 13
# dormientibu 11
# reliefparti 13
# gollah 11
# tpact 11
# pabra 10
# puttingwv 16
# lengthywritten 16
# admittedlyat 11
# duplicatebil 10
# delhiv 18
# plantprotect 24
# partnerpropprincip 18
# allegedrath 11
# tehsilarki 22
# dartcouri 10
# inpgi 16
# acknowledgementgiven 13
# admittedlyal 16
# addth 10
# jugiana 22
# noedin 11
# chpa 12
# arg 11
# graduateprogramm 10
# pathrika 22
# sukamani 10
# procter 17
# makarana 10
# thereofbi 11
# healththereaft 17
# makarand 21
# shrishti 11
# ownsurveyor 11
# disapprob 16
# elri 12
# noprotest 12
# mskrrassoci 12
# karunesh 13
# cumcertif 11
# spentbefor 15
# healthshield 13
# munnuswami 10
# sameail 10
# anyplot 21
# rsexr 14
# champhai 11
# atpadi 12
# reportpertain 17
# sbpass 11
# panakk 12
# fabia 17
# loansof 17
# effectingelectr 14
# coverpolici 17
# financeindia 20
# sangrurcentr 11
# plotbooth 13
# avijayakumar 20
# aswapuram 16
# gettingapprov 14
# inkarimnagar 21
# cannotbeliev 11
# opponentwho 11
# motorcycleand 18
# courtcomplain 10
# policyautomat 10
# chandrodaya 10
# shimpi 20
# chelladurai 16
# reasonwa 11
# getelectr 23
# noseri 24
# noserv 14
# gettingtreat 17
# jmii 14
# practicesinc 11
# paidadmiss 18
# ljdfsglv 10
# jhankar 10
# suddenand 10
# scheduleflat 14
# naisissu 16
# gdg 12
# towndevelop 10
# bughafunszkksa 12
# ofdestin 22
# asstengr 15
# complainantundisputedli 12
# skpatil 10
# meterstop 15
# cradl 23
# euqal 13
# abovetherefor 17
# barajamda 20
# mrudula 10
# performainvoic 17
# itreason 13
# replacedvid 11
# brevi 17
# holdersth 18
# vijayanagaram 15
# anypressur 12
# forprofession 14
# complainantsleg 20
# gogad 17
# sugarmil 11
# akrishnan 24
# tallyingwith 16
# shuma 12
# gogat 13
# sujathamma 11
# withregist 22
# jagitialexa 16
# skpanda 14
# groveland 17
# sumvid 10
# afterappl 24
# floorst 24
# fogla 17
# siliguribranch 16
# opsjd 11
# independentevid 14
# jssd 21
# handsetha 12
# searchrequisit 16
# lingamp 18
# beendetermin 11
# roshal 15
# deceasedtest 16
# celib 13
# celin 18
# requestingopposit 10
# executivemagistr 24
# epwtdj 18
# aprolong 11
# dksokgu 12
# billbi 15
# channi 14
# sitewa 22
# agut 22
# expenseswithin 16
# whethera 21
# kmtr 13
# fromspend 11
# opppartyand 17
# dofnocx 10
# forwith 16
# gatad 14
# confidor 19
# notea 14
# dispurs 11
# comlex 10
# threfor 14
# sellinggood 16
# rrn 13
# ofnonjoind 21
# cff 11
# rrf 15
# rhugtkj 11
# nobodyscas 13
# arrangedbi 21
# unauthorizedentri 12
# cfx 12
# dksbl 19
# entryi 21
# gress 19
# refundedon 10
# fataldiseas 10
# vamohta 10
# ratmahalasa 12
# intocustodi 15
# drpvv 11
# withconsolid 10
# honbleandhra 21
# pothireddyp 12
# ekansh 16
# moreyield 14
# directorpartn 14
# rnshopra 16
# tevaramellih 11
# dsctk 12
# chokshi 15
# accidentalextern 12
# complainantsdefault 15
# perinorm 11
# nobnd 13
# andadjoin 10
# lenientview 16
# remitr 12
# exaremain 14
# simpleton 16
# thisse 19
# arepair 13
# drawingdin 21
# applo 10
# dheksvj 13
# paperclip 19
# viusifjokn 22
# kidneyhospit 11
# frffkl 21
# shimgoa 10
# ratesth 16
# utsava 12
# vitiatedbi 11
# shallcomm 14
# msstate 11
# theirobserv 13
# jkfkjsliksmsav 20
# saith 14
# resptno 23
# beenresist 23
# securedth 18
# dasankoppa 21
# fiabl 10
# anabnorm 11
# retirementfrom 19
# summonsissu 10
# notinvestig 15
# artificialmean 12
# nocm 18
# gomsnod 17
# interestment 24
# perusedentir 11
# meritsalong 11
# abor 14
# ncdrf 11
# proop 14
# alongwithwritten 18
# inquiryfir 12
# peopleand 13
# acceptsth 12
# taw 24
# alogwith 15
# nocw 15
# waspast 19
# influenceth 22
# condescend 12
# interrogatoriesfil 10
# sdgm 21
# shapoor 10
# ravikrishnan 17
# saroad 16
# kalanad 22
# unpaidth 21
# thisprincipl 16
# erandawan 24
# kalyanikar 17
# contactedwith 21
# namedseema 11
# furtherinvest 12
# benifit 11
# arisento 19
# tpo 22
# immova 16
# evidenceif 14
# shmrsaluja 12
# petitionsfil 12
# badqual 13
# emplye 18
# margosa 13
# seekedredress 15
# reiteratingtheir 11
# reportingth 21
# bherunath 11
# requiredmeasur 10
# ifjokfnuhdh 10
# ofaic 13
# jkw 16
# schemeamount 17
# ssjodha 21
# rotegur 19
# viswamitra 11
# educationcours 15
# basanthi 12
# thawarm 21
# singhsodhi 13
# fundrul 15
# fgfgpz 19
# connectioneven 13
# againfrom 12
# ranpara 10
# donefre 13
# hisident 20
# ierespond 23
# experiencein 16
# byi 18
# thatremain 15
# ofsahara 13
# againstequ 11
# knowingthat 20
# damagedbi 24
# lrengarajan 10
# aremer 16
# mordhwaj 17
# inocul 19
# policiesshould 10
# hisrepresentativerel 11
# theperil 23
# pramachandran 16
# mraroy 10
# soapier 15
# asfd 20
# asfe 24
# muraliso 22
# bouncedtherefor 15
# riderbenefit 10
# chartcno 11
# andindiffer 13
# vengthlang 14
# shriman 12
# theirtravel 10
# providingtreat 10
# stanli 21
# bhand 15
# goliya 11
# ascertainedfrom 10
# wasunintent 24
# afterspot 16
# kishoreso 20
# ccdid 10
# chargedund 15
# thatproperti 12
# complailn 16
# defaultunjustifi 12
# documentsdespit 13
# oftyp 11
# ukgha 23
# exbranch 11
# afterphys 12
# skalagh 10
# nlrvarieti 14
# daroli 13
# besidesfinanci 11
# managedth 13
# notesth 13
# werecrossexamin 14
# gotexecut 22
# considerthi 10
# isright 19
# snparashar 18
# reasonablecost 16
# beknown 23
# nandikotkur 22
# rejectedbecaus 12
# paprola 12
# andextract 14
# bygovt 23
# settlementoff 15
# arnav 14
# variousprovis 15
# usedit 11
# morepan 12
# octnov 12
# noleakag 22
# mrbmtripathi 24
# necessarydetail 17
# ofmba 10
# exarespect 16
# exhibiteddocu 18
# ofcrack 15
# remainedunrepuls 11
# droop 10
# districtsinghbhum 14
# meningioma 12
# susidi 23
# hecaus 19
# hostelcharg 13
# whorepres 11
# notdesir 22
# courtsdur 11
# settlementa 21
# kutub 13
# ofkidney 23
# afterminut 14
# policyholderand 11
# suvrata 19
# fhak 13
# pointwhich 21
# isfdax 19
# citedin 11
# irrespec 19
# anyfraud 22
# perian 18
# preemp 12
# andexport 18
# omzddf 22
# cksj 10
# poovappa 17
# paymentaft 24
# beltala 24
# investigatorha 24
# hadrepres 22
# examinersconfidenti 13
# homefor 12
# doalso 14
# complaintsu 12
# offtak 13
# assuredit 13
# complaintsi 13
# loansto 14
# mruulalit 16
# isilliter 17
# mentionedagainst 12
# metter 12
# chamkaursingh 21
# ticketsto 18
# vrm 10
# documentscopi 13
# aifjokfnuh 12
# iimit 16
# thateveryth 11
# maharashtrian 13
# aboobak 13
# wagescal 21
# manbir 13
# wimco 11
# tonondisclosur 13
# strictlyspeak 15
# deenv 20
# kacherithazham 11
# ekvira 15
# sajeevan 14
# hornbi 20
# exrexr 20
# forjustic 18
# vkgjk 11
# spatial 12
# roadpathankot 10
# thisproduct 18
# dene 21
# kalikinkar 12
# ofdebt 16
# avsubramanyam 24
# busfrom 22
# inerror 19
# chamundeswari 23
# vuzwu 16
# pensionat 14
# jka 16
# heardreason 10
# girishkumar 16
# sustian 15
# insuredcattl 19
# institutedagainst 12
# somallappa 22
# viewwa 17
# petitionermr 18
# operationat 21
# tehsilshahpur 10
# saidprocedur 14
# thatexist 13
# mahindersingh 11
# grossweight 19
# deceasedsuff 22
# exbwith 12
# considerableamount 14
# mrsbdandapani 11
# havingright 15
# dope 13
# tpz 11
# theshortfal 22
# nosbi 10
# shashikumar 11
# dkjksa 13
# soadmittedli 10
# orlocu 11
# surrenderedhi 18
# therectifi 19
# meterso 16
# eiiilu 15
# appellantorgcomplainantscas 24
# murgad 11
# forumcommit 20
# complainantwheth 18
# exhta 12
# disputesdist 17
# gingelli 11
# limitationwil 10
# notwel 12
# postin 10
# guaranteewarrante 21
# vehiclethough 23
# deposedbefor 14
# deliberatelyconc 23
# wheelerin 12
# nirwani 16
# ebb 20
# availal 22
# sribvsuresh 10
# ebn 22
# coli 13
# notinterfer 14
# ebj 15
# ebp 17
# paulson 17
# influenceor 12
# gurvindersingh 21
# actionbefor 15
# nineonli 13
# endorsementschedul 12
# simmi 23
# bist 15
# panti 15
# variouscorrespond 16
# arisefurth 10
# onebottl 17
# lva 15
# circularwil 10
# philipos 17
# thatfour 12
# exrwaalongwith 15
# ultimatepurpos 21
# kafnuakd 14
# largeamount 22
# friendof 22
# vishwasnagar 12
# jagruthi 12
# gyanpur 11
# onelectr 10
# promptlyattend 15
# asconstruct 10
# konanakunt 22
# complainantscontain 17
# ocno 18
# hyphen 10
# parameterslaid 12
# haemostasi 17
# nagarajupeta 12
# theyearli 23
# feaser 21
# undueharass 18
# bbl 11
# agreementb 10
# opnoopno 11
# nobreach 23
# bbb 24
# agreementr 15
# parilesh 11
# samelat 10
# consolidatedcompens 20
# mrprabhavalkar 12
# allegationsfurth 12
# bbr 10
# psuubz 21
# pmegp 19
# dharanappa 15
# soongachi 12
# actingupon 18
# ofelectrocut 14
# mpremraj 12
# amountfinanceschemematur 21
# gowliguda 10
# ijifjoknhxk 14
# paidthre 14
# policyop 23
# applicationfail 12
# pdhinduja 10
# wasshort 16
# rightkne 22
# sedley 12
# complaintne 13
# esavafdr 13
# guljari 16
# cashth 18
# phonebi 11
# andwithhold 13
# loka 24
# southernregion 16
# shahkari 11
# waswheth 11
# compagni 14
# cancomfort 13
# internationalbusi 13
# ramasagar 10
# rcrevno 23
# accidentregist 10
# taramati 12
# onleft 11
# saidprovision 11
# papersform 15
# shridharan 14
# aninstitut 23
# adcon 10
# conditionsst 10
# babje 16
# wereentrust 24
# mentionedmr 12
# respondentssubmit 12
# irrigatehi 13
# displutesredress 12
# barum 12
# aftercalcul 23
# upholdingth 21
# jkchanda 21
# heavyvehicl 11
# utnoor 12
# fincrop 24
# disconnectedin 10
# mrcpsharma 20
# theoc 15
# rocker 10
# wereal 16
# uponissu 19
# weread 20
# mrkjdj 24
# ramachandrapur 10
# swedesh 20
# bhurje 23
# corei 11
# saidreplac 11
# rctc 14
# seeni 15
# sathyashankara 12
# dqa 11
# skc 11
# admittedhi 24
# sko 18
# distrayagada 15
# areretir 15
# investigationoffic 11
# withoutflow 15
# fornorm 11
# mariyammanah 11
# kumarsahoo 11
# neelakantan 12
# shdsbain 10
# computerwa 23
# knox 15
# bombayhous 20
# indiarepres 13
# darker 24
# sonaram 19
# fullydamag 18
# aelectr 21
# increasedbi 13
# hercredit 18
# khatedarten 12
# partyboth 22
# sahayogiesshiksha 13
# arelik 19
# theiragr 18
# mrvirendra 10
# documentssought 20
# bottleof 23
# veryseri 20
# levelin 10
# areliv 12
# wereperus 24
# masterof 22
# nagaruntari 15
# complainantexr 17
# schemethrough 22
# cathlab 10
# unitpric 12
# krath 11
# manjeetsingh 23
# opsrath 15
# wheelof 10
# interconnectport 13
# isharm 23
# complainantext 17
# receivinginform 17
# levelledbi 21
# shyochand 24
# returnand 10
# bdjkjukek 18
# mahabubnagartown 13
# nowbc 14
# nowbb 20
# sonment 11
# vtthoma 11
# throne 22
# isbelow 10
# otherproperti 11
# ningamm 23
# stageiii 10
# ioa 14
# regardingthes 10
# tpbox 10
# shkhem 10
# appreciatethat 22
# ehukjk 14
# bolamscas 17
# bearingsr 10
# fasali 12
# toexhibit 17
# mediclaimof 15
# peapulli 10
# mayjunether 10
# lansgklin 17
# greaterfrom 16
# nonutil 15
# authorizeth 11
# ajni 23
# thetipp 23
# presidentvic 10
# manabendra 14
# kattar 11
# fdkuyki 16
# kakinadaon 13
# cannotstand 13
# connectionthat 22
# travelto 16
# etci 18
# wasdisplay 17
# cablesltd 10
# sabith 16
# prespecifi 17
# partiesnow 13
# banksfunct 15
# partiesnor 21
# orcommun 15
# followingpay 12
# whilehold 21
# thedrain 10
# cescltd 24
# absenttherefor 11
# gssaini 11
# iswarant 17
# pandyan 24
# advshritandal 14
# ammanabrolu 13
# pushpabuild 10
# kalman 10
# tufpwhh 11
# srivenkata 11
# sicn 17
# sich 11
# thatregul 11
# andcomprehens 10
# kalahanuman 11
# counterwrittenvers 14
# railwaydepart 18
# assesss 12
# spthirumala 13
# srikvsheshadri 10
# heartand 13
# kpkzi 14
# todecreas 11
# tuifk 16
# furtherdefici 10
# vslignit 13
# abhimanu 13
# thomascook 11
# hargurpratap 20
# nadanah 23
# fundin 19
# chellamma 10
# kjkcgk 17
# wasconced 10
# ramdurga 15
# unwantedlitig 14
# suitpetit 16
# consideringthes 16
# floorwithout 12
# opiniongiven 17

# %%
dictionary.doc2bow(['word','lost'])
# Out:
# [(925, 1), (1106, 1)]

# %%
dictionary.dfs[1]
# Out:
# 107751

# %%
# save the dictionary
dictionary.save('dict/stem')
dictionary.filter_extremes(no_below=10, keep_n=None)
dictionary.compactify()
dictionary.save('dict/stem10')
dictionary.filter_extremes(no_below=25, keep_n=None)
dictionary.compactify()
dictionary.save('dict/stem25')
# Out:
# 2018-04-28 16:43:44,634 : INFO : saving Dictionary object under dict/stem, separately None
# 2018-04-28 16:43:44,715 : INFO : saved dict/stem
# 2018-04-28 16:43:44,955 : INFO : discarding 0 tokens: []...
# 2018-04-28 16:43:44,958 : INFO : keeping 155879 tokens which were in no less than 10 and no more than 175992 (=50.0%) documents
# 2018-04-28 16:43:45,243 : INFO : resulting dictionary: Dictionary(155879 unique tokens: [u'ksrinivasa', u'percopi', u'halagundi', u'largeord', u'gavat']...)
# 2018-04-28 16:43:45,438 : INFO : saving Dictionary object under dict/stem10, separately None
# 2018-04-28 16:43:45,521 : INFO : saved dict/stem10
# 2018-04-28 16:43:45,807 : INFO : discarding 71585 tokens: [(u'mundack', 12), (u'thiruvananthapuramopposit', 13), (u'atx', 22), (u'kathrikadavu', 13), (u'odyssey', 11), (u'partiesm', 16), (u'thiruvananthapuramth', 19), (u'fedex', 13), (u'partiesp', 10), (u'aryanad', 10)]...
# 2018-04-28 16:43:45,808 : INFO : keeping 84294 tokens which were in no less than 25 and no more than 175992 (=50.0%) documents
# 2018-04-28 16:43:46,033 : INFO : resulting dictionary: Dictionary(84294 unique tokens: [u'thediagnost', u'metnal', u'ksrinivasa', u'percopi', u'pskharagpur']...)
# 2018-04-28 16:43:46,156 : INFO : saving Dictionary object under dict/stem25, separately None
# 2018-04-28 16:43:46,207 : INFO : saved dict/stem25

# %%
#################################### laod the dictinary
dictionary = corpora.Dictionary.load('dict/stem10')
# Out:
# 2018-04-28 17:16:33,728 : INFO : loading Dictionary object from dict/stem10
# 2018-04-28 17:16:33,780 : INFO : loaded dict/stem10

# %%
# This is BOW wrapper
c = my_corpus()
bow_corpus = c.everything()

# %%
# %%time
######################################## save BOW
corpora.MmCorpus.serialize('corpus/bow_stem10.mm', bow_corpus)
# Out:
# 2018-04-28 17:16:55,047 : INFO : storing corpus in Matrix Market format to corpus/bow_stem10.mm
# 2018-04-28 17:16:55,047 : INFO : saving sparse matrix to corpus/bow_stem10.mm
# 2018-04-28 17:16:55,722 : INFO : PROGRESS: saving document #0

# %%
# %%time
# ######################################## save BOW
# corpora.MmCorpus.serialize('stem100.mm', corpus)

# %%
######################################## load BOW
corpus = corpora.MmCorpus('stem100.mm')

# %%
# get the query truth in dictionary
query_truth = {}
for i in range(1,11):
    query_truth[str(i)]=[]
    
    
f = open('LegalAdhocTask/Consumer.qrels')
lines = [line.rstrip('\n').split("\t") for line in f]
for line in lines:
    del line[1]
    query_truth[line[0]].append(line[1:])

# %%
# load doc_len
with open('doc_len_stem100.pkl', 'rb') as ip:
    doc_len = pickle.load(ip)

# %%
import math
from six import iteritems
from six.moves import xrange

#     The variable k1 is a positive tuning parameter that calibrates the
#     document term frequency scaling. A k1 value of 0 corresponds to a binary
#     model (no term frequency), and a large value corresponds to using raw term
#     frequency. b is another tuning parameter (0 ≤ b ≤ 1) which determines
#     the scaling by document length: b = 1 corresponds to fully scaling the term
#     weight by the document length, while b = 0 corresponds to no length normalization


# BM25 parameters.
PARAM_K1 =1.2
PARAM_B = 0.75

# incase the idf is zero
EPSILON = 0.01


class BM25(object):

    def __init__(self, corpus):
        self.corpus_size = dictionary.num_docs
        s = 0
        for i in corpus:
            for x in i:
                s = s + x[1]
        s = float(s)    
        self.avgdl = s / self.corpus_size
        self.corpus = corpus
        self.df = dictionary.dfs
        self.idf = {}
        self.initialize()

    def initialize(self):
        for word, freq in iteritems(self.df):
            self.idf[word] = math.log(self.corpus_size - freq + 0.5) - math.log(freq + 0.5)

    def get_score(self, query, index, average_idf):
        score = 0
        index_doc = dict(self.corpus[index])
        
        for word,freq in query:
            if word not in index_doc:
                continue
            idf = self.idf[word] if self.idf[word] >= 0 else EPSILON * average_idf
            p1 = freq
            p2 = idf * index_doc[word] * (PARAM_K1 + 1)
            p3 = index_doc[word] + PARAM_K1 * (1 - PARAM_B + PARAM_B * doc_len[index] / self.avgdl)
            score += (p1*p2)/p3
        return score

    def get_scores(self, query, average_idf):
        scores = []
        for index in xrange(self.corpus_size):
            score = self.get_score(query, index, average_idf)
            scores.append(score)
        return scores

# %%
# %%time
bm25 = BM25(corpus)

# %%
# need to pass it to the function that calculates the score
average_idf = sum(map(lambda k: float(bm25.idf[k]), bm25.idf.keys())) / len(bm25.idf.keys())

# %%
# %%time
results = copy.deepcopy(query_truth)

sim_list = [0]
rank_list = [0]
queries = [0]
for i,query in enumerate(files_to_tokens('LegalAdhocTask/q*.txt')):
    queries.append(query)
    sims = bm25.get_scores(dictionary.doc2bow(query), average_idf)
    sim_list.append(sims)
    # rank of every document wrt similarity
    ranks = rankdata(sims, method='ordinal')
    ranks= len(ranks)+1 - ranks 
    rank_list.append(ranks)
    
    # update the query truth tuples with similarity score and the ranks
    for x in results[str(i+1)]:
        x.append(sims[filenames.index(x[0]+'.txt')])
        x.append(ranks[filenames.index(x[0]+'.txt')])
    print i

# %%
results

# %%
results

# %%
# Store results in 1st sheet
wb = Workbook()
dest_filename = 'BM25.xlsx'
ws1 = wb.active
ws1.title = "K1 = 1.2 B = 0.75 EPS = 0.01 |"
ws1.append(['Query','Filename', 'Relevance', 'Score', 'Rank'])
for key,value in results.iteritems():
    for i in value:
        ws1.append([int(key)]+ i)

wb.save(filename = dest_filename)

# %%
#Query wise (F score)

import pandas as pd

f = pd.ExcelFile('BM25.xlsx')

from scipy.stats import hmean



model_name = 'BM25'
places = 4
wb = load_workbook('BM25.xlsx')
ws1 = wb.create_sheet(title="evaluation_Qwise")

ws1.append(['Query','Docs considered', 'Precision/Recall', 'Model', 1, 5 ,10, 25, 50, 100, 500, 1000])

k = [1.0, 5.0 ,10.0, 25.0, 50.0, 100.0, 500.0, 1000.0]
for sheet in f.sheet_names:
    if(sheet == "evaluation"):
        continue
    for q in np.arange(1,11):

        x = f.parse(sheet)
        x = x[x['Query'] == q]
        total_1 = (float)(x[x['Relevance'] == 1].shape[0])
        total_0 = (float)(x[x['Relevance'] == 0].shape[0])
        total = (float)(x.shape[0])
        
        ####  repitition due to complication in considering both 1 & 0 relevance
        # precision 1
        row = [q, 1, 'P', model_name + ' :' + sheet]
        for i in k:
            row.append(x[np.logical_and(x['Relevance'] == 1 , x['Rank'] <= i)].shape[0]/i)
        ws1.append(row);
        p1 = row;
        # precision 0
        row = [q, 0, 'P', model_name + ' :' + sheet]
        for i in k:
            row.append(x[np.logical_and(x['Relevance'] == 0 , x['Rank'] <= i)].shape[0]/i)    
        ws1.append(row);
        p0 = row;
        #precision 10
        row = [q, 10, 'P', model_name + ' :' + sheet]
        for i in k:
            row.append(x[x['Rank'] <= i].shape[0]/i)  
        ws1.append(row);
        p10 = row;  
        
        
        # recall 1
        row = [q, 1, 'R', model_name + ' :' + sheet]
        for i in k:
            row.append(x[np.logical_and(x['Relevance'] == 1 , x['Rank'] <= i)].shape[0]/total_1)
            row[-1] = round(row[-1],places)
        ws1.append(row);
        r1 = row;    
        # recall 0
        row = [q, 0, 'R', model_name + ' :' + sheet]
        for i in k:
            row.append(x[np.logical_and(x['Relevance'] == 0 , x['Rank'] <= i)].shape[0]/total_0)
            row[-1] = round(row[-1],places)
        ws1.append(row);
        r0 = row;
        #recall 10
        row = [q, 10, 'R', model_name + ' :' + sheet]
        for i in k:
            row.append(x[x['Rank'] <= i].shape[0]/total)
            row[-1] = round(row[-1],places)
        ws1.append(row);
        r10 = row;      


        # F 1
        row = [q, 1, 'F', model_name + ' :' + sheet]
        for i in range(-len(k), 0, 1):
            if p1[i] == 0.0 :
                row.append(0.0)
            else:
                row.append(hmean([p1[i],r1[i]]))
            row[-1] = round(row[-1],places)
        ws1.append(row);

        # F 0
        row = [q, 0, 'F', model_name + ' :' + sheet]
        for i in range(-len(k), 0, 1):
            if p0[i] == 0.0:
                row.append(0.0)
            else:
                row.append(hmean([p0[i],r0[i]]))
            row[-1] = round(row[-1],places)
        ws1.append(row);

        # F 10
        row = [q, 10, 'F', model_name + ' :' + sheet]
        for i in range(-len(k), 0, 1):
            if p10[i] == 0.0:
                row.append(0.0)
            else:
                row.append(hmean([p10[i],r10[i]]))
            row[-1] = round(row[-1],places)
        ws1.append(row);
        
wb.save(filename = 'BM25.xlsx')

# %%
#Query wise Average precision
# precision sum
def p_sum(z):
    z = z.copy()  
    z.sort_values(inplace=True)
    result = 0
    for i,val in enumerate(z):
        result += (i+1)/float(val) 
    return result


import pandas as pd

f = pd.ExcelFile('BM25.xlsx')

from scipy.stats import hmean


model_name = 'BM25'
places = 4
wb = load_workbook('BM25.xlsx')
ws1 = wb.create_sheet(title="AP_Qwise")

ws1.append(['Query','Docs considered', 'Precision/Recall', 'Model', 1, 5 ,10, 25, 50, 100, 500, 1000])


for sheet in f.sheet_names:    
    if(sheet == "evaluation"or sheet == "evaluation_Qwise"):
        continue
    for q in np.arange(1,11):
        x = f.parse(sheet)
        x = x[x['Query'] == q]
        total = {}
        total[1] = (float)(x[x['Relevance'] == 1].shape[0])
        total[0] = (float)(x[x['Relevance'] == 0].shape[0])
        total[10] = (float)(x.shape[0])
        
        for rel in [1,0]:
            # precision 1
            row = [q, rel, 'AP', model_name + ' :' + sheet]
            for i in [1.0, 5.0, 10.0, 25.0, 50.0, 100.0, 500.0, 1000.0]:
                row.append(p_sum(x[np.logical_and(x['Relevance'] == rel, x['Rank'] <= i)]['Rank'])/total[rel])
            ws1.append(row);

        row = [q, 10, 'AP', model_name + ' :' + sheet]
        for i in [1.0, 5.0, 10.0, 25.0, 50.0, 100.0, 500.0, 1000.0]:
            row.append(p_sum(x[x['Rank'] <= i]['Rank'])/total[10])
        ws1.append(row);
wb.save(filename = 'BM25.xlsx')

# %%
############################################################

# %%
def Top_x(x, R):
    R = list(R)
    x_names = []
    for i in range(x):
        x_names.append(filenames[R.index(i + 1)].strip('.txt'))
    return x_names

# %%
def score_stat(word, freq, index):
    index_doc = dict(bm25.corpus[index])
    word = dictionary.doc2bow([word])[0][0]
    idf = bm25.idf[word] if bm25.idf[word] >= 0 else EPSILON * average_idf
    score = freq*((idf * index_doc[word] * (PARAM_K1 + 1)
              / (index_doc[word] + PARAM_K1 * (1 - PARAM_B + PARAM_B * doc_len[index] / bm25.avgdl))))
    return (index_doc[word], score)

# %%
wb = Workbook()
dest_filename = 'Temp.xlsx'
ws = wb.active
ws.title = "Blank"
#ws.append([(2.2,2.2)])
wb.save(filename = dest_filename)
def common_words(q, F):
    temp = []
    for word, freq in dictionary.doc2bow(queries[q]) :
        temp.append((dictionary[word], freq, round(bm25.idf[word], 2)))
    temp.sort(key=lambda x: (x[2],x[1]), reverse=True)
    q_words = [i[0]  for i in temp]
    q_freq = [i[1]  for i in temp]
    index = filenames.index(F + '.txt')
    index_doc = dict(bm25.corpus[index])
    row = []
    for word, freq in  zip(q_words, q_freq):
        w = dictionary.doc2bow([word])[0][0]
        if w in index_doc: 
            f, s = score_stat(word, freq, index)
            row.append([word + ', ' + str(round(bm25.idf[w], 2)), freq, f,  round( (s*100)/sim_list[q][index], 1)])  
    row.sort(key = lambda x: (x[3],x[1],x[2]), reverse = True)
    wb = load_workbook('Temp.xlsx')
    ws = wb.create_sheet(title=str(q) + F)
    ws.append(['word,idf', 'Query freq', 'freq', '% score'])
    for i in row:
        ws.append(i)
    wb.save(filename = 'Temp.xlsx')

# %%
f = open("toberead.txt", 'r') 
count = 0
q = 1
for i in f:
    if i == '\n':
        continue
    count = count + 1
    common_words(q, i.strip())
    if count % 5 == 0:
        q = q + 1

# %%
for i in files_to_tokens(full_filenames[filenames.index(doc + '.txt')]):
    for j in i:
        print j

# %%
doc = 'ConsumerCourt_SCDRC_30176'
corpus[]

# %%
common_words(1, 'ConsumerCourt_DCDRC_41588')

# %%
df = pd.DataFrame(index= None, columns=['words','pair'])

# %%
df

# %%
print df

# %%
df.append(['lol', ('we','wew')])

# %%
def uncommon_words(q, filename)

# %%
# Store results in 1st sheet
wb = Workbook()
dest_filename = 'Explore_BM25.xlsx'
ws = wb.active
ws.title = "Blank"
#ws.append([(2.2,2.2)])
wb.save(filename = dest_filename)

wb = load_workbook('Explore_BM25.xlsx')

for q in range(1, 11):
    ws = wb.create_sheet(title="q" + str(q))
    #x_names = Top_x(10, rank_list[q])
    top_row = ['Doc Name', 'Rel', 'Doc Length', ' Rank', 'Score']
    sec_row = [' ']*5
    temp = []
    for word, freq in dictionary.doc2bow(queries[q]) :
        temp.append((dictionary[word], freq, round(bm25.idf[word], 2)))
    temp.sort(key=lambda x: (x[2],x[1]), reverse=True)
    ws.append(top_row + [i[0]  for i in temp])
    ws.append(sec_row + [str(i[1]) + ', ' + str(i[2]) for i in temp])
    q_words = [i[0]  for i in temp]
    q_freq = [i[1]  for i in temp]
    
    #continue
    doc_list = [i[0] for i in query_truth[str(q)]] + Top_x(10, rank_list[q])
    doc_list = list((set(doc_list)))
    doc_list.sort(key = lambda doc : rank_list[q][filenames.index(doc + '.txt')])
    doc_row = []
    for doc in doc_list:
        temp  = [doc]
        rel_dic = dict(query_truth[str(q)])
        if doc in rel_dic:
            temp.append(rel_dic[doc])
        else:
            temp.append('Not')
        temp.append(doc_len[filenames.index(doc + '.txt')])
        temp.append(rank_list[q][filenames.index(doc + '.txt')])
        temp.append(round(sim_list[q][filenames.index(doc + '.txt')], 2))
        doc_row.append(temp)

    for row in doc_row:
        index = filenames.index(row[0] + '.txt')
        index_doc = dict(bm25.corpus[index])
        
        for word, freq in  zip(q_words, q_freq):
            if dictionary.doc2bow([word])[0][0] in index_doc: 
                f, s = score_stat(word, freq, index)
                row.append( str(f) + ', ' +  str(round( (s*100)/sim_list[q][index], 1) ))
            else:
                row.append('X')
        ws.append(row)
        ws.append([])        
wb.save(filename = dest_filename)

# %%
# Store results in 1st sheet
wb = Workbook()
dest_filename = 'Explore_BM25_uncom.xlsx'
ws = wb.active
ws.title = "Blank"
#ws.append([(2.2,2.2)])
wb.save(filename = dest_filename)



wb = load_workbook('Explore_BM25_uncom.xlsx')

for q in range(1, 11):
    ws = wb.create_sheet(title="q" + str(q))
    #x_names = Top_x(10, rank_list[q])
    top_row = ['Doc Name', 'Rel', 'Doc Length', ' Rank', 'Score']
    sec_row = [' ']*5
    temp = []
    for word, freq in dictionary.doc2bow(queries[q]) :
        temp.append((dictionary[word], freq, round(bm25.idf[word], 2)))
    temp.sort(key=lambda x: (x[2],x[1]), reverse=True)
    ws.append(top_row + [i[0]  for i in temp])
    ws.append(sec_row + [str(i[1]) + ', ' + str(i[2]) for i in temp])
    q_words = [i[0]  for i in temp]
    q_freq = [i[1]  for i in temp]
    
    #continue
    doc_list = [i[0] for i in query_truth[str(q)]] + Top_x(10, rank_list[q])
    doc_list = list((set(doc_list)))
    doc_list.sort(key = lambda doc : rank_list[q][filenames.index(doc + '.txt')])
    doc_row = []
    for doc in doc_list:
        temp  = [doc]
        rel_dic = dict(query_truth[str(q)])
        if doc in rel_dic:
            temp.append(rel_dic[doc])
        else:
            temp.append('Not')
        temp.append(doc_len[filenames.index(doc + '.txt')])
        temp.append(rank_list[q][filenames.index(doc + '.txt')])
        temp.append(round(sim_list[q][filenames.index(doc + '.txt')], 2))
        doc_row.append(temp)

    for row in doc_row:
        index = filenames.index(row[0] + '.txt')
        index_doc = dict(bm25.corpus[index])
        
#         for word, freq in  zip(q_words, q_freq):
#             if dictionary.doc2bow([word])[0][0] in index_doc: 
#                 f, s = score_stat(word, freq, index)
#                 row.append( str(f) + ', ' +  str(round( (s*100)/sim_list[q][index], 1) ))
#             else:
#                 row.append('X')
        #ws.append(row)
        
        sec_row = [' ']*5
        temp = []
        for word, freq in index_doc.iteritems():
            if dictionary[word] not in q_words:
                temp.append((dictionary[word], freq, round(bm25.idf[word], 2)))
        ws.append(row + [i[0]  for i in temp])
        ws.append(sec_row + [str(i[1]) + ', ' + str(i[2]) for i in temp])
        ws.append([])        
wb.save(filename = dest_filename)

# %%
# Store results in 1st sheet
wb = Workbook()
dest_filename = 'Explore_BM25_all.xlsx'
ws = wb.active
ws.title = "Blank"
#ws.append([(2.2,2.2)])
wb.save(filename = dest_filename)



wb = load_workbook('Explore_BM25_all.xlsx')

for q in range(1, 11):
    ws = wb.create_sheet(title="q" + str(q))
    #x_names = Top_x(10, rank_list[q])
    top_row = ['Doc Name', 'Rel', 'Doc Length', ' Rank', 'Score']
    sec_row = [' ']*5
    temp = []
    for word, freq in dictionary.doc2bow(queries[q]) :
        temp.append((dictionary[word], freq, round(bm25.idf[word], 2)))
    temp.sort(key=lambda x: (x[2],x[1]), reverse=True)
    ws.append(top_row + [i[0]  for i in temp])
    ws.append(sec_row + [str(i[1]) + ', ' + str(i[2]) for i in temp])
    q_words = [i[0]  for i in temp]
    q_freq = [i[1]  for i in temp]
    
    #continue
    doc_list = [i[0] for i in query_truth[str(q)]] + Top_x(10, rank_list[q])
    doc_list = list((set(doc_list)))
    doc_list.sort(key = lambda doc : rank_list[q][filenames.index(doc + '.txt')])
    doc_row = []
    for doc in doc_list:
        temp  = [doc]
        rel_dic = dict(query_truth[str(q)])
        if doc in rel_dic:
            temp.append(rel_dic[doc])
        else:
            temp.append('Not')
        temp.append(doc_len[filenames.index(doc + '.txt')])
        temp.append(rank_list[q][filenames.index(doc + '.txt')])
        temp.append(round(sim_list[q][filenames.index(doc + '.txt')], 2))
        doc_row.append(temp)

    for row in doc_row:
        index = filenames.index(row[0] + '.txt')
        index_doc = dict(bm25.corpus[index])
        
        for word, freq in  zip(q_words, q_freq):
            if dictionary.doc2bow([word])[0][0] in index_doc: 
                f, s = score_stat(word, freq, index)
                row.append( str(f) + ', ' +  str(round( (s*100)/sim_list[q][index], 1) ))
            else:
                row.append('X')
        ws.append(row)
        
        sec_row = [' ']*5
        temp = []
        for word, freq in index_doc.iteritems():
            if dictionary[word] not in q_words:
                temp.append((dictionary[word], freq, round(bm25.idf[word], 2)))
        ws.append(sec_row + [i[0]  for i in temp])
        ws.append(sec_row + [str(i[1]) + ', ' + str(i[2]) for i in temp])
        ws.append([])        
wb.save(filename = dest_filename)
