# %%
import os
os.chdir("/home/atulgang/Thesis")

# %%
import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)

# %%
import nltk
from nltk.tokenize import word_tokenize
from stop_words import get_stop_words
from nltk.stem import WordNetLemmatizer
from gensim import corpora, models
import gensim
import glob2
from itertools import chain
import os
import numpy as np
import itertools
import cPickle as pickle
from  scipy.stats import rankdata
import copy
from openpyxl import Workbook
from openpyxl.compat import range
from openpyxl.utils import get_column_letter
from openpyxl import load_workbook
import pandas as pd
from scipy.stats import hmean
from nltk.stem import PorterStemmer
from nltk.tokenize import sent_tokenize, word_tokenize
# Out:
# 2018-05-06 15:40:09,749 : INFO : 'pattern' package not found; tag filters are not available for English

# %%
# ignores everything except english alphabet and  
def only_alphabet(text):
    return ''.join(i for i in text if (ord(i)<123 and ord(i)>96) or (ord(i)<91 and ord(i)>64) or ord(i)==32) 

full_filenames = []
x= ['LegalAdhocTask/ConsumerCourtAdhocdata/DCDRC/**/*.txt','LegalAdhocTask/ConsumerCourtAdhocdata/NCDRC/**/*.txt','LegalAdhocTask/ConsumerCourtAdhocdata/SCDRC/**/*.txt', 'LegalAdhocTask/SC-HCAdhocData/DelhiHC/**/*.txt','LegalAdhocTask/SC-HCAdhocData/JharkhandHC/**/*.txt', 'LegalAdhocTask/SC-HCAdhocData/JodhpurHC/**/*.txt' ,'LegalAdhocTask/SC-HCAdhocData/KolkataHC/**/*.txt', 'LegalAdhocTask/SC-HCAdhocData/SupremeCourt/**/*.txt']
for glob_filenames in x:
    glob_filenames = os.path.normpath(glob_filenames)
    for filename in sorted(glob2.glob(glob_filenames)):
        full_filenames.append(filename)
            
filenames = []
x= ['LegalAdhocTask/ConsumerCourtAdhocdata/DCDRC/**/*.txt','LegalAdhocTask/ConsumerCourtAdhocdata/NCDRC/**/*.txt','LegalAdhocTask/ConsumerCourtAdhocdata/SCDRC/**/*.txt', 'LegalAdhocTask/SC-HCAdhocData/DelhiHC/**/*.txt','LegalAdhocTask/SC-HCAdhocData/JharkhandHC/**/*.txt', 'LegalAdhocTask/SC-HCAdhocData/JodhpurHC/**/*.txt' ,'LegalAdhocTask/SC-HCAdhocData/KolkataHC/**/*.txt', 'LegalAdhocTask/SC-HCAdhocData/SupremeCourt/**/*.txt']
for glob_filenames in x:
    glob_filenames = os.path.normpath(glob_filenames)
    for filename in sorted(glob2.glob(glob_filenames)):
        filenames.append(os.path.basename(filename))

# %%
en_stop = set(get_stop_words('en'))
ps = PorterStemmer()

# "yield" for each file return token list  i.e list of lists
def files_to_tokens(glob_filenames):
    glob_filenames = os.path.normpath(glob_filenames)
    for filename in sorted(glob2.glob(glob_filenames)):
        f = open(filename)
        # read the whole file as lowercase string
        string = (f.read()).lower()
        try:
            temp = word_tokenize(string)
        except:
            string = string.decode("latin-1")
            temp = word_tokenize(string)

        tokens = []
        # tokenize that string
        for word in temp:
            w =  only_alphabet(word).lower()
            if w not in en_stop:
                if w:
                    tokens.append(ps.stem(w))

        yield tokens
        f.close()


        
# yields token list for files specific to courts; needed for creating dictionaries
class texts:
    def DCDRC(self):
        return files_to_tokens('LegalAdhocTask/ConsumerCourtAdhocdata/DCDRC/**/*.txt')
    def NCDRC(self):
        return files_to_tokens('LegalAdhocTask/ConsumerCourtAdhocdata/NCDRC/**/*.txt')
    def SCDRC(self):
        return files_to_tokens('LegalAdhocTask/ConsumerCourtAdhocdata/SCDRC/**/*.txt')
    def DelhiHC(self):
        return files_to_tokens('LegalAdhocTask/SC-HCAdhocData/DelhiHC/**/*.txt')
    def JharkhandHC(self):
        return files_to_tokens('LegalAdhocTask/SC-HCAdhocData/JharkhandHC/**/*.txt')
    def JodhpurHC(self):
        return files_to_tokens('LegalAdhocTask/SC-HCAdhocData/JodhpurHC/**/*.txt')
    def KolkataHC(self):
        return files_to_tokens('LegalAdhocTask/SC-HCAdhocData/KolkataHC/**/*.txt')
    def SupremeCourt(self):
        return files_to_tokens('LegalAdhocTask/SC-HCAdhocData/SupremeCourt/**/*.txt')
    def everything(self):
        return chain(self.DCDRC(), self.NCDRC(), self.SCDRC(), self.DelhiHC(),
                     self.JharkhandHC(), self.JodhpurHC(), self.KolkataHC(), self.SupremeCourt())

# yields bow for each file - tuples id,fq ; needed to train models   
class my_corpus:    
    def DCDRC(self):
        for text in files_to_tokens('LegalAdhocTask/ConsumerCourtAdhocdata/DCDRC/*.txt'):
            yield dictionary.doc2bow(text)
    def NCDRC(self):
        for text in files_to_tokens('LegalAdhocTask/ConsumerCourtAdhocdata/NCDRC/**/*.txt'):
            yield dictionary.doc2bow(text)            
    def SCDRC(self):
        for text in files_to_tokens('LegalAdhocTask/ConsumerCourtAdhocdata/SCDRC/**/*.txt'):
            yield dictionary.doc2bow(text)
    def DelhiHC(self):
        for text in files_to_tokens('LegalAdhocTask/SC-HCAdhocData/DelhiHC/**/*.txt'):
            yield dictionary.doc2bow(text)
    def JharkhandHC(self):
        for text in files_to_tokens('LegalAdhocTask/SC-HCAdhocData/JharkhandHC/**/*.txt'):
            yield dictionary.doc2bow(text)
    def JodhpurHC(self):
        for text in  files_to_tokens('LegalAdhocTask/SC-HCAdhocData/JodhpurHC/**/*.txt'):
            yield dictionary.doc2bow(text)
    def KolkataHC(self):
        for text in  files_to_tokens('LegalAdhocTask/SC-HCAdhocData/KolkataHC/**/*.txt'):
            yield dictionary.doc2bow(text)
    def SupremeCourt(self):
        for text in  files_to_tokens('LegalAdhocTask/SC-HCAdhocData/SupremeCourt/**/*.txt'):
            yield dictionary.doc2bow(text)
    def everything(self):
        return chain(self.DCDRC(), self.NCDRC(), self.SCDRC(), self.DelhiHC(),
                     self.JharkhandHC(), self.JodhpurHC(), self.KolkataHC(), self.SupremeCourt())

# %%
#################################### laod the dictinary
dictionary = corpora.Dictionary.load('dict/stem10')
# Out:
# 2018-04-29 17:41:02,006 : INFO : loading Dictionary object from dict/stem10
# 2018-04-29 17:41:02,053 : INFO : loaded dict/stem10

# %%
######################################## load BOW
corpus = corpora.MmCorpus('corpus/bow_stem10.mm')
# Out:
# 2018-04-29 17:41:02,157 : INFO : loaded corpus index from corpus/bow_stem10.mm.index
# 2018-04-29 17:41:02,157 : INFO : initializing cython corpus reader from corpus/bow_stem10.mm
# 2018-04-29 17:41:02,158 : INFO : accepted corpus with 351985 documents, 155879 features, 96286955 non-zero entries

# %%
# %%time
# Tfidf model
# Will take time as to generate a model it processes over the whole corpus
tfidf = gensim.models.TfidfModel(corpus)
# save tfidf model
tfidf.save('py_models/tfidf_stem10.mdl')
# Out:
# 2018-04-29 17:41:02,240 : INFO : collecting document frequencies
# 2018-04-29 17:41:02,241 : INFO : PROGRESS: processing document #0
# 2018-04-29 17:41:03,811 : INFO : PROGRESS: processing document #10000
# 2018-04-29 17:41:05,612 : INFO : PROGRESS: processing document #20000
# 2018-04-29 17:41:07,297 : INFO : PROGRESS: processing document #30000
# 2018-04-29 17:41:09,072 : INFO : PROGRESS: processing document #40000
# 2018-04-29 17:41:10,494 : INFO : PROGRESS: processing document #50000
# 2018-04-29 17:41:12,095 : INFO : PROGRESS: processing document #60000
# 2018-04-29 17:41:13,565 : INFO : PROGRESS: processing document #70000
# 2018-04-29 17:41:15,276 : INFO : PROGRESS: processing document #80000
# 2018-04-29 17:41:17,091 : INFO : PROGRESS: processing document #90000
# 2018-04-29 17:41:19,102 : INFO : PROGRESS: processing document #100000
# 2018-04-29 17:41:21,159 : INFO : PROGRESS: processing document #110000
# 2018-04-29 17:41:22,280 : INFO : PROGRESS: processing document #120000
# 2018-04-29 17:41:23,964 : INFO : PROGRESS: processing document #130000
# 2018-04-29 17:41:25,032 : INFO : PROGRESS: processing document #140000
# 2018-04-29 17:41:26,384 : INFO : PROGRESS: processing document #150000
# 2018-04-29 17:41:27,840 : INFO : PROGRESS: processing document #160000
# 2018-04-29 17:41:29,306 : INFO : PROGRESS: processing document #170000
# 2018-04-29 17:41:30,947 : INFO : PROGRESS: processing document #180000
# 2018-04-29 17:41:32,830 : INFO : PROGRESS: processing document #190000
# 2018-04-29 17:41:34,949 : INFO : PROGRESS: processing document #200000
# 2018-04-29 17:41:37,038 : INFO : PROGRESS: processing document #210000
# 2018-04-29 17:41:38,901 : INFO : PROGRESS: processing document #220000
# 2018-04-29 17:41:39,533 : INFO : PROGRESS: processing document #230000
# 2018-04-29 17:41:39,958 : INFO : PROGRESS: processing document #240000
# 2018-04-29 17:41:40,510 : INFO : PROGRESS: processing document #250000
# 2018-04-29 17:41:40,979 : INFO : PROGRESS: processing document #260000
# 2018-04-29 17:41:41,409 : INFO : PROGRESS: processing document #270000
# 2018-04-29 17:41:42,036 : INFO : PROGRESS: processing document #280000
# 2018-04-29 17:41:42,579 : INFO : PROGRESS: processing document #290000
# 2018-04-29 17:41:43,386 : INFO : PROGRESS: processing document #300000
# 2018-04-29 17:41:44,247 : INFO : PROGRESS: processing document #310000
# 2018-04-29 17:41:45,246 : INFO : PROGRESS: processing document #320000
# 2018-04-29 17:41:48,134 : INFO : PROGRESS: processing document #330000
# 2018-04-29 17:41:50,549 : INFO : PROGRESS: processing document #340000
# 2018-04-29 17:41:52,817 : INFO : PROGRESS: processing document #350000
# 2018-04-29 17:41:53,345 : INFO : calculating IDF weights for 351985 documents and 155878 features (96286955 matrix non-zeros)
# 2018-04-29 17:41:53,618 : INFO : saving TfidfModel object under py_models/tfidf_stem10.mdl, separately None
# 2018-04-29 17:41:54,126 : INFO : saved py_models/tfidf_stem10.mdl
# CPU times: user 51.6 s, sys: 316 ms, total: 51.9 s
# Wall time: 51.9 s

# %%
##################################### load tfidf model
tfidf = gensim.models.tfidfmodel.TfidfModel.load('py_models/tfidf_stem10.mdl')
# Out:
# 2018-04-29 17:41:54,131 : INFO : loading TfidfModel object from py_models/tfidf_stem10.mdl
# 2018-04-29 17:41:54,206 : INFO : loaded py_models/tfidf_stem10.mdl

# %%
# %%time
# tfidf wrapper coprus
# doesn't take time - yield
tfidf_corpus = tfidf[corpus]

# actual tfidf corpus serialized
corpora.MmCorpus.serialize('corpus/tfidf_stem10.mm', tfidf_corpus)
# Out:
# 2018-04-29 17:41:54,252 : INFO : storing corpus in Matrix Market format to corpus/tfidf_stem10.mm
# 2018-04-29 17:41:54,253 : INFO : saving sparse matrix to corpus/tfidf_stem10.mm
# 2018-04-29 17:41:54,255 : INFO : PROGRESS: saving document #0
# 2018-04-29 17:41:55,831 : INFO : PROGRESS: saving document #1000
# 2018-04-29 17:41:57,059 : INFO : PROGRESS: saving document #2000
# 2018-04-29 17:41:58,566 : INFO : PROGRESS: saving document #3000
# 2018-04-29 17:42:00,400 : INFO : PROGRESS: saving document #4000
# 2018-04-29 17:42:02,635 : INFO : PROGRESS: saving document #5000
# 2018-04-29 17:42:04,152 : INFO : PROGRESS: saving document #6000
# 2018-04-29 17:42:05,758 : INFO : PROGRESS: saving document #7000
# 2018-04-29 17:42:08,211 : INFO : PROGRESS: saving document #8000
# 2018-04-29 17:42:10,040 : INFO : PROGRESS: saving document #9000
# 2018-04-29 17:42:12,385 : INFO : PROGRESS: saving document #10000
# 2018-04-29 17:42:14,302 : INFO : PROGRESS: saving document #11000
# 2018-04-29 17:42:16,078 : INFO : PROGRESS: saving document #12000
# 2018-04-29 17:42:17,877 : INFO : PROGRESS: saving document #13000
# 2018-04-29 17:42:19,844 : INFO : PROGRESS: saving document #14000
# 2018-04-29 17:42:22,257 : INFO : PROGRESS: saving document #15000
# 2018-04-29 17:42:24,860 : INFO : PROGRESS: saving document #16000
# 2018-04-29 17:42:26,674 : INFO : PROGRESS: saving document #17000
# 2018-04-29 17:42:28,586 : INFO : PROGRESS: saving document #18000
# 2018-04-29 17:42:30,750 : INFO : PROGRESS: saving document #19000
# 2018-04-29 17:42:32,194 : INFO : PROGRESS: saving document #20000
# 2018-04-29 17:42:33,691 : INFO : PROGRESS: saving document #21000
# 2018-04-29 17:42:35,299 : INFO : PROGRESS: saving document #22000
# 2018-04-29 17:42:37,232 : INFO : PROGRESS: saving document #23000
# 2018-04-29 17:42:39,074 : INFO : PROGRESS: saving document #24000
# 2018-04-29 17:42:41,091 : INFO : PROGRESS: saving document #25000
# 2018-04-29 17:42:43,076 : INFO : PROGRESS: saving document #26000
# 2018-04-29 17:42:44,932 : INFO : PROGRESS: saving document #27000
# 2018-04-29 17:42:47,062 : INFO : PROGRESS: saving document #28000
# 2018-04-29 17:42:49,082 : INFO : PROGRESS: saving document #29000
# 2018-04-29 17:42:51,035 : INFO : PROGRESS: saving document #30000
# 2018-04-29 17:42:52,492 : INFO : PROGRESS: saving document #31000
# 2018-04-29 17:42:54,031 : INFO : PROGRESS: saving document #32000
# 2018-04-29 17:42:56,250 : INFO : PROGRESS: saving document #33000
# 2018-04-29 17:42:58,133 : INFO : PROGRESS: saving document #34000
# 2018-04-29 17:43:01,254 : INFO : PROGRESS: saving document #35000
# 2018-04-29 17:43:04,027 : INFO : PROGRESS: saving document #36000
# 2018-04-29 17:43:06,179 : INFO : PROGRESS: saving document #37000
# 2018-04-29 17:43:07,817 : INFO : PROGRESS: saving document #38000
# 2018-04-29 17:43:09,826 : INFO : PROGRESS: saving document #39000
# 2018-04-29 17:43:11,399 : INFO : PROGRESS: saving document #40000
# 2018-04-29 17:43:13,039 : INFO : PROGRESS: saving document #41000
# 2018-04-29 17:43:14,176 : INFO : PROGRESS: saving document #42000
# 2018-04-29 17:43:15,364 : INFO : PROGRESS: saving document #43000
# 2018-04-29 17:43:16,828 : INFO : PROGRESS: saving document #44000
# 2018-04-29 17:43:18,522 : INFO : PROGRESS: saving document #45000
# 2018-04-29 17:43:19,842 : INFO : PROGRESS: saving document #46000
# 2018-04-29 17:43:21,049 : INFO : PROGRESS: saving document #47000
# 2018-04-29 17:43:22,887 : INFO : PROGRESS: saving document #48000
# 2018-04-29 17:43:24,854 : INFO : PROGRESS: saving document #49000
# 2018-04-29 17:43:26,686 : INFO : PROGRESS: saving document #50000
# 2018-04-29 17:43:28,181 : INFO : PROGRESS: saving document #51000
# 2018-04-29 17:43:30,117 : INFO : PROGRESS: saving document #52000
# 2018-04-29 17:43:31,800 : INFO : PROGRESS: saving document #53000
# 2018-04-29 17:43:33,252 : INFO : PROGRESS: saving document #54000
# 2018-04-29 17:43:35,362 : INFO : PROGRESS: saving document #55000
# 2018-04-29 17:43:37,145 : INFO : PROGRESS: saving document #56000
# 2018-04-29 17:43:39,119 : INFO : PROGRESS: saving document #57000
# 2018-04-29 17:43:41,601 : INFO : PROGRESS: saving document #58000
# 2018-04-29 17:43:43,480 : INFO : PROGRESS: saving document #59000
# 2018-04-29 17:43:44,594 : INFO : PROGRESS: saving document #60000
# 2018-04-29 17:43:46,280 : INFO : PROGRESS: saving document #61000
# 2018-04-29 17:43:47,604 : INFO : PROGRESS: saving document #62000
# 2018-04-29 17:43:49,041 : INFO : PROGRESS: saving document #63000
# 2018-04-29 17:43:50,510 : INFO : PROGRESS: saving document #64000
# 2018-04-29 17:43:52,456 : INFO : PROGRESS: saving document #65000
# 2018-04-29 17:43:54,048 : INFO : PROGRESS: saving document #66000
# 2018-04-29 17:43:56,030 : INFO : PROGRESS: saving document #67000
# 2018-04-29 17:43:57,779 : INFO : PROGRESS: saving document #68000
# 2018-04-29 17:43:59,009 : INFO : PROGRESS: saving document #69000
# 2018-04-29 17:44:00,570 : INFO : PROGRESS: saving document #70000
# 2018-04-29 17:44:02,864 : INFO : PROGRESS: saving document #71000
# 2018-04-29 17:44:04,819 : INFO : PROGRESS: saving document #72000
# 2018-04-29 17:44:06,638 : INFO : PROGRESS: saving document #73000
# 2018-04-29 17:44:08,300 : INFO : PROGRESS: saving document #74000
# 2018-04-29 17:44:09,843 : INFO : PROGRESS: saving document #75000
# 2018-04-29 17:44:11,579 : INFO : PROGRESS: saving document #76000
# 2018-04-29 17:44:13,203 : INFO : PROGRESS: saving document #77000
# 2018-04-29 17:44:15,079 : INFO : PROGRESS: saving document #78000
# 2018-04-29 17:44:17,003 : INFO : PROGRESS: saving document #79000
# 2018-04-29 17:44:18,798 : INFO : PROGRESS: saving document #80000
# 2018-04-29 17:44:20,607 : INFO : PROGRESS: saving document #81000
# 2018-04-29 17:44:22,635 : INFO : PROGRESS: saving document #82000
# 2018-04-29 17:44:24,380 : INFO : PROGRESS: saving document #83000
# 2018-04-29 17:44:26,555 : INFO : PROGRESS: saving document #84000
# 2018-04-29 17:44:28,692 : INFO : PROGRESS: saving document #85000
# 2018-04-29 17:44:30,703 : INFO : PROGRESS: saving document #86000
# 2018-04-29 17:44:32,606 : INFO : PROGRESS: saving document #87000
# 2018-04-29 17:44:34,307 : INFO : PROGRESS: saving document #88000
# 2018-04-29 17:44:36,758 : INFO : PROGRESS: saving document #89000
# 2018-04-29 17:44:38,729 : INFO : PROGRESS: saving document #90000
# 2018-04-29 17:44:40,750 : INFO : PROGRESS: saving document #91000
# 2018-04-29 17:44:43,006 : INFO : PROGRESS: saving document #92000
# 2018-04-29 17:44:45,388 : INFO : PROGRESS: saving document #93000
# 2018-04-29 17:44:47,468 : INFO : PROGRESS: saving document #94000
# 2018-04-29 17:44:49,659 : INFO : PROGRESS: saving document #95000
# 2018-04-29 17:44:51,803 : INFO : PROGRESS: saving document #96000
# 2018-04-29 17:44:54,191 : INFO : PROGRESS: saving document #97000
# 2018-04-29 17:44:56,470 : INFO : PROGRESS: saving document #98000
# 2018-04-29 17:44:58,590 : INFO : PROGRESS: saving document #99000
# 2018-04-29 17:45:00,726 : INFO : PROGRESS: saving document #100000
# 2018-04-29 17:45:02,698 : INFO : PROGRESS: saving document #101000
# 2018-04-29 17:45:04,714 : INFO : PROGRESS: saving document #102000
# 2018-04-29 17:45:07,004 : INFO : PROGRESS: saving document #103000
# 2018-04-29 17:45:09,171 : INFO : PROGRESS: saving document #104000
# 2018-04-29 17:45:11,386 : INFO : PROGRESS: saving document #105000
# 2018-04-29 17:45:13,965 : INFO : PROGRESS: saving document #106000
# 2018-04-29 17:45:16,403 : INFO : PROGRESS: saving document #107000
# 2018-04-29 17:45:18,828 : INFO : PROGRESS: saving document #108000
# 2018-04-29 17:45:20,391 : INFO : PROGRESS: saving document #109000
# 2018-04-29 17:45:22,104 : INFO : PROGRESS: saving document #110000
# 2018-04-29 17:45:23,344 : INFO : PROGRESS: saving document #111000
# 2018-04-29 17:45:24,337 : INFO : PROGRESS: saving document #112000
# 2018-04-29 17:45:25,554 : INFO : PROGRESS: saving document #113000
# 2018-04-29 17:45:26,906 : INFO : PROGRESS: saving document #114000
# 2018-04-29 17:45:27,932 : INFO : PROGRESS: saving document #115000
# 2018-04-29 17:45:28,759 : INFO : PROGRESS: saving document #116000
# 2018-04-29 17:45:30,084 : INFO : PROGRESS: saving document #117000
# 2018-04-29 17:45:31,516 : INFO : PROGRESS: saving document #118000
# 2018-04-29 17:45:32,901 : INFO : PROGRESS: saving document #119000
# 2018-04-29 17:45:34,236 : INFO : PROGRESS: saving document #120000
# 2018-04-29 17:45:35,706 : INFO : PROGRESS: saving document #121000
# 2018-04-29 17:45:37,177 : INFO : PROGRESS: saving document #122000
# 2018-04-29 17:45:39,073 : INFO : PROGRESS: saving document #123000
# 2018-04-29 17:45:41,218 : INFO : PROGRESS: saving document #124000
# 2018-04-29 17:45:43,894 : INFO : PROGRESS: saving document #125000
# 2018-04-29 17:45:46,156 : INFO : PROGRESS: saving document #126000
# 2018-04-29 17:45:47,986 : INFO : PROGRESS: saving document #127000
# 2018-04-29 17:45:49,449 : INFO : PROGRESS: saving document #128000
# 2018-04-29 17:45:50,947 : INFO : PROGRESS: saving document #129000
# 2018-04-29 17:45:52,105 : INFO : PROGRESS: saving document #130000
# 2018-04-29 17:45:53,173 : INFO : PROGRESS: saving document #131000
# 2018-04-29 17:45:54,271 : INFO : PROGRESS: saving document #132000
# 2018-04-29 17:45:55,350 : INFO : PROGRESS: saving document #133000
# 2018-04-29 17:45:56,584 : INFO : PROGRESS: saving document #134000
# 2018-04-29 17:45:57,644 : INFO : PROGRESS: saving document #135000
# 2018-04-29 17:45:58,680 : INFO : PROGRESS: saving document #136000
# 2018-04-29 17:45:59,851 : INFO : PROGRESS: saving document #137000
# 2018-04-29 17:46:01,099 : INFO : PROGRESS: saving document #138000
# 2018-04-29 17:46:02,224 : INFO : PROGRESS: saving document #139000
# 2018-04-29 17:46:03,308 : INFO : PROGRESS: saving document #140000
# 2018-04-29 17:46:04,497 : INFO : PROGRESS: saving document #141000
# 2018-04-29 17:46:06,053 : INFO : PROGRESS: saving document #142000
# 2018-04-29 17:46:07,514 : INFO : PROGRESS: saving document #143000
# 2018-04-29 17:46:09,234 : INFO : PROGRESS: saving document #144000
# 2018-04-29 17:46:10,865 : INFO : PROGRESS: saving document #145000
# 2018-04-29 17:46:12,358 : INFO : PROGRESS: saving document #146000
# 2018-04-29 17:46:13,508 : INFO : PROGRESS: saving document #147000
# 2018-04-29 17:46:14,963 : INFO : PROGRESS: saving document #148000
# 2018-04-29 17:46:16,079 : INFO : PROGRESS: saving document #149000
# 2018-04-29 17:46:17,410 : INFO : PROGRESS: saving document #150000
# 2018-04-29 17:46:19,138 : INFO : PROGRESS: saving document #151000
# 2018-04-29 17:46:20,701 : INFO : PROGRESS: saving document #152000
# 2018-04-29 17:46:22,143 : INFO : PROGRESS: saving document #153000
# 2018-04-29 17:46:22,965 : INFO : PROGRESS: saving document #154000
# 2018-04-29 17:46:24,324 : INFO : PROGRESS: saving document #155000
# 2018-04-29 17:46:26,088 : INFO : PROGRESS: saving document #156000
# 2018-04-29 17:46:28,214 : INFO : PROGRESS: saving document #157000
# 2018-04-29 17:46:30,067 : INFO : PROGRESS: saving document #158000
# 2018-04-29 17:46:31,533 : INFO : PROGRESS: saving document #159000
# 2018-04-29 17:46:32,911 : INFO : PROGRESS: saving document #160000
# 2018-04-29 17:46:34,511 : INFO : PROGRESS: saving document #161000
# 2018-04-29 17:46:36,149 : INFO : PROGRESS: saving document #162000
# 2018-04-29 17:46:38,173 : INFO : PROGRESS: saving document #163000
# 2018-04-29 17:46:40,295 : INFO : PROGRESS: saving document #164000
# 2018-04-29 17:46:41,773 : INFO : PROGRESS: saving document #165000
# 2018-04-29 17:46:43,105 : INFO : PROGRESS: saving document #166000
# 2018-04-29 17:46:44,352 : INFO : PROGRESS: saving document #167000
# 2018-04-29 17:46:45,656 : INFO : PROGRESS: saving document #168000
# 2018-04-29 17:46:46,826 : INFO : PROGRESS: saving document #169000
# 2018-04-29 17:46:48,607 : INFO : PROGRESS: saving document #170000
# 2018-04-29 17:46:50,644 : INFO : PROGRESS: saving document #171000
# 2018-04-29 17:46:52,210 : INFO : PROGRESS: saving document #172000
# 2018-04-29 17:46:53,400 : INFO : PROGRESS: saving document #173000
# 2018-04-29 17:46:55,443 : INFO : PROGRESS: saving document #174000
# 2018-04-29 17:46:58,119 : INFO : PROGRESS: saving document #175000
# 2018-04-29 17:47:00,090 : INFO : PROGRESS: saving document #176000
# 2018-04-29 17:47:01,511 : INFO : PROGRESS: saving document #177000
# 2018-04-29 17:47:03,119 : INFO : PROGRESS: saving document #178000
# 2018-04-29 17:47:04,695 : INFO : PROGRESS: saving document #179000
# 2018-04-29 17:47:06,357 : INFO : PROGRESS: saving document #180000
# 2018-04-29 17:47:07,978 : INFO : PROGRESS: saving document #181000
# 2018-04-29 17:47:09,614 : INFO : PROGRESS: saving document #182000
# 2018-04-29 17:47:11,140 : INFO : PROGRESS: saving document #183000
# 2018-04-29 17:47:13,479 : INFO : PROGRESS: saving document #184000
# 2018-04-29 17:47:15,536 : INFO : PROGRESS: saving document #185000
# 2018-04-29 17:47:17,633 : INFO : PROGRESS: saving document #186000
# 2018-04-29 17:47:19,911 : INFO : PROGRESS: saving document #187000
# 2018-04-29 17:47:22,114 : INFO : PROGRESS: saving document #188000
# 2018-04-29 17:47:24,107 : INFO : PROGRESS: saving document #189000
# 2018-04-29 17:47:26,751 : INFO : PROGRESS: saving document #190000
# 2018-04-29 17:47:29,138 : INFO : PROGRESS: saving document #191000
# 2018-04-29 17:47:31,164 : INFO : PROGRESS: saving document #192000
# 2018-04-29 17:47:33,441 : INFO : PROGRESS: saving document #193000
# 2018-04-29 17:47:35,962 : INFO : PROGRESS: saving document #194000
# 2018-04-29 17:47:38,134 : INFO : PROGRESS: saving document #195000
# 2018-04-29 17:47:40,640 : INFO : PROGRESS: saving document #196000
# 2018-04-29 17:47:42,687 : INFO : PROGRESS: saving document #197000
# 2018-04-29 17:47:44,608 : INFO : PROGRESS: saving document #198000
# 2018-04-29 17:47:46,805 : INFO : PROGRESS: saving document #199000
# 2018-04-29 17:47:49,373 : INFO : PROGRESS: saving document #200000
# 2018-04-29 17:47:51,384 : INFO : PROGRESS: saving document #201000
# 2018-04-29 17:47:53,893 : INFO : PROGRESS: saving document #202000
# 2018-04-29 17:47:56,169 : INFO : PROGRESS: saving document #203000
# 2018-04-29 17:47:58,139 : INFO : PROGRESS: saving document #204000
# 2018-04-29 17:48:00,413 : INFO : PROGRESS: saving document #205000
# 2018-04-29 17:48:02,504 : INFO : PROGRESS: saving document #206000
# 2018-04-29 17:48:04,872 : INFO : PROGRESS: saving document #207000
# 2018-04-29 17:48:06,496 : INFO : PROGRESS: saving document #208000
# 2018-04-29 17:48:08,677 : INFO : PROGRESS: saving document #209000
# 2018-04-29 17:48:10,896 : INFO : PROGRESS: saving document #210000
# 2018-04-29 17:48:13,356 : INFO : PROGRESS: saving document #211000
# 2018-04-29 17:48:15,768 : INFO : PROGRESS: saving document #212000
# 2018-04-29 17:48:18,208 : INFO : PROGRESS: saving document #213000
# 2018-04-29 17:48:20,457 : INFO : PROGRESS: saving document #214000
# 2018-04-29 17:48:23,029 : INFO : PROGRESS: saving document #215000
# 2018-04-29 17:48:24,872 : INFO : PROGRESS: saving document #216000
# 2018-04-29 17:48:27,163 : INFO : PROGRESS: saving document #217000
# 2018-04-29 17:48:28,417 : INFO : PROGRESS: saving document #218000
# 2018-04-29 17:48:29,436 : INFO : PROGRESS: saving document #219000
# 2018-04-29 17:48:30,681 : INFO : PROGRESS: saving document #220000
# 2018-04-29 17:48:31,909 : INFO : PROGRESS: saving document #221000
# 2018-04-29 17:48:32,987 : INFO : PROGRESS: saving document #222000
# 2018-04-29 17:48:34,053 : INFO : PROGRESS: saving document #223000
# 2018-04-29 17:48:34,638 : INFO : PROGRESS: saving document #224000
# 2018-04-29 17:48:35,173 : INFO : PROGRESS: saving document #225000
# 2018-04-29 17:48:35,635 : INFO : PROGRESS: saving document #226000
# 2018-04-29 17:48:36,104 : INFO : PROGRESS: saving document #227000
# 2018-04-29 17:48:36,596 : INFO : PROGRESS: saving document #228000
# 2018-04-29 17:48:37,100 : INFO : PROGRESS: saving document #229000
# 2018-04-29 17:48:37,618 : INFO : PROGRESS: saving document #230000
# 2018-04-29 17:48:38,117 : INFO : PROGRESS: saving document #231000
# 2018-04-29 17:48:38,619 : INFO : PROGRESS: saving document #232000
# 2018-04-29 17:48:39,119 : INFO : PROGRESS: saving document #233000
# 2018-04-29 17:48:39,595 : INFO : PROGRESS: saving document #234000
# 2018-04-29 17:48:40,076 : INFO : PROGRESS: saving document #235000
# 2018-04-29 17:48:40,557 : INFO : PROGRESS: saving document #236000
# 2018-04-29 17:48:41,039 : INFO : PROGRESS: saving document #237000
# 2018-04-29 17:48:41,509 : INFO : PROGRESS: saving document #238000
# 2018-04-29 17:48:41,966 : INFO : PROGRESS: saving document #239000
# 2018-04-29 17:48:42,414 : INFO : PROGRESS: saving document #240000
# 2018-04-29 17:48:42,863 : INFO : PROGRESS: saving document #241000
# 2018-04-29 17:48:43,481 : INFO : PROGRESS: saving document #242000
# 2018-04-29 17:48:44,073 : INFO : PROGRESS: saving document #243000
# 2018-04-29 17:48:44,725 : INFO : PROGRESS: saving document #244000
# 2018-04-29 17:48:45,316 : INFO : PROGRESS: saving document #245000
# 2018-04-29 17:48:45,871 : INFO : PROGRESS: saving document #246000
# 2018-04-29 17:48:46,523 : INFO : PROGRESS: saving document #247000
# 2018-04-29 17:48:47,135 : INFO : PROGRESS: saving document #248000
# 2018-04-29 17:48:47,761 : INFO : PROGRESS: saving document #249000
# 2018-04-29 17:48:48,460 : INFO : PROGRESS: saving document #250000
# 2018-04-29 17:48:49,131 : INFO : PROGRESS: saving document #251000
# 2018-04-29 17:48:49,756 : INFO : PROGRESS: saving document #252000
# 2018-04-29 17:48:50,335 : INFO : PROGRESS: saving document #253000
# 2018-04-29 17:48:50,866 : INFO : PROGRESS: saving document #254000
# 2018-04-29 17:48:51,373 : INFO : PROGRESS: saving document #255000
# 2018-04-29 17:48:51,831 : INFO : PROGRESS: saving document #256000
# 2018-04-29 17:48:52,281 : INFO : PROGRESS: saving document #257000
# 2018-04-29 17:48:52,730 : INFO : PROGRESS: saving document #258000
# 2018-04-29 17:48:53,181 : INFO : PROGRESS: saving document #259000
# 2018-04-29 17:48:53,630 : INFO : PROGRESS: saving document #260000
# 2018-04-29 17:48:54,092 : INFO : PROGRESS: saving document #261000
# 2018-04-29 17:48:54,556 : INFO : PROGRESS: saving document #262000
# 2018-04-29 17:48:55,025 : INFO : PROGRESS: saving document #263000
# 2018-04-29 17:48:55,492 : INFO : PROGRESS: saving document #264000
# 2018-04-29 17:48:55,954 : INFO : PROGRESS: saving document #265000
# 2018-04-29 17:48:56,437 : INFO : PROGRESS: saving document #266000
# 2018-04-29 17:48:56,941 : INFO : PROGRESS: saving document #267000
# 2018-04-29 17:48:57,442 : INFO : PROGRESS: saving document #268000
# 2018-04-29 17:48:57,913 : INFO : PROGRESS: saving document #269000
# 2018-04-29 17:48:58,464 : INFO : PROGRESS: saving document #270000
# 2018-04-29 17:48:59,191 : INFO : PROGRESS: saving document #271000
# 2018-04-29 17:48:59,815 : INFO : PROGRESS: saving document #272000
# 2018-04-29 17:49:00,513 : INFO : PROGRESS: saving document #273000
# 2018-04-29 17:49:01,239 : INFO : PROGRESS: saving document #274000
# 2018-04-29 17:49:01,816 : INFO : PROGRESS: saving document #275000
# 2018-04-29 17:49:02,621 : INFO : PROGRESS: saving document #276000
# 2018-04-29 17:49:03,270 : INFO : PROGRESS: saving document #277000
# 2018-04-29 17:49:03,918 : INFO : PROGRESS: saving document #278000
# 2018-04-29 17:49:04,565 : INFO : PROGRESS: saving document #279000
# 2018-04-29 17:49:05,206 : INFO : PROGRESS: saving document #280000
# 2018-04-29 17:49:05,836 : INFO : PROGRESS: saving document #281000
# 2018-04-29 17:49:06,446 : INFO : PROGRESS: saving document #282000
# 2018-04-29 17:49:07,001 : INFO : PROGRESS: saving document #283000
# 2018-04-29 17:49:07,494 : INFO : PROGRESS: saving document #284000
# 2018-04-29 17:49:08,022 : INFO : PROGRESS: saving document #285000
# 2018-04-29 17:49:08,546 : INFO : PROGRESS: saving document #286000
# 2018-04-29 17:49:09,026 : INFO : PROGRESS: saving document #287000
# 2018-04-29 17:49:09,495 : INFO : PROGRESS: saving document #288000
# 2018-04-29 17:49:10,168 : INFO : PROGRESS: saving document #289000
# 2018-04-29 17:49:11,137 : INFO : PROGRESS: saving document #290000
# 2018-04-29 17:49:12,034 : INFO : PROGRESS: saving document #291000
# 2018-04-29 17:49:12,961 : INFO : PROGRESS: saving document #292000
# 2018-04-29 17:49:13,917 : INFO : PROGRESS: saving document #293000
# 2018-04-29 17:49:14,807 : INFO : PROGRESS: saving document #294000
# 2018-04-29 17:49:15,767 : INFO : PROGRESS: saving document #295000
# 2018-04-29 17:49:16,497 : INFO : PROGRESS: saving document #296000
# 2018-04-29 17:49:17,360 : INFO : PROGRESS: saving document #297000
# 2018-04-29 17:49:18,167 : INFO : PROGRESS: saving document #298000
# 2018-04-29 17:49:19,138 : INFO : PROGRESS: saving document #299000
# 2018-04-29 17:49:19,900 : INFO : PROGRESS: saving document #300000
# 2018-04-29 17:49:20,852 : INFO : PROGRESS: saving document #301000
# 2018-04-29 17:49:21,619 : INFO : PROGRESS: saving document #302000
# 2018-04-29 17:49:22,351 : INFO : PROGRESS: saving document #303000
# 2018-04-29 17:49:23,217 : INFO : PROGRESS: saving document #304000
# 2018-04-29 17:49:24,004 : INFO : PROGRESS: saving document #305000
# 2018-04-29 17:49:24,964 : INFO : PROGRESS: saving document #306000
# 2018-04-29 17:49:25,971 : INFO : PROGRESS: saving document #307000
# 2018-04-29 17:49:27,112 : INFO : PROGRESS: saving document #308000
# 2018-04-29 17:49:27,976 : INFO : PROGRESS: saving document #309000
# 2018-04-29 17:49:29,343 : INFO : PROGRESS: saving document #310000
# 2018-04-29 17:49:30,608 : INFO : PROGRESS: saving document #311000
# 2018-04-29 17:49:31,863 : INFO : PROGRESS: saving document #312000
# 2018-04-29 17:49:33,046 : INFO : PROGRESS: saving document #313000
# 2018-04-29 17:49:34,034 : INFO : PROGRESS: saving document #314000
# 2018-04-29 17:49:34,960 : INFO : PROGRESS: saving document #315000
# 2018-04-29 17:49:36,136 : INFO : PROGRESS: saving document #316000
# 2018-04-29 17:49:37,019 : INFO : PROGRESS: saving document #317000
# 2018-04-29 17:49:37,853 : INFO : PROGRESS: saving document #318000
# 2018-04-29 17:49:38,844 : INFO : PROGRESS: saving document #319000
# 2018-04-29 17:49:40,019 : INFO : PROGRESS: saving document #320000
# 2018-04-29 17:49:41,663 : INFO : PROGRESS: saving document #321000
# 2018-04-29 17:49:44,710 : INFO : PROGRESS: saving document #322000
# 2018-04-29 17:49:48,233 : INFO : PROGRESS: saving document #323000
# 2018-04-29 17:49:51,316 : INFO : PROGRESS: saving document #324000
# 2018-04-29 17:49:54,363 : INFO : PROGRESS: saving document #325000
# 2018-04-29 17:49:57,161 : INFO : PROGRESS: saving document #326000
# 2018-04-29 17:50:00,072 : INFO : PROGRESS: saving document #327000
# 2018-04-29 17:50:03,373 : INFO : PROGRESS: saving document #328000
# 2018-04-29 17:50:06,752 : INFO : PROGRESS: saving document #329000
# 2018-04-29 17:50:10,838 : INFO : PROGRESS: saving document #330000
# 2018-04-29 17:50:13,973 : INFO : PROGRESS: saving document #331000
# 2018-04-29 17:50:17,085 : INFO : PROGRESS: saving document #332000
# 2018-04-29 17:50:19,846 : INFO : PROGRESS: saving document #333000
# 2018-04-29 17:50:22,455 : INFO : PROGRESS: saving document #334000
# 2018-04-29 17:50:24,409 : INFO : PROGRESS: saving document #335000
# 2018-04-29 17:50:26,354 : INFO : PROGRESS: saving document #336000
# 2018-04-29 17:50:28,295 : INFO : PROGRESS: saving document #337000
# 2018-04-29 17:50:30,500 : INFO : PROGRESS: saving document #338000
# 2018-04-29 17:50:32,949 : INFO : PROGRESS: saving document #339000
# 2018-04-29 17:50:35,333 : INFO : PROGRESS: saving document #340000
# 2018-04-29 17:50:37,899 : INFO : PROGRESS: saving document #341000
# 2018-04-29 17:50:40,553 : INFO : PROGRESS: saving document #342000
# 2018-04-29 17:50:43,433 : INFO : PROGRESS: saving document #343000
# 2018-04-29 17:50:46,111 : INFO : PROGRESS: saving document #344000
# 2018-04-29 17:50:48,450 : INFO : PROGRESS: saving document #345000
# 2018-04-29 17:50:50,334 : INFO : PROGRESS: saving document #346000
# 2018-04-29 17:50:52,475 : INFO : PROGRESS: saving document #347000
# 2018-04-29 17:50:54,730 : INFO : PROGRESS: saving document #348000
# 2018-04-29 17:50:56,880 : INFO : PROGRESS: saving document #349000
# 2018-04-29 17:50:59,305 : INFO : PROGRESS: saving document #350000
# 2018-04-29 17:51:01,936 : INFO : PROGRESS: saving document #351000
# 2018-04-29 17:51:04,649 : INFO : saved 351985x155879 matrix, density=0.175% (96286955/54867069815)
# 2018-04-29 17:51:04,650 : INFO : saving MmCorpus index to corpus/tfidf_stem10.mm.index
# CPU times: user 9min 4s, sys: 3.33 s, total: 9min 7s
# Wall time: 9min 10s

# %%
##################################### load tfidf corpus
tfidf_corpus = corpora.MmCorpus('corpus/tfidf_stem10.mm')
# Out:
# 2018-04-29 17:51:04,763 : INFO : loaded corpus index from corpus/tfidf_stem10.mm.index
# 2018-04-29 17:51:04,764 : INFO : initializing cython corpus reader from corpus/tfidf_stem10.mm
# 2018-04-29 17:51:04,765 : INFO : accepted corpus with 351985 documents, 155879 features, 96286955 non-zero entries

# %%
# get the query truth in dictionary
query_truth = {}
for i in range(1,11):
    query_truth[str(i)]=[]
    
    
f = open('LegalAdhocTask/Consumer.qrels')
lines = [line.rstrip('\n').split("\t") for line in f]
for line in lines:
    del line[1]
    query_truth[line[0]].append(line[1:])

# %%
# %%time
# create index - Tfidf
tfidf_index = gensim.similarities.Similarity('py_models/tfidf_stem10.index',tfidf_corpus,len(dictionary))

# save index - tfidf
gensim.similarities.Similarity.save(tfidf_index,'py_models/TFIDF_stem10_index')
# Out:
# 2018-04-29 17:51:04,994 : INFO : starting similarity index under py_models/tfidf_stem10.index
# 2018-04-29 17:51:09,208 : INFO : PROGRESS: fresh_shard size=10000
# 2018-04-29 17:51:14,323 : INFO : PROGRESS: fresh_shard size=20000
# 2018-04-29 17:51:18,681 : INFO : PROGRESS: fresh_shard size=30000
# 2018-04-29 17:51:19,799 : INFO : creating sparse index
# 2018-04-29 17:51:19,799 : INFO : creating sparse matrix from corpus
# 2018-04-29 17:51:19,800 : INFO : PROGRESS: at document #0/32768
# 2018-04-29 17:51:24,733 : INFO : PROGRESS: at document #10000/32768
# 2018-04-29 17:51:29,998 : INFO : PROGRESS: at document #20000/32768
# 2018-04-29 17:51:35,212 : INFO : PROGRESS: at document #30000/32768
# 2018-04-29 17:51:36,454 : INFO : created <32768x155879 sparse matrix of type '<type 'numpy.float32'>'
# 	with 10592639 stored elements in Compressed Sparse Row format>
# 2018-04-29 17:51:36,455 : INFO : creating sparse shard #0
# 2018-04-29 17:51:36,455 : INFO : saving index shard to py_models/tfidf_stem10.index.0
# 2018-04-29 17:51:36,456 : INFO : saving SparseMatrixSimilarity object under py_models/tfidf_stem10.index.0, separately None
# 2018-04-29 17:51:36,457 : INFO : storing scipy.sparse array 'index' under py_models/tfidf_stem10.index.0.index.npy
# 2018-04-29 17:51:36,493 : INFO : saved py_models/tfidf_stem10.index.0
# 2018-04-29 17:51:36,493 : INFO : loading SparseMatrixSimilarity object from py_models/tfidf_stem10.index.0
# 2018-04-29 17:51:36,494 : INFO : loading index from py_models/tfidf_stem10.index.0.index.npy with mmap=r
# 2018-04-29 17:51:36,496 : INFO : loaded py_models/tfidf_stem10.index.0
# 2018-04-29 17:51:36,532 : INFO : PROGRESS: fresh_shard size=0
# 2018-04-29 17:51:40,996 : INFO : PROGRESS: fresh_shard size=10000
# 2018-04-29 17:51:44,982 : INFO : PROGRESS: fresh_shard size=20000
# 2018-04-29 17:51:49,167 : INFO : PROGRESS: fresh_shard size=30000
# 2018-04-29 17:51:50,434 : INFO : creating sparse index
# 2018-04-29 17:51:50,434 : INFO : creating sparse matrix from corpus
# 2018-04-29 17:51:50,436 : INFO : PROGRESS: at document #0/32768
# 2018-04-29 17:51:55,451 : INFO : PROGRESS: at document #10000/32768
# 2018-04-29 17:51:59,817 : INFO : PROGRESS: at document #20000/32768
# 2018-04-29 17:52:04,538 : INFO : PROGRESS: at document #30000/32768
# 2018-04-29 17:52:05,816 : INFO : created <32768x155879 sparse matrix of type '<type 'numpy.float32'>'
# 	with 9827175 stored elements in Compressed Sparse Row format>
# 2018-04-29 17:52:05,816 : INFO : creating sparse shard #1
# 2018-04-29 17:52:05,817 : INFO : saving index shard to py_models/tfidf_stem10.index.1
# 2018-04-29 17:52:05,818 : INFO : saving SparseMatrixSimilarity object under py_models/tfidf_stem10.index.1, separately None
# 2018-04-29 17:52:05,877 : INFO : saved py_models/tfidf_stem10.index.1
# 2018-04-29 17:52:05,878 : INFO : loading SparseMatrixSimilarity object from py_models/tfidf_stem10.index.1
# 2018-04-29 17:52:05,932 : INFO : loaded py_models/tfidf_stem10.index.1
# 2018-04-29 17:52:05,967 : INFO : PROGRESS: fresh_shard size=0
# 2018-04-29 17:52:10,624 : INFO : PROGRESS: fresh_shard size=10000
# 2018-04-29 17:52:15,202 : INFO : PROGRESS: fresh_shard size=20000
# 2018-04-29 17:52:20,014 : INFO : PROGRESS: fresh_shard size=30000
# 2018-04-29 17:52:21,426 : INFO : creating sparse index
# 2018-04-29 17:52:21,427 : INFO : creating sparse matrix from corpus
# 2018-04-29 17:52:21,428 : INFO : PROGRESS: at document #0/32768
# 2018-04-29 17:52:26,075 : INFO : PROGRESS: at document #10000/32768
# 2018-04-29 17:52:31,398 : INFO : PROGRESS: at document #20000/32768
# 2018-04-29 17:52:37,037 : INFO : PROGRESS: at document #30000/32768
# 2018-04-29 17:52:38,801 : INFO : created <32768x155879 sparse matrix of type '<type 'numpy.float32'>'
# 	with 11149758 stored elements in Compressed Sparse Row format>
# 2018-04-29 17:52:38,802 : INFO : creating sparse shard #2
# 2018-04-29 17:52:38,803 : INFO : saving index shard to py_models/tfidf_stem10.index.2
# 2018-04-29 17:52:38,803 : INFO : saving SparseMatrixSimilarity object under py_models/tfidf_stem10.index.2, separately None
# 2018-04-29 17:52:38,804 : INFO : storing scipy.sparse array 'index' under py_models/tfidf_stem10.index.2.index.npy
# 2018-04-29 17:52:38,841 : INFO : saved py_models/tfidf_stem10.index.2
# 2018-04-29 17:52:38,842 : INFO : loading SparseMatrixSimilarity object from py_models/tfidf_stem10.index.2
# 2018-04-29 17:52:38,842 : INFO : loading index from py_models/tfidf_stem10.index.2.index.npy with mmap=r
# 2018-04-29 17:52:38,844 : INFO : loaded py_models/tfidf_stem10.index.2
# 2018-04-29 17:52:38,885 : INFO : PROGRESS: fresh_shard size=0
# 2018-04-29 17:52:43,903 : INFO : PROGRESS: fresh_shard size=10000
# 2018-04-29 17:52:47,613 : INFO : PROGRESS: fresh_shard size=20000
# 2018-04-29 17:52:51,975 : INFO : PROGRESS: fresh_shard size=30000
# 2018-04-29 17:52:53,154 : INFO : creating sparse index
# 2018-04-29 17:52:53,155 : INFO : creating sparse matrix from corpus
# 2018-04-29 17:52:53,156 : INFO : PROGRESS: at document #0/32768
# 2018-04-29 17:52:59,328 : INFO : PROGRESS: at document #10000/32768
# 2018-04-29 17:53:02,755 : INFO : PROGRESS: at document #20000/32768
# 2018-04-29 17:53:07,835 : INFO : PROGRESS: at document #30000/32768
# 2018-04-29 17:53:08,784 : INFO : created <32768x155879 sparse matrix of type '<type 'numpy.float32'>'
# 	with 9996440 stored elements in Compressed Sparse Row format>
# 2018-04-29 17:53:08,785 : INFO : creating sparse shard #3
# 2018-04-29 17:53:08,786 : INFO : saving index shard to py_models/tfidf_stem10.index.3
# 2018-04-29 17:53:08,787 : INFO : saving SparseMatrixSimilarity object under py_models/tfidf_stem10.index.3, separately None
# 2018-04-29 17:53:08,846 : INFO : saved py_models/tfidf_stem10.index.3
# 2018-04-29 17:53:08,847 : INFO : loading SparseMatrixSimilarity object from py_models/tfidf_stem10.index.3
# 2018-04-29 17:53:08,902 : INFO : loaded py_models/tfidf_stem10.index.3
# 2018-04-29 17:53:08,938 : INFO : PROGRESS: fresh_shard size=0
# 2018-04-29 17:53:12,445 : INFO : PROGRESS: fresh_shard size=10000
# 2018-04-29 17:53:17,080 : INFO : PROGRESS: fresh_shard size=20000
# 2018-04-29 17:53:21,243 : INFO : PROGRESS: fresh_shard size=30000
# 2018-04-29 17:53:22,478 : INFO : creating sparse index
# 2018-04-29 17:53:22,479 : INFO : creating sparse matrix from corpus
# 2018-04-29 17:53:22,480 : INFO : PROGRESS: at document #0/32768
# 2018-04-29 17:53:25,642 : INFO : PROGRESS: at document #10000/32768
# 2018-04-29 17:53:29,718 : INFO : PROGRESS: at document #20000/32768
# 2018-04-29 17:53:33,953 : INFO : PROGRESS: at document #30000/32768
# 2018-04-29 17:53:35,460 : INFO : created <32768x155879 sparse matrix of type '<type 'numpy.float32'>'
# 	with 8259618 stored elements in Compressed Sparse Row format>
# 2018-04-29 17:53:35,460 : INFO : creating sparse shard #4
# 2018-04-29 17:53:35,463 : INFO : saving index shard to py_models/tfidf_stem10.index.4
# 2018-04-29 17:53:35,463 : INFO : saving SparseMatrixSimilarity object under py_models/tfidf_stem10.index.4, separately None
# 2018-04-29 17:53:35,515 : INFO : saved py_models/tfidf_stem10.index.4
# 2018-04-29 17:53:35,516 : INFO : loading SparseMatrixSimilarity object from py_models/tfidf_stem10.index.4
# 2018-04-29 17:53:35,557 : INFO : loaded py_models/tfidf_stem10.index.4
# 2018-04-29 17:53:35,591 : INFO : PROGRESS: fresh_shard size=0
# 2018-04-29 17:53:40,137 : INFO : PROGRESS: fresh_shard size=10000
# 2018-04-29 17:53:45,028 : INFO : PROGRESS: fresh_shard size=20000
# 2018-04-29 17:53:50,022 : INFO : PROGRESS: fresh_shard size=30000
# 2018-04-29 17:53:51,383 : INFO : creating sparse index
# 2018-04-29 17:53:51,383 : INFO : creating sparse matrix from corpus
# 2018-04-29 17:53:51,384 : INFO : PROGRESS: at document #0/32768
# 2018-04-29 17:53:55,622 : INFO : PROGRESS: at document #10000/32768
# 2018-04-29 17:54:00,678 : INFO : PROGRESS: at document #20000/32768
# 2018-04-29 17:54:06,932 : INFO : PROGRESS: at document #30000/32768
# 2018-04-29 17:54:08,692 : INFO : created <32768x155879 sparse matrix of type '<type 'numpy.float32'>'
# 	with 10976269 stored elements in Compressed Sparse Row format>
# 2018-04-29 17:54:08,693 : INFO : creating sparse shard #5
# 2018-04-29 17:54:08,694 : INFO : saving index shard to py_models/tfidf_stem10.index.5
# 2018-04-29 17:54:08,694 : INFO : saving SparseMatrixSimilarity object under py_models/tfidf_stem10.index.5, separately None
# 2018-04-29 17:54:08,695 : INFO : storing scipy.sparse array 'index' under py_models/tfidf_stem10.index.5.index.npy
# 2018-04-29 17:54:08,730 : INFO : saved py_models/tfidf_stem10.index.5
# 2018-04-29 17:54:08,731 : INFO : loading SparseMatrixSimilarity object from py_models/tfidf_stem10.index.5
# 2018-04-29 17:54:08,732 : INFO : loading index from py_models/tfidf_stem10.index.5.index.npy with mmap=r
# 2018-04-29 17:54:08,733 : INFO : loaded py_models/tfidf_stem10.index.5
# 2018-04-29 17:54:08,770 : INFO : PROGRESS: fresh_shard size=0
# 2018-04-29 17:54:13,949 : INFO : PROGRESS: fresh_shard size=10000
# 2018-04-29 17:54:18,849 : INFO : PROGRESS: fresh_shard size=20000
# 2018-04-29 17:54:22,162 : INFO : PROGRESS: fresh_shard size=30000
# 2018-04-29 17:54:22,890 : INFO : creating sparse index
# 2018-04-29 17:54:22,890 : INFO : creating sparse matrix from corpus
# 2018-04-29 17:54:22,892 : INFO : PROGRESS: at document #0/32768
# 2018-04-29 17:54:29,023 : INFO : PROGRESS: at document #10000/32768
# 2018-04-29 17:54:35,043 : INFO : PROGRESS: at document #20000/32768
# 2018-04-29 17:54:37,789 : INFO : PROGRESS: at document #30000/32768
# 2018-04-29 17:54:38,168 : INFO : created <32768x155879 sparse matrix of type '<type 'numpy.float32'>'
# 	with 9747512 stored elements in Compressed Sparse Row format>
# 2018-04-29 17:54:38,168 : INFO : creating sparse shard #6
# 2018-04-29 17:54:38,169 : INFO : saving index shard to py_models/tfidf_stem10.index.6
# 2018-04-29 17:54:38,169 : INFO : saving SparseMatrixSimilarity object under py_models/tfidf_stem10.index.6, separately None
# 2018-04-29 17:54:38,234 : INFO : saved py_models/tfidf_stem10.index.6
# 2018-04-29 17:54:38,235 : INFO : loading SparseMatrixSimilarity object from py_models/tfidf_stem10.index.6
# 2018-04-29 17:54:38,291 : INFO : loaded py_models/tfidf_stem10.index.6
# 2018-04-29 17:54:38,323 : INFO : PROGRESS: fresh_shard size=0
# 2018-04-29 17:54:40,963 : INFO : PROGRESS: fresh_shard size=10000
# 2018-04-29 17:54:43,783 : INFO : PROGRESS: fresh_shard size=20000
# 2018-04-29 17:54:46,548 : INFO : PROGRESS: fresh_shard size=30000
# 2018-04-29 17:54:47,283 : INFO : creating sparse index
# 2018-04-29 17:54:47,284 : INFO : creating sparse matrix from corpus
# 2018-04-29 17:54:47,284 : INFO : PROGRESS: at document #0/32768
# 2018-04-29 17:54:48,644 : INFO : PROGRESS: at document #10000/32768
# 2018-04-29 17:54:50,248 : INFO : PROGRESS: at document #20000/32768
# 2018-04-29 17:54:51,727 : INFO : PROGRESS: at document #30000/32768
# 2018-04-29 17:54:52,082 : INFO : created <32768x155879 sparse matrix of type '<type 'numpy.float32'>'
# 	with 2944325 stored elements in Compressed Sparse Row format>
# 2018-04-29 17:54:52,083 : INFO : creating sparse shard #7
# 2018-04-29 17:54:52,083 : INFO : saving index shard to py_models/tfidf_stem10.index.7
# 2018-04-29 17:54:52,084 : INFO : saving SparseMatrixSimilarity object under py_models/tfidf_stem10.index.7, separately None
# 2018-04-29 17:54:52,099 : INFO : saved py_models/tfidf_stem10.index.7
# 2018-04-29 17:54:52,100 : INFO : loading SparseMatrixSimilarity object from py_models/tfidf_stem10.index.7
# 2018-04-29 17:54:52,116 : INFO : loaded py_models/tfidf_stem10.index.7
# 2018-04-29 17:54:52,145 : INFO : PROGRESS: fresh_shard size=0
# 2018-04-29 17:54:54,950 : INFO : PROGRESS: fresh_shard size=10000
# 2018-04-29 17:54:57,906 : INFO : PROGRESS: fresh_shard size=20000
# 2018-04-29 17:55:00,903 : INFO : PROGRESS: fresh_shard size=30000
# 2018-04-29 17:55:01,803 : INFO : creating sparse index
# 2018-04-29 17:55:01,803 : INFO : creating sparse matrix from corpus
# 2018-04-29 17:55:01,804 : INFO : PROGRESS: at document #0/32768
# 2018-04-29 17:55:03,260 : INFO : PROGRESS: at document #10000/32768
# 2018-04-29 17:55:05,045 : INFO : PROGRESS: at document #20000/32768
# 2018-04-29 17:55:06,854 : INFO : PROGRESS: at document #30000/32768
# 2018-04-29 17:55:07,643 : INFO : created <32768x155879 sparse matrix of type '<type 'numpy.float32'>'
# 	with 3612725 stored elements in Compressed Sparse Row format>
# 2018-04-29 17:55:07,644 : INFO : creating sparse shard #8
# 2018-04-29 17:55:07,645 : INFO : saving index shard to py_models/tfidf_stem10.index.8
# 2018-04-29 17:55:07,645 : INFO : saving SparseMatrixSimilarity object under py_models/tfidf_stem10.index.8, separately None
# 2018-04-29 17:55:07,662 : INFO : saved py_models/tfidf_stem10.index.8
# 2018-04-29 17:55:07,663 : INFO : loading SparseMatrixSimilarity object from py_models/tfidf_stem10.index.8
# 2018-04-29 17:55:07,681 : INFO : loaded py_models/tfidf_stem10.index.8
# 2018-04-29 17:55:07,711 : INFO : PROGRESS: fresh_shard size=0
# 2018-04-29 17:55:11,106 : INFO : PROGRESS: fresh_shard size=10000
# 2018-04-29 17:55:14,564 : INFO : PROGRESS: fresh_shard size=20000
# 2018-04-29 17:55:19,219 : INFO : PROGRESS: fresh_shard size=30000
# 2018-04-29 17:55:20,874 : INFO : creating sparse index
# 2018-04-29 17:55:20,875 : INFO : creating sparse matrix from corpus
# 2018-04-29 17:55:20,875 : INFO : PROGRESS: at document #0/32768
# 2018-04-29 17:55:23,149 : INFO : PROGRESS: at document #10000/32768
# 2018-04-29 17:55:26,184 : INFO : PROGRESS: at document #20000/32768
# 2018-04-29 17:55:31,511 : INFO : PROGRESS: at document #30000/32768
# 2018-04-29 17:55:33,810 : INFO : created <32768x155879 sparse matrix of type '<type 'numpy.float32'>'
# 	with 8245234 stored elements in Compressed Sparse Row format>
# 2018-04-29 17:55:33,811 : INFO : creating sparse shard #9
# 2018-04-29 17:55:33,811 : INFO : saving index shard to py_models/tfidf_stem10.index.9
# 2018-04-29 17:55:33,812 : INFO : saving SparseMatrixSimilarity object under py_models/tfidf_stem10.index.9, separately None
# 2018-04-29 17:55:33,854 : INFO : saved py_models/tfidf_stem10.index.9
# 2018-04-29 17:55:33,854 : INFO : loading SparseMatrixSimilarity object from py_models/tfidf_stem10.index.9
# 2018-04-29 17:55:33,895 : INFO : loaded py_models/tfidf_stem10.index.9
# 2018-04-29 17:55:33,924 : INFO : PROGRESS: fresh_shard size=0
# 2018-04-29 17:55:39,542 : INFO : PROGRESS: fresh_shard size=10000
# 2018-04-29 17:55:44,594 : INFO : PROGRESS: fresh_shard size=20000
# 2018-04-29 17:55:46,730 : INFO : creating sparse index
# 2018-04-29 17:55:46,731 : INFO : creating sparse matrix from corpus
# 2018-04-29 17:55:46,733 : INFO : PROGRESS: at document #0/24305
# 2018-04-29 17:55:54,030 : INFO : PROGRESS: at document #10000/24305
# 2018-04-29 17:56:00,674 : INFO : PROGRESS: at document #20000/24305
# 2018-04-29 17:56:03,557 : INFO : created <24305x155879 sparse matrix of type '<type 'numpy.float32'>'
# 	with 10935260 stored elements in Compressed Sparse Row format>
# 2018-04-29 17:56:03,558 : INFO : creating sparse shard #10
# 2018-04-29 17:56:03,559 : INFO : saving index shard to py_models/tfidf_stem10.index.10
# 2018-04-29 17:56:03,559 : INFO : saving SparseMatrixSimilarity object under py_models/tfidf_stem10.index.10, separately None
# 2018-04-29 17:56:03,560 : INFO : storing scipy.sparse array 'index' under py_models/tfidf_stem10.index.10.index.npy
# 2018-04-29 17:56:03,595 : INFO : saved py_models/tfidf_stem10.index.10
# 2018-04-29 17:56:03,596 : INFO : loading SparseMatrixSimilarity object from py_models/tfidf_stem10.index.10
# 2018-04-29 17:56:03,596 : INFO : loading index from py_models/tfidf_stem10.index.10.index.npy with mmap=r
# 2018-04-29 17:56:03,598 : INFO : loaded py_models/tfidf_stem10.index.10
# 2018-04-29 17:56:03,626 : INFO : saving Similarity object under py_models/TFIDF_stem10_index, separately None
# 2018-04-29 17:56:03,628 : INFO : saved py_models/TFIDF_stem10_index
# CPU times: user 4min 50s, sys: 1.95 s, total: 4min 52s
# Wall time: 4min 58s

# %%
########################### load tfidf index
tfidf_index = gensim.similarities.Similarity.load('py_models/TFIDF_stem10_index')
# Out:
# 2018-04-29 17:56:03,632 : INFO : loading Similarity object from py_models/TFIDF_stem10_index
# 2018-04-29 17:56:03,633 : INFO : loaded py_models/TFIDF_stem10_index

# %%
# %%time

# calculate similarity for all 
tfidf_index.num_best= None
i#######################         SIMILIRATIES SCORES AND RANKING    ###########################
results = copy.deepcopy(query_truth)
### lists of list (indexing from 1, dummy element)
sim_list = [0]
rank_list = [0]
queries = [0]
for i,query in enumerate(files_to_tokens('LegalAdhocTask/q*.txt')):
    queries.append(query)
    # inside the square bracket determines query representation
    
    sims = tfidf_index[tfidf[dictionary.doc2bow(query)]]
    sim_list.append(sims)
    # rank of every document wrt similarity
    ranks = rankdata(sims, method='ordinal')
    ranks= len(ranks)+1 - ranks 
    rank_list.append(ranks)
    
    # update the query truth tuples with similarity score and the ranks
    for x in results[str(i+1)]:
        x.append(sims[filenames.index(x[0]+'.txt')])
        x.append(ranks[filenames.index(x[0]+'.txt')])
        #x.append(common_words(filenames.index(x[0]+'.txt'), tfidf_corpus, query))
    
    # sort wrt relevance(from truth) and then ranks(from our model)
    #tfidf_results[str(i+1)].sort(key=lambda x: (-int(x[1]),x[3]))
# Out:
# 2018-04-29 17:56:04,101 : INFO : loading SparseMatrixSimilarity object from py_models/tfidf_stem10.index.0
# 2018-04-29 17:56:04,102 : INFO : loading index from py_models/tfidf_stem10.index.0.index.npy with mmap=r
# 2018-04-29 17:56:04,103 : INFO : loaded py_models/tfidf_stem10.index.0
# 2018-04-29 17:56:04,287 : INFO : loading SparseMatrixSimilarity object from py_models/tfidf_stem10.index.1
# 2018-04-29 17:56:04,327 : INFO : loaded py_models/tfidf_stem10.index.1
# 2018-04-29 17:56:04,360 : INFO : loading SparseMatrixSimilarity object from py_models/tfidf_stem10.index.2
# 2018-04-29 17:56:04,361 : INFO : loading index from py_models/tfidf_stem10.index.2.index.npy with mmap=r
# 2018-04-29 17:56:04,363 : INFO : loaded py_models/tfidf_stem10.index.2
# 2018-04-29 17:56:04,404 : INFO : loading SparseMatrixSimilarity object from py_models/tfidf_stem10.index.3
# 2018-04-29 17:56:04,444 : INFO : loaded py_models/tfidf_stem10.index.3
# 2018-04-29 17:56:04,479 : INFO : loading SparseMatrixSimilarity object from py_models/tfidf_stem10.index.4
# 2018-04-29 17:56:04,506 : INFO : loaded py_models/tfidf_stem10.index.4
# 2018-04-29 17:56:04,534 : INFO : loading SparseMatrixSimilarity object from py_models/tfidf_stem10.index.5
# 2018-04-29 17:56:04,535 : INFO : loading index from py_models/tfidf_stem10.index.5.index.npy with mmap=r
# 2018-04-29 17:56:04,536 : INFO : loaded py_models/tfidf_stem10.index.5
# 2018-04-29 17:56:04,576 : INFO : loading SparseMatrixSimilarity object from py_models/tfidf_stem10.index.6
# 2018-04-29 17:56:04,622 : INFO : loaded py_models/tfidf_stem10.index.6
# 2018-04-29 17:56:04,652 : INFO : loading SparseMatrixSimilarity object from py_models/tfidf_stem10.index.7
# 2018-04-29 17:56:04,665 : INFO : loaded py_models/tfidf_stem10.index.7
# 2018-04-29 17:56:04,676 : INFO : loading SparseMatrixSimilarity object from py_models/tfidf_stem10.index.8
# 2018-04-29 17:56:04,693 : INFO : loaded py_models/tfidf_stem10.index.8
# 2018-04-29 17:56:04,706 : INFO : loading SparseMatrixSimilarity object from py_models/tfidf_stem10.index.9
# 2018-04-29 17:56:04,752 : INFO : loaded py_models/tfidf_stem10.index.9
# 2018-04-29 17:56:04,778 : INFO : loading SparseMatrixSimilarity object from py_models/tfidf_stem10.index.10
# 2018-04-29 17:56:04,779 : INFO : loading index from py_models/tfidf_stem10.index.10.index.npy with mmap=r
# 2018-04-29 17:56:04,781 : INFO : loaded py_models/tfidf_stem10.index.10
# CPU times: user 4.96 s, sys: 180 ms, total: 5.14 s
# Wall time: 5.54 s

# %%
results
# Out:
# {'1': [['ConsumerCourt_DCDRC_100385', '1', 0.1611565, 231],
#   ['ConsumerCourt_DCDRC_106530', '0', 0.083039396, 1486],
#   ['ConsumerCourt_DCDRC_107608', '1', 0.09029148, 1267],
#   ['ConsumerCourt_DCDRC_114291', '1', 0.1345675, 500],
#   ['ConsumerCourt_DCDRC_114382', '1', 0.09826105, 1090],
#   ['ConsumerCourt_DCDRC_118185', '1', 0.1027393, 1011],
#   ['ConsumerCourt_DCDRC_130318', '0', 0.12567905, 619],
#   ['ConsumerCourt_DCDRC_130570', '1', 0.299501, 5],
#   ['ConsumerCourt_DCDRC_131146', '1', 0.07303761, 1869],
#   ['ConsumerCourt_DCDRC_131717', '1', 0.09042325, 1263],
#   ['ConsumerCourt_DCDRC_131741', '1', 0.082710735, 1493],
#   ['ConsumerCourt_DCDRC_131818', '1', 0.100662984, 1051],
#   ['ConsumerCourt_DCDRC_131950', '0', 0.05740654, 2740],
#   ['ConsumerCourt_DCDRC_131972', '0', 0.102337584, 1023],
#   ['ConsumerCourt_DCDRC_132932', '0', 0.07669497, 1708],
#   ['ConsumerCourt_DCDRC_133592', '1', 0.16075738, 234],
#   ['ConsumerCourt_DCDRC_134386', '0', 0.3293872, 1],
#   ['ConsumerCourt_DCDRC_135474', '1', 0.06337156, 2323],
#   ['ConsumerCourt_DCDRC_139024', '0', 0.18173252, 118],
#   ['ConsumerCourt_DCDRC_139205', '0', 0.2831737, 6],
#   ['ConsumerCourt_DCDRC_140039', '1', 0.27433375, 8],
#   ['ConsumerCourt_DCDRC_145708', '0', 0.23487717, 23],
#   ['ConsumerCourt_DCDRC_187214', '1', 0.06730411, 2119],
#   ['ConsumerCourt_DCDRC_207784', '1', 0.04498952, 4197],
#   ['ConsumerCourt_DCDRC_217344', '1', 0.19287935, 77],
#   ['ConsumerCourt_DCDRC_217471', '1', 0.14259192, 404],
#   ['ConsumerCourt_DCDRC_222797', '0', 0.16513336, 199],
#   ['ConsumerCourt_DCDRC_222844', '1', 0.14416757, 376],
#   ['ConsumerCourt_DCDRC_224228', '0', 0.19136731, 82],
#   ['ConsumerCourt_DCDRC_224833', '0', 0.15831985, 251],
#   ['ConsumerCourt_DCDRC_226072', '1', 0.22468494, 28],
#   ['ConsumerCourt_DCDRC_38498', '0', 0.24825011, 20],
#   ['ConsumerCourt_DCDRC_39186', '1', 0.16384393, 207],
#   ['ConsumerCourt_DCDRC_41317', '1', 0.22143506, 34],
#   ['ConsumerCourt_DCDRC_41588', '1', 0.20425524, 57],
#   ['ConsumerCourt_DCDRC_42118', '1', 0.14569022, 359],
#   ['ConsumerCourt_DCDRC_42618', '1', 0.14983867, 324],
#   ['ConsumerCourt_DCDRC_42649', '1', 0.31754613, 2],
#   ['ConsumerCourt_DCDRC_44200', '1', 0.12349875, 653],
#   ['ConsumerCourt_DCDRC_46368', '1', 0.1200559, 700],
#   ['ConsumerCourt_DCDRC_46519', '1', 0.15961054, 245],
#   ['ConsumerCourt_DCDRC_46543', '1', 0.11005775, 851],
#   ['ConsumerCourt_DCDRC_53138', '1', 0.13334148, 520],
#   ['ConsumerCourt_DCDRC_55517', '1', 0.20607823, 53],
#   ['ConsumerCourt_DCDRC_55612', '1', 0.11288748, 801],
#   ['ConsumerCourt_DCDRC_55678', '1', 0.17201208, 161],
#   ['ConsumerCourt_DCDRC_55899', '1', 0.18316472, 109],
#   ['ConsumerCourt_DCDRC_57484', '0', 0.25175548, 17],
#   ['ConsumerCourt_DCDRC_74868', '1', 0.12525648, 624],
#   ['ConsumerCourt_DCDRC_80057', '1', 0.26908073, 12],
#   ['ConsumerCourt_DCDRC_83596', '0', 0.20165388, 61],
#   ['ConsumerCourt_DCDRC_83779', '0', 0.14567252, 360],
#   ['ConsumerCourt_DCDRC_96667', '1', 0.2529859, 16],
#   ['ConsumerCourt_DCDRC_98733', '1', 0.2540431, 15],
#   ['ConsumerCourt_SCDRC_52678', '0', 0.14233495, 408],
#   ['DelhiHC_2011_4267', '0', 0.10805426, 895],
#   ['KolkataHCOriginalSite_2012_36', '0', 0.036105145, 6247]],
#  '10': [['ConsumerCourt_DCDRC_220958', '0', 0.099776074, 1011],
#   ['ConsumerCourt_DCDRC_222509', '0', 0.33039978, 4],
#   ['ConsumerCourt_DCDRC_223570', '0', 0.31057563, 5],
#   ['ConsumerCourt_DCDRC_227314', '0', 0.13118109, 491],
#   ['ConsumerCourt_DCDRC_228688', '1', 0.29306477, 7],
#   ['ConsumerCourt_DCDRC_235883', '0', 0.2864321, 9],
#   ['ConsumerCourt_DCDRC_38192', '0', 0.4137223, 2],
#   ['ConsumerCourt_DCDRC_41485', '0', 0.2628532, 18],
#   ['ConsumerCourt_DCDRC_41489', '0', 0.2628532, 17],
#   ['ConsumerCourt_DCDRC_41520', '0', 0.26623762, 15],
#   ['ConsumerCourt_SCDRC_44836', '0', 0.19781756, 81],
#   ['ConsumerCourt_SCDRC_56350', '0', 0.2826793, 10],
#   ['ConsumerCourt_SCDRC_65898', '0', 0.25575107, 20],
#   ['ConsumerCourt_SCDRC_68718', '0', 0.2654395, 16],
#   ['ConsumerCourt_SCDRC_69937', '1', 0.5430679, 1],
#   ['ConsumerCourt_SCDRC_70632', '0', 0.11090098, 760],
#   ['DelhiHC_2008_2771', '0', 0.17631137, 156],
#   ['DelhiHC_2008_2772', '0', 0.17631137, 155]],
#  '2': [['ConsumerCourt_DCDRC_103241', '0', 0.051430628, 2155],
#   ['ConsumerCourt_DCDRC_107786', '1', 0.28186178, 207],
#   ['ConsumerCourt_DCDRC_114305', '1', 0.38080525, 44],
#   ['ConsumerCourt_DCDRC_120930', '1', 0.38446587, 41],
#   ['ConsumerCourt_DCDRC_123490', '1', 0.33965826, 100],
#   ['ConsumerCourt_DCDRC_125352', '1', 0.43366805, 6],
#   ['ConsumerCourt_DCDRC_127791', '0', 0.07475726, 1243],
#   ['ConsumerCourt_DCDRC_130071', '0', 0.08764972, 1010],
#   ['ConsumerCourt_DCDRC_130920', '1', 0.29391444, 183],
#   ['ConsumerCourt_DCDRC_131972', '0', 0.05300704, 2037],
#   ['ConsumerCourt_DCDRC_133106', '1', 0.3987822, 27],
#   ['ConsumerCourt_DCDRC_133260', '0', 0.37636763, 48],
#   ['ConsumerCourt_DCDRC_143284', '1', 0.30799034, 146],
#   ['ConsumerCourt_DCDRC_143334', '0', 0.41024476, 20],
#   ['ConsumerCourt_DCDRC_144440', '0', 0.17599177, 472],
#   ['ConsumerCourt_DCDRC_202900', '0', 0.021580815, 27235],
#   ['ConsumerCourt_DCDRC_202903', '0', 0.01640921, 58324],
#   ['ConsumerCourt_DCDRC_207376', '1', 0.058776174, 1700],
#   ['ConsumerCourt_DCDRC_212601', '0', 0.29736072, 174],
#   ['ConsumerCourt_DCDRC_212692', '1', 0.4367042, 4],
#   ['ConsumerCourt_DCDRC_214518', '1', 0.36779368, 56],
#   ['ConsumerCourt_DCDRC_226924', '0', 0.26312292, 256],
#   ['ConsumerCourt_DCDRC_227866', '1', 0.42632622, 10],
#   ['ConsumerCourt_DCDRC_228749', '1', 0.35217598, 84],
#   ['ConsumerCourt_DCDRC_229221', '0', 0.35258132, 82],
#   ['ConsumerCourt_DCDRC_230361', '1', 0.4196249, 12],
#   ['ConsumerCourt_DCDRC_41190', '0', 0.05444078, 1947],
#   ['ConsumerCourt_DCDRC_50671', '1', 0.078174345, 1173],
#   ['ConsumerCourt_DCDRC_52620', '1', 0.06723582, 1401],
#   ['ConsumerCourt_DCDRC_53093', '1', 0.3739522, 52],
#   ['ConsumerCourt_DCDRC_53138', '0', 0.04040861, 3834],
#   ['ConsumerCourt_DCDRC_53153', '1', 0.1086269, 805],
#   ['ConsumerCourt_DCDRC_53432', '0', 0.06443474, 1478],
#   ['ConsumerCourt_DCDRC_53875', '0', 0.06498259, 1465],
#   ['ConsumerCourt_DCDRC_53881', '0', 0.06498259, 1464],
#   ['ConsumerCourt_DCDRC_56471', '1', 0.20065427, 396],
#   ['ConsumerCourt_DCDRC_56761', '0', 0.044496488, 2996],
#   ['ConsumerCourt_DCDRC_57453', '0', 0.32442302, 126],
#   ['ConsumerCourt_DCDRC_57583', '0', 0.047006015, 2617],
#   ['ConsumerCourt_DCDRC_62986', '0', 0.34244955, 96],
#   ['ConsumerCourt_DCDRC_63724', '0', 0.2815093, 208],
#   ['ConsumerCourt_DCDRC_68765', '0', 0.27442086, 223],
#   ['ConsumerCourt_DCDRC_68808', '0', 0.18874632, 430],
#   ['ConsumerCourt_DCDRC_69863', '0', 0.22961207, 335],
#   ['ConsumerCourt_DCDRC_74887', '0', 0.30578008, 150],
#   ['ConsumerCourt_DCDRC_75562', '0', 0.37862107, 47],
#   ['ConsumerCourt_DCDRC_76114', '0', 0.36150378, 69],
#   ['ConsumerCourt_DCDRC_76186', '0', 0.19587733, 414],
#   ['ConsumerCourt_DCDRC_76270', '0', 0.24723719, 288],
#   ['ConsumerCourt_DCDRC_77085', '1', 0.33539176, 114],
#   ['ConsumerCourt_DCDRC_77280', '0', 0.045806333, 2782],
#   ['ConsumerCourt_DCDRC_77935', '1', 0.38762945, 37],
#   ['ConsumerCourt_DCDRC_87186', '0', 0.2989078, 172],
#   ['ConsumerCourt_DCDRC_91864', '1', 0.39979905, 26],
#   ['ConsumerCourt_DCDRC_96244', '1', 0.4364809, 5],
#   ['ConsumerCourt_NCDRC_1317', '0', 0.35441113, 79],
#   ['ConsumerCourt_SCDRC_49685', '0', 0.32497197, 125],
#   ['ConsumerCourt_SCDRC_60064', '1', 0.4731634, 1],
#   ['ConsumerCourt_SCDRC_62062', '1', 0.38977453, 36]],
#  '3': [['ConsumerCourt_DCDRC_103355', '0', 0.110509254, 343],
#   ['ConsumerCourt_DCDRC_129293', '1', 0.3107976, 3],
#   ['ConsumerCourt_DCDRC_133013', '1', 0.12881264, 192],
#   ['ConsumerCourt_DCDRC_133017', '0', 0.20706193, 30],
#   ['ConsumerCourt_DCDRC_137661', '0', 0.11165758, 331],
#   ['ConsumerCourt_DCDRC_153064', '0', 0.086100854, 813],
#   ['ConsumerCourt_DCDRC_187619', '1', 0.27746734, 7],
#   ['ConsumerCourt_DCDRC_200840', '0', 0.1296957, 183],
#   ['ConsumerCourt_DCDRC_222260', '1', 0.22577763, 19],
#   ['ConsumerCourt_DCDRC_222772', '1', 0.22180803, 23],
#   ['ConsumerCourt_DCDRC_223618', '1', 0.21191037, 29],
#   ['ConsumerCourt_DCDRC_228476', '0', 0.11071877, 342],
#   ['ConsumerCourt_DCDRC_228963', '1', 0.24823391, 11],
#   ['ConsumerCourt_DCDRC_230634', '1', 0.2371585, 15],
#   ['ConsumerCourt_DCDRC_235824', '0', 0.28881812, 4],
#   ['ConsumerCourt_DCDRC_45666', '0', 0.083077416, 909],
#   ['ConsumerCourt_DCDRC_47493', '1', 0.12898453, 189],
#   ['ConsumerCourt_DCDRC_52566', '0', 0.1666285, 64],
#   ['ConsumerCourt_DCDRC_73184', '0', 0.17510326, 53],
#   ['ConsumerCourt_DCDRC_73185', '0', 0.17656308, 52],
#   ['ConsumerCourt_NCDRC_2861', '1', 0.12308805, 230],
#   ['ConsumerCourt_NCDRC_2902', '0', 0.075286336, 1229],
#   ['ConsumerCourt_NCDRC_2979', '0', 0.1043381, 415],
#   ['ConsumerCourt_NCDRC_632', '0', 0.16830662, 60],
#   ['ConsumerCourt_NCDRC_637', '0', 0.16820653, 61],
#   ['ConsumerCourt_SCDRC_2052', '0', 0.25795245, 9],
#   ['ConsumerCourt_SCDRC_22704', '0', 0.11870433, 260],
#   ['ConsumerCourt_SCDRC_29484', '0', 0.13600786, 149],
#   ['ConsumerCourt_SCDRC_29552', '0', 0.0902304, 694],
#   ['ConsumerCourt_SCDRC_30176', '0', 0.14620028, 109],
#   ['ConsumerCourt_SCDRC_48394', '0', 0.12922199, 186],
#   ['ConsumerCourt_SCDRC_63569', '0', 0.08277894, 921],
#   ['ConsumerCourt_SCDRC_63609', '0', 0.16287975, 76],
#   ['ConsumerCourt_SCDRC_65919', '0', 0.23838247, 14],
#   ['ConsumerCourt_SCDRC_66200', '0', 0.14326784, 119],
#   ['ConsumerCourt_SCDRC_69801', '0', 0.124082014, 226],
#   ['ConsumerCourt_SCDRC_814', '0', 0.10008443, 491],
#   ['DelhiHC_2012_388', '0', 0.2828729, 6]],
#  '4': [['ConsumerCourt_DCDRC_106570', '0', 0.26137975, 208],
#   ['ConsumerCourt_DCDRC_116129', '1', 0.2609072, 215],
#   ['ConsumerCourt_DCDRC_128836', '0', 0.2039963, 781],
#   ['ConsumerCourt_DCDRC_130725', '1', 0.2340425, 424],
#   ['ConsumerCourt_DCDRC_133137', '0', 0.27846658, 114],
#   ['ConsumerCourt_DCDRC_173376', '0', 0.033190902, 39074],
#   ['ConsumerCourt_DCDRC_174292', '0', 0.18947212, 948],
#   ['ConsumerCourt_DCDRC_174300', '1', 0.16351411, 1526],
#   ['ConsumerCourt_DCDRC_202903', '0', 0.012051443, 163095],
#   ['ConsumerCourt_DCDRC_205816', '1', 0.2228248, 530],
#   ['ConsumerCourt_DCDRC_207155', '0', 0.095200926, 6598],
#   ['ConsumerCourt_DCDRC_207197', '0', 0.22835356, 474],
#   ['ConsumerCourt_DCDRC_212467', '1', 0.29541487, 59],
#   ['ConsumerCourt_DCDRC_213156', '0', 0.24487622, 334],
#   ['ConsumerCourt_DCDRC_213473', '0', 0.2479133, 319],
#   ['ConsumerCourt_DCDRC_213784', '0', 0.28588668, 90],
#   ['ConsumerCourt_DCDRC_214475', '0', 0.25171393, 296],
#   ['ConsumerCourt_DCDRC_218582', '0', 0.17633617, 1194],
#   ['ConsumerCourt_DCDRC_221177', '0', 0.20136039, 811],
#   ['ConsumerCourt_DCDRC_221424', '0', 0.26726538, 169],
#   ['ConsumerCourt_DCDRC_223275', '0', 0.24437161, 338],
#   ['ConsumerCourt_DCDRC_226909', '0', 0.08663697, 8034],
#   ['ConsumerCourt_DCDRC_227099', '0', 0.2002567, 823],
#   ['ConsumerCourt_DCDRC_229902', '0', 0.15184124, 1901],
#   ['ConsumerCourt_DCDRC_47636', '0', 0.1482732, 2050],
#   ['ConsumerCourt_DCDRC_49131', '0', 0.34659943, 9],
#   ['ConsumerCourt_DCDRC_51881', '0', 0.2930157, 68],
#   ['ConsumerCourt_DCDRC_52357', '0', 0.34663302, 8],
#   ['ConsumerCourt_DCDRC_53202', '0', 0.31169063, 22],
#   ['ConsumerCourt_DCDRC_53580', '1', 0.31864274, 16],
#   ['ConsumerCourt_DCDRC_54056', '1', 0.26479205, 185],
#   ['ConsumerCourt_DCDRC_70122', '0', 0.29778388, 49],
#   ['ConsumerCourt_DCDRC_73309', '0', 0.29944634, 42],
#   ['ConsumerCourt_NCDRC_2154', '0', 0.066234306, 12823],
#   ['ConsumerCourt_NCDRC_3506', '0', 0.089826144, 7469],
#   ['ConsumerCourt_SCDRC_1143', '1', 0.28220138, 105],
#   ['ConsumerCourt_SCDRC_1288', '1', 0.32752612, 13],
#   ['ConsumerCourt_SCDRC_22830', '0', 0.16865166, 1392],
#   ['ConsumerCourt_SCDRC_37679', '1', 0.2602272, 225],
#   ['ConsumerCourt_SCDRC_471', '0', 0.06936583, 11912],
#   ['ConsumerCourt_SCDRC_49973', '1', 0.25176296, 295],
#   ['ConsumerCourt_SCDRC_5406', '0', 0.13028808, 2988],
#   ['ConsumerCourt_SCDRC_7046', '1', 0.35766643, 1],
#   ['DelhiHC_2012_3856', '0', 0.08867737, 7678],
#   ['SupremeCourt_2009_1421', '0', 0.18697084, 989]],
#  '5': [['ConsumerCourt_DCDRC_124651', '0', 0.1401157, 1798],
#   ['ConsumerCourt_DCDRC_138545', '0', 0.2235276, 366],
#   ['ConsumerCourt_DCDRC_139183', '0', 0.30269468, 35],
#   ['ConsumerCourt_DCDRC_141380', '0', 0.110547766, 2909],
#   ['ConsumerCourt_DCDRC_148691', '1', 0.32144183, 13],
#   ['ConsumerCourt_DCDRC_202903', '0', 0.007873748, 169776],
#   ['ConsumerCourt_DCDRC_208296', '0', 0.17963648, 925],
#   ['ConsumerCourt_DCDRC_223817', '0', 0.2044896, 553],
#   ['ConsumerCourt_DCDRC_226994', '0', 0.0467554, 9795],
#   ['ConsumerCourt_DCDRC_229911', '1', 0.2096841, 496],
#   ['ConsumerCourt_DCDRC_41155', '1', 0.2720156, 106],
#   ['ConsumerCourt_DCDRC_41262', '0', 0.26399475, 123],
#   ['ConsumerCourt_DCDRC_41428', '0', 0.22719677, 339],
#   ['ConsumerCourt_DCDRC_42411', '0', 0.15220386, 1479],
#   ['ConsumerCourt_DCDRC_46404', '0', 0.26079825, 134],
#   ['ConsumerCourt_DCDRC_53679', '1', 0.16407084, 1207],
#   ['ConsumerCourt_DCDRC_57315', '1', 0.24608272, 216],
#   ['ConsumerCourt_DCDRC_57465', '0', 0.12868173, 2155],
#   ['ConsumerCourt_DCDRC_57488', '0', 0.24087012, 245],
#   ['ConsumerCourt_DCDRC_57914', '1', 0.27128106, 109],
#   ['ConsumerCourt_DCDRC_66294', '0', 0.22994149, 318],
#   ['ConsumerCourt_DCDRC_96799', '0', 0.30777642, 27],
#   ['ConsumerCourt_NCDRC_1337', '1', 0.30022228, 41],
#   ['ConsumerCourt_NCDRC_1338', '0', 0.30022228, 40],
#   ['ConsumerCourt_NCDRC_2983', '1', 0.28024226, 80],
#   ['ConsumerCourt_SCDRC_28656', '0', 0.24089846, 243],
#   ['ConsumerCourt_SCDRC_33517', '1', 0.33337206, 6],
#   ['ConsumerCourt_SCDRC_5122', '0', 0.1988763, 630],
#   ['ConsumerCourt_SCDRC_71374', '1', 0.19637991, 664]],
#  '6': [['ConsumerCourt_DCDRC_103021', '1', 0.3685494, 1],
#   ['ConsumerCourt_DCDRC_119836', '1', 0.07924058, 893],
#   ['ConsumerCourt_DCDRC_125237', '1', 0.038820237, 3956],
#   ['ConsumerCourt_DCDRC_126276', '0', 0.041895397, 3398],
#   ['ConsumerCourt_DCDRC_131266', '1', 0.1580395, 178],
#   ['ConsumerCourt_DCDRC_133353', '1', 0.09134012, 657],
#   ['ConsumerCourt_DCDRC_133354', '0', 0.07983952, 877],
#   ['ConsumerCourt_DCDRC_134804', '0', 0.06876923, 1176],
#   ['ConsumerCourt_DCDRC_138617', '1', 0.1336439, 277],
#   ['ConsumerCourt_DCDRC_143983', '0', 0.017133243, 25126],
#   ['ConsumerCourt_DCDRC_207387', '1', 0.11681179, 376],
#   ['ConsumerCourt_DCDRC_220958', '1', 0.15218002, 193],
#   ['ConsumerCourt_DCDRC_223570', '1', 0.10150424, 504],
#   ['ConsumerCourt_DCDRC_223783', '0', 0.116138466, 382],
#   ['ConsumerCourt_DCDRC_38192', '1', 0.19591542, 84],
#   ['ConsumerCourt_DCDRC_41485', '0', 0.13949938, 252],
#   ['ConsumerCourt_DCDRC_41489', '0', 0.13949938, 251],
#   ['ConsumerCourt_DCDRC_41520', '1', 0.1495416, 203],
#   ['ConsumerCourt_DCDRC_45421', '0', 0.13835761, 261],
#   ['ConsumerCourt_DCDRC_52148', '0', 0.13298886, 282],
#   ['ConsumerCourt_DCDRC_70186', '0', 0.34367996, 2],
#   ['ConsumerCourt_DCDRC_70341', '0', 0.32972756, 5],
#   ['ConsumerCourt_DCDRC_90054', '0', 0.06490121, 1341],
#   ['ConsumerCourt_SCDRC_28640', '1', 0.14311327, 246],
#   ['ConsumerCourt_SCDRC_64152', '0', 0.15008046, 197],
#   ['ConsumerCourt_SCDRC_68718', '1', 0.14532708, 230],
#   ['ConsumerCourt_SCDRC_70632', '0', 0.17119725, 131],
#   ['DelhiHC_2009_735', '1', 0.048364017, 2540],
#   ['DelhiHC_2012_372', '0', 0.014893034, 33729],
#   ['DelhiHC_2012_374', '0', 0.014893034, 33728],
#   ['SupremeCourt_1996_416', '0', 0.08537105, 756]],
#  '7': [['ConsumerCourt_DCDRC_119406', '1', 0.061520986, 283],
#   ['ConsumerCourt_DCDRC_121344', '0', 0.08959839, 75],
#   ['ConsumerCourt_DCDRC_127019', '0', 0.100634746, 51],
#   ['ConsumerCourt_DCDRC_130205', '0', 0.23525475, 10],
#   ['ConsumerCourt_DCDRC_207672', '1', 0.11046625, 37],
#   ['ConsumerCourt_DCDRC_222487', '0', 0.24646091, 8],
#   ['ConsumerCourt_DCDRC_224805', '0', 0.08192506, 93],
#   ['ConsumerCourt_DCDRC_235755', '0', 0.098052785, 54],
#   ['ConsumerCourt_DCDRC_236026', '1', 0.107560374, 41],
#   ['ConsumerCourt_DCDRC_236229', '0', 0.47917834, 5],
#   ['ConsumerCourt_DCDRC_33939', '0', 0.105497606, 44],
#   ['ConsumerCourt_DCDRC_44337', '1', 0.0597811, 315],
#   ['ConsumerCourt_DCDRC_45534', '0', 0.6127172, 1],
#   ['ConsumerCourt_DCDRC_46470', '0', 0.3038322, 7],
#   ['ConsumerCourt_DCDRC_48811', '0', 0.077446505, 114],
#   ['ConsumerCourt_DCDRC_51454', '1', 0.11549441, 34],
#   ['ConsumerCourt_DCDRC_64180', '0', 0.5977621, 2],
#   ['ConsumerCourt_DCDRC_73953', '0', 0.09382345, 65],
#   ['ConsumerCourt_DCDRC_75554', '0', 0.07827706, 109],
#   ['ConsumerCourt_SCDRC_1050', '0', 0.12545456, 28],
#   ['ConsumerCourt_SCDRC_1387', '0', 0.54102755, 4],
#   ['ConsumerCourt_SCDRC_1418', '0', 0.37004957, 6],
#   ['ConsumerCourt_SCDRC_65323', '0', 0.13242519, 27],
#   ['ConsumerCourt_SCDRC_66203', '0', 0.032967016, 2728],
#   ['DelhiHC_2012_2026', '0', 0.23872411, 9]],
#  '8': [['ConsumerCourt_DCDRC_101057', '1', 0.112201266, 21],
#   ['ConsumerCourt_DCDRC_118168', '0', 0.040179025, 1343],
#   ['ConsumerCourt_DCDRC_118989', '0', 0.106724784, 26],
#   ['ConsumerCourt_DCDRC_120003', '1', 0.050470654, 511],
#   ['ConsumerCourt_DCDRC_120004', '1', 0.050983902, 485],
#   ['ConsumerCourt_DCDRC_121058', '0', 0.050908163, 488],
#   ['ConsumerCourt_DCDRC_125286', '0', 0.05690732, 289],
#   ['ConsumerCourt_DCDRC_126274', '0', 0.038327157, 1628],
#   ['ConsumerCourt_DCDRC_128072', '1', 0.10683736, 25],
#   ['ConsumerCourt_DCDRC_129352', '0', 0.058017887, 262],
#   ['ConsumerCourt_DCDRC_129820', '0', 0.12861805, 11],
#   ['ConsumerCourt_DCDRC_131144', '0', 0.033596758, 2768],
#   ['ConsumerCourt_DCDRC_131587', '0', 0.05232794, 441],
#   ['ConsumerCourt_DCDRC_131846', '0', 0.01890456, 16220],
#   ['ConsumerCourt_DCDRC_132917', '0', 0.029684916, 4266],
#   ['ConsumerCourt_DCDRC_132928', '0', 0.10349699, 31],
#   ['ConsumerCourt_DCDRC_134709', '0', 0.15885127, 3],
#   ['ConsumerCourt_DCDRC_140632', '0', 0.08097281, 76],
#   ['ConsumerCourt_DCDRC_140644', '0', 0.041888062, 1128],
#   ['ConsumerCourt_DCDRC_145502', '0', 0.22279546, 1],
#   ['ConsumerCourt_DCDRC_169855', '0', 0.013639865, 33180],
#   ['ConsumerCourt_DCDRC_202901', '0', 0.012182468, 41376],
#   ['ConsumerCourt_DCDRC_203935', '0', 0.049236365, 565],
#   ['ConsumerCourt_DCDRC_222781', '0', 0.04270294, 1041],
#   ['ConsumerCourt_DCDRC_223340', '0', 0.10012986, 33],
#   ['ConsumerCourt_DCDRC_228779', '0', 0.061288074, 214],
#   ['ConsumerCourt_DCDRC_229540', '0', 0.06344739, 185],
#   ['ConsumerCourt_DCDRC_39867', '0', 0.09333912, 47],
#   ['ConsumerCourt_DCDRC_40822', '0', 0.13684183, 10],
#   ['ConsumerCourt_DCDRC_41058', '0', 0.08850581, 60],
#   ['ConsumerCourt_DCDRC_41514', '0', 0.0863592, 65],
#   ['ConsumerCourt_DCDRC_57900', '1', 0.051946066, 459],
#   ['ConsumerCourt_DCDRC_69224', '0', 0.0922409, 51],
#   ['ConsumerCourt_DCDRC_71619', '0', 0.02860611, 4835],
#   ['ConsumerCourt_DCDRC_73864', '0', 0.066415384, 144],
#   ['ConsumerCourt_DCDRC_75339', '0', 0.09006033, 59],
#   ['ConsumerCourt_DCDRC_75574', '1', 0.030386034, 3914],
#   ['ConsumerCourt_DCDRC_76123', '0', 0.079196304, 80],
#   ['ConsumerCourt_DCDRC_85243', '0', 0.061187252, 219],
#   ['ConsumerCourt_SCDRC_29744', '0', 0.09889413, 36],
#   ['ConsumerCourt_SCDRC_33757', '0', 0.15563965, 4],
#   ['ConsumerCourt_SCDRC_53283', '0', 0.06536047, 158],
#   ['ConsumerCourt_SCDRC_63603', '0', 0.04733666, 652],
#   ['ConsumerCourt_SCDRC_66106', '1', 0.05661826, 295],
#   ['ConsumerCourt_SCDRC_66890', '0', 0.04378543, 943],
#   ['ConsumerCourt_SCDRC_67067', '0', 0.037299085, 1807],
#   ['ConsumerCourt_SCDRC_67949', '0', 0.06972445, 119],
#   ['ConsumerCourt_SCDRC_67951', '0', 0.055329807, 324],
#   ['ConsumerCourt_SCDRC_72333', '1', 0.05302891, 406],
#   ['JodhpurHC_2008_1906', '0', 0.008506074, 73025]],
#  '9': [['ConsumerCourt_DCDRC_108097', '0', 0.07482489, 1857],
#   ['ConsumerCourt_DCDRC_119856', '1', 0.1952854, 35],
#   ['ConsumerCourt_DCDRC_119986', '0', 0.22923806, 7],
#   ['ConsumerCourt_DCDRC_128297', '0', 0.054187942, 4838],
#   ['ConsumerCourt_DCDRC_128836', '0', 0.02067229, 55338],
#   ['ConsumerCourt_DCDRC_130625', '0', 0.027806332, 29163],
#   ['ConsumerCourt_DCDRC_133010', '0', 0.0861836, 1288],
#   ['ConsumerCourt_DCDRC_138306', '1', 0.29405653, 4],
#   ['ConsumerCourt_DCDRC_139625', '0', 0.1663665, 111],
#   ['ConsumerCourt_DCDRC_143537', '0', 0.18472746, 58],
#   ['ConsumerCourt_DCDRC_202901', '0', 0.004328671, 256782],
#   ['ConsumerCourt_DCDRC_202902', '0', 0.013148949, 117703],
#   ['ConsumerCourt_DCDRC_202903', '0', 0.009586263, 167326],
#   ['ConsumerCourt_DCDRC_222047', '1', 0.11585044, 513],
#   ['ConsumerCourt_DCDRC_224718', '1', 0.109551266, 618],
#   ['ConsumerCourt_DCDRC_226994', '0', 0.0384319, 13070],
#   ['ConsumerCourt_DCDRC_227115', '0', 0.130599, 344],
#   ['ConsumerCourt_DCDRC_227445', '0', 0.115274586, 519],
#   ['ConsumerCourt_DCDRC_236013', '1', 0.31552777, 3],
#   ['ConsumerCourt_DCDRC_38039', '1', 0.329712, 2],
#   ['ConsumerCourt_DCDRC_38552', '0', 0.20207666, 22],
#   ['ConsumerCourt_DCDRC_45418', '0', 0.35286936, 1],
#   ['ConsumerCourt_DCDRC_53237', '1', 0.15703411, 149],
#   ['ConsumerCourt_DCDRC_56957', '0', 0.18365142, 59],
#   ['ConsumerCourt_DCDRC_89958', '0', 0.065982774, 2638],
#   ['ConsumerCourt_NCDRC_2916', '0', 0.1529289, 171],
#   ['ConsumerCourt_NCDRC_437', '0', 0.017108273, 78898],
#   ['ConsumerCourt_SCDRC_40659', '0', 0.15887578, 142],
#   ['ConsumerCourt_SCDRC_49689', '0', 0.07578382, 1794],
#   ['ConsumerCourt_SCDRC_53178', '0', 0.09047137, 1086],
#   ['ConsumerCourt_SCDRC_65050', '0', 0.285811, 5],
#   ['ConsumerCourt_SCDRC_67634', '0', 0.016621152, 82856],
#   ['ConsumerCourt_SCDRC_68803', '0', 0.13268949, 321],
#   ['DelhiHC_2008_1343', '0', 0.02718037, 30795],
#   ['DelhiHC_2009_453', '0', 0.021514116, 51151],
#   ['DelhiHC_2010_4683', '0', 0.035598837, 15953],
#   ['DelhiHC_2010_6192', '0', 0.050935127, 5819],
#   ['DelhiHC_2011_69', '0', 0.017885357, 72837],
#   ['DelhiHC_2013_811', '0', 0.028816963, 26907],
#   ['SupremeCourt_2008_278', '0', 0.010291236, 156349]]}

# %%
model_name = 'TFIDF_stem10'

with open('py_results/' + model_name + 'sim_list.pkl', 'wb') as output:
    pickle.dump(sim_list, output, pickle.HIGHEST_PROTOCOL)
with open('py_results/' + model_name + 'rank_list.pkl', 'wb') as output:
    pickle.dump(rank_list, output, pickle.HIGHEST_PROTOCOL)

# %%
with open('py_results/' + model_name + 'sim_list.pkl', 'rb') as ip:
    sim_list = pickle.load(ip)
with open('py_results/' + model_name + 'rank_list.pkl', 'rb') as ip:
    rank_list = pickle.load(ip)

# %%
# Store results in 1st sheet


wb = Workbook()
dest_filename = 'result_excel/' + model_name + '.xlsx'
ws1 = wb.active
ws1.title = "ground_truth"
ws1.append(['Query','Filename', 'Relevance', 'Score', 'Rank'])
for key,value in results.iteritems():
    for i in value:
        ws1.append([int(key)]+ i)

wb.save(filename = dest_filename)

#Query wise (F score)

import pandas as pd

f = pd.ExcelFile(dest_filename)

from scipy.stats import hmean



places = 4
wb = load_workbook(dest_filename)
ws1 = wb.create_sheet(title="evaluation_Qwise")

ws1.append(['Query','Docs considered', 'Precision/Recall', 'Model', 1, 5 ,10, 25, 50, 100, 500, 1000])

k = [1.0, 5.0 ,10.0, 25.0, 50.0, 100.0, 500.0, 1000.0]
for sheet in f.sheet_names:
    if(sheet == "evaluation"):
        continue
    for q in np.arange(1,11):

        x = f.parse(sheet)
        x = x[x['Query'] == q]
        total_1 = (float)(x[x['Relevance'] == 1].shape[0])
        total_0 = (float)(x[x['Relevance'] == 0].shape[0])
        total = (float)(x.shape[0])
        
        ####  repitition due to complication in considering both 1 & 0 relevance
        # precision 1
        row = [q, 1, 'P', model_name ]
        for i in k:
            row.append(x[np.logical_and(x['Relevance'] == 1 , x['Rank'] <= i)].shape[0]/i)
        ws1.append(row);
        p1 = row;
        # precision 0
        row = [q, 0, 'P', model_name ]
        for i in k:
            row.append(x[np.logical_and(x['Relevance'] == 0 , x['Rank'] <= i)].shape[0]/i)    
        ws1.append(row);
        p0 = row;
        #precision 10
        row = [q, 10, 'P', model_name]
        for i in k:
            row.append(x[x['Rank'] <= i].shape[0]/i)  
        ws1.append(row);
        p10 = row;  
        
        
        # recall 1
        row = [q, 1, 'R', model_name]
        for i in k:
            row.append(x[np.logical_and(x['Relevance'] == 1 , x['Rank'] <= i)].shape[0]/total_1)
            row[-1] = round(row[-1],places)
        ws1.append(row);
        r1 = row;    
        # recall 0
        row = [q, 0, 'R', model_name ]
        for i in k:
            row.append(x[np.logical_and(x['Relevance'] == 0 , x['Rank'] <= i)].shape[0]/total_0)
            row[-1] = round(row[-1],places)
        ws1.append(row);
        r0 = row;
        #recall 10
        row = [q, 10, 'R', model_name ]
        for i in k:
            row.append(x[x['Rank'] <= i].shape[0]/total)
            row[-1] = round(row[-1],places)
        ws1.append(row);
        r10 = row;      


        # F 1
        row = [q, 1, 'F', model_name ]
        for i in range(-len(k), 0, 1):
            if p1[i] == 0.0 :
                row.append(0.0)
            else:
                row.append(hmean([p1[i],r1[i]]))
            row[-1] = round(row[-1],places)
        ws1.append(row);

        # F 0
        row = [q, 0, 'F', model_name]
        for i in range(-len(k), 0, 1):
            if p0[i] == 0.0:
                row.append(0.0)
            else:
                row.append(hmean([p0[i],r0[i]]))
            row[-1] = round(row[-1],places)
        ws1.append(row);

        # F 10
        row = [q, 10, 'F', model_name]
        for i in range(-len(k), 0, 1):
            if p10[i] == 0.0:
                row.append(0.0)
            else:
                row.append(hmean([p10[i],r10[i]]))
            row[-1] = round(row[-1],places)
        ws1.append(row);
        
wb.save(filename = dest_filename)


#Query wise Average precision
# precision sum
def p_sum(z):
    z = z.copy()  
    z.sort_values(inplace=True)
    result = 0
    for i,val in enumerate(z):
        result += (i+1)/float(val) 
    return result


import pandas as pd

f = pd.ExcelFile(dest_filename)

from scipy.stats import hmean


places = 4
wb = load_workbook(dest_filename)
ws1 = wb.create_sheet(title="AP_Qwise")

ws1.append(['Query','Docs considered', 'Precision/Recall', 'Model', 1, 5 ,10, 25, 50, 100, 500, 1000])


for sheet in f.sheet_names:    
    if(sheet == "evaluation"or sheet == "evaluation_Qwise"):
        continue
    for q in np.arange(1,11):
        x = f.parse(sheet)
        x = x[x['Query'] == q]
        total = {}
        total[1] = (float)(x[x['Relevance'] == 1].shape[0])
        total[0] = (float)(x[x['Relevance'] == 0].shape[0])
        total[10] = (float)(x.shape[0])
        
        for rel in [1,0]:
            # precision 1
            row = [q, rel, 'AP', model_name ]
            for i in [1.0, 5.0, 10.0, 25.0, 50.0, 100.0, 500.0, 1000.0]:
                row.append(p_sum(x[np.logical_and(x['Relevance'] == rel, x['Rank'] <= i)]['Rank'])/total[rel])
            ws1.append(row);

        row = [q, 10, 'AP', model_name ]
        for i in [1.0, 5.0, 10.0, 25.0, 50.0, 100.0, 500.0, 1000.0]:
            row.append(p_sum(x[x['Rank'] <= i]['Rank'])/total[10])
        ws1.append(row);
wb.save(filename = dest_filename)

# %%
def append_df_to_excel(filename, df, sheet_name='Sheet1', startrow=None,
                       truncate_sheet=False, 
                       **to_excel_kwargs):
    """
    Append a DataFrame [df] to existing Excel file [filename]
    into [sheet_name] Sheet.
    If [filename] doesn't exist, then this function will create it.

    Parameters:
      filename : File path or existing ExcelWriter
                 (Example: '/path/to/file.xlsx')
      df : dataframe to save to workbook
      sheet_name : Name of sheet which will contain DataFrame.
                   (default: 'Sheet1')
      startrow : upper left cell row to dump data frame.
                 Per default (startrow=None) calculate the last row
                 in the existing DF and write to the next row...
      truncate_sheet : truncate (remove and recreate) [sheet_name]
                       before writing DataFrame to Excel file
      to_excel_kwargs : arguments which will be passed to `DataFrame.to_excel()`
                        [can be dictionary]

    Returns: None
    """
    from openpyxl import load_workbook

    # ignore [engine] parameter if it was passed
    if 'engine' in to_excel_kwargs:
        to_excel_kwargs.pop('engine')

    writer = pd.ExcelWriter(filename, engine='openpyxl')

    try:
        # try to open an existing workbook
        writer.book = load_workbook(filename)

        # get the last row in the existing Excel sheet
        # if it was not specified explicitly
        if startrow is None and sheet_name in writer.book.sheetnames:
            startrow = writer.book[sheet_name].max_row

        # truncate sheet
        if truncate_sheet and sheet_name in writer.book.sheetnames:
            # index of [sheet_name] sheet
            idx = writer.book.sheetnames.index(sheet_name)
            # remove [sheet_name]
            writer.book.remove(writer.book.worksheets[idx])
            # create an empty sheet [sheet_name] using old index
            writer.book.create_sheet(sheet_name, idx)

        # copy existing sheets
        writer.sheets = {ws.title:ws for ws in writer.book.worksheets}
    except FileNotFoundError:
        # file does not exist yet, we will create it
        pass

    if startrow is None:
        startrow = 0

    # write out the new sheet
    df.to_excel(writer, sheet_name, startrow=startrow, index= False, header = False, **to_excel_kwargs)

    # save the workbook
    writer.save()

    
f = pd.ExcelFile(dest_filename)
sec_dest = 'result_excel/all_results.xlsx'
f2 = pd.ExcelFile(sec_dest)
append_df_to_excel(sec_dest, f.parse(1), sheet_name= f2.sheet_names[0])
append_df_to_excel(sec_dest, f.parse(2), sheet_name= f2.sheet_names[1])

# %%
############################################################

# %%
def Top_x(x, R):
    R = list(R)
    x_names = []
    for i in range(x):
        x_names.append(filenames[R.index(i + 1)].strip('.txt'))
    return x_names

# %%
def score_stat(word, freq, index):
    index_doc = dict(bm25.corpus[index])
    word = dictionary.doc2bow([word])[0][0]
    idf = bm25.idf[word] if bm25.idf[word] >= 0 else EPSILON * average_idf
    score = freq*((idf * index_doc[word] * (PARAM_K1 + 1)
              / (index_doc[word] + PARAM_K1 * (1 - PARAM_B + PARAM_B * doc_len[index] / bm25.avgdl))))
    return (index_doc[word], score)

# %%
wb = Workbook()
dest_filename = 'Temp.xlsx'
ws = wb.active
ws.title = "Blank"
#ws.append([(2.2,2.2)])
wb.save(filename = dest_filename)
def common_words(q, F):
    temp = []
    for word, freq in dictionary.doc2bow(queries[q]) :
        temp.append((dictionary[word], freq, round(bm25.idf[word], 2)))
    temp.sort(key=lambda x: (x[2],x[1]), reverse=True)
    q_words = [i[0]  for i in temp]
    q_freq = [i[1]  for i in temp]
    index = filenames.index(F + '.txt')
    index_doc = dict(bm25.corpus[index])
    row = []
    for word, freq in  zip(q_words, q_freq):
        w = dictionary.doc2bow([word])[0][0]
        if w in index_doc: 
            f, s = score_stat(word, freq, index)
            row.append([word + ', ' + str(round(bm25.idf[w], 2)), freq, f,  round( (s*100)/sim_list[q][index], 1)])  
    row.sort(key = lambda x: (x[3],x[1],x[2]), reverse = True)
    wb = load_workbook('Temp.xlsx')
    ws = wb.create_sheet(title=str(q) + F)
    ws.append(['word,idf', 'Query freq', 'freq', '% score'])
    for i in row:
        ws.append(i)
    wb.save(filename = 'Temp.xlsx')

# %%
f = open("toberead.txt", 'r') 
count = 0
q = 1
for i in f:
    if i == '\n':
        continue
    count = count + 1
    common_words(q, i.strip())
    if count % 5 == 0:
        q = q + 1

# %%
for i in files_to_tokens(full_filenames[filenames.index(doc + '.txt')]):
    for j in i:
        print j

# %%
doc = 'ConsumerCourt_SCDRC_30176'
corpus[]

# %%
common_words(1, 'ConsumerCourt_DCDRC_41588')

# %%
df = pd.DataFrame(index= None, columns=['words','pair'])

# %%
df

# %%
print df

# %%
df.append(['lol', ('we','wew')])

# %%
def uncommon_words(q, filename)

# %%
# Store results in 1st sheet
wb = Workbook()
dest_filename = 'Explore_BM25.xlsx'
ws = wb.active
ws.title = "Blank"
#ws.append([(2.2,2.2)])
wb.save(filename = dest_filename)

wb = load_workbook('Explore_BM25.xlsx')

for q in range(1, 11):
    ws = wb.create_sheet(title="q" + str(q))
    #x_names = Top_x(10, rank_list[q])
    top_row = ['Doc Name', 'Rel', 'Doc Length', ' Rank', 'Score']
    sec_row = [' ']*5
    temp = []
    for word, freq in dictionary.doc2bow(queries[q]) :
        temp.append((dictionary[word], freq, round(bm25.idf[word], 2)))
    temp.sort(key=lambda x: (x[2],x[1]), reverse=True)
    ws.append(top_row + [i[0]  for i in temp])
    ws.append(sec_row + [str(i[1]) + ', ' + str(i[2]) for i in temp])
    q_words = [i[0]  for i in temp]
    q_freq = [i[1]  for i in temp]
    
    #continue
    doc_list = [i[0] for i in query_truth[str(q)]] + Top_x(10, rank_list[q])
    doc_list = list((set(doc_list)))
    doc_list.sort(key = lambda doc : rank_list[q][filenames.index(doc + '.txt')])
    doc_row = []
    for doc in doc_list:
        temp  = [doc]
        rel_dic = dict(query_truth[str(q)])
        if doc in rel_dic:
            temp.append(rel_dic[doc])
        else:
            temp.append('Not')
        temp.append(doc_len[filenames.index(doc + '.txt')])
        temp.append(rank_list[q][filenames.index(doc + '.txt')])
        temp.append(round(sim_list[q][filenames.index(doc + '.txt')], 2))
        doc_row.append(temp)

    for row in doc_row:
        index = filenames.index(row[0] + '.txt')
        index_doc = dict(bm25.corpus[index])
        
        for word, freq in  zip(q_words, q_freq):
            if dictionary.doc2bow([word])[0][0] in index_doc: 
                f, s = score_stat(word, freq, index)
                row.append( str(f) + ', ' +  str(round( (s*100)/sim_list[q][index], 1) ))
            else:
                row.append('X')
        ws.append(row)
        ws.append([])        
wb.save(filename = dest_filename)

# %%
# Store results in 1st sheet
wb = Workbook()
dest_filename = 'Explore_BM25_uncom.xlsx'
ws = wb.active
ws.title = "Blank"
#ws.append([(2.2,2.2)])
wb.save(filename = dest_filename)



wb = load_workbook('Explore_BM25_uncom.xlsx')

for q in range(1, 11):
    ws = wb.create_sheet(title="q" + str(q))
    #x_names = Top_x(10, rank_list[q])
    top_row = ['Doc Name', 'Rel', 'Doc Length', ' Rank', 'Score']
    sec_row = [' ']*5
    temp = []
    for word, freq in dictionary.doc2bow(queries[q]) :
        temp.append((dictionary[word], freq, round(bm25.idf[word], 2)))
    temp.sort(key=lambda x: (x[2],x[1]), reverse=True)
    ws.append(top_row + [i[0]  for i in temp])
    ws.append(sec_row + [str(i[1]) + ', ' + str(i[2]) for i in temp])
    q_words = [i[0]  for i in temp]
    q_freq = [i[1]  for i in temp]
    
    #continue
    doc_list = [i[0] for i in query_truth[str(q)]] + Top_x(10, rank_list[q])
    doc_list = list((set(doc_list)))
    doc_list.sort(key = lambda doc : rank_list[q][filenames.index(doc + '.txt')])
    doc_row = []
    for doc in doc_list:
        temp  = [doc]
        rel_dic = dict(query_truth[str(q)])
        if doc in rel_dic:
            temp.append(rel_dic[doc])
        else:
            temp.append('Not')
        temp.append(doc_len[filenames.index(doc + '.txt')])
        temp.append(rank_list[q][filenames.index(doc + '.txt')])
        temp.append(round(sim_list[q][filenames.index(doc + '.txt')], 2))
        doc_row.append(temp)

    for row in doc_row:
        index = filenames.index(row[0] + '.txt')
        index_doc = dict(bm25.corpus[index])
        
#         for word, freq in  zip(q_words, q_freq):
#             if dictionary.doc2bow([word])[0][0] in index_doc: 
#                 f, s = score_stat(word, freq, index)
#                 row.append( str(f) + ', ' +  str(round( (s*100)/sim_list[q][index], 1) ))
#             else:
#                 row.append('X')
        #ws.append(row)
        
        sec_row = [' ']*5
        temp = []
        for word, freq in index_doc.iteritems():
            if dictionary[word] not in q_words:
                temp.append((dictionary[word], freq, round(bm25.idf[word], 2)))
        ws.append(row + [i[0]  for i in temp])
        ws.append(sec_row + [str(i[1]) + ', ' + str(i[2]) for i in temp])
        ws.append([])        
wb.save(filename = dest_filename)

# %%
# Store results in 1st sheet
wb = Workbook()
dest_filename = 'Explore_BM25_all.xlsx'
ws = wb.active
ws.title = "Blank"
#ws.append([(2.2,2.2)])
wb.save(filename = dest_filename)



wb = load_workbook('Explore_BM25_all.xlsx')

for q in range(1, 11):
    ws = wb.create_sheet(title="q" + str(q))
    #x_names = Top_x(10, rank_list[q])
    top_row = ['Doc Name', 'Rel', 'Doc Length', ' Rank', 'Score']
    sec_row = [' ']*5
    temp = []
    for word, freq in dictionary.doc2bow(queries[q]) :
        temp.append((dictionary[word], freq, round(bm25.idf[word], 2)))
    temp.sort(key=lambda x: (x[2],x[1]), reverse=True)
    ws.append(top_row + [i[0]  for i in temp])
    ws.append(sec_row + [str(i[1]) + ', ' + str(i[2]) for i in temp])
    q_words = [i[0]  for i in temp]
    q_freq = [i[1]  for i in temp]
    
    #continue
    doc_list = [i[0] for i in query_truth[str(q)]] + Top_x(10, rank_list[q])
    doc_list = list((set(doc_list)))
    doc_list.sort(key = lambda doc : rank_list[q][filenames.index(doc + '.txt')])
    doc_row = []
    for doc in doc_list:
        temp  = [doc]
        rel_dic = dict(query_truth[str(q)])
        if doc in rel_dic:
            temp.append(rel_dic[doc])
        else:
            temp.append('Not')
        temp.append(doc_len[filenames.index(doc + '.txt')])
        temp.append(rank_list[q][filenames.index(doc + '.txt')])
        temp.append(round(sim_list[q][filenames.index(doc + '.txt')], 2))
        doc_row.append(temp)

    for row in doc_row:
        index = filenames.index(row[0] + '.txt')
        index_doc = dict(bm25.corpus[index])
        
        for word, freq in  zip(q_words, q_freq):
            if dictionary.doc2bow([word])[0][0] in index_doc: 
                f, s = score_stat(word, freq, index)
                row.append( str(f) + ', ' +  str(round( (s*100)/sim_list[q][index], 1) ))
            else:
                row.append('X')
        ws.append(row)
        
        sec_row = [' ']*5
        temp = []
        for word, freq in index_doc.iteritems():
            if dictionary[word] not in q_words:
                temp.append((dictionary[word], freq, round(bm25.idf[word], 2)))
        ws.append(sec_row + [i[0]  for i in temp])
        ws.append(sec_row + [str(i[1]) + ', ' + str(i[2]) for i in temp])
        ws.append([])        
wb.save(filename = dest_filename)
