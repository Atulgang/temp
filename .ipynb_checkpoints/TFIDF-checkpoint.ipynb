# %%
import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)

# %%
import nltk
from nltk.tokenize import word_tokenize
from stop_words import get_stop_words
from nltk.stem import WordNetLemmatizer
from gensim import corpora, models
import gensim
import glob2
from itertools import chain
import os
import numpy as np
import itertools
import cPickle as pickle
from  scipy.stats import rankdata
import copy
# Out:
# 2018-01-12 22:20:45,287 : INFO : 'pattern' package not found; tag filters are not available for English

# %%
# Remove non-alphabets from text
def only_alphabet(text):
    return ''.join(i for i in text if (ord(i)<123 and ord(i)>96) or (ord(i)<91 and ord(i)>64) or ord(i)==32)

# %%
# get stopwords as set
en_stop = set(get_stop_words('en'))

# get Vocabulary and remove words with length less than 3 
vocab  = open("wordsEn.txt").read().splitlines()
vocab = [i for i in vocab  if len(i)>2]

# vocab is sorted in descending order 
vocab.sort(key=len, reverse=True)

vocab_set = set(vocab)

# %%
full_filenames = []
x= ['LegalAdhocTask/ConsumerCourtAdhocdata/DCDRC/**/*.txt','LegalAdhocTask/ConsumerCourtAdhocdata/NCDRC/**/*.txt','LegalAdhocTask/ConsumerCourtAdhocdata/SCDRC/**/*.txt', 'LegalAdhocTask/SC-HCAdhocData/DelhiHC/**/*.txt','LegalAdhocTask/SC-HCAdhocData/JharkhandHC/**/*.txt', 'LegalAdhocTask/SC-HCAdhocData/JodhpurHC/**/*.txt' ,'LegalAdhocTask/SC-HCAdhocData/KolkataHC/**/*.txt', 'LegalAdhocTask/SC-HCAdhocData/SupremeCourt/**/*.txt']
for glob_filenames in x:
    glob_filenames = os.path.normpath(glob_filenames)
    for filename in sorted(glob2.glob(glob_filenames)):
        full_filenames.append(filename)
            
filenames = []
x= ['LegalAdhocTask/ConsumerCourtAdhocdata/DCDRC/**/*.txt','LegalAdhocTask/ConsumerCourtAdhocdata/NCDRC/**/*.txt','LegalAdhocTask/ConsumerCourtAdhocdata/SCDRC/**/*.txt', 'LegalAdhocTask/SC-HCAdhocData/DelhiHC/**/*.txt','LegalAdhocTask/SC-HCAdhocData/JharkhandHC/**/*.txt', 'LegalAdhocTask/SC-HCAdhocData/JodhpurHC/**/*.txt' ,'LegalAdhocTask/SC-HCAdhocData/KolkataHC/**/*.txt', 'LegalAdhocTask/SC-HCAdhocData/SupremeCourt/**/*.txt']
for glob_filenames in x:
    glob_filenames = os.path.normpath(glob_filenames)
    for filename in sorted(glob2.glob(glob_filenames)):
        filenames.append(os.path.basename(filename))


# "yield" for each file return token list  i.e list of lists
def files_to_tokens(glob_filenames):
    glob_filenames = os.path.normpath(glob_filenames)
    lemmatizer = WordNetLemmatizer()
    for filename in sorted(glob2.glob(glob_filenames)):
        f = open(filename)
        # read the whole file as lowercase string
        string = only_alphabet(f.read()).lower()
        
        # tokenize that string
        tokens =  word_tokenize(string)
        
        # remove stop words tokens and length two tokens
        tokens = [lemmatizer.lemmatize(i) for i in tokens if i not in en_stop and len(i)>2]

        #seperate words stuck together
        for i,token in enumerate(tokens):
            if token not in vocab_set:
                # both prefix and suffix incase one of the word is of len(2)
                # prefix match
                flag = 0
                for j in range(len(token)-2,2,-1):
                    if token[:j] in vocab_set:
                            tokens.append(token[:j])
                            tokens.append(token[j:])
                            del tokens[i]
                            flag = 1
                            break               
                
                if flag == 1:
                    continue 
                # suffix match
                flag = 0
                for j in range(1,len(token)-2):
                    if token[j:] in vocab_set:
                            tokens.append(token[:j])
                            tokens.append(token[j:])
                            flag =1
                            del tokens[i]                            
                            break               

        # again remove stop words and length two tokens AND WORDS not in vocab
        tokens = [i for i in tokens if i not in en_stop and len(i)>2 and i in vocab_set]                
        if len(tokens) == 0:
            print "empty document"
        yield tokens
        f.close()

        
# yields token list for files specific to courts; needed for creating dictionaries
class texts:
    def DCDRC(self):
        return files_to_tokens('LegalAdhocTask/ConsumerCourtAdhocdata/DCDRC/**/*.txt')
    def NCDRC(self):
        return files_to_tokens('LegalAdhocTask/ConsumerCourtAdhocdata/NCDRC/**/*.txt')
    def SCDRC(self):
        return files_to_tokens('LegalAdhocTask/ConsumerCourtAdhocdata/SCDRC/**/*.txt')
    def DelhiHC(self):
        return files_to_tokens('LegalAdhocTask/SC-HCAdhocData/DelhiHC/**/*.txt')
    def JharkhandHC(self):
        return files_to_tokens('LegalAdhocTask/SC-HCAdhocData/JharkhandHC/**/*.txt')
    def JodhpurHC(self):
        return files_to_tokens('LegalAdhocTask/SC-HCAdhocData/JodhpurHC/**/*.txt')
    def KolkataHC(self):
        return files_to_tokens('LegalAdhocTask/SC-HCAdhocData/KolkataHC/**/*.txt')
    def SupremeCourt(self):
        return files_to_tokens('LegalAdhocTask/SC-HCAdhocData/SupremeCourt/**/*.txt')

# yields bow for each file - tuples id,fq ; needed to train models   
class my_corpus:    
    def DCDRC(self):
        for text in files_to_tokens('LegalAdhocTask/ConsumerCourtAdhocdata/DCDRC/*.txt'):
            yield dictionary.doc2bow(text)
    def NCDRC(self):
        for text in files_to_tokens('LegalAdhocTask/ConsumerCourtAdhocdata/NCDRC/**/*.txt'):
            yield dictionary.doc2bow(text)            
    def SCDRC(self):
        for text in files_to_tokens('LegalAdhocTask/ConsumerCourtAdhocdata/SCDRC/**/*.txt'):
            yield dictionary.doc2bow(text)
    def DelhiHC(self):
        for text in files_to_tokens('LegalAdhocTask/SC-HCAdhocData/DelhiHC/**/*.txt'):
            yield dictionary.doc2bow(text)
    def JharkhandHC(self):
        for text in files_to_tokens('LegalAdhocTask/SC-HCAdhocData/JharkhandHC/**/*.txt'):
            yield dictionary.doc2bow(text)
    def JodhpurHC(self):
        for text in  files_to_tokens('LegalAdhocTask/SC-HCAdhocData/JodhpurHC/**/*.txt'):
            yield dictionary.doc2bow(text)
    def KolkataHC(self):
        for text in  files_to_tokens('LegalAdhocTask/SC-HCAdhocData/KolkataHC/**/*.txt'):
            yield dictionary.doc2bow(text)
    def SupremeCourt(self):
        for text in  files_to_tokens('LegalAdhocTask/SC-HCAdhocData/SupremeCourt/**/*.txt'):
            yield dictionary.doc2bow(text)
    def everything(self):
        return chain(self.DCDRC(), self.NCDRC(), self.SCDRC(), self.DelhiHC(),
                     self.JharkhandHC(), self.JodhpurHC(), self.KolkataHC(), self.SupremeCourt())

# %%
# Create all the court specific dictionaries
T = texts()
dictionary_DCDRC = corpora.Dictionary(text for text in T.DCDRC())
dictionary_NCDRC = corpora.Dictionary(text for text in T.NCDRC())
dictionary_SCDRC = corpora.Dictionary(text for text in T.SCDRC())
dictionary_DelhiHC = corpora.Dictionary(text for text in T.DelhiHC())
dictionary_JharkhandHC = corpora.Dictionary(text for text in T.JharkhandHC())
dictionary_JodhpurHC = corpora.Dictionary(text for text in T.JodhpurHC())
dictionary_KolkataHC = corpora.Dictionary(text for text in T.KolkataHC())
dictionary_SupremeCourt = corpora.Dictionary(text for text in T.SupremeCourt())
# ## check out dictionaries
# dictionary_DCDRC.save_as_text('newdictionary_DCDRC.txt') 
# dictionary_NCDRC.save_as_text('newdictionary_NCDRC.txt') 
# dictionary_SCDRC.save_as_text('newdictionary_SCDRC.txt') 
# dictionary_DelhiHC.save_as_text('newdictionary_DelhiHC.txt') 
# dictionary_JharkhandHC.save_as_text('newdictionary_JharkhandHC.txt') 
# dictionary_JodhpurHC.save_as_text('newdictionary_JodhpurHC.txt') 
# dictionary_KolkataHC.save_as_text('newdictionary_KolkataHC.txt') 
# dictionary_SupremeCourt.save_as_text('newdictionary_SupremeCourt.txt') 
# Save actual dictionaries
dictionary_DCDRC.save('newdictionary_DCDRC') 
dictionary_NCDRC.save('newdictionary_NCDRC') 
dictionary_SCDRC.save('newdictionary_SCDRC') 
dictionary_DelhiHC.save('newdictionary_DelhiHC') 
dictionary_JharkhandHC.save('newdictionary_JharkhandHC') 
dictionary_JodhpurHC.save('newdictionary_JodhpurHC') 
dictionary_KolkataHC.save('newdictionary_KolkataHC') 
dictionary_SupremeCourt.save('newdictionary_SupremeCourt')

# %%
# load those dictionaries
dictionary_DCDRC = corpora.Dictionary.load('newdictionary_DCDRC') 
dictionary_NCDRC = corpora.Dictionary.load('newdictionary_NCDRC') 
dictionary_SCDRC = corpora.Dictionary.load('newdictionary_SCDRC') 
dictionary_DelhiHC = corpora.Dictionary.load('newdictionary_DelhiHC') 
dictionary_JharkhandHC = corpora.Dictionary.load('newdictionary_JharkhandHC') 
dictionary_JodhpurHC = corpora.Dictionary.load('newdictionary_JodhpurHC') 
dictionary_KolkataHC = corpora.Dictionary.load('newdictionary_KolkataHC') 
dictionary_SupremeCourt= corpora.Dictionary.load('newdictionary_SupremeCourt')

# %%
# discard words occuring in less than 5 documents and in more than 50% 
dictionary_DCDRC.filter_extremes(keep_n=None)
dictionary_NCDRC.filter_extremes(keep_n=None) 
dictionary_SCDRC .filter_extremes(keep_n=None)
dictionary_DelhiHC.filter_extremes(keep_n=None) 
dictionary_JharkhandHC.filter_extremes(keep_n=None) 
dictionary_JodhpurHC.filter_extremes(keep_n=None) 
dictionary_KolkataHC.filter_extremes(keep_n=None) 
dictionary_SupremeCourt.filter_extremes(keep_n=None) 
# Merge all the dictionaries
dictionary = dictionary_DCDRC
dictionary.merge_with(dictionary_DelhiHC)
dictionary.merge_with(dictionary_NCDRC)
dictionary.merge_with(dictionary_SCDRC)
dictionary.merge_with(dictionary_SupremeCourt)
dictionary.merge_with(dictionary_JharkhandHC)
dictionary.merge_with(dictionary_JodhpurHC)
dictionary.merge_with(dictionary_KolkataHC)
# Need this after merging
dictionary.compactify()

# %%
# save the dictionary
dictionary.save('newdictionary')

# %%
#################################### laod the dictinary
dictionary = corpora.Dictionary.load('newdictionary')
# Out:
# 2018-01-12 22:21:04,374 : INFO : loading Dictionary object from newdictionary
# 2018-01-12 22:21:04,386 : INFO : loaded newdictionary

# %%
# This is BOW wrapper
c = my_corpus()
corpus = c.everything()
# save BOW
corpora.MmCorpus.serialize('newcorpus.mm', corpus)

# %%
######################################## load BOW
corpus = corpora.MmCorpus('newcorpus.mm')
# Out:
# 2018-01-12 22:21:08,344 : INFO : loaded corpus index from newcorpus.mm.index
# 2018-01-12 22:21:08,345 : INFO : initializing corpus reader from newcorpus.mm
# 2018-01-12 22:21:08,346 : INFO : accepted corpus with 351985 documents, 35955 features, 88778565 non-zero entries

# %%
# Tfidf model
# Will take time as to generate a model it processes over the whole corpus
tfidf = gensim.models.TfidfModel(corpus)
# save tfidf model
tfidf.save('newtfidf.mdl')

# %%
##################################### load tfidf model
tfidf = gensim.models.tfidfmodel.TfidfModel.load('newtfidf.mdl')
# Out:
# 2018-01-12 22:21:13,565 : INFO : loading TfidfModel object from newtfidf.mdl
# 2018-01-12 22:21:13,647 : INFO : loaded newtfidf.mdl

# %%
# tfidf wrapper coprus
# doesn't take time - yield
tfidf_corpus = tfidf[corpus]

# actual tfidf corpus serialized
corpora.MmCorpus.serialize('newtfidf_corpus.mm', tfidf_corpus)

# %%
##################################### load tfidf corpus
tfidf_corpus = corpora.MmCorpus('newtfidf_corpus.mm')
# Out:
# 2018-01-12 22:21:17,418 : INFO : loaded corpus index from newtfidf_corpus.mm.index
# 2018-01-12 22:21:17,419 : INFO : initializing corpus reader from newtfidf_corpus.mm
# 2018-01-12 22:21:17,470 : INFO : accepted corpus with 351985 documents, 35955 features, 88778565 non-zero entries

# %%
# get the query truth in dictionary
# query no. gives the list of 0-1 documents
query_truth = {}
for i in range(1,11):
    query_truth[str(i)]=[]
    
f = open('LegalAdhocTask/Consumer.qrels')
lines = [line.rstrip('\n').split("\t") for line in f]
for line in lines:
    del line[1]
    query_truth[line[0]].append(line[1:])

# %%
# create index - Tfidf
tfidf_index = gensim.similarities.Similarity('tfidf.index',tfidf_corpus,len(dictionary))

# save index - tfidf
gensim.similarities.Similarity.save(tfidf_index,'TFIDF_index')

# %%
########################### load tfidf index
tfidf_index = gensim.similarities.Similarity.load('TFIDF_index')
# Out:
# 2018-01-12 22:21:25,294 : INFO : loading Similarity object from TFIDF_index
# 2018-01-12 22:21:25,295 : INFO : loaded TFIDF_index

# %%
# calculate similarity for all 
tfidf_index.num_best= None

# %%
#######################         SIMILIRATIES SCORES AND RANKING    ###########################
tfidf_results = copy.deepcopy(query_truth)
### lists of list (indexing from 1, dummy element)
sim_list = [0]
rank_list = [0]
queries = [0]
for i,query in enumerate(files_to_tokens('LegalAdhocTask/q*.txt')):
    queries.append(query)
    # inside the square bracket determines query representation
    
    sims = tfidf_index[tfidf[dictionary.doc2bow(query)]]
    sim_list.append(sims)
    # rank of every document wrt similarity
    ranks = rankdata(sims, method='ordinal')
    ranks= len(ranks)+1 - ranks 
    rank_list.append(ranks)
    
    # update the query truth tuples with similarity score and the ranks
    for x in tfidf_results[str(i+1)]:
        x.append(sims[filenames.index(x[0]+'.txt')])
        x.append(ranks[filenames.index(x[0]+'.txt')])
        #x.append(common_words(filenames.index(x[0]+'.txt'), tfidf_corpus, query))
    
    # sort wrt relevance(from truth) and then ranks(from our model)
    #tfidf_results[str(i+1)].sort(key=lambda x: (-int(x[1]),x[3]))
# Out:
# 2018-01-12 22:21:38,285 : INFO : loading SparseMatrixSimilarity object from tfidf.index.0
# 2018-01-12 22:21:38,869 : INFO : loaded tfidf.index.0
# 2018-01-12 22:21:38,953 : INFO : loading SparseMatrixSimilarity object from tfidf.index.1
# 2018-01-12 22:21:39,421 : INFO : loaded tfidf.index.1
# 2018-01-12 22:21:39,448 : INFO : loading SparseMatrixSimilarity object from tfidf.index.2
# 2018-01-12 22:21:39,957 : INFO : loaded tfidf.index.2
# 2018-01-12 22:21:40,005 : INFO : loading SparseMatrixSimilarity object from tfidf.index.3
# 2018-01-12 22:21:40,509 : INFO : loaded tfidf.index.3
# 2018-01-12 22:21:40,556 : INFO : loading SparseMatrixSimilarity object from tfidf.index.4
# 2018-01-12 22:21:40,886 : INFO : loaded tfidf.index.4
# 2018-01-12 22:21:40,918 : INFO : loading SparseMatrixSimilarity object from tfidf.index.5
# 2018-01-12 22:21:40,919 : INFO : loading index from tfidf.index.5.index.npy with mmap=r
# 2018-01-12 22:21:40,983 : INFO : loaded tfidf.index.5
# 2018-01-12 22:21:41,512 : INFO : loading SparseMatrixSimilarity object from tfidf.index.6
# 2018-01-12 22:21:42,014 : INFO : loaded tfidf.index.6
# 2018-01-12 22:21:42,056 : INFO : loading SparseMatrixSimilarity object from tfidf.index.7
# 2018-01-12 22:21:42,175 : INFO : loaded tfidf.index.7
# 2018-01-12 22:21:42,187 : INFO : loading SparseMatrixSimilarity object from tfidf.index.8
# 2018-01-12 22:21:42,344 : INFO : loaded tfidf.index.8
# 2018-01-12 22:21:42,361 : INFO : loading SparseMatrixSimilarity object from tfidf.index.9
# 2018-01-12 22:21:42,790 : INFO : loaded tfidf.index.9
# 2018-01-12 22:21:42,828 : INFO : loading SparseMatrixSimilarity object from tfidf.index.10
# 2018-01-12 22:21:42,829 : INFO : loading index from tfidf.index.10.index.npy with mmap=r
# 2018-01-12 22:21:42,901 : INFO : loaded tfidf.index.10

# %%
tfidf_results
# Out:
# {'1': [['ConsumerCourt_DCDRC_100385', '1', 0.24860436, 274],
#   ['ConsumerCourt_DCDRC_106530', '0', 0.19510467, 711],
#   ['ConsumerCourt_DCDRC_107608', '1', 0.1246242, 1779],
#   ['ConsumerCourt_DCDRC_114291', '1', 0.19972853, 669],
#   ['ConsumerCourt_DCDRC_114382', '1', 0.14082284, 1461],
#   ['ConsumerCourt_DCDRC_118185', '1', 0.046876241, 9035],
#   ['ConsumerCourt_DCDRC_130318', '0', 0.18421404, 840],
#   ['ConsumerCourt_DCDRC_130570', '1', 0.35782218, 37],
#   ['ConsumerCourt_DCDRC_131146', '1', 0.081247769, 3593],
#   ['ConsumerCourt_DCDRC_131717', '1', 0.12323821, 1815],
#   ['ConsumerCourt_DCDRC_131741', '1', 0.16732627, 1063],
#   ['ConsumerCourt_DCDRC_131818', '1', 0.14837956, 1328],
#   ['ConsumerCourt_DCDRC_131950', '0', 0.073916182, 4151],
#   ['ConsumerCourt_DCDRC_131972', '0', 0.13214688, 1619],
#   ['ConsumerCourt_DCDRC_132932', '0', 0.10617077, 2326],
#   ['ConsumerCourt_DCDRC_133592', '1', 0.27560019, 157],
#   ['ConsumerCourt_DCDRC_134386', '0', 0.54824233, 1],
#   ['ConsumerCourt_DCDRC_135474', '1', 0.11499894, 2037],
#   ['ConsumerCourt_DCDRC_139024', '0', 0.27845153, 151],
#   ['ConsumerCourt_DCDRC_139205', '0', 0.34678739, 45],
#   ['ConsumerCourt_DCDRC_140039', '1', 0.32230711, 70],
#   ['ConsumerCourt_DCDRC_145708', '0', 0.45274115, 6],
#   ['ConsumerCourt_DCDRC_187214', '1', 0.10187973, 2490],
#   ['ConsumerCourt_DCDRC_207784', '1', 0.056903392, 6511],
#   ['ConsumerCourt_DCDRC_217344', '1', 0.30339226, 94],
#   ['ConsumerCourt_DCDRC_217471', '1', 0.22937046, 406],
#   ['ConsumerCourt_DCDRC_222797', '0', 0.25399891, 244],
#   ['ConsumerCourt_DCDRC_222844', '1', 0.2306449, 398],
#   ['ConsumerCourt_DCDRC_224228', '0', 0.2487818, 273],
#   ['ConsumerCourt_DCDRC_224833', '0', 0.29982787, 99],
#   ['ConsumerCourt_DCDRC_226072', '1', 0.41369277, 14],
#   ['ConsumerCourt_DCDRC_38498', '0', 0.38594341, 21],
#   ['ConsumerCourt_DCDRC_39186', '1', 0.19768378, 691],
#   ['ConsumerCourt_DCDRC_41317', '1', 0.11379609, 2076],
#   ['ConsumerCourt_DCDRC_41588', '1', 0.33278599, 54],
#   ['ConsumerCourt_DCDRC_42118', '1', 0.18760437, 787],
#   ['ConsumerCourt_DCDRC_42618', '1', 0.22404736, 449],
#   ['ConsumerCourt_DCDRC_42649', '1', 0.45853043, 5],
#   ['ConsumerCourt_DCDRC_44200', '1', 0.19407943, 720],
#   ['ConsumerCourt_DCDRC_46368', '1', 0.23966464, 331],
#   ['ConsumerCourt_DCDRC_46519', '1', 0.21995942, 484],
#   ['ConsumerCourt_DCDRC_46543', '1', 0.14554347, 1364],
#   ['ConsumerCourt_DCDRC_53138', '1', 0.13873544, 1499],
#   ['ConsumerCourt_DCDRC_55517', '1', 0.35226679, 41],
#   ['ConsumerCourt_DCDRC_55612', '1', 0.17693545, 933],
#   ['ConsumerCourt_DCDRC_55678', '1', 0.25786078, 219],
#   ['ConsumerCourt_DCDRC_55899', '1', 0.30997869, 85],
#   ['ConsumerCourt_DCDRC_57484', '0', 0.36580664, 31],
#   ['ConsumerCourt_DCDRC_74868', '1', 0.19762827, 692],
#   ['ConsumerCourt_DCDRC_80057', '1', 0.41790479, 11],
#   ['ConsumerCourt_DCDRC_83596', '0', 0.31225777, 79],
#   ['ConsumerCourt_DCDRC_83779', '0', 0.21915299, 490],
#   ['ConsumerCourt_DCDRC_96667', '1', 0.41926709, 9],
#   ['ConsumerCourt_DCDRC_98733', '1', 0.34599787, 47],
#   ['ConsumerCourt_SCDRC_52678', '0', 0.22192861, 469],
#   ['DelhiHC_2011_4267', '0', 0.15694781, 1193],
#   ['KolkataHCOriginalSite_2012_36', '0', 0.037989065, 13044]],
#  '10': [['ConsumerCourt_DCDRC_220958', '0', 0.1362889, 558],
#   ['ConsumerCourt_DCDRC_222509', '0', 0.28534901, 13],
#   ['ConsumerCourt_DCDRC_223570', '0', 0.36227629, 3],
#   ['ConsumerCourt_DCDRC_227314', '0', 0.1807445, 200],
#   ['ConsumerCourt_DCDRC_228688', '1', 0.28143129, 14],
#   ['ConsumerCourt_DCDRC_235883', '0', 0.26513213, 21],
#   ['ConsumerCourt_DCDRC_38192', '0', 0.46158475, 2],
#   ['ConsumerCourt_DCDRC_41485', '0', 0.25532925, 29],
#   ['ConsumerCourt_DCDRC_41489', '0', 0.25532925, 28],
#   ['ConsumerCourt_DCDRC_41520', '0', 0.31069452, 9],
#   ['ConsumerCourt_SCDRC_44836', '0', 0.19695055, 124],
#   ['ConsumerCourt_SCDRC_56350', '0', 0.35584745, 5],
#   ['ConsumerCourt_SCDRC_65898', '0', 0.21077757, 84],
#   ['ConsumerCourt_SCDRC_68718', '0', 0.35836241, 4],
#   ['ConsumerCourt_SCDRC_69937', '1', 0.65603954, 1],
#   ['ConsumerCourt_SCDRC_70632', '0', 0.10277697, 1082],
#   ['DelhiHC_2008_2771', '0', 0.20522806, 102],
#   ['DelhiHC_2008_2772', '0', 0.20522806, 101]],
#  '2': [['ConsumerCourt_DCDRC_103241', '0', 0.085983202, 249],
#   ['ConsumerCourt_DCDRC_107786', '1', 0.071430162, 526],
#   ['ConsumerCourt_DCDRC_114305', '1', 0.047545128, 2524],
#   ['ConsumerCourt_DCDRC_120930', '1', 0.047224849, 2606],
#   ['ConsumerCourt_DCDRC_123490', '1', 0.084539123, 272],
#   ['ConsumerCourt_DCDRC_125352', '1', 0.076858908, 404],
#   ['ConsumerCourt_DCDRC_127791', '0', 0.084097974, 276],
#   ['ConsumerCourt_DCDRC_130071', '0', 0.057286832, 1211],
#   ['ConsumerCourt_DCDRC_130920', '1', 0.051614959, 1826],
#   ['ConsumerCourt_DCDRC_131972', '0', 0.045818109, 2931],
#   ['ConsumerCourt_DCDRC_133106', '1', 0.046035215, 2867],
#   ['ConsumerCourt_DCDRC_133260', '0', 0.079933874, 347],
#   ['ConsumerCourt_DCDRC_143284', '1', 0.04502086, 3128],
#   ['ConsumerCourt_DCDRC_143334', '0', 0.12081463, 52],
#   ['ConsumerCourt_DCDRC_144440', '0', 0.057874702, 1162],
#   ['ConsumerCourt_DCDRC_202900', '0', 0.029433528, 15963],
#   ['ConsumerCourt_DCDRC_202903', '0', 0.035661768, 7642],
#   ['ConsumerCourt_DCDRC_207376', '1', 0.055928212, 1320],
#   ['ConsumerCourt_DCDRC_212601', '0', 0.056218799, 1297],
#   ['ConsumerCourt_DCDRC_212692', '1', 0.06776946, 649],
#   ['ConsumerCourt_DCDRC_214518', '1', 0.097047754, 135],
#   ['ConsumerCourt_DCDRC_226924', '0', 0.07849925, 376],
#   ['ConsumerCourt_DCDRC_227866', '1', 0.067711435, 651],
#   ['ConsumerCourt_DCDRC_228749', '1', 0.12901193, 43],
#   ['ConsumerCourt_DCDRC_229221', '0', 0.058295012, 1121],
#   ['ConsumerCourt_DCDRC_230361', '1', 0.069210313, 601],
#   ['ConsumerCourt_DCDRC_41190', '0', 0.073440872, 477],
#   ['ConsumerCourt_DCDRC_50671', '1', 0.055909663, 1322],
#   ['ConsumerCourt_DCDRC_52620', '1', 0.11473192, 60],
#   ['ConsumerCourt_DCDRC_53093', '1', 0.11407738, 63],
#   ['ConsumerCourt_DCDRC_53138', '0', 0.045954324, 2892],
#   ['ConsumerCourt_DCDRC_53153', '1', 0.10960063, 77],
#   ['ConsumerCourt_DCDRC_53432', '0', 0.074514344, 454],
#   ['ConsumerCourt_DCDRC_53875', '0', 0.036501691, 7000],
#   ['ConsumerCourt_DCDRC_53881', '0', 0.036501691, 6999],
#   ['ConsumerCourt_DCDRC_56471', '1', 0.1038534, 96],
#   ['ConsumerCourt_DCDRC_56761', '0', 0.063327596, 813],
#   ['ConsumerCourt_DCDRC_57453', '0', 0.044874068, 3167],
#   ['ConsumerCourt_DCDRC_57583', '0', 0.02217528, 41936],
#   ['ConsumerCourt_DCDRC_62986', '0', 0.080575265, 336],
#   ['ConsumerCourt_DCDRC_63724', '0', 0.029728355, 15373],
#   ['ConsumerCourt_DCDRC_68765', '0', 0.048372, 2330],
#   ['ConsumerCourt_DCDRC_68808', '0', 0.052149583, 1753],
#   ['ConsumerCourt_DCDRC_69863', '0', 0.079615742, 352],
#   ['ConsumerCourt_DCDRC_74887', '0', 0.069507316, 589],
#   ['ConsumerCourt_DCDRC_75562', '0', 0.054384872, 1505],
#   ['ConsumerCourt_DCDRC_76114', '0', 0.027877837, 19508],
#   ['ConsumerCourt_DCDRC_76186', '0', 0.021492999, 46010],
#   ['ConsumerCourt_DCDRC_76270', '0', 0.050069764, 2041],
#   ['ConsumerCourt_DCDRC_77085', '1', 0.073646739, 472],
#   ['ConsumerCourt_DCDRC_77280', '0', 0.033107091, 10148],
#   ['ConsumerCourt_DCDRC_77935', '1', 0.076521628, 412],
#   ['ConsumerCourt_DCDRC_87186', '0', 0.042538911, 3883],
#   ['ConsumerCourt_DCDRC_91864', '1', 0.085535847, 256],
#   ['ConsumerCourt_DCDRC_96244', '1', 0.074047461, 464],
#   ['ConsumerCourt_NCDRC_1317', '0', 0.11671551, 54],
#   ['ConsumerCourt_SCDRC_49685', '0', 0.061089538, 921],
#   ['ConsumerCourt_SCDRC_60064', '1', 0.064300925, 778],
#   ['ConsumerCourt_SCDRC_62062', '1', 0.017644189, 76958]],
#  '3': [['ConsumerCourt_DCDRC_103355', '0', 0.10654728, 493],
#   ['ConsumerCourt_DCDRC_129293', '1', 0.33665749, 4],
#   ['ConsumerCourt_DCDRC_133013', '1', 0.13959754, 225],
#   ['ConsumerCourt_DCDRC_133017', '0', 0.22861525, 46],
#   ['ConsumerCourt_DCDRC_137661', '0', 0.15738939, 150],
#   ['ConsumerCourt_DCDRC_153064', '0', 0.030067964, 9112],
#   ['ConsumerCourt_DCDRC_187619', '1', 0.25007316, 32],
#   ['ConsumerCourt_DCDRC_200840', '0', 0.12741975, 291],
#   ['ConsumerCourt_DCDRC_222260', '1', 0.26814976, 22],
#   ['ConsumerCourt_DCDRC_222772', '1', 0.23441324, 43],
#   ['ConsumerCourt_DCDRC_223618', '1', 0.26635903, 24],
#   ['ConsumerCourt_DCDRC_228476', '0', 0.12489417, 310],
#   ['ConsumerCourt_DCDRC_228963', '1', 0.28764078, 14],
#   ['ConsumerCourt_DCDRC_230634', '1', 0.32663813, 6],
#   ['ConsumerCourt_DCDRC_235824', '0', 0.38199013, 2],
#   ['ConsumerCourt_DCDRC_45666', '0', 0.10048855, 586],
#   ['ConsumerCourt_DCDRC_47493', '1', 0.16779792, 125],
#   ['ConsumerCourt_DCDRC_52566', '0', 0.1661353, 128],
#   ['ConsumerCourt_DCDRC_73184', '0', 0.20039062, 69],
#   ['ConsumerCourt_DCDRC_73185', '0', 0.19892664, 72],
#   ['ConsumerCourt_NCDRC_2861', '1', 0.0975926, 633],
#   ['ConsumerCourt_NCDRC_2902', '0', 0.085591264, 886],
#   ['ConsumerCourt_NCDRC_2979', '0', 0.13832594, 236],
#   ['ConsumerCourt_NCDRC_632', '0', 0.091315411, 764],
#   ['ConsumerCourt_NCDRC_637', '0', 0.090792373, 772],
#   ['ConsumerCourt_SCDRC_2052', '0', 0.29039922, 12],
#   ['ConsumerCourt_SCDRC_22704', '0', 0.073761769, 1299],
#   ['ConsumerCourt_SCDRC_29484', '0', 0.13419849, 255],
#   ['ConsumerCourt_SCDRC_29552', '0', 0.03757149, 5762],
#   ['ConsumerCourt_SCDRC_30176', '0', 0.21150319, 58],
#   ['ConsumerCourt_SCDRC_48394', '0', 0.073297068, 1313],
#   ['ConsumerCourt_SCDRC_63569', '0', 0.098521665, 622],
#   ['ConsumerCourt_SCDRC_63609', '0', 0.20613545, 63],
#   ['ConsumerCourt_SCDRC_65919', '0', 0.26929134, 21],
#   ['ConsumerCourt_SCDRC_66200', '0', 0.11475945, 395],
#   ['ConsumerCourt_SCDRC_69801', '0', 0.10743552, 487],
#   ['ConsumerCourt_SCDRC_814', '0', 0.099014305, 613],
#   ['DelhiHC_2012_388', '0', 0.043486319, 4201]],
#  '4': [['ConsumerCourt_DCDRC_106570', '0', 0.15800607, 2499],
#   ['ConsumerCourt_DCDRC_116129', '1', 0.14293851, 3555],
#   ['ConsumerCourt_DCDRC_128836', '0', 0.15024613, 3008],
#   ['ConsumerCourt_DCDRC_130725', '1', 0.28222367, 28],
#   ['ConsumerCourt_DCDRC_133137', '0', 0.2261349, 323],
#   ['ConsumerCourt_DCDRC_173376', '0', 0.032142263, 45373],
#   ['ConsumerCourt_DCDRC_174292', '0', 0.13385072, 4335],
#   ['ConsumerCourt_DCDRC_174300', '1', 0.12937793, 4786],
#   ['ConsumerCourt_DCDRC_202903', '0', 0.019896992, 85431],
#   ['ConsumerCourt_DCDRC_205816', '1', 0.19167396, 995],
#   ['ConsumerCourt_DCDRC_207155', '0', 0.19980262, 778],
#   ['ConsumerCourt_DCDRC_207197', '0', 0.15672044, 2577],
#   ['ConsumerCourt_DCDRC_212467', '1', 0.21092513, 538],
#   ['ConsumerCourt_DCDRC_213156', '0', 0.20879474, 576],
#   ['ConsumerCourt_DCDRC_213473', '0', 0.16356063, 2166],
#   ['ConsumerCourt_DCDRC_213784', '0', 0.29321241, 16],
#   ['ConsumerCourt_DCDRC_214475', '0', 0.18335588, 1250],
#   ['ConsumerCourt_DCDRC_218582', '0', 0.34034017, 1],
#   ['ConsumerCourt_DCDRC_221177', '0', 0.18246789, 1280],
#   ['ConsumerCourt_DCDRC_221424', '0', 0.2325394, 253],
#   ['ConsumerCourt_DCDRC_223275', '0', 0.15934372, 2401],
#   ['ConsumerCourt_DCDRC_226909', '0', 0.080537066, 12541],
#   ['ConsumerCourt_DCDRC_227099', '0', 0.17186749, 1730],
#   ['ConsumerCourt_DCDRC_229902', '0', 0.12734303, 4992],
#   ['ConsumerCourt_DCDRC_47636', '0', 0.19859329, 809],
#   ['ConsumerCourt_DCDRC_49131', '0', 0.29222387, 17],
#   ['ConsumerCourt_DCDRC_51881', '0', 0.24497828, 122],
#   ['ConsumerCourt_DCDRC_52357', '0', 0.27031028, 46],
#   ['ConsumerCourt_DCDRC_53202', '0', 0.23226172, 259],
#   ['ConsumerCourt_DCDRC_53580', '1', 0.2086941, 578],
#   ['ConsumerCourt_DCDRC_54056', '1', 0.19836192, 814],
#   ['ConsumerCourt_DCDRC_70122', '0', 0.16122611, 2295],
#   ['ConsumerCourt_DCDRC_73309', '0', 0.24484254, 123],
#   ['ConsumerCourt_NCDRC_2154', '0', 0.025110316, 64120],
#   ['ConsumerCourt_NCDRC_3506', '0', 0.13020794, 4703],
#   ['ConsumerCourt_SCDRC_1143', '1', 0.17702062, 1484],
#   ['ConsumerCourt_SCDRC_1288', '1', 0.24276374, 133],
#   ['ConsumerCourt_SCDRC_22830', '0', 0.18101893, 1329],
#   ['ConsumerCourt_SCDRC_37679', '1', 0.19461933, 911],
#   ['ConsumerCourt_SCDRC_471', '0', 0.077013403, 13503],
#   ['ConsumerCourt_SCDRC_49973', '1', 0.22447225, 344],
#   ['ConsumerCourt_SCDRC_5406', '0', 0.029243749, 51928],
#   ['ConsumerCourt_SCDRC_7046', '1', 0.27349868, 41],
#   ['DelhiHC_2012_3856', '0', 0.10048141, 8593],
#   ['SupremeCourt_2009_1421', '0', 0.1460958, 3302]],
#  '5': [['ConsumerCourt_DCDRC_124651', '0', 0.10278593, 5720],
#   ['ConsumerCourt_DCDRC_138545', '0', 0.28761116, 803],
#   ['ConsumerCourt_DCDRC_139183', '0', 0.43444189, 33],
#   ['ConsumerCourt_DCDRC_141380', '0', 0.098476969, 6024],
#   ['ConsumerCourt_DCDRC_148691', '1', 0.47221848, 6],
#   ['ConsumerCourt_DCDRC_202903', '0', 0.022287691, 61448],
#   ['ConsumerCourt_DCDRC_208296', '0', 0.29474869, 735],
#   ['ConsumerCourt_DCDRC_223817', '0', 0.23326804, 1570],
#   ['ConsumerCourt_DCDRC_226994', '0', 0.074880213, 8170],
#   ['ConsumerCourt_DCDRC_229911', '1', 0.15418741, 3434],
#   ['ConsumerCourt_DCDRC_41155', '1', 0.33944792, 365],
#   ['ConsumerCourt_DCDRC_41262', '0', 0.26785573, 1046],
#   ['ConsumerCourt_DCDRC_41428', '0', 0.15547928, 3391],
#   ['ConsumerCourt_DCDRC_42411', '0', 0.14413178, 3790],
#   ['ConsumerCourt_DCDRC_46404', '0', 0.15150295, 3527],
#   ['ConsumerCourt_DCDRC_53679', '1', 0.23016742, 1628],
#   ['ConsumerCourt_DCDRC_57315', '1', 0.24334015, 1401],
#   ['ConsumerCourt_DCDRC_57465', '0', 0.14219494, 3854],
#   ['ConsumerCourt_DCDRC_57488', '0', 0.23036334, 1622],
#   ['ConsumerCourt_DCDRC_57914', '1', 0.22751038, 1681],
#   ['ConsumerCourt_DCDRC_66294', '0', 0.26522416, 1071],
#   ['ConsumerCourt_DCDRC_96799', '0', 0.4613325, 9],
#   ['ConsumerCourt_NCDRC_1337', '1', 0.35878986, 238],
#   ['ConsumerCourt_NCDRC_1338', '0', 0.35878986, 237],
#   ['ConsumerCourt_NCDRC_2983', '1', 0.35720366, 253],
#   ['ConsumerCourt_SCDRC_28656', '0', 0.3656027, 205],
#   ['ConsumerCourt_SCDRC_33517', '1', 0.46084994, 10],
#   ['ConsumerCourt_SCDRC_5122', '0', 0.14979605, 3591],
#   ['ConsumerCourt_SCDRC_71374', '1', 0.27257904, 982]],
#  '6': [['ConsumerCourt_DCDRC_103021', '1', 0.19786049, 134],
#   ['ConsumerCourt_DCDRC_119836', '1', 0.044592723, 4115],
#   ['ConsumerCourt_DCDRC_125237', '1', 0.047479928, 3682],
#   ['ConsumerCourt_DCDRC_126276', '0', 0.066672683, 1981],
#   ['ConsumerCourt_DCDRC_131266', '1', 0.093190134, 1028],
#   ['ConsumerCourt_DCDRC_133353', '1', 0.090473801, 1106],
#   ['ConsumerCourt_DCDRC_133354', '0', 0.090038404, 1120],
#   ['ConsumerCourt_DCDRC_134804', '0', 0.088060692, 1176],
#   ['ConsumerCourt_DCDRC_138617', '1', 0.16324054, 263],
#   ['ConsumerCourt_DCDRC_143983', '0', 0.0069543207, 91724],
#   ['ConsumerCourt_DCDRC_207387', '1', 0.073050134, 1658],
#   ['ConsumerCourt_DCDRC_220958', '1', 0.16818269, 233],
#   ['ConsumerCourt_DCDRC_223570', '1', 0.11875867, 622],
#   ['ConsumerCourt_DCDRC_223783', '0', 0.2232915, 84],
#   ['ConsumerCourt_DCDRC_38192', '1', 0.16945145, 231],
#   ['ConsumerCourt_DCDRC_41485', '0', 0.21713653, 102],
#   ['ConsumerCourt_DCDRC_41489', '0', 0.21713653, 101],
#   ['ConsumerCourt_DCDRC_41520', '1', 0.10029949, 890],
#   ['ConsumerCourt_DCDRC_45421', '0', 0.019880494, 17603],
#   ['ConsumerCourt_DCDRC_52148', '0', 0.022853084, 13534],
#   ['ConsumerCourt_DCDRC_70186', '0', 0.20912358, 116],
#   ['ConsumerCourt_DCDRC_70341', '0', 0.22253911, 86],
#   ['ConsumerCourt_DCDRC_90054', '0', 0.022203486, 14268],
#   ['ConsumerCourt_SCDRC_28640', '1', 0.043066647, 4371],
#   ['ConsumerCourt_SCDRC_64152', '0', 0.072355986, 1697],
#   ['ConsumerCourt_SCDRC_68718', '1', 0.092157677, 1068],
#   ['ConsumerCourt_SCDRC_70632', '0', 0.19873722, 130],
#   ['DelhiHC_2009_735', '1', 0.045112479, 4032],
#   ['DelhiHC_2012_372', '0', 0.046936266, 3758],
#   ['DelhiHC_2012_374', '0', 0.046936266, 3757],
#   ['SupremeCourt_1996_416', '0', 0.015868109, 26677]],
#  '7': [['ConsumerCourt_DCDRC_119406', '1', 0.077979483, 234],
#   ['ConsumerCourt_DCDRC_121344', '0', 0.17738989, 22],
#   ['ConsumerCourt_DCDRC_127019', '0', 0.095093593, 134],
#   ['ConsumerCourt_DCDRC_130205', '0', 0.21776417, 16],
#   ['ConsumerCourt_DCDRC_207672', '1', 0.13540889, 47],
#   ['ConsumerCourt_DCDRC_222487', '0', 0.40374577, 6],
#   ['ConsumerCourt_DCDRC_224805', '0', 0.086419411, 181],
#   ['ConsumerCourt_DCDRC_235755', '0', 0.09832865, 123],
#   ['ConsumerCourt_DCDRC_236026', '1', 0.15799899, 27],
#   ['ConsumerCourt_DCDRC_236229', '0', 0.53613454, 4],
#   ['ConsumerCourt_DCDRC_33939', '0', 0.13698167, 45],
#   ['ConsumerCourt_DCDRC_44337', '1', 0.18876231, 21],
#   ['ConsumerCourt_DCDRC_45534', '0', 0.66861832, 2],
#   ['ConsumerCourt_DCDRC_46470', '0', 0.32188582, 8],
#   ['ConsumerCourt_DCDRC_48811', '0', 0.15419805, 32],
#   ['ConsumerCourt_DCDRC_51454', '1', 0.11507327, 74],
#   ['ConsumerCourt_DCDRC_64180', '0', 0.66928756, 1],
#   ['ConsumerCourt_DCDRC_73953', '0', 0.1037476, 103],
#   ['ConsumerCourt_DCDRC_75554', '0', 0.054409612, 626],
#   ['ConsumerCourt_SCDRC_1050', '0', 0.087182261, 180],
#   ['ConsumerCourt_SCDRC_1387', '0', 0.5471366, 3],
#   ['ConsumerCourt_SCDRC_1418', '0', 0.36053503, 7],
#   ['ConsumerCourt_SCDRC_65323', '0', 0.19680807, 18],
#   ['ConsumerCourt_SCDRC_66203', '0', 0.02874174, 3735],
#   ['DelhiHC_2012_2026', '0', 0.21968134, 15]],
#  '8': [['ConsumerCourt_DCDRC_101057', '1', 0.043979604, 2501],
#   ['ConsumerCourt_DCDRC_118168', '0', 0.032408956, 6757],
#   ['ConsumerCourt_DCDRC_118989', '0', 0.040478967, 3248],
#   ['ConsumerCourt_DCDRC_120003', '1', 0.042621452, 2750],
#   ['ConsumerCourt_DCDRC_120004', '1', 0.042278975, 2805],
#   ['ConsumerCourt_DCDRC_121058', '0', 0.046755016, 2053],
#   ['ConsumerCourt_DCDRC_125286', '0', 0.024642397, 14692],
#   ['ConsumerCourt_DCDRC_126274', '0', 0.023101078, 17339],
#   ['ConsumerCourt_DCDRC_128072', '1', 0.11269941, 45],
#   ['ConsumerCourt_DCDRC_129352', '0', 0.040077493, 3350],
#   ['ConsumerCourt_DCDRC_129820', '0', 0.15200223, 10],
#   ['ConsumerCourt_DCDRC_131144', '0', 0.037369102, 4262],
#   ['ConsumerCourt_DCDRC_131587', '0', 0.064531922, 595],
#   ['ConsumerCourt_DCDRC_131846', '0', 0.0132721, 55062],
#   ['ConsumerCourt_DCDRC_132917', '0', 0.018539427, 29254],
#   ['ConsumerCourt_DCDRC_132928', '0', 0.064849623, 583],
#   ['ConsumerCourt_DCDRC_134709', '0', 0.18076484, 6],
#   ['ConsumerCourt_DCDRC_140632', '0', 0.035468016, 5079],
#   ['ConsumerCourt_DCDRC_140644', '0', 0.034677926, 5453],
#   ['ConsumerCourt_DCDRC_145502', '0', 0.29039091, 1],
#   ['ConsumerCourt_DCDRC_169855', '0', 0.026075954, 12542],
#   ['ConsumerCourt_DCDRC_202901', '0', 0.023592213, 16427],
#   ['ConsumerCourt_DCDRC_203935', '0', 0.072254658, 370],
#   ['ConsumerCourt_DCDRC_222781', '0', 0.021739943, 20316],
#   ['ConsumerCourt_DCDRC_223340', '0', 0.031938657, 7076],
#   ['ConsumerCourt_DCDRC_228779', '0', 0.054507129, 1190],
#   ['ConsumerCourt_DCDRC_229540', '0', 0.018178364, 30445],
#   ['ConsumerCourt_DCDRC_39867', '0', 0.017764376, 31947],
#   ['ConsumerCourt_DCDRC_40822', '0', 0.17871192, 7],
#   ['ConsumerCourt_DCDRC_41058', '0', 0.1152693, 42],
#   ['ConsumerCourt_DCDRC_41514', '0', 0.092328161, 113],
#   ['ConsumerCourt_DCDRC_57900', '1', 0.0079984246, 108945],
#   ['ConsumerCourt_DCDRC_69224', '0', 0.057146855, 975],
#   ['ConsumerCourt_DCDRC_71619', '0', 0.035446376, 5089],
#   ['ConsumerCourt_DCDRC_73864', '0', 0.037434537, 4243],
#   ['ConsumerCourt_DCDRC_75339', '0', 0.084822252, 173],
#   ['ConsumerCourt_DCDRC_75574', '1', 0.033429213, 6175],
#   ['ConsumerCourt_DCDRC_76123', '0', 0.11938008, 33],
#   ['ConsumerCourt_DCDRC_85243', '0', 0.01770997, 32153],
#   ['ConsumerCourt_SCDRC_29744', '0', 0.13363338, 17],
#   ['ConsumerCourt_SCDRC_33757', '0', 0.20879313, 3],
#   ['ConsumerCourt_SCDRC_53283', '0', 0.075388551, 309],
#   ['ConsumerCourt_SCDRC_63603', '0', 0.018719986, 28677],
#   ['ConsumerCourt_SCDRC_66106', '1', 0.020021526, 24729],
#   ['ConsumerCourt_SCDRC_66890', '0', 0.013132636, 56079],
#   ['ConsumerCourt_SCDRC_67067', '0', 0.024067871, 15630],
#   ['ConsumerCourt_SCDRC_67949', '0', 0.010376779, 79480],
#   ['ConsumerCourt_SCDRC_67951', '0', 0.03947255, 3545],
#   ['ConsumerCourt_SCDRC_72333', '1', 0.035883039, 4910],
#   ['JodhpurHC_2008_1906', '0', 0.012261828, 62432]],
#  '9': [['ConsumerCourt_DCDRC_108097', '0', 0.061617699, 4577],
#   ['ConsumerCourt_DCDRC_119856', '1', 0.17853652, 99],
#   ['ConsumerCourt_DCDRC_119986', '0', 0.2085429, 28],
#   ['ConsumerCourt_DCDRC_128297', '0', 0.062103339, 4475],
#   ['ConsumerCourt_DCDRC_128836', '0', 0.017672813, 80692],
#   ['ConsumerCourt_DCDRC_130625', '0', 0.020173717, 65457],
#   ['ConsumerCourt_DCDRC_133010', '0', 0.062004477, 4498],
#   ['ConsumerCourt_DCDRC_138306', '1', 0.33703169, 4],
#   ['ConsumerCourt_DCDRC_139625', '0', 0.145952, 294],
#   ['ConsumerCourt_DCDRC_143537', '0', 0.1671835, 152],
#   ['ConsumerCourt_DCDRC_202901', '0', 0.0046484265, 242842],
#   ['ConsumerCourt_DCDRC_202902', '0', 0.017441755, 82328],
#   ['ConsumerCourt_DCDRC_202903', '0', 0.010431924, 153696],
#   ['ConsumerCourt_DCDRC_222047', '1', 0.12722531, 505],
#   ['ConsumerCourt_DCDRC_224718', '1', 0.10130809, 997],
#   ['ConsumerCourt_DCDRC_226994', '0', 0.050581817, 8375],
#   ['ConsumerCourt_DCDRC_227115', '0', 0.10721556, 865],
#   ['ConsumerCourt_DCDRC_227445', '0', 0.12982443, 463],
#   ['ConsumerCourt_DCDRC_236013', '1', 0.37280327, 2],
#   ['ConsumerCourt_DCDRC_38039', '1', 0.36136904, 3],
#   ['ConsumerCourt_DCDRC_38552', '0', 0.20730405, 31],
#   ['ConsumerCourt_DCDRC_45418', '0', 0.37808719, 1],
#   ['ConsumerCourt_DCDRC_53237', '1', 0.16791074, 147],
#   ['ConsumerCourt_DCDRC_56957', '0', 0.2316938, 10],
#   ['ConsumerCourt_DCDRC_89958', '0', 0.060779106, 4795],
#   ['ConsumerCourt_NCDRC_2916', '0', 0.19438666, 56],
#   ['ConsumerCourt_NCDRC_437', '0', 0.016869776, 86354],
#   ['ConsumerCourt_SCDRC_40659', '0', 0.153402, 237],
#   ['ConsumerCourt_SCDRC_49689', '0', 0.055400297, 6388],
#   ['ConsumerCourt_SCDRC_53178', '0', 0.11038554, 767],
#   ['ConsumerCourt_SCDRC_65050', '0', 0.3009738, 5],
#   ['ConsumerCourt_SCDRC_67634', '0', 0.023931433, 48320],
#   ['ConsumerCourt_SCDRC_68803', '0', 0.19918752, 42],
#   ['DelhiHC_2008_1343', '0', 0.025311606, 43534],
#   ['DelhiHC_2009_453', '0', 0.027597405, 36721],
#   ['DelhiHC_2010_4683', '0', 0.038213447, 17492],
#   ['DelhiHC_2010_6192', '0', 0.04445545, 11891],
#   ['DelhiHC_2011_69', '0', 0.022894207, 52454],
#   ['DelhiHC_2013_811', '0', 0.027174987, 37875],
#   ['SupremeCourt_2008_278', '0', 0.010602046, 151375]]}

# %%
from openpyxl import Workbook
from openpyxl.compat import range
from openpyxl.utils import get_column_letter
from openpyxl import load_workbook

# %%
# Store results in 1st sheet
wb = Workbook()
dest_filename = 'tfidf.xlsx'
ws1 = wb.active
ws1.title = "TFIDF"
ws1.append(['Query','Filename', 'Relevance', 'Score', 'Rank'])
for key,value in tfidf_results.iteritems():
    for i in value:
        ws1.append([int(key)]+ i)

wb.save(filename = dest_filename)

# %%
#evaluation_Qwise - Precision, Recall and Fscore

import pandas as pd

f = pd.ExcelFile('tfidf.xlsx')

from scipy.stats import hmean



model_name = 'tfidf'
places = 4
wb = load_workbook('tfidf.xlsx')
ws1 = wb.create_sheet(title="evaluation_Qwise")

ws1.append(['Query','Docs considered', 'Precision/Recall', 'Model', 1, 5 ,10, 25, 50, 100, 500, 1000])

k = [1.0, 5.0 ,10.0, 25.0, 50.0, 100.0, 500.0, 1000.0]
for sheet in f.sheet_names:
    if(sheet == "evaluation"):
        continue
    for q in np.arange(1,11):

        x = f.parse(sheet)
        x = x[x['Query'] == q]
        total_1 = (float)(x[x['Relevance'] == 1].shape[0])
        total_0 = (float)(x[x['Relevance'] == 0].shape[0])
        total = (float)(x.shape[0])
        
        ####  repitition due to complication in considering both 1 & 0 relevance
        # precision 1
        row = [q, 1, 'P', model_name + ' :' + sheet]
        for i in k:
            row.append(x[np.logical_and(x['Relevance'] == 1 , x['Rank'] <= i)].shape[0]/i)
        ws1.append(row);
        p1 = row;
        # precision 0
        row = [q, 0, 'P', model_name + ' :' + sheet]
        for i in k:
            row.append(x[np.logical_and(x['Relevance'] == 0 , x['Rank'] <= i)].shape[0]/i)    
        ws1.append(row);
        p0 = row;
        #precision 10
        row = [q, 10, 'P', model_name + ' :' + sheet]
        for i in k:
            row.append(x[x['Rank'] <= i].shape[0]/i)  
        ws1.append(row);
        p10 = row;  
        
        
        # recall 1
        row = [q, 1, 'R', model_name + ' :' + sheet]
        for i in k:
            row.append(x[np.logical_and(x['Relevance'] == 1 , x['Rank'] <= i)].shape[0]/total_1)
            row[-1] = round(row[-1],places)
        ws1.append(row);
        r1 = row;    
        # recall 0
        row = [q, 0, 'R', model_name + ' :' + sheet]
        for i in k:
            row.append(x[np.logical_and(x['Relevance'] == 0 , x['Rank'] <= i)].shape[0]/total_0)
            row[-1] = round(row[-1],places)
        ws1.append(row);
        r0 = row;
        #recall 10
        row = [q, 10, 'R', model_name + ' :' + sheet]
        for i in k:
            row.append(x[x['Rank'] <= i].shape[0]/total)
            row[-1] = round(row[-1],places)
        ws1.append(row);
        r10 = row;      


        # F 1
        row = [q, 1, 'F', model_name + ' :' + sheet]
        for i in range(-len(k), 0, 1):
            if p1[i] == 0.0 :
                row.append(0.0)
            else:
                row.append(hmean([p1[i],r1[i]]))
            row[-1] = round(row[-1],places)
        ws1.append(row);

        # F 0
        row = [q, 0, 'F', model_name + ' :' + sheet]
        for i in range(-len(k), 0, 1):
            if p0[i] == 0.0:
                row.append(0.0)
            else:
                row.append(hmean([p0[i],r0[i]]))
            row[-1] = round(row[-1],places)
        ws1.append(row);

        # F 10
        row = [q, 10, 'F', model_name + ' :' + sheet]
        for i in range(-len(k), 0, 1):
            if p10[i] == 0.0:
                row.append(0.0)
            else:
                row.append(hmean([p10[i],r10[i]]))
            row[-1] = round(row[-1],places)
        ws1.append(row);
        
wb.save(filename = 'tfidf.xlsx')

# %%
#Query wise Average precision
# precision sum
def p_sum(z):
    z = z.copy()  
    z.sort_values(inplace=True)
    result = 0
    for i,val in enumerate(z):
        result += (i+1)/float(val) 
    return result


import pandas as pd

f = pd.ExcelFile('tfidf.xlsx')

from scipy.stats import hmean


model_name = 'tfidf'
places = 4
wb = load_workbook('tfidf.xlsx')
ws1 = wb.create_sheet(title="AP_Qwise")

ws1.append(['Query','Docs considered', 'Precision/Recall', 'Model', 1, 5 ,10, 25, 50, 100, 500, 1000])


for sheet in f.sheet_names:
    
    if(sheet == "evaluation"or sheet == "evaluation_Qwise"):
        continue
    for q in np.arange(1,11):

        x = f.parse(sheet)
        x = x[x['Query'] == q]
        total = {}
        total[1] = (float)(x[x['Relevance'] == 1].shape[0])
        total[0] = (float)(x[x['Relevance'] == 0].shape[0])
        total[10] = (float)(x.shape[0])
        
        for rel in [1,0]:
            # precision 1
            row = [q, rel, 'AP', model_name + ' :' + sheet]
            for i in [1.0, 5.0, 10.0, 25.0, 50.0, 100.0, 500.0, 1000.0]:
                row.append(p_sum(x[np.logical_and(x['Relevance'] == rel, x['Rank'] <= i)]['Rank'])/total[rel])
            ws1.append(row);

        row = [q, 10, 'AP', model_name + ' :' + sheet]
        for i in [1.0, 5.0, 10.0, 25.0, 50.0, 100.0, 500.0, 1000.0]:
            row.append(p_sum(x[x['Rank'] <= i]['Rank'])/total[10])
        ws1.append(row);
wb.save(filename = 'tfidf.xlsx')
